# %%
import pandas as pd

# %%
df = pd.read_csv('hive-0.csv')
df
# Out:
#         id  CountDeclMethodPrivate  AvgLineCode  CountLine  MaxCyclomatic  \
# 0        1                       0            5         94              5
# 1        2                       0            6        376             31
# 2        3                       0            0         28              0
# 3        4                       0            4        127              2
# 4        5                       5           24        743             22
# ...    ...                     ...          ...        ...            ...
# 1411  1412                       0           20         84              6
# 1412  1413                       0           11        473              7
# 1413  1414                       0           17         41              4
# 1414  1415                       0            4        230              7
# 1415  1416                       0            6        126              7
#
#       CountDeclMethodDefault  AvgEssential  CountDeclClassVariable  \
# 0                          0             1                       0
# 1                          0             1                       0
# 2                          0             0                       0
# 3                          0             1                       0
# 4                          2             2                       4
# ...                      ...           ...                     ...
# 1411                       0             0                       0
# 1412                       0             0                       0
# 1413                       0             0                       0
# 1414                       0             0                       0
# 1415                       0             0                       0
#
#       SumCyclomaticStrict  AvgCyclomatic  ...  DDEV  Added_lines  Del_lines  \
# 0                       9              2  ...     0            0          0
# 1                      74              2  ...     0            0          0
# 2                       0              0  ...     1           28          0
# 3                      12              1  ...     1          127          0
# 4                     118              5  ...     3           26          6
# ...                   ...            ...  ...   ...          ...        ...
# 1411                    8              4  ...     1           84          0
# 1412                   43              1  ...     1          473          0
# 1413                    4              4  ...     1           40          0
# 1414                   48              1  ...     1          230          0
# 1415                   31              2  ...     1          128          2
#
#       OWN_LINE  OWN_COMMIT  MINOR_COMMIT  MINOR_LINE  MAJOR_COMMIT  \
# 0     1.000000         0.0             0           1             0
# 1     0.553191         0.0             0           3             0
# 2     1.000000         1.0             0           1             1
# 3     1.000000         1.0             0           1             1
# 4     0.261104         0.6             0           7             3
# ...        ...         ...           ...         ...           ...
# 1411  1.000000         1.0             0           1             1
# 1412  1.000000         1.0             0           1             1
# 1413  1.000000         1.0             0           1             1
# 1414  1.000000         1.0             0           1             1
# 1415  1.000000         1.0             0           1             1
#
#       MAJOR_LINE  RealBugCount
# 0              0             0
# 1              3             1
# 2              0             0
# 3              0             0
# 4              6             0
# ...          ...           ...
# 1411           0             0
# 1412           0             1
# 1413           0             0
# 1414           0             0
# 1415           0             1
#
# [1416 rows x 67 columns]

# %%
df.drop(['id'], axis=1, inplace=True)

# %%
df['RealBugCount'].unique()
# Out:
# array([0, 1, 4, 2, 3, 6, 5, 8, 7], dtype=int64)

# %%
df['RealBugCount'].replace([4, 2, 3, 6, 5, 8, 7], 1, inplace=True)
df['RealBugCount'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df = df.rename({'RealBugCount':'class'}, axis=1)
df
# Out:
#       CountDeclMethodPrivate  AvgLineCode  CountLine  MaxCyclomatic  \
# 0                          0            5         94              5
# 1                          0            6        376             31
# 2                          0            0         28              0
# 3                          0            4        127              2
# 4                          5           24        743             22
# ...                      ...          ...        ...            ...
# 1411                       0           20         84              6
# 1412                       0           11        473              7
# 1413                       0           17         41              4
# 1414                       0            4        230              7
# 1415                       0            6        126              7
#
#       CountDeclMethodDefault  AvgEssential  CountDeclClassVariable  \
# 0                          0             1                       0
# 1                          0             1                       0
# 2                          0             0                       0
# 3                          0             1                       0
# 4                          2             2                       4
# ...                      ...           ...                     ...
# 1411                       0             0                       0
# 1412                       0             0                       0
# 1413                       0             0                       0
# 1414                       0             0                       0
# 1415                       0             0                       0
#
#       SumCyclomaticStrict  AvgCyclomatic  AvgLine  ...  DDEV  Added_lines  \
# 0                       9              2        7  ...     0            0
# 1                      74              2        7  ...     0            0
# 2                       0              0        0  ...     1           28
# 3                      12              1        5  ...     1          127
# 4                     118              5       32  ...     3           26
# ...                   ...            ...      ...  ...   ...          ...
# 1411                    8              4       27  ...     1           84
# 1412                   43              1       15  ...     1          473
# 1413                    4              4       18  ...     1           40
# 1414                   48              1        5  ...     1          230
# 1415                   31              2        7  ...     1          128
#
#       Del_lines  OWN_LINE  OWN_COMMIT  MINOR_COMMIT  MINOR_LINE  MAJOR_COMMIT  \
# 0             0  1.000000         0.0             0           1             0
# 1             0  0.553191         0.0             0           3             0
# 2             0  1.000000         1.0             0           1             1
# 3             0  1.000000         1.0             0           1             1
# 4             6  0.261104         0.6             0           7             3
# ...         ...       ...         ...           ...         ...           ...
# 1411          0  1.000000         1.0             0           1             1
# 1412          0  1.000000         1.0             0           1             1
# 1413          0  1.000000         1.0             0           1             1
# 1414          0  1.000000         1.0             0           1             1
# 1415          2  1.000000         1.0             0           1             1
#
#       MAJOR_LINE  class
# 0              0      0
# 1              3      1
# 2              0      0
# 3              0      0
# 4              6      0
# ...          ...    ...
# 1411           0      0
# 1412           0      1
# 1413           0      0
# 1414           0      0
# 1415           0      1
#
# [1416 rows x 66 columns]

# %%
df[df['class'] == 0]
# Out:
#       CountDeclMethodPrivate  AvgLineCode  CountLine  MaxCyclomatic  \
# 0                          0            5         94              5
# 2                          0            0         28              0
# 3                          0            4        127              2
# 4                          5           24        743             22
# 5                          0            5        141              3
# ...                      ...          ...        ...            ...
# 1408                       5           15        377              4
# 1410                       0            3         36              2
# 1411                       0           20         84              6
# 1413                       0           17         41              4
# 1414                       0            4        230              7
#
#       CountDeclMethodDefault  AvgEssential  CountDeclClassVariable  \
# 0                          0             1                       0
# 2                          0             0                       0
# 3                          0             1                       0
# 4                          2             2                       4
# 5                          0             1                       0
# ...                      ...           ...                     ...
# 1408                       0             1                       1
# 1410                       0             0                       0
# 1411                       0             0                       0
# 1413                       0             0                       0
# 1414                       0             0                       0
#
#       SumCyclomaticStrict  AvgCyclomatic  AvgLine  ...  DDEV  Added_lines  \
# 0                       9              2        7  ...     0            0
# 2                       0              0        0  ...     1           28
# 3                      12              1        5  ...     1          127
# 4                     118              5       32  ...     3           26
# 5                      14              1        5  ...     0            0
# ...                   ...            ...      ...  ...   ...          ...
# 1408                   26              2       19  ...     1          119
# 1410                    6              1        3  ...     1           36
# 1411                    8              4       27  ...     1           84
# 1413                    4              4       18  ...     1           40
# 1414                   48              1        5  ...     1          230
#
#       Del_lines  OWN_LINE  OWN_COMMIT  MINOR_COMMIT  MINOR_LINE  MAJOR_COMMIT  \
# 0             0  1.000000         0.0             0           1             0
# 2             0  1.000000         1.0             0           1             1
# 3             0  1.000000         1.0             0           1             1
# 4             6  0.261104         0.6             0           7             3
# 5             0  0.439716         0.0             0           4             0
# ...         ...       ...         ...           ...         ...           ...
# 1408         33  0.360743         1.0             0           3             1
# 1410          0  1.000000         1.0             0           1             1
# 1411          0  1.000000         1.0             0           1             1
# 1413          0  1.000000         1.0             0           1             1
# 1414          0  1.000000         1.0             0           1             1
#
#       MAJOR_LINE  class
# 0              0      0
# 2              0      0
# 3              0      0
# 4              6      0
# 5              2      0
# ...          ...    ...
# 1408           0      0
# 1410           0      0
# 1411           0      0
# 1413           0      0
# 1414           0      0
#
# [1133 rows x 66 columns]

# %%
X = df.drop(['class'], axis=1)
X
# Out:
#       CountDeclMethodPrivate  AvgLineCode  CountLine  MaxCyclomatic  \
# 0                          0            5         94              5
# 1                          0            6        376             31
# 2                          0            0         28              0
# 3                          0            4        127              2
# 4                          5           24        743             22
# ...                      ...          ...        ...            ...
# 1411                       0           20         84              6
# 1412                       0           11        473              7
# 1413                       0           17         41              4
# 1414                       0            4        230              7
# 1415                       0            6        126              7
#
#       CountDeclMethodDefault  AvgEssential  CountDeclClassVariable  \
# 0                          0             1                       0
# 1                          0             1                       0
# 2                          0             0                       0
# 3                          0             1                       0
# 4                          2             2                       4
# ...                      ...           ...                     ...
# 1411                       0             0                       0
# 1412                       0             0                       0
# 1413                       0             0                       0
# 1414                       0             0                       0
# 1415                       0             0                       0
#
#       SumCyclomaticStrict  AvgCyclomatic  AvgLine  ...  ADEV  DDEV  \
# 0                       9              2        7  ...     0     0
# 1                      74              2        7  ...     0     0
# 2                       0              0        0  ...     1     1
# 3                      12              1        5  ...     1     1
# 4                     118              5       32  ...     5     3
# ...                   ...            ...      ...  ...   ...   ...
# 1411                    8              4       27  ...     1     1
# 1412                   43              1       15  ...     4     1
# 1413                    4              4       18  ...     1     1
# 1414                   48              1        5  ...     2     1
# 1415                   31              2        7  ...     3     1
#
#       Added_lines  Del_lines  OWN_LINE  OWN_COMMIT  MINOR_COMMIT  MINOR_LINE  \
# 0               0          0  1.000000         0.0             0           1
# 1               0          0  0.553191         0.0             0           3
# 2              28          0  1.000000         1.0             0           1
# 3             127          0  1.000000         1.0             0           1
# 4              26          6  0.261104         0.6             0           7
# ...           ...        ...       ...         ...           ...         ...
# 1411           84          0  1.000000         1.0             0           1
# 1412          473          0  1.000000         1.0             0           1
# 1413           40          0  1.000000         1.0             0           1
# 1414          230          0  1.000000         1.0             0           1
# 1415          128          2  1.000000         1.0             0           1
#
#       MAJOR_COMMIT  MAJOR_LINE
# 0                0           0
# 1                0           3
# 2                1           0
# 3                1           0
# 4                3           6
# ...            ...         ...
# 1411             1           0
# 1412             1           0
# 1413             1           0
# 1414             1           0
# 1415             1           0
#
# [1416 rows x 65 columns]

# %%
Y = df['class']
Y
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 1411    0
# 1412    1
# 1413    0
# 1414    0
# 1415    1
# Name: class, Length: 1416, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import *

# %% [markdown]
# # All Features

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7835294117647059
# Precision :  1.0
# Recall :  0.010752688172043012
# F1 Score :  0.021276595744680854
# AUC :  0.5053763440860215

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7835294117647059
# Precision :  1.0
# Recall :  0.010752688172043012
# F1 Score :  0.021276595744680854
# AUC :  0.5053763440860215

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8658823529411764
# Precision :  0.7727272727272727
# Recall :  0.5483870967741935
# F1 Score :  0.6415094339622641
# AUC :  0.7516031869413137

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8141176470588235
# Precision :  0.8181818181818182
# Recall :  0.1935483870967742
# F1 Score :  0.3130434782608696
# AUC :  0.590750097162845

# %% [markdown]
# # PEARSON CORRELATION

# %%
cor = df.corr()
cor_target = abs(cor['class'])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.35]
relevant_features
# Out:
# MaxCyclomaticStrict      0.360888
# MaxCyclomaticModified    0.367041
# CountOutput_Max          0.364960
# MaxNesting_Max           0.350846
# class                    1.000000
# Name: class, dtype: float64

# %%
X_new = df[['MaxCyclomaticStrict', 'MaxCyclomaticModified', 'CountOutput_Max', 'MaxNesting_Max']]
X_new
# Out:
#       MaxCyclomaticStrict  MaxCyclomaticModified  CountOutput_Max  \
# 0                       5                      5                7
# 1                      36                     31               26
# 2                       0                      0                0
# 3                       3                      2                5
# 4                      25                     22               61
# ...                   ...                    ...              ...
# 1411                    0                      6                0
# 1412                    0                      7                0
# 1413                    0                      4                0
# 1414                    0                      7                0
# 1415                    0                      7                0
#
#       MaxNesting_Max
# 0                  4
# 1                  4
# 2                  1
# 3                  1
# 4                  7
# ...              ...
# 1411               3
# 1412               4
# 1413               2
# 1414               3
# 1415               3
#
# [1416 rows x 4 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8211764705882353
# Precision :  0.639344262295082
# Recall :  0.41935483870967744
# F1 Score :  0.5064935064935064
# AUC :  0.6765448892343568

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8
# Precision :  0.7222222222222222
# Recall :  0.13978494623655913
# F1 Score :  0.2342342342342342
# AUC :  0.5623623526363518

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8211764705882353
# Precision :  0.6666666666666666
# Recall :  0.3655913978494624
# F1 Score :  0.4722222222222222
# AUC :  0.657193289286177

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8188235294117647
# Precision :  0.6739130434782609
# Recall :  0.3333333333333333
# F1 Score :  0.4460431654676259
# AUC :  0.6440763052208834

# %% [markdown]
# # INFORMATION GAIN 10

# %%
from sklearn.feature_selection import mutual_info_classif
gain = mutual_info_classif(X,Y)
gain
# Out:
# array([0.07092041, 0.05337434, 0.13379935, 0.08999857, 0.0228144 ,
#        0.02463094, 0.05656837, 0.11842416, 0.03650847, 0.06910568,
#        0.06080739, 0.        , 0.04017644, 0.09883672, 0.09697456,
#        0.01864593, 0.09457987, 0.12621335, 0.12982279, 0.01884262,
#        0.04856458, 0.08484879, 0.09466952, 0.14074678, 0.11654501,
#        0.1186031 , 0.13891476, 0.14353373, 0.12709501, 0.11935429,
#        0.12209747, 0.13930515, 0.09107017, 0.13070515, 0.00477421,
#        0.08236936, 0.03220513, 0.04992261, 0.        , 0.00670246,
#        0.04307146, 0.06405644, 0.07974713, 0.06256283, 0.01206122,
#        0.08034659, 0.10531245, 0.01181082, 0.12045184, 0.10993478,
#        0.03243682, 0.07522427, 0.09289628, 0.        , 0.05036338,
#        0.05290201, 0.03921984, 0.05123966, 0.03145936, 0.06316668,
#        0.041018  , 0.01912006, 0.05200463, 0.04531608, 0.02716546])

# %%
col_list = X.columns
col_list
# Out:
# Index(['CountDeclMethodPrivate', 'AvgLineCode', 'CountLine', 'MaxCyclomatic',
#        'CountDeclMethodDefault', 'AvgEssential', 'CountDeclClassVariable',
#        'SumCyclomaticStrict', 'AvgCyclomatic', 'AvgLine',
#        'CountDeclClassMethod', 'AvgLineComment', 'AvgCyclomaticModified',
#        'CountDeclFunction', 'CountLineComment', 'CountDeclClass',
#        'CountDeclMethod', 'SumCyclomaticModified', 'CountLineCodeDecl',
#        'CountDeclMethodProtected', 'CountDeclInstanceVariable',
#        'MaxCyclomaticStrict', 'CountDeclMethodPublic', 'CountLineCodeExe',
#        'SumCyclomatic', 'SumEssential', 'CountStmtDecl', 'CountLineCode',
#        'CountStmtExe', 'RatioCommentToCode', 'CountLineBlank', 'CountStmt',
#        'MaxCyclomaticModified', 'CountSemicolon', 'AvgLineBlank',
#        'CountDeclInstanceMethod', 'AvgCyclomaticStrict',
#        'PercentLackOfCohesion', 'MaxInheritanceTree', 'CountClassDerived',
#        'CountClassCoupled', 'CountClassBase', 'CountInput_Max',
#        'CountInput_Mean', 'CountInput_Min', 'CountOutput_Max',
#        'CountOutput_Mean', 'CountOutput_Min', 'CountPath_Max',
#        'CountPath_Mean', 'CountPath_Min', 'MaxNesting_Max', 'MaxNesting_Mean',
#        'MaxNesting_Min', 'COMM', 'ADEV', 'DDEV', 'Added_lines', 'Del_lines',
#        'OWN_LINE', 'OWN_COMMIT', 'MINOR_COMMIT', 'MINOR_LINE', 'MAJOR_COMMIT',
#        'MAJOR_LINE'],
#       dtype='object')

# %%
temp = pd.DataFrame(list(zip(col_list, gain)), columns =['col', 'score']) 
temp
# Out:
#                        col     score
# 0   CountDeclMethodPrivate  0.070920
# 1              AvgLineCode  0.053374
# 2                CountLine  0.133799
# 3            MaxCyclomatic  0.089999
# 4   CountDeclMethodDefault  0.022814
# ..                     ...       ...
# 60              OWN_COMMIT  0.041018
# 61            MINOR_COMMIT  0.019120
# 62              MINOR_LINE  0.052005
# 63            MAJOR_COMMIT  0.045316
# 64              MAJOR_LINE  0.027165
#
# [65 rows x 2 columns]

# %%
temp_sort = temp.sort_values(['score'], ascending=False)
temp_sort[:10]
# Out:
#                       col     score
# 27          CountLineCode  0.143534
# 23       CountLineCodeExe  0.140747
# 31              CountStmt  0.139305
# 26          CountStmtDecl  0.138915
# 2               CountLine  0.133799
# 33         CountSemicolon  0.130705
# 18      CountLineCodeDecl  0.129823
# 28           CountStmtExe  0.127095
# 17  SumCyclomaticModified  0.126213
# 30         CountLineBlank  0.122097

# %%
FS = list(temp_sort['col'][:10])
FS
# Out:
# ['CountLineCode',
#  'CountLineCodeExe',
#  'CountStmt',
#  'CountStmtDecl',
#  'CountLine',
#  'CountSemicolon',
#  'CountLineCodeDecl',
#  'CountStmtExe',
#  'SumCyclomaticModified',
#  'CountLineBlank']

# %%
X_new = df[FS]
X_new
# Out:
#       CountLineCode  CountLineCodeExe  CountStmt  CountStmtDecl  CountLine  \
# 0                41                14         29             18         94
# 1               275               136        200             90        376
# 2                 4                 0          2              2         28
# 3                82                19         46             32        127
# 4               548               371        417            170        743
# ...             ...               ...        ...            ...        ...
# 1411             50                40         49             10         84
# 1412            301               262        241             39        473
# 1413             21                15         16              5         41
# 1414            168               124        160             44        230
# 1415             95                74         84             19        126
#
#       CountSemicolon  CountLineCodeDecl  CountStmtExe  SumCyclomaticModified  \
# 0                 20                 19            11                      9
# 1                130                 87           110                     67
# 2                  1                  2             0                      0
# 3                 32                 53            14                     11
# 4                306                159           247                    105
# ...              ...                ...           ...                    ...
# 1411               0                 10            39                      8
# 1412               0                 39           202                     43
# 1413               0                  5            11                      4
# 1414               0                 44           116                     48
# 1415               0                 21            65                     31
#
#       CountLineBlank
# 0                 14
# 1                 79
# 2                  2
# 3                 16
# 4                 90
# ...              ...
# 1411              17
# 1412              70
# 1413               5
# 1414              45
# 1415              15
#
# [1416 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8705882352941177
# Precision :  0.8064516129032258
# Recall :  0.5376344086021505
# F1 Score :  0.6451612903225806
# AUC :  0.7507449151444487

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8282352941176471
# Precision :  0.8571428571428571
# Recall :  0.25806451612903225
# F1 Score :  0.39669421487603307
# AUC :  0.6230081616789739

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8376470588235294
# Precision :  0.6714285714285714
# Recall :  0.5053763440860215
# F1 Score :  0.5766871165644173
# AUC :  0.7180496178261433

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8305882352941176
# Precision :  0.8387096774193549
# Recall :  0.27956989247311825
# F1 Score :  0.41935483870967744
# AUC :  0.6322548257546314

# %% [markdown]
# # INFORMATION GAIN 15

# %%
from sklearn.feature_selection import mutual_info_classif
gain = mutual_info_classif(X,Y)
gain
# Out:
# array([0.06980192, 0.06166052, 0.13767727, 0.08732314, 0.00961896,
#        0.0198629 , 0.06282842, 0.11290774, 0.04066751, 0.05085408,
#        0.0667187 , 0.0011405 , 0.04067327, 0.09399941, 0.09619469,
#        0.05238186, 0.09537181, 0.11817109, 0.1243239 , 0.0171432 ,
#        0.07111909, 0.09254469, 0.07370538, 0.1435853 , 0.1415782 ,
#        0.10222304, 0.13050052, 0.13669703, 0.12600311, 0.12996816,
#        0.12234704, 0.14602637, 0.08294238, 0.12753472, 0.00268398,
#        0.08930952, 0.03057773, 0.04722921, 0.        , 0.        ,
#        0.0310987 , 0.04904247, 0.06082376, 0.04924213, 0.00591981,
#        0.08113275, 0.09308664, 0.        , 0.10551371, 0.09840789,
#        0.02741933, 0.06830109, 0.09821922, 0.01927056, 0.06894043,
#        0.05680276, 0.04379414, 0.04299603, 0.05129759, 0.06892923,
#        0.034394  , 0.00834143, 0.04652262, 0.0581082 , 0.04312147])

# %%
col_list = X.columns
col_list
# Out:
# Index(['CountDeclMethodPrivate', 'AvgLineCode', 'CountLine', 'MaxCyclomatic',
#        'CountDeclMethodDefault', 'AvgEssential', 'CountDeclClassVariable',
#        'SumCyclomaticStrict', 'AvgCyclomatic', 'AvgLine',
#        'CountDeclClassMethod', 'AvgLineComment', 'AvgCyclomaticModified',
#        'CountDeclFunction', 'CountLineComment', 'CountDeclClass',
#        'CountDeclMethod', 'SumCyclomaticModified', 'CountLineCodeDecl',
#        'CountDeclMethodProtected', 'CountDeclInstanceVariable',
#        'MaxCyclomaticStrict', 'CountDeclMethodPublic', 'CountLineCodeExe',
#        'SumCyclomatic', 'SumEssential', 'CountStmtDecl', 'CountLineCode',
#        'CountStmtExe', 'RatioCommentToCode', 'CountLineBlank', 'CountStmt',
#        'MaxCyclomaticModified', 'CountSemicolon', 'AvgLineBlank',
#        'CountDeclInstanceMethod', 'AvgCyclomaticStrict',
#        'PercentLackOfCohesion', 'MaxInheritanceTree', 'CountClassDerived',
#        'CountClassCoupled', 'CountClassBase', 'CountInput_Max',
#        'CountInput_Mean', 'CountInput_Min', 'CountOutput_Max',
#        'CountOutput_Mean', 'CountOutput_Min', 'CountPath_Max',
#        'CountPath_Mean', 'CountPath_Min', 'MaxNesting_Max', 'MaxNesting_Mean',
#        'MaxNesting_Min', 'COMM', 'ADEV', 'DDEV', 'Added_lines', 'Del_lines',
#        'OWN_LINE', 'OWN_COMMIT', 'MINOR_COMMIT', 'MINOR_LINE', 'MAJOR_COMMIT',
#        'MAJOR_LINE'],
#       dtype='object')

# %%
temp = pd.DataFrame(list(zip(col_list, gain)), columns =['col', 'score']) 
temp
# Out:
#                        col     score
# 0   CountDeclMethodPrivate  0.069802
# 1              AvgLineCode  0.061661
# 2                CountLine  0.137677
# 3            MaxCyclomatic  0.087323
# 4   CountDeclMethodDefault  0.009619
# ..                     ...       ...
# 60              OWN_COMMIT  0.034394
# 61            MINOR_COMMIT  0.008341
# 62              MINOR_LINE  0.046523
# 63            MAJOR_COMMIT  0.058108
# 64              MAJOR_LINE  0.043121
#
# [65 rows x 2 columns]

# %%
temp_sort = temp.sort_values(['score'], ascending=False)
temp_sort[:15]
# Out:
#                       col     score
# 31              CountStmt  0.146026
# 23       CountLineCodeExe  0.143585
# 24          SumCyclomatic  0.141578
# 2               CountLine  0.137677
# 27          CountLineCode  0.136697
# 26          CountStmtDecl  0.130501
# 29     RatioCommentToCode  0.129968
# 33         CountSemicolon  0.127535
# 28           CountStmtExe  0.126003
# 18      CountLineCodeDecl  0.124324
# 30         CountLineBlank  0.122347
# 17  SumCyclomaticModified  0.118171
# 7     SumCyclomaticStrict  0.112908
# 48          CountPath_Max  0.105514
# 25           SumEssential  0.102223

# %%
FS = list(temp_sort['col'][:15])
FS
# Out:
# ['CountStmt',
#  'CountLineCodeExe',
#  'SumCyclomatic',
#  'CountLine',
#  'CountLineCode',
#  'CountStmtDecl',
#  'RatioCommentToCode',
#  'CountSemicolon',
#  'CountStmtExe',
#  'CountLineCodeDecl',
#  'CountLineBlank',
#  'SumCyclomaticModified',
#  'SumCyclomaticStrict',
#  'CountPath_Max',
#  'SumEssential']

# %%
X_new = df[FS]
X_new
# Out:
#       CountStmt  CountLineCodeExe  SumCyclomatic  CountLine  CountLineCode  \
# 0            29                14              9         94             41
# 1           200               136             67        376            275
# 2             2                 0              0         28              4
# 3            46                19             11        127             82
# 4           417               371            105        743            548
# ...         ...               ...            ...        ...            ...
# 1411         49                40              8         84             50
# 1412        241               262             43        473            301
# 1413         16                15              4         41             21
# 1414        160               124             48        230            168
# 1415         84                74             31        126             95
#
#       CountStmtDecl  RatioCommentToCode  CountSemicolon  CountStmtExe  \
# 0                18                0.95              20            11
# 1                90                0.08             130           110
# 2                 2                5.50               1             0
# 3                32                0.35              32            14
# 4               170                0.20             306           247
# ...             ...                 ...             ...           ...
# 1411             10                0.34               0            39
# 1412             39                0.34               0           202
# 1413              5                0.71               0            11
# 1414             44                0.10               0           116
# 1415             19                0.17               0            65
#
#       CountLineCodeDecl  CountLineBlank  SumCyclomaticModified  \
# 0                    19              14                      9
# 1                    87              79                     67
# 2                     2               2                      0
# 3                    53              16                     11
# 4                   159              90                    105
# ...                 ...             ...                    ...
# 1411                 10              17                      8
# 1412                 39              70                     43
# 1413                  5               5                      4
# 1414                 44              45                     48
# 1415                 21              15                     31
#
#       SumCyclomaticStrict  CountPath_Max  SumEssential
# 0                       9              8             5
# 1                      74        1034880            33
# 2                       0              0             0
# 3                      12              2             8
# 4                     118           1949            43
# ...                   ...            ...           ...
# 1411                    8             10             2
# 1412                   43             12            26
# 1413                    4              5             3
# 1414                   48             16            30
# 1415                   31             14            18
#
# [1416 rows x 15 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8635294117647059
# Precision :  0.7536231884057971
# Recall :  0.5591397849462365
# F1 Score :  0.6419753086419753
# AUC :  0.753967482834564

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7835294117647059
# Precision :  1.0
# Recall :  0.010752688172043012
# F1 Score :  0.021276595744680854
# AUC :  0.5053763440860215

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8470588235294118
# Precision :  0.7
# Recall :  0.5268817204301075
# F1 Score :  0.6012269938650306
# AUC :  0.7318143541909573

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8211764705882353
# Precision :  0.84
# Recall :  0.22580645161290322
# F1 Score :  0.3559322033898305
# AUC :  0.6068791294209094

# %% [markdown]
# # FISHER SCORE

# %%
FScore = []

for m in  range(len(col_list)):
        mu = df[col_list[m]].mean()

        n_1 = df[df['class'] == 0].count()[1]
        mu_1 = df[col_list[m]][df['class'] == 0].mean()
        var_1 = df[col_list[m]][df['class'] == 0].var()

        n_2 = df[df['class'] == 1].count()[1]
        mu_2 = df[col_list[m]][df['class'] == 1].mean()
        var_2 = df[col_list[m]][df['class'] == 1].var()

        inter_class = n_1*(mu_1-mu)**2 + n_2*(mu_2-mu)**2
        intra_class = (n_1-1)*var_1 + (n_2-1)*var_2

        FScore.append(inter_class / intra_class)

FScore
# Out:
# [0.029824415067606556,
#  0.05209216909127459,
#  0.02794543629797898,
#  0.12398235854025318,
#  0.009428755076365574,
#  0.005407287782794463,
#  0.010439778753265162,
#  0.019799121822225457,
#  0.04181882283835776,
#  0.04452454354166519,
#  0.01818837749212082,
#  0.0005065365152441654,
#  0.03952428408763619,
#  0.016252562020562657,
#  0.02844628313542429,
#  0.01431541772508637,
#  0.009003043898543549,
#  0.02080598508699808,
#  0.0330279194147529,
#  0.0073409132324296225,
#  0.006320504894340547,
#  0.14974266059567887,
#  0.008054905652950986,
#  0.028976185898394523,
#  0.02034953466105942,
#  0.01649870223383119,
#  0.03369668058003521,
#  0.027137239083339853,
#  0.025191174634016197,
#  0.031286049177264255,
#  0.025511366515255058,
#  0.028474558092238072,
#  0.15569428473854172,
#  0.027170868794540063,
#  0.016123514493039438,
#  0.008387270252103372,
#  0.042680622915179385,
#  0.06027773214995154,
#  1.0609170130881646e-08,
#  0.00023031665037268607,
#  0.08308763318866537,
#  0.07825068973630504,
#  0.0755572020784139,
#  0.00839249362475639,
#  0.007353033228705599,
#  0.15366296750682334,
#  0.04836450108025455,
#  0.002173139420114293,
#  0.00922599492051597,
#  0.005759631293439536,
#  0.010952833034854902,
#  0.1403717972853624,
#  0.029903192938106966,
#  0.003979778328146539,
#  0.1028101669070064,
#  0.1028101669070064,
#  0.11902881984300871,
#  0.02269903079784754,
#  0.01766768928453268,
#  0.07045257932827702,
#  0.017987824430403334,
#  0.005694955465749846,
#  0.10608310994257657,
#  0.11898079770262292,
#  0.11032668956404391]

# %%
temp = pd.DataFrame(list(zip(col_list, FScore)), columns =['col', 'score']) 
temp
# Out:
#                        col     score
# 0   CountDeclMethodPrivate  0.029824
# 1              AvgLineCode  0.052092
# 2                CountLine  0.027945
# 3            MaxCyclomatic  0.123982
# 4   CountDeclMethodDefault  0.009429
# ..                     ...       ...
# 60              OWN_COMMIT  0.017988
# 61            MINOR_COMMIT  0.005695
# 62              MINOR_LINE  0.106083
# 63            MAJOR_COMMIT  0.118981
# 64              MAJOR_LINE  0.110327
#
# [65 rows x 2 columns]

# %%
temp_sort = temp.sort_values(['score'], ascending=False)
temp_sort[:10]
# Out:
#                       col     score
# 32  MaxCyclomaticModified  0.155694
# 45        CountOutput_Max  0.153663
# 21    MaxCyclomaticStrict  0.149743
# 51         MaxNesting_Max  0.140372
# 3           MaxCyclomatic  0.123982
# 56                   DDEV  0.119029
# 63           MAJOR_COMMIT  0.118981
# 64             MAJOR_LINE  0.110327
# 62             MINOR_LINE  0.106083
# 55                   ADEV  0.102810

# %%
FS = list(temp_sort['col'][:10])
FS
# Out:
# ['MaxCyclomaticModified',
#  'CountOutput_Max',
#  'MaxCyclomaticStrict',
#  'MaxNesting_Max',
#  'MaxCyclomatic',
#  'DDEV',
#  'MAJOR_COMMIT',
#  'MAJOR_LINE',
#  'MINOR_LINE',
#  'ADEV']

# %%
X_new = df[FS]
X_new
# Out:
#       MaxCyclomaticModified  CountOutput_Max  MaxCyclomaticStrict  \
# 0                         5                7                    5
# 1                        31               26                   36
# 2                         0                0                    0
# 3                         2                5                    3
# 4                        22               61                   25
# ...                     ...              ...                  ...
# 1411                      6                0                    0
# 1412                      7                0                    0
# 1413                      4                0                    0
# 1414                      7                0                    0
# 1415                      7                0                    0
#
#       MaxNesting_Max  MaxCyclomatic  DDEV  MAJOR_COMMIT  MAJOR_LINE  \
# 0                  4              5     0             0           0
# 1                  4             31     0             0           3
# 2                  1              0     1             1           0
# 3                  1              2     1             1           0
# 4                  7             22     3             3           6
# ...              ...            ...   ...           ...         ...
# 1411               3              6     1             1           0
# 1412               4              7     1             1           0
# 1413               2              4     1             1           0
# 1414               3              7     1             1           0
# 1415               3              7     1             1           0
#
#       MINOR_LINE  ADEV
# 0              1     0
# 1              3     0
# 2              1     1
# 3              1     1
# 4              7     5
# ...          ...   ...
# 1411           1     1
# 1412           1     4
# 1413           1     1
# 1414           1     2
# 1415           1     3
#
# [1416 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8564705882352941
# Precision :  0.7758620689655172
# Recall :  0.4838709677419355
# F1 Score :  0.5960264900662252
# AUC :  0.7223571706179557

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7976470588235294
# Precision :  0.6206896551724138
# Recall :  0.1935483870967742
# F1 Score :  0.29508196721311475
# AUC :  0.5802079284881462

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8305882352941176
# Precision :  0.6842105263157895
# Recall :  0.41935483870967744
# F1 Score :  0.5200000000000001
# AUC :  0.682568985619899

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7952941176470588
# Precision :  0.5555555555555556
# Recall :  0.3225806451612903
# F1 Score :  0.40816326530612246
# AUC :  0.6251457442673921

# %% [markdown]
# # SVM RFE 10

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,random_state=23)

# %%
from sklearn.feature_selection import RFE
rec_model = RandomForestClassifier()

rfe = RFE(rec_model, n_features_to_select=10)
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=RandomForestClassifier(), n_features_to_select=10)

# %%
X_train = X_train.loc[:, rfe.support_]
X_train
# Out:
#       CountLine  CountLineComment  CountLineCodeExe  CountStmtDecl  \
# 76          342                42               122             86
# 923          62                20                11             11
# 809          98                23                37             19
# 281         168                33                53             46
# 3           127                29                19             32
# ...         ...               ...               ...            ...
# 31           50                22                 8             10
# 950          37                17                 2              6
# 1064         14                 1                 2              4
# 742         244                25               134             60
# 595         856               114               434            197
#
#       CountLineCode  CountStmtExe  RatioCommentToCode  CountStmt  \
# 76              257            73                0.16        159
# 923              35             8                0.57         19
# 809              64            20                0.36         39
# 281             109            34                0.30         80
# 3                82            14                0.35         46
# ...             ...           ...                 ...        ...
# 31               21             4                1.05         14
# 950              15             1                1.13          7
# 1064              9             2                0.11          6
# 742             189            92                0.13        152
# 595             670           281                0.17        478
#
#       CountSemicolon  OWN_LINE
# 76               112  0.587719
# 923               13  1.000000
# 809               30  0.989796
# 281               61  0.767857
# 3                 32  1.000000
# ...              ...       ...
# 31                 9  0.780000
# 950                5  1.000000
# 1064               3  1.000000
# 742              107  0.442623
# 595              358  0.355140
#
# [991 rows x 10 columns]

# %%
X_test = X_test.loc[:, rfe.support_]
X_test
# Out:
#       CountLine  CountLineComment  CountLineCodeExe  CountStmtDecl  \
# 633         250                87                82             38
# 271          68                12                25              9
# 473         147                29                39             34
# 298          35                21                 0              7
# 406          27                22                 0              2
# ...         ...               ...               ...            ...
# 1413         41                15                15              5
# 1363       1179                22               175            442
# 1097        185                62                78             23
# 801         138                27                58             30
# 1214         62                20                 7             10
#
#       CountLineCode  CountStmtExe  RatioCommentToCode  CountStmt  \
# 633             141            61                0.62         99
# 271              49            14                0.24         23
# 473              94            33                0.31         67
# 298               9             0                2.33          7
# 406               3             0                7.33          2
# ...             ...           ...                 ...        ...
# 1413             21            11                0.71         16
# 1363            826           161                0.03        603
# 1097            110            60                0.56         83
# 801             100            37                0.27         67
# 1214             33             7                0.61         17
#
#       CountSemicolon  OWN_LINE
# 633               66  0.776000
# 271               19  0.970588
# 473               46  0.857143
# 298                6  0.800000
# 406                1  1.000000
# ...              ...       ...
# 1413               0  1.000000
# 1363             411  0.603902
# 1097              63  0.518919
# 801               50  0.586957
# 1214               9  0.483871
#
# [425 rows x 10 columns]

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8870588235294118
# Precision :  0.835820895522388
# Recall :  0.6021505376344086
# F1 Score :  0.7
# AUC :  0.7845090037569633

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8282352941176471
# Precision :  0.8571428571428571
# Recall :  0.25806451612903225
# F1 Score :  0.39669421487603307
# AUC :  0.6230081616789739

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8470588235294118
# Precision :  0.7121212121212122
# Recall :  0.5053763440860215
# F1 Score :  0.5911949685534591
# AUC :  0.7240737142116853

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8329411764705882
# Precision :  0.84375
# Recall :  0.2903225806451613
# F1 Score :  0.432
# AUC :  0.6376311698406529

# %% [markdown]
# # SVM RFE 15

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,random_state=23)

# %%
from sklearn.feature_selection import RFE
rec_model = RandomForestClassifier()

rfe = RFE(rec_model, n_features_to_select=15)
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=RandomForestClassifier(), n_features_to_select=15)

# %%
X_train = X_train.loc[:, rfe.support_]
X_train
# Out:
#       CountLine  CountLineComment  CountLineCodeExe  SumCyclomatic  \
# 76          342                42               122             46
# 923          62                20                11              5
# 809          98                23                37              8
# 281         168                33                53             17
# 3           127                29                19             11
# ...         ...               ...               ...            ...
# 31           50                22                 8              4
# 950          37                17                 2              1
# 1064         14                 1                 2              2
# 742         244                25               134             39
# 595         856               114               434            136
#
#       CountStmtDecl  CountLineCode  CountStmtExe  RatioCommentToCode  \
# 76               86            257            73                0.16
# 923              11             35             8                0.57
# 809              19             64            20                0.36
# 281              46            109            34                0.30
# 3                32             82            14                0.35
# ...             ...            ...           ...                 ...
# 31               10             21             4                1.05
# 950               6             15             1                1.13
# 1064              4              9             2                0.11
# 742              60            189            92                0.13
# 595             197            670           281                0.17
#
#       CountStmt  CountSemicolon  CountInput_Mean  CountPath_Mean  \
# 76          159             112         2.722222        4.111111
# 923          19              13         1.000000        2.500000
# 809          39              30         4.000000        6.333333
# 281          80              61         4.000000        2.125000
# 3            46              32         2.000000        1.375000
# ...         ...             ...              ...             ...
# 31           14               9         1.000000        1.333333
# 950           7               5         3.000000        1.000000
# 1064          6               3         2.000000        1.000000
# 742         152             107         3.600000        6.500000
# 595         478             358         9.953488       37.720930
#
#       MaxNesting_Mean  Added_lines  OWN_LINE
# 76           1.400000           60  0.587719
# 923          0.750000            0  1.000000
# 809          0.800000            0  0.989796
# 281          1.916667            5  0.767857
# 3            0.416667          127  1.000000
# ...               ...          ...       ...
# 31           0.500000            0  0.780000
# 950          0.000000            0  1.000000
# 1064         0.000000            0  1.000000
# 742          1.083333            5  0.442623
# 595          1.180000          108  0.355140
#
# [991 rows x 15 columns]

# %%
X_test = X_test.loc[:, rfe.support_]
X_test
# Out:
#       CountLine  CountLineComment  CountLineCodeExe  SumCyclomatic  \
# 633         250                87                82             28
# 271          68                12                25             15
# 473         147                29                39             20
# 298          35                21                 0              3
# 406          27                22                 0              0
# ...         ...               ...               ...            ...
# 1413         41                15                15              4
# 1363       1179                22               175            189
# 1097        185                62                78             25
# 801         138                27                58             17
# 1214         62                20                 7             10
#
#       CountStmtDecl  CountLineCode  CountStmtExe  RatioCommentToCode  \
# 633              38            141            61                0.62
# 271               9             49            14                0.24
# 473              34             94            33                0.31
# 298               7              9             0                2.33
# 406               2              3             0                7.33
# ...             ...            ...           ...                 ...
# 1413              5             21            11                0.71
# 1363            442            826           161                0.03
# 1097             23            110            60                0.56
# 801              30            100            37                0.27
# 1214             10             33             7                0.61
#
#       CountStmt  CountSemicolon  CountInput_Mean  CountPath_Mean  \
# 633          99              66         4.777778        4.888889
# 271          23              19         3.000000        2.600000
# 473          67              46         3.214286        1.428571
# 298           7               6         1.000000        1.000000
# 406           2               1         0.000000        0.000000
# ...         ...             ...              ...             ...
# 1413         16               0         0.000000        3.000000
# 1363        603             411         0.890323        1.219355
# 1097         83              63         5.400000       21.200000
# 801          67              50         5.000000        9.666667
# 1214         17               9         1.000000        1.000000
#
#       MaxNesting_Mean  Added_lines  OWN_LINE
# 633          1.307692           15  0.776000
# 271          0.428571            0  0.970588
# 473          0.333333            8  0.857143
# 298          0.000000            0  0.800000
# 406          0.000000            0  1.000000
# ...               ...          ...       ...
# 1413         2.000000           40  1.000000
# 1363         0.506977            0  0.603902
# 1097         1.571429            0  0.518919
# 801          3.800000           42  0.586957
# 1214         0.000000            0  0.483871
#
# [425 rows x 15 columns]

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8776470588235294
# Precision :  0.7887323943661971
# Recall :  0.6021505376344086
# F1 Score :  0.6829268292682926
# AUC :  0.7784849073714212

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7905882352941176
# Precision :  1.0
# Recall :  0.043010752688172046
# F1 Score :  0.08247422680412372
# AUC :  0.521505376344086

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8494117647058823
# Precision :  0.7230769230769231
# Recall :  0.5053763440860215
# F1 Score :  0.5949367088607593
# AUC :  0.725579738308071

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8211764705882353
# Precision :  0.7931034482758621
# Recall :  0.24731182795698925
# F1 Score :  0.3770491803278688
# AUC :  0.6146197694001814

# %% [markdown]
# # MRMR 10

# %%
from sklearn.feature_selection import f_regression

F = pd.Series(f_regression(X, Y)[0], index = X.columns)
corr = X.corr().abs().clip(.00001)

# %%
selected = []
feat_score = []
not_selected = list(X.columns)

# %%
K = 10

for i in range(K):
    
    # compute FCQ score for all the (currently) excluded features (this is Formula 2)
    score = F.loc[not_selected] / corr.loc[not_selected, selected].mean(axis = 1).fillna(.00001)
    
    # find best feature, add it to selected and remove it from not_selected
    best = score.index[score.argmax()]
    selected.append(best)
    feat_score.append(score[best])
    not_selected.remove(best)

# %%
selected
# Out:
# ['MaxCyclomaticModified',
#  'CountPath_Min',
#  'MINOR_LINE',
#  'CountOutput_Max',
#  'DDEV',
#  'CountClassBase',
#  'MaxNesting_Max',
#  'MaxCyclomaticStrict',
#  'MAJOR_COMMIT',
#  'MAJOR_LINE']

# %%
X_new = X[selected]
X_new
# Out:
#       MaxCyclomaticModified  CountPath_Min  MINOR_LINE  CountOutput_Max  DDEV  \
# 0                         5              1           1                7     0
# 1                        31              1           3               26     0
# 2                         0              0           1                0     1
# 3                         2              1           1                5     1
# 4                        22              1           7               61     3
# ...                     ...            ...         ...              ...   ...
# 1411                      6              1           1                0     1
# 1412                      7              1           1                0     1
# 1413                      4              1           1                0     1
# 1414                      7              1           1                0     1
# 1415                      7              1           1                0     1
#
#       CountClassBase  MaxNesting_Max  MaxCyclomaticStrict  MAJOR_COMMIT  \
# 0                  1               4                    5             0
# 1                  2               4                   36             0
# 2                  1               1                    0             1
# 3                  2               1                    3             1
# 4                  2               7                   25             3
# ...              ...             ...                  ...           ...
# 1411               0               3                    0             1
# 1412               0               4                    0             1
# 1413               0               2                    0             1
# 1414               1               3                    0             1
# 1415               0               3                    0             1
#
#       MAJOR_LINE
# 0              0
# 1              3
# 2              0
# 3              0
# 4              6
# ...          ...
# 1411           0
# 1412           0
# 1413           0
# 1414           0
# 1415           0
#
# [1416 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8682352941176471
# Precision :  0.8032786885245902
# Recall :  0.5268817204301075
# F1 Score :  0.6363636363636364
# AUC :  0.7453685710584272

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8023529411764706
# Precision :  0.6363636363636364
# Recall :  0.22580645161290322
# F1 Score :  0.3333333333333333
# AUC :  0.5948309366498251

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8164705882352942
# Precision :  0.631578947368421
# Recall :  0.3870967741935484
# F1 Score :  0.48000000000000004
# AUC :  0.6619218810726778

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8164705882352942
# Precision :  0.6056338028169014
# Recall :  0.46236559139784944
# F1 Score :  0.524390243902439
# AUC :  0.6890141210001296

# %% [markdown]
# # MRMR 15

# %%
from sklearn.feature_selection import f_regression

F = pd.Series(f_regression(X, Y)[0], index = X.columns)
corr = X.corr().abs().clip(.00001)

# %%
selected = []
feat_score = []
not_selected = list(X.columns)

# %%
K = 15

for i in range(K):
    
    # compute FCQ score for all the (currently) excluded features (this is Formula 2)
    score = F.loc[not_selected] / corr.loc[not_selected, selected].mean(axis = 1).fillna(.00001)
    
    # find best feature, add it to selected and remove it from not_selected
    best = score.index[score.argmax()]
    selected.append(best)
    feat_score.append(score[best])
    not_selected.remove(best)

# %%
selected
# Out:
# ['MaxCyclomaticModified',
#  'CountPath_Min',
#  'MINOR_LINE',
#  'CountOutput_Max',
#  'DDEV',
#  'CountClassBase',
#  'MaxNesting_Max',
#  'MaxCyclomaticStrict',
#  'MAJOR_COMMIT',
#  'MAJOR_LINE',
#  'MaxCyclomatic',
#  'COMM',
#  'CountInput_Max',
#  'ADEV',
#  'OWN_LINE']

# %%
X_new = X[selected]
X_new
# Out:
#       MaxCyclomaticModified  CountPath_Min  MINOR_LINE  CountOutput_Max  DDEV  \
# 0                         5              1           1                7     0
# 1                        31              1           3               26     0
# 2                         0              0           1                0     1
# 3                         2              1           1                5     1
# 4                        22              1           7               61     3
# ...                     ...            ...         ...              ...   ...
# 1411                      6              1           1                0     1
# 1412                      7              1           1                0     1
# 1413                      4              1           1                0     1
# 1414                      7              1           1                0     1
# 1415                      7              1           1                0     1
#
#       CountClassBase  MaxNesting_Max  MaxCyclomaticStrict  MAJOR_COMMIT  \
# 0                  1               4                    5             0
# 1                  2               4                   36             0
# 2                  1               1                    0             1
# 3                  2               1                    3             1
# 4                  2               7                   25             3
# ...              ...             ...                  ...           ...
# 1411               0               3                    0             1
# 1412               0               4                    0             1
# 1413               0               2                    0             1
# 1414               1               3                    0             1
# 1415               0               3                    0             1
#
#       MAJOR_LINE  MaxCyclomatic  COMM  CountInput_Max  ADEV  OWN_LINE
# 0              0              5     0               3     0  1.000000
# 1              3             31     0              21     0  0.553191
# 2              0              0     1               0     1  1.000000
# 3              0              2     1               4     1  1.000000
# 4              6             22     5              16     5  0.261104
# ...          ...            ...   ...             ...   ...       ...
# 1411           0              6     1               0     1  1.000000
# 1412           0              7     4               0     4  1.000000
# 1413           0              4     1               0     1  1.000000
# 1414           0              7     2               0     2  1.000000
# 1415           0              7     3               0     3  1.000000
#
# [1416 rows x 15 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8447058823529412
# Precision :  0.7142857142857143
# Recall :  0.4838709677419355
# F1 Score :  0.5769230769230769
# AUC :  0.714827050136028

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8141176470588235
# Precision :  0.6296296296296297
# Recall :  0.3655913978494624
# F1 Score :  0.46258503401360546
# AUC :  0.6526752169970205

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8023529411764706
# Precision :  0.6285714285714286
# Recall :  0.23655913978494625
# F1 Score :  0.34375
# AUC :  0.598701256639461

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8141176470588235
# Precision :  0.6296296296296297
# Recall :  0.3655913978494624
# F1 Score :  0.46258503401360546
# AUC :  0.6526752169970205

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8023529411764706
# Precision :  0.5714285714285714
# Recall :  0.3870967741935484
# F1 Score :  0.4615384615384615
# AUC :  0.6528857364943647

# %% [markdown]
# # MRMR HFS

# %%
def HSF(df, df_train):
    
    from copy import deepcopy
    col_list = list(df_train.columns)
    print(col_list)
    d = df_train.shape[1]
    SF = []
    merit = [0 for i in range(d)]
    merit_archive = [0 for i in range(d)]
    Total_FS = [0 for i in range(d)]

    rel_CF = RHFS(df, d, col_list)

    max_value = max(rel_CF)
    Feature_max_index = rel_CF.index(max_value)

    n = 0

    SF.append(Feature_max_index)

    merit_archive[n] = deepcopy(max_value)

    Total_FS[n] = deepcopy(SF)

    while n < d-1:

        for i in range(d):

            red_FF = SHFS(SF, df_train, i, col_list,d)

            top = (d + d*(sum(rel_CF)/len(rel_CF)))
            bottom = (d + (d*(d-1)*(sum(red_FF)/len(red_FF))))**(1/2)
            merit[i] = top/bottom

        for val in SF:
            merit[val] = -9999999

        max_value = max(merit)
        Feature_max_index = merit.index(max_value)

        if Feature_max_index not in SF:
            SF.append(Feature_max_index)

        n += 1
        
        Total_FS[n] = deepcopy(SF)

        merit_archive[n] = max_value

    index_val = merit_archive.index(max(merit_archive))

    Feature_subset = Total_FS[index_val]

    subset_list = []

    for val in Feature_subset:
        subset_list.append(col_list[val])
    return subset_list


def RHFS(df, d, col_list):
    rel_CF = [0 for i in range(d)]
    count = 0

    igain = IG(X,df['class'])

    for m in  range(d):
        mu = df[col_list[m]].mean()

        n_1 = df[df['class'] == 0].count()[1]
        mu_1 = df[col_list[m]][df['class'] == 0].mean()
        var_1 = df[col_list[m]][df['class'] == 0].var()

        n_2 = df[df['class'] == 1].count()[1]
        mu_2 = df[col_list[m]][df['class'] == 1].mean()
        var_2 = df[col_list[m]][df['class'] == 1].var()

        inter_class = n_1*(mu_1-mu)**2 + n_2*(mu_2-mu)**2
        intra_class = (n_1-1)*var_1 + (n_2-1)*var_2

        fscore = inter_class / intra_class

        rel_CF[count] = (1/2)*(fscore + igain[m])
        count += 1
    
    return rel_CF

        
        

def IG(col_1, col_2):
    from sklearn.feature_selection import mutual_info_classif
    gain = mutual_info_classif(col_1,col_2)
    return gain   

def relief(col_1,col_2):
    pass



def SHFS(SF, df_train, i, col_list,d):
    from itertools import combinations
    from copy import deepcopy
    red_FF = []
    temp_SF = deepcopy(SF)
    if i not in SF:
        temp_SF.append(i)
        P_pairs = list(combinations(temp_SF,2))
        for pair in P_pairs:

            ied_value = (IED(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            pc_value = (PC(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            cs_value = (CS(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2

            red_FF.append((1/3)*(ied_value + pc_value + cs_value))
            # red_FF.append((1/2)*(pc_value + cs_value))
    else:
        red_FF = [0]
    return red_FF

def IED(col_1, col_2):
    import numpy as np
    dist = np.linalg.norm(col_1 - col_2)
    return 1/dist

def PC(col_1, col_2):
    from scipy.stats import pearsonr
    corr, _ = pearsonr(col_1 , col_2)
    return corr

def CS(col_1, col_2):
    from scipy import spatial
    similarity = 1 - spatial.distance.cosine(col_1, col_2)
    return similarity

# %%
FS = HSF(df, X)
FS
# Out:
# ['CountDeclMethodPrivate', 'AvgLineCode', 'CountLine', 'MaxCyclomatic', 'CountDeclMethodDefault', 'AvgEssential', 'CountDeclClassVariable', 'SumCyclomaticStrict', 'AvgCyclomatic', 'AvgLine', 'CountDeclClassMethod', 'AvgLineComment', 'AvgCyclomaticModified', 'CountDeclFunction', 'CountLineComment', 'CountDeclClass', 'CountDeclMethod', 'SumCyclomaticModified', 'CountLineCodeDecl', 'CountDeclMethodProtected', 'CountDeclInstanceVariable', 'MaxCyclomaticStrict', 'CountDeclMethodPublic', 'CountLineCodeExe', 'SumCyclomatic', 'SumEssential', 'CountStmtDecl', 'CountLineCode', 'CountStmtExe', 'RatioCommentToCode', 'CountLineBlank', 'CountStmt', 'MaxCyclomaticModified', 'CountSemicolon', 'AvgLineBlank', 'CountDeclInstanceMethod', 'AvgCyclomaticStrict', 'PercentLackOfCohesion', 'MaxInheritanceTree', 'CountClassDerived', 'CountClassCoupled', 'CountClassBase', 'CountInput_Max', 'CountInput_Mean', 'CountInput_Min', 'CountOutput_Max', 'CountOutput_Mean', 'CountOutput_Min', 'CountPath_Max', 'CountPath_Mean', 'CountPath_Min', 'MaxNesting_Max', 'MaxNesting_Mean', 'MaxNesting_Min', 'COMM', 'ADEV', 'DDEV', 'Added_lines', 'Del_lines', 'OWN_LINE', 'OWN_COMMIT', 'MINOR_COMMIT', 'MINOR_LINE', 'MAJOR_COMMIT', 'MAJOR_LINE']
# C:\Users\acer\AppData\Local\Temp\ipykernel_10760\2073211282.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1/dist
# ['MaxCyclomaticModified', 'MINOR_COMMIT', 'CountClassDerived']

# %%
X_new = X[FS]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8
# Precision :  0.6818181818181818
# Recall :  0.16129032258064516
# F1 Score :  0.2608695652173913
# AUC :  0.5701029926156238

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7858823529411765
# Precision :  0.5625
# Recall :  0.0967741935483871
# F1 Score :  0.16513761467889906
# AUC :  0.5378449280994947

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7458823529411764
# Precision :  0.4025974025974026
# Recall :  0.3333333333333333
# F1 Score :  0.3647058823529412
# AUC :  0.5973895582329317

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7835294117647059
# Precision :  0.5555555555555556
# Recall :  0.053763440860215055
# F1 Score :  0.09803921568627452
# AUC :  0.5208576240445654

# %% [markdown]
# # HFS NEW

# %%
def HSF(df, df_train):
    
    from copy import deepcopy
    col_list = list(df_train.columns)
    print(col_list)
    d = df_train.shape[1]
    SF = []
    merit = [0 for i in range(d)]
    merit_archive = [0 for i in range(d)]
    Total_FS = [0 for i in range(d)]

    rel_CF = RHFS(df, d, col_list)

    max_value = max(rel_CF)
    Feature_max_index = rel_CF.index(max_value)

    n = 0

    SF.append(Feature_max_index)

    merit_archive[n] = deepcopy(max_value)

    Total_FS[n] = deepcopy(SF)

    while n < d-1:

        for i in range(d):

            red_FF = SHFS(SF, df_train, i, col_list,d)

            top = (d + d*(sum(rel_CF)/len(rel_CF)))
            bottom = (d - (sum(red_FF)/len(red_FF)))**(1/2)

            merit[i] = top/bottom

        for val in SF:
            merit[val] = -9999999

        max_value = max(merit)
        Feature_max_index = merit.index(max_value)

        if Feature_max_index not in SF:
            SF.append(Feature_max_index)

        n += 1
        
        Total_FS[n] = deepcopy(SF)

        merit_archive[n] = max_value

    index_val = merit_archive.index(max(merit_archive))

    Feature_subset = Total_FS[index_val]

    subset_list = []

    for val in Feature_subset:
        subset_list.append(col_list[val])
    return subset_list


def RHFS(df, d, col_list):
    rel_CF = [0 for i in range(d)]
    count = 0

    igain = IG(X,df['class'])

    for m in  range(d):
        mu = df[col_list[m]].mean()

        n_1 = df[df['class'] == 0].count()[1]
        mu_1 = df[col_list[m]][df['class'] == 0].mean()
        var_1 = df[col_list[m]][df['class'] == 0].var()

        n_2 = df[df['class'] == 1].count()[1]
        mu_2 = df[col_list[m]][df['class'] == 1].mean()
        var_2 = df[col_list[m]][df['class'] == 1].var()

        inter_class = n_1*(mu_1-mu)**2 + n_2*(mu_2-mu)**2
        intra_class = (n_1-1)*var_1 + (n_2-1)*var_2

        fscore = inter_class / intra_class

        rel_CF[count] = (1/2)*(fscore + igain[m])
        count += 1
    
    return rel_CF

        
        

def IG(col_1, col_2):
    from sklearn.feature_selection import mutual_info_classif
    gain = mutual_info_classif(col_1,col_2)
    return gain   

def relief(col_1,col_2):
    pass



def SHFS(SF, df_train, i, col_list,d):
    from itertools import combinations
    from copy import deepcopy
    red_FF = []
    temp_SF = deepcopy(SF)
    if i not in SF:
        temp_SF.append(i)
        P_pairs = list(combinations(temp_SF,2))
        for pair in P_pairs:

            ied_value = (IED(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            pc_value = (PC(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            cs_value = (CS(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2

            red_FF.append((1/3)*(ied_value + pc_value + cs_value))
            # red_FF.append((1/2)*(pc_value + cs_value))
    else:
        red_FF = [0]
    return red_FF

def IED(col_1, col_2):
    import numpy as np
    dist = np.linalg.norm(col_1 - col_2)
    return 1/dist

def PC(col_1, col_2):
    from scipy.stats import pearsonr
    corr, _ = pearsonr(col_1 , col_2)
    return corr

def CS(col_1, col_2):
    from scipy import spatial
    similarity = 1 - spatial.distance.cosine(col_1, col_2)
    return similarity

# %%
FS = HSF(df, X)
FS
# Out:
# ['CountDeclMethodPrivate', 'AvgLineCode', 'CountLine', 'MaxCyclomatic', 'CountDeclMethodDefault', 'AvgEssential', 'CountDeclClassVariable', 'SumCyclomaticStrict', 'AvgCyclomatic', 'AvgLine', 'CountDeclClassMethod', 'AvgLineComment', 'AvgCyclomaticModified', 'CountDeclFunction', 'CountLineComment', 'CountDeclClass', 'CountDeclMethod', 'SumCyclomaticModified', 'CountLineCodeDecl', 'CountDeclMethodProtected', 'CountDeclInstanceVariable', 'MaxCyclomaticStrict', 'CountDeclMethodPublic', 'CountLineCodeExe', 'SumCyclomatic', 'SumEssential', 'CountStmtDecl', 'CountLineCode', 'CountStmtExe', 'RatioCommentToCode', 'CountLineBlank', 'CountStmt', 'MaxCyclomaticModified', 'CountSemicolon', 'AvgLineBlank', 'CountDeclInstanceMethod', 'AvgCyclomaticStrict', 'PercentLackOfCohesion', 'MaxInheritanceTree', 'CountClassDerived', 'CountClassCoupled', 'CountClassBase', 'CountInput_Max', 'CountInput_Mean', 'CountInput_Min', 'CountOutput_Max', 'CountOutput_Mean', 'CountOutput_Min', 'CountPath_Max', 'CountPath_Mean', 'CountPath_Min', 'MaxNesting_Max', 'MaxNesting_Mean', 'MaxNesting_Min', 'COMM', 'ADEV', 'DDEV', 'Added_lines', 'Del_lines', 'OWN_LINE', 'OWN_COMMIT', 'MINOR_COMMIT', 'MINOR_LINE', 'MAJOR_COMMIT', 'MAJOR_LINE']
# C:\Users\acer\AppData\Local\Temp\ipykernel_10760\4067302685.py:125: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1/dist
# ['MaxCyclomaticModified', 'MaxCyclomatic']

# %%
X_new = X[FS]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7858823529411765
# Precision :  0.53125
# Recall :  0.1827956989247312
# F1 Score :  0.27199999999999996
# AUC :  0.5688074880165825

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.788235294117647
# Precision :  0.5652173913043478
# Recall :  0.13978494623655913
# F1 Score :  0.22413793103448276
# AUC :  0.5548322321544241

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7764705882352941
# Precision :  0.4852941176470588
# Recall :  0.3548387096774194
# F1 Score :  0.4099378881987578
# AUC :  0.6247085114652158

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8117647058823529
# Precision :  0.6756756756756757
# Recall :  0.26881720430107525
# F1 Score :  0.38461538461538464
# AUC :  0.6163363129939111
