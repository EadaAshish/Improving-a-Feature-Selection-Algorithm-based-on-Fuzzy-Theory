# %%
import pandas as pd

# %%
df = pd.read_csv('wicket-1.csv')
df
# Out:
#         id  CountDeclMethodPrivate  AvgLineCode  CountLine  MaxCyclomatic  \
# 0        1                       0           10        212              8
# 1        2                       0            4        273              3
# 2        3                       0            4        231              2
# 3        4                       0            6        104              2
# 4        5                       0            5        128              2
# ...    ...                     ...          ...        ...            ...
# 1758  1759                       0            1         34              1
# 1759  1760                       0            4         83              3
# 1760  1761                       0            5        100              3
# 1761  1762                       1           10        266              9
# 1762  1763                       0            2         37              1
#
#       CountDeclMethodDefault  AvgEssential  CountDeclClassVariable  \
# 0                          0             1                       0
# 1                          0             1                       1
# 2                          0             1                       1
# 3                          0             1                       1
# 4                          0             1                       1
# ...                      ...           ...                     ...
# 1758                       1             1                       0
# 1759                       2             1                       1
# 1760                       0             1                       1
# 1761                       0             1                       2
# 1762                       0             1                       0
#
#       SumCyclomaticStrict  AvgCyclomatic  ...  DDEV  Added_lines  Del_lines  \
# 0                      18              2  ...     3          396          5
# 1                      18              1  ...     2          546          0
# 2                      12              1  ...     3          463          1
# 3                       4              1  ...     2          210          0
# 4                       5              1  ...     2          258          0
# ...                   ...            ...  ...   ...          ...        ...
# 1758                    1              1  ...     2           70          0
# 1759                    7              1  ...     2          168          0
# 1760                    7              1  ...     3          204          2
# 1761                   23              2  ...     2          532          0
# 1762                    1              1  ...     3           75         38
#
#       OWN_LINE  OWN_COMMIT  MINOR_COMMIT  MINOR_LINE  MAJOR_COMMIT  \
# 0     0.966981    0.666667             0           1             3
# 1     0.937729    0.500000             0           2             2
# 2     0.917749    0.333333             0           2             3
# 3     0.971429    0.500000             0           1             2
# 4     0.968992    0.500000             0           1             2
# ...        ...         ...           ...         ...           ...
# 1758  0.971429    0.500000             0           1             2
# 1759  0.988095    0.500000             0           1             2
# 1760  0.980198    0.500000             0           1             3
# 1761  0.962406    0.500000             0           1             2
# 1762  1.000000    0.500000             0           1             3
#
#       MAJOR_LINE  RealBugCount
# 0              1             0
# 1              0             0
# 2              1             0
# 3              1             0
# 4              1             0
# ...          ...           ...
# 1758           1             0
# 1759           1             0
# 1760           1             0
# 1761           1             0
# 1762           0             0
#
# [1763 rows x 67 columns]

# %%
df.drop(['id'], axis=1, inplace=True)

# %%
df['RealBugCount'].unique()
# Out:
# array([0, 2, 1, 7, 3, 5, 8, 4], dtype=int64)

# %%
df['RealBugCount'].replace([2, 1, 7, 3, 5, 8, 4], 1, inplace=True)
df['RealBugCount'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df = df.rename({'RealBugCount':'class'}, axis=1)
df
# Out:
#       CountDeclMethodPrivate  AvgLineCode  CountLine  MaxCyclomatic  \
# 0                          0           10        212              8
# 1                          0            4        273              3
# 2                          0            4        231              2
# 3                          0            6        104              2
# 4                          0            5        128              2
# ...                      ...          ...        ...            ...
# 1758                       0            1         34              1
# 1759                       0            4         83              3
# 1760                       0            5        100              3
# 1761                       1           10        266              9
# 1762                       0            2         37              1
#
#       CountDeclMethodDefault  AvgEssential  CountDeclClassVariable  \
# 0                          0             1                       0
# 1                          0             1                       1
# 2                          0             1                       1
# 3                          0             1                       1
# 4                          0             1                       1
# ...                      ...           ...                     ...
# 1758                       1             1                       0
# 1759                       2             1                       1
# 1760                       0             1                       1
# 1761                       0             1                       2
# 1762                       0             1                       0
#
#       SumCyclomaticStrict  AvgCyclomatic  AvgLine  ...  DDEV  Added_lines  \
# 0                      18              2       18  ...     3          396
# 1                      18              1       12  ...     2          546
# 2                      12              1       14  ...     3          463
# 3                       4              1       16  ...     2          210
# 4                       5              1       18  ...     2          258
# ...                   ...            ...      ...  ...   ...          ...
# 1758                    1              1        9  ...     2           70
# 1759                    7              1        7  ...     2          168
# 1760                    7              1       12  ...     3          204
# 1761                   23              2       17  ...     2          532
# 1762                    1              1        4  ...     3           75
#
#       Del_lines  OWN_LINE  OWN_COMMIT  MINOR_COMMIT  MINOR_LINE  MAJOR_COMMIT  \
# 0             5  0.966981    0.666667             0           1             3
# 1             0  0.937729    0.500000             0           2             2
# 2             1  0.917749    0.333333             0           2             3
# 3             0  0.971429    0.500000             0           1             2
# 4             0  0.968992    0.500000             0           1             2
# ...         ...       ...         ...           ...         ...           ...
# 1758          0  0.971429    0.500000             0           1             2
# 1759          0  0.988095    0.500000             0           1             2
# 1760          2  0.980198    0.500000             0           1             3
# 1761          0  0.962406    0.500000             0           1             2
# 1762         38  1.000000    0.500000             0           1             3
#
#       MAJOR_LINE  class
# 0              1      0
# 1              0      0
# 2              1      0
# 3              1      0
# 4              1      0
# ...          ...    ...
# 1758           1      0
# 1759           1      0
# 1760           1      0
# 1761           1      0
# 1762           0      0
#
# [1763 rows x 66 columns]

# %%
df[df['class'] == 0]
# Out:
#       CountDeclMethodPrivate  AvgLineCode  CountLine  MaxCyclomatic  \
# 0                          0           10        212              8
# 1                          0            4        273              3
# 2                          0            4        231              2
# 3                          0            6        104              2
# 4                          0            5        128              2
# ...                      ...          ...        ...            ...
# 1758                       0            1         34              1
# 1759                       0            4         83              3
# 1760                       0            5        100              3
# 1761                       1           10        266              9
# 1762                       0            2         37              1
#
#       CountDeclMethodDefault  AvgEssential  CountDeclClassVariable  \
# 0                          0             1                       0
# 1                          0             1                       1
# 2                          0             1                       1
# 3                          0             1                       1
# 4                          0             1                       1
# ...                      ...           ...                     ...
# 1758                       1             1                       0
# 1759                       2             1                       1
# 1760                       0             1                       1
# 1761                       0             1                       2
# 1762                       0             1                       0
#
#       SumCyclomaticStrict  AvgCyclomatic  AvgLine  ...  DDEV  Added_lines  \
# 0                      18              2       18  ...     3          396
# 1                      18              1       12  ...     2          546
# 2                      12              1       14  ...     3          463
# 3                       4              1       16  ...     2          210
# 4                       5              1       18  ...     2          258
# ...                   ...            ...      ...  ...   ...          ...
# 1758                    1              1        9  ...     2           70
# 1759                    7              1        7  ...     2          168
# 1760                    7              1       12  ...     3          204
# 1761                   23              2       17  ...     2          532
# 1762                    1              1        4  ...     3           75
#
#       Del_lines  OWN_LINE  OWN_COMMIT  MINOR_COMMIT  MINOR_LINE  MAJOR_COMMIT  \
# 0             5  0.966981    0.666667             0           1             3
# 1             0  0.937729    0.500000             0           2             2
# 2             1  0.917749    0.333333             0           2             3
# 3             0  0.971429    0.500000             0           1             2
# 4             0  0.968992    0.500000             0           1             2
# ...         ...       ...         ...           ...         ...           ...
# 1758          0  0.971429    0.500000             0           1             2
# 1759          0  0.988095    0.500000             0           1             2
# 1760          2  0.980198    0.500000             0           1             3
# 1761          0  0.962406    0.500000             0           1             2
# 1762         38  1.000000    0.500000             0           1             3
#
#       MAJOR_LINE  class
# 0              1      0
# 1              0      0
# 2              1      0
# 3              1      0
# 4              1      0
# ...          ...    ...
# 1758           1      0
# 1759           1      0
# 1760           1      0
# 1761           1      0
# 1762           0      0
#
# [1633 rows x 66 columns]

# %%
X = df.drop(['class'], axis=1)
X
# Out:
#       CountDeclMethodPrivate  AvgLineCode  CountLine  MaxCyclomatic  \
# 0                          0           10        212              8
# 1                          0            4        273              3
# 2                          0            4        231              2
# 3                          0            6        104              2
# 4                          0            5        128              2
# ...                      ...          ...        ...            ...
# 1758                       0            1         34              1
# 1759                       0            4         83              3
# 1760                       0            5        100              3
# 1761                       1           10        266              9
# 1762                       0            2         37              1
#
#       CountDeclMethodDefault  AvgEssential  CountDeclClassVariable  \
# 0                          0             1                       0
# 1                          0             1                       1
# 2                          0             1                       1
# 3                          0             1                       1
# 4                          0             1                       1
# ...                      ...           ...                     ...
# 1758                       1             1                       0
# 1759                       2             1                       1
# 1760                       0             1                       1
# 1761                       0             1                       2
# 1762                       0             1                       0
#
#       SumCyclomaticStrict  AvgCyclomatic  AvgLine  ...  ADEV  DDEV  \
# 0                      18              2       18  ...     6     3
# 1                      18              1       12  ...     2     2
# 2                      12              1       14  ...     3     3
# 3                       4              1       16  ...     2     2
# 4                       5              1       18  ...     2     2
# ...                   ...            ...      ...  ...   ...   ...
# 1758                    1              1        9  ...     2     2
# 1759                    7              1        7  ...     2     2
# 1760                    7              1       12  ...     4     3
# 1761                   23              2       17  ...     2     2
# 1762                    1              1        4  ...     4     3
#
#       Added_lines  Del_lines  OWN_LINE  OWN_COMMIT  MINOR_COMMIT  MINOR_LINE  \
# 0             396          5  0.966981    0.666667             0           1
# 1             546          0  0.937729    0.500000             0           2
# 2             463          1  0.917749    0.333333             0           2
# 3             210          0  0.971429    0.500000             0           1
# 4             258          0  0.968992    0.500000             0           1
# ...           ...        ...       ...         ...           ...         ...
# 1758           70          0  0.971429    0.500000             0           1
# 1759          168          0  0.988095    0.500000             0           1
# 1760          204          2  0.980198    0.500000             0           1
# 1761          532          0  0.962406    0.500000             0           1
# 1762           75         38  1.000000    0.500000             0           1
#
#       MAJOR_COMMIT  MAJOR_LINE
# 0                3           1
# 1                2           0
# 2                3           1
# 3                2           1
# 4                2           1
# ...            ...         ...
# 1758             2           1
# 1759             2           1
# 1760             3           1
# 1761             2           1
# 1762             3           0
#
# [1763 rows x 65 columns]

# %%
Y = df['class']
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1758    0
# 1759    0
# 1760    0
# 1761    0
# 1762    0
# Name: class, Length: 1763, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import *

# %% [markdown]
# # All Features

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9376181474480151
# Precision :  1.0
# Recall :  0.029411764705882353
# F1 Score :  0.05714285714285715
# AUC :  0.5147058823529411

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9376181474480151
# Precision :  1.0
# Recall :  0.029411764705882353
# F1 Score :  0.05714285714285715
# AUC :  0.5147058823529411

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9357277882797732
# Precision :  0.5
# Recall :  0.11764705882352941
# F1 Score :  0.19047619047619047
# AUC :  0.5547831253713607

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9017013232514177
# Precision :  0.23529411764705882
# Recall :  0.23529411764705882
# F1 Score :  0.23529411764705882
# AUC :  0.5913844325609031

# %% [markdown]
# # PEARSON CORRELATION

# %%
cor = df.corr()
cor_target = abs(cor['class'])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.35]
relevant_features
# Out:
# COMM     0.382651
# ADEV     0.382651
# class    1.000000
# Name: class, dtype: float64

# %%
X_new = df[['COMM', 'ADEV']]
X_new
# Out:
#       COMM  ADEV
# 0        6     6
# 1        2     2
# 2        3     3
# 3        2     2
# 4        2     2
# ...    ...   ...
# 1758     2     2
# 1759     2     2
# 1760     4     4
# 1761     2     2
# 1762     4     4
#
# [1763 rows x 2 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9300567107750473
# Precision :  0.3333333333333333
# Recall :  0.08823529411764706
# F1 Score :  0.13953488372093023
# AUC :  0.5380570409982174

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9395085066162571
# Precision :  1.0
# Recall :  0.058823529411764705
# F1 Score :  0.1111111111111111
# AUC :  0.5294117647058824

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9073724007561437
# Precision :  0.2222222222222222
# Recall :  0.17647058823529413
# F1 Score :  0.19672131147540983
# AUC :  0.5670231729055258

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9319470699432892
# Precision :  0.4444444444444444
# Recall :  0.23529411764705882
# F1 Score :  0.30769230769230765
# AUC :  0.6075460487225194

# %% [markdown]
# # INFORMATION GAIN 10

# %%
from sklearn.feature_selection import mutual_info_classif
gain = mutual_info_classif(X,Y)
gain
# Out:
# array([0.02175303, 0.028024  , 0.05012064, 0.03397683, 0.        ,
#        0.        , 0.01428461, 0.04800137, 0.01379038, 0.02281846,
#        0.        , 0.01686193, 0.01607215, 0.04265012, 0.03228385,
#        0.00632484, 0.04202144, 0.05111687, 0.06444689, 0.03343264,
#        0.03832972, 0.0406273 , 0.0305422 , 0.04489638, 0.05396264,
#        0.03868898, 0.06070423, 0.05065441, 0.05502447, 0.04487286,
#        0.03890303, 0.04758367, 0.03174825, 0.04582378, 0.00899942,
#        0.038179  , 0.02380381, 0.01923947, 0.00893488, 0.00525381,
#        0.0423664 , 0.01423891, 0.0408682 , 0.02729416, 0.01939849,
#        0.04340172, 0.03509217, 0.00310908, 0.0363404 , 0.03141695,
#        0.        , 0.03136886, 0.02125431, 0.00798334, 0.04462136,
#        0.04080449, 0.04765442, 0.05088355, 0.03880164, 0.02179832,
#        0.03421131, 0.00208745, 0.0077516 , 0.03282076, 0.02416166])

# %%
col_list = X.columns
col_list
# Out:
# Index(['CountDeclMethodPrivate', 'AvgLineCode', 'CountLine', 'MaxCyclomatic',
#        'CountDeclMethodDefault', 'AvgEssential', 'CountDeclClassVariable',
#        'SumCyclomaticStrict', 'AvgCyclomatic', 'AvgLine',
#        'CountDeclClassMethod', 'AvgLineComment', 'AvgCyclomaticModified',
#        'CountDeclFunction', 'CountLineComment', 'CountDeclClass',
#        'CountDeclMethod', 'SumCyclomaticModified', 'CountLineCodeDecl',
#        'CountDeclMethodProtected', 'CountDeclInstanceVariable',
#        'MaxCyclomaticStrict', 'CountDeclMethodPublic', 'CountLineCodeExe',
#        'SumCyclomatic', 'SumEssential', 'CountStmtDecl', 'CountLineCode',
#        'CountStmtExe', 'RatioCommentToCode', 'CountLineBlank', 'CountStmt',
#        'MaxCyclomaticModified', 'CountSemicolon', 'AvgLineBlank',
#        'CountDeclInstanceMethod', 'AvgCyclomaticStrict',
#        'PercentLackOfCohesion', 'MaxInheritanceTree', 'CountClassDerived',
#        'CountClassCoupled', 'CountClassBase', 'CountInput_Max',
#        'CountInput_Mean', 'CountInput_Min', 'CountOutput_Max',
#        'CountOutput_Mean', 'CountOutput_Min', 'CountPath_Max',
#        'CountPath_Mean', 'CountPath_Min', 'MaxNesting_Max', 'MaxNesting_Mean',
#        'MaxNesting_Min', 'COMM', 'ADEV', 'DDEV', 'Added_lines', 'Del_lines',
#        'OWN_LINE', 'OWN_COMMIT', 'MINOR_COMMIT', 'MINOR_LINE', 'MAJOR_COMMIT',
#        'MAJOR_LINE'],
#       dtype='object')

# %%
temp = pd.DataFrame(list(zip(col_list, gain)), columns =['col', 'score']) 
temp
# Out:
#                        col     score
# 0   CountDeclMethodPrivate  0.021753
# 1              AvgLineCode  0.028024
# 2                CountLine  0.050121
# 3            MaxCyclomatic  0.033977
# 4   CountDeclMethodDefault  0.000000
# ..                     ...       ...
# 60              OWN_COMMIT  0.034211
# 61            MINOR_COMMIT  0.002087
# 62              MINOR_LINE  0.007752
# 63            MAJOR_COMMIT  0.032821
# 64              MAJOR_LINE  0.024162
#
# [65 rows x 2 columns]

# %%
temp_sort = temp.sort_values(['score'], ascending=False)
temp_sort[:10]
# Out:
#                       col     score
# 18      CountLineCodeDecl  0.064447
# 26          CountStmtDecl  0.060704
# 28           CountStmtExe  0.055024
# 24          SumCyclomatic  0.053963
# 17  SumCyclomaticModified  0.051117
# 57            Added_lines  0.050884
# 27          CountLineCode  0.050654
# 2               CountLine  0.050121
# 7     SumCyclomaticStrict  0.048001
# 56                   DDEV  0.047654

# %%
FS = list(temp_sort['col'][:10])
FS
# Out:
# ['CountLineCodeDecl',
#  'CountStmtDecl',
#  'CountStmtExe',
#  'SumCyclomatic',
#  'SumCyclomaticModified',
#  'Added_lines',
#  'CountLineCode',
#  'CountLine',
#  'SumCyclomaticStrict',
#  'DDEV']

# %%
X_new = df[FS]
X_new
# Out:
#       CountLineCodeDecl  CountStmtDecl  CountStmtExe  SumCyclomatic  \
# 0                    35             35            27             18
# 1                    34             34            22             18
# 2                    27             27            14             12
# 3                    14             14             6              4
# 4                    15             15             7              5
# ...                 ...            ...           ...            ...
# 1758                  3              3             0              1
# 1759                 16             17            11              7
# 1760                 19             18            12              7
# 1761                 51             52            59             23
# 1762                  4              4             0              1
#
#       SumCyclomaticModified  Added_lines  CountLineCode  CountLine  \
# 0                        18          396            106        212
# 1                        18          546             94        273
# 2                        12          463             67        231
# 3                         4          210             30        104
# 4                         5          258             33        128
# ...                     ...          ...            ...        ...
# 1758                      1           70              3         34
# 1759                      7          168             34         83
# 1760                      7          204             40        100
# 1761                     23          532            142        266
# 1762                      1           75              6         37
#
#       SumCyclomaticStrict  DDEV
# 0                      18     3
# 1                      18     2
# 2                      12     3
# 3                       4     2
# 4                       5     2
# ...                   ...   ...
# 1758                    1     2
# 1759                    7     2
# 1760                    7     3
# 1761                   23     2
# 1762                    1     3
#
# [1763 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9357277882797732
# Precision :  0.5
# Recall :  0.17647058823529413
# F1 Score :  0.2608695652173913
# AUC :  0.5821746880570411

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9357277882797732
# Precision :  0.0
# Recall :  0.0
# F1 Score :  0.0
# AUC :  0.5
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9281663516068053
# Precision :  0.3333333333333333
# Recall :  0.11764705882352941
# F1 Score :  0.1739130434782609
# AUC :  0.5507427213309566

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9243856332703214
# Precision :  0.38461538461538464
# Recall :  0.29411764705882354
# F1 Score :  0.33333333333333337
# AUC :  0.6308972073677956

# %% [markdown]
# # INFORMATION GAIN 15

# %%
from sklearn.feature_selection import mutual_info_classif
gain = mutual_info_classif(X,Y)
gain
# Out:
# array([0.01870608, 0.02895806, 0.04915771, 0.04023735, 0.        ,
#        0.00756402, 0.01358893, 0.05386871, 0.02179614, 0.02136884,
#        0.00811108, 0.02120805, 0.0194172 , 0.03941394, 0.03791835,
#        0.02128084, 0.04346097, 0.05531539, 0.05783983, 0.02640426,
#        0.03677899, 0.03840482, 0.03293232, 0.04598323, 0.05620586,
#        0.03855483, 0.05687459, 0.0529264 , 0.05357777, 0.03415482,
#        0.03804556, 0.04555748, 0.03963282, 0.04536245, 0.00994166,
#        0.04116161, 0.02543088, 0.01861143, 0.00381488, 0.00999089,
#        0.03700766, 0.02298059, 0.02905845, 0.02803689, 0.        ,
#        0.04670352, 0.03733059, 0.        , 0.04005568, 0.03408841,
#        0.        , 0.02727407, 0.02279595, 0.        , 0.04736624,
#        0.04340075, 0.0430755 , 0.05028877, 0.0304482 , 0.02104603,
#        0.03112872, 0.0056129 , 0.        , 0.04629506, 0.03020698])

# %%
col_list = X.columns
col_list
# Out:
# Index(['CountDeclMethodPrivate', 'AvgLineCode', 'CountLine', 'MaxCyclomatic',
#        'CountDeclMethodDefault', 'AvgEssential', 'CountDeclClassVariable',
#        'SumCyclomaticStrict', 'AvgCyclomatic', 'AvgLine',
#        'CountDeclClassMethod', 'AvgLineComment', 'AvgCyclomaticModified',
#        'CountDeclFunction', 'CountLineComment', 'CountDeclClass',
#        'CountDeclMethod', 'SumCyclomaticModified', 'CountLineCodeDecl',
#        'CountDeclMethodProtected', 'CountDeclInstanceVariable',
#        'MaxCyclomaticStrict', 'CountDeclMethodPublic', 'CountLineCodeExe',
#        'SumCyclomatic', 'SumEssential', 'CountStmtDecl', 'CountLineCode',
#        'CountStmtExe', 'RatioCommentToCode', 'CountLineBlank', 'CountStmt',
#        'MaxCyclomaticModified', 'CountSemicolon', 'AvgLineBlank',
#        'CountDeclInstanceMethod', 'AvgCyclomaticStrict',
#        'PercentLackOfCohesion', 'MaxInheritanceTree', 'CountClassDerived',
#        'CountClassCoupled', 'CountClassBase', 'CountInput_Max',
#        'CountInput_Mean', 'CountInput_Min', 'CountOutput_Max',
#        'CountOutput_Mean', 'CountOutput_Min', 'CountPath_Max',
#        'CountPath_Mean', 'CountPath_Min', 'MaxNesting_Max', 'MaxNesting_Mean',
#        'MaxNesting_Min', 'COMM', 'ADEV', 'DDEV', 'Added_lines', 'Del_lines',
#        'OWN_LINE', 'OWN_COMMIT', 'MINOR_COMMIT', 'MINOR_LINE', 'MAJOR_COMMIT',
#        'MAJOR_LINE'],
#       dtype='object')

# %%
temp = pd.DataFrame(list(zip(col_list, gain)), columns =['col', 'score']) 
temp
# Out:
#                        col     score
# 0   CountDeclMethodPrivate  0.018706
# 1              AvgLineCode  0.028958
# 2                CountLine  0.049158
# 3            MaxCyclomatic  0.040237
# 4   CountDeclMethodDefault  0.000000
# ..                     ...       ...
# 60              OWN_COMMIT  0.031129
# 61            MINOR_COMMIT  0.005613
# 62              MINOR_LINE  0.000000
# 63            MAJOR_COMMIT  0.046295
# 64              MAJOR_LINE  0.030207
#
# [65 rows x 2 columns]

# %%
temp_sort = temp.sort_values(['score'], ascending=False)
temp_sort[:15]
# Out:
#                       col     score
# 18      CountLineCodeDecl  0.057840
# 26          CountStmtDecl  0.056875
# 24          SumCyclomatic  0.056206
# 17  SumCyclomaticModified  0.055315
# 7     SumCyclomaticStrict  0.053869
# 28           CountStmtExe  0.053578
# 27          CountLineCode  0.052926
# 57            Added_lines  0.050289
# 2               CountLine  0.049158
# 54                   COMM  0.047366
# 45        CountOutput_Max  0.046704
# 63           MAJOR_COMMIT  0.046295
# 23       CountLineCodeExe  0.045983
# 31              CountStmt  0.045557
# 33         CountSemicolon  0.045362

# %%
FS = list(temp_sort['col'][:15])
FS
# Out:
# ['CountLineCodeDecl',
#  'CountStmtDecl',
#  'SumCyclomatic',
#  'SumCyclomaticModified',
#  'SumCyclomaticStrict',
#  'CountStmtExe',
#  'CountLineCode',
#  'Added_lines',
#  'CountLine',
#  'COMM',
#  'CountOutput_Max',
#  'MAJOR_COMMIT',
#  'CountLineCodeExe',
#  'CountStmt',
#  'CountSemicolon']

# %%
X_new = df[FS]
X_new
# Out:
#       CountLineCodeDecl  CountStmtDecl  SumCyclomatic  SumCyclomaticModified  \
# 0                    35             35             18                     18
# 1                    34             34             18                     18
# 2                    27             27             12                     12
# 3                    14             14              4                      4
# 4                    15             15              5                      5
# ...                 ...            ...            ...                    ...
# 1758                  3              3              1                      1
# 1759                 16             17              7                      7
# 1760                 19             18              7                      7
# 1761                 51             52             23                     23
# 1762                  4              4              1                      1
#
#       SumCyclomaticStrict  CountStmtExe  CountLineCode  Added_lines  \
# 0                      18            27            106          396
# 1                      18            22             94          546
# 2                      12            14             67          463
# 3                       4             6             30          210
# 4                       5             7             33          258
# ...                   ...           ...            ...          ...
# 1758                    1             0              3           70
# 1759                    7            11             34          168
# 1760                    7            12             40          204
# 1761                   23            59            142          532
# 1762                    1             0              6           75
#
#       CountLine  COMM  CountOutput_Max  MAJOR_COMMIT  CountLineCodeExe  \
# 0           212     6               11             3                40
# 1           273     2                3             2                24
# 2           231     3                3             3                15
# 3           104     2                6             2                 8
# 4           128     2                4             2                 9
# ...         ...   ...              ...           ...               ...
# 1758         34     2                0             2                 0
# 1759         83     2                5             2                13
# 1760        100     4                8             3                17
# 1761        266     2               17             2                83
# 1762         37     4                1             3                 0
#
#       CountStmt  CountSemicolon
# 0            62              45
# 1            56              37
# 2            41              28
# 3            20              15
# 4            22              16
# ...         ...             ...
# 1758          3               2
# 1759         28              20
# 1760         30              21
# 1761        111              85
# 1762          4               2
#
# [1763 rows x 15 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9300567107750473
# Precision :  0.4
# Recall :  0.17647058823529413
# F1 Score :  0.2448979591836735
# AUC :  0.5791443850267379

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9376181474480151
# Precision :  1.0
# Recall :  0.029411764705882353
# F1 Score :  0.05714285714285715
# AUC :  0.5147058823529411

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9357277882797732
# Precision :  0.5
# Recall :  0.14705882352941177
# F1 Score :  0.22727272727272727
# AUC :  0.5684789067142009

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9206049149338374
# Precision :  0.34615384615384615
# Recall :  0.2647058823529412
# F1 Score :  0.29999999999999993
# AUC :  0.6151812240047534

# %% [markdown]
# # FISHER SCORE

# %%
FScore = []

for m in  range(len(col_list)):
        mu = df[col_list[m]].mean()

        n_1 = df[df['class'] == 0].count()[1]
        mu_1 = df[col_list[m]][df['class'] == 0].mean()
        var_1 = df[col_list[m]][df['class'] == 0].var()

        n_2 = df[df['class'] == 1].count()[1]
        mu_2 = df[col_list[m]][df['class'] == 1].mean()
        var_2 = df[col_list[m]][df['class'] == 1].var()

        inter_class = n_1*(mu_1-mu)**2 + n_2*(mu_2-mu)**2
        intra_class = (n_1-1)*var_1 + (n_2-1)*var_2

        FScore.append(inter_class / intra_class)

FScore
# Out:
# [0.05050823983403898,
#  0.03139652235802918,
#  0.11919398060681617,
#  0.10211949127873128,
#  8.797468874815512e-09,
#  0.00994398265918535,
#  0.03666687800151097,
#  0.1066735481810689,
#  0.03161843814061339,
#  0.0295875685907784,
#  0.0006742339909854301,
#  0.0031698317831966136,
#  0.030801487464626062,
#  0.09640944674400748,
#  0.08620543854312483,
#  0.04700466978178359,
#  0.09644209284358027,
#  0.11082012981868632,
#  0.13715003306822696,
#  0.08080905233717899,
#  0.0509930527407456,
#  0.09020481862480198,
#  0.0804567663565745,
#  0.1243971553083698,
#  0.10862060556436351,
#  0.09021093840067511,
#  0.1364679475147002,
#  0.1278102675589807,
#  0.10396428013738629,
#  0.0302214330869719,
#  0.12140536536961663,
#  0.12232171273672729,
#  0.10837160856737652,
#  0.12346683212961987,
#  0.006198620376535992,
#  0.09999010521478963,
#  0.02807345101288404,
#  0.016677070554123073,
#  0.0001443418629903529,
#  0.008200442796994613,
#  0.13520773977577982,
#  0.013962780319326852,
#  0.03217893537526949,
#  0.01315568986635413,
#  5.6261837452806865e-05,
#  0.13178599378193462,
#  0.02328051868436396,
#  0.004561466134038453,
#  3.823543797004748e-05,
#  2.94848535583979e-05,
#  0.007184117432179686,
#  0.08150802391076795,
#  0.038463155453460914,
#  0.0018238118184734037,
#  0.17153888467567283,
#  0.17153888467567283,
#  0.13823730932121542,
#  0.12837082377636247,
#  0.06781720246603716,
#  0.0002450167344813899,
#  0.010808362869995366,
#  0.030684990031625732,
#  0.0012899474782280143,
#  0.12209363886207576,
#  0.07344477638510906]

# %%
temp = pd.DataFrame(list(zip(col_list, FScore)), columns =['col', 'score']) 
temp
# Out:
#                        col         score
# 0   CountDeclMethodPrivate  5.050824e-02
# 1              AvgLineCode  3.139652e-02
# 2                CountLine  1.191940e-01
# 3            MaxCyclomatic  1.021195e-01
# 4   CountDeclMethodDefault  8.797469e-09
# ..                     ...           ...
# 60              OWN_COMMIT  1.080836e-02
# 61            MINOR_COMMIT  3.068499e-02
# 62              MINOR_LINE  1.289947e-03
# 63            MAJOR_COMMIT  1.220936e-01
# 64              MAJOR_LINE  7.344478e-02
#
# [65 rows x 2 columns]

# %%
temp_sort = temp.sort_values(['score'], ascending=False)
temp_sort[:10]
# Out:
#                   col     score
# 55               ADEV  0.171539
# 54               COMM  0.171539
# 56               DDEV  0.138237
# 18  CountLineCodeDecl  0.137150
# 26      CountStmtDecl  0.136468
# 40  CountClassCoupled  0.135208
# 45    CountOutput_Max  0.131786
# 57        Added_lines  0.128371
# 27      CountLineCode  0.127810
# 23   CountLineCodeExe  0.124397

# %%
FS = list(temp_sort['col'][:10])
FS
# Out:
# ['ADEV',
#  'COMM',
#  'DDEV',
#  'CountLineCodeDecl',
#  'CountStmtDecl',
#  'CountClassCoupled',
#  'CountOutput_Max',
#  'Added_lines',
#  'CountLineCode',
#  'CountLineCodeExe']

# %%
X_new = df[FS]
X_new
# Out:
#       ADEV  COMM  DDEV  CountLineCodeDecl  CountStmtDecl  CountClassCoupled  \
# 0        6     6     3                 35             35                  6
# 1        2     2     2                 34             34                  7
# 2        3     3     3                 27             27                  5
# 3        2     2     2                 14             14                  1
# 4        2     2     2                 15             15                  1
# ...    ...   ...   ...                ...            ...                ...
# 1758     2     2     2                  3              3                  1
# 1759     2     2     2                 16             17                  2
# 1760     4     4     3                 19             18                  1
# 1761     2     2     2                 51             52                  3
# 1762     4     4     3                  4              4                  0
#
#       CountOutput_Max  Added_lines  CountLineCode  CountLineCodeExe
# 0                  11          396            106                40
# 1                   3          546             94                24
# 2                   3          463             67                15
# 3                   6          210             30                 8
# 4                   4          258             33                 9
# ...               ...          ...            ...               ...
# 1758                0           70              3                 0
# 1759                5          168             34                13
# 1760                8          204             40                17
# 1761               17          532            142                83
# 1762                1           75              6                 0
#
# [1763 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9338374291115312
# Precision :  0.4666666666666667
# Recall :  0.20588235294117646
# F1 Score :  0.28571428571428564
# AUC :  0.5948603683897802

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9357277882797732
# Precision :  0.0
# Recall :  0.0
# F1 Score :  0.0
# AUC :  0.5
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9262759924385633
# Precision :  0.3333333333333333
# Recall :  0.14705882352941177
# F1 Score :  0.20408163265306123
# AUC :  0.5634284016636958

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9206049149338374
# Precision :  0.34615384615384615
# Recall :  0.2647058823529412
# F1 Score :  0.29999999999999993
# AUC :  0.6151812240047534

# %% [markdown]
# # SVM RFE 10

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,random_state=23)

# %%
from sklearn.feature_selection import RFE
rec_model = RandomForestClassifier()

rfe = RFE(rec_model, n_features_to_select=10)
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=RandomForestClassifier(), n_features_to_select=10)

# %%
X_train = X_train.loc[:, rfe.support_]
X_train
# Out:
#       CountLine  CountLineComment  CountLineCodeExe  CountStmtDecl  \
# 9            37                24                 1              5
# 970          57                31                 5              9
# 1382         67                24                19             13
# 453          72                37                 7             10
# 885          36                30                 0              2
# ...         ...               ...               ...            ...
# 1512         36                24                 1              5
# 950          35                22                 2              5
# 1064         44                24                 4              7
# 742        1167               231               349            204
# 595          74                57                 0              9
#
#       RatioCommentToCode  CountOutput_Max  CountOutput_Mean  ADEV  \
# 9                   2.67                1          1.000000     3
# 970                 1.55                4          3.500000     3
# 1382                0.67                7          5.000000     2
# 453                 1.32                9          5.000000     2
# 885                 7.50                0          0.000000     1
# ...                  ...              ...               ...   ...
# 1512                2.67                3          3.000000     2
# 950                 2.20                2          2.000000     2
# 1064                1.71                6          6.000000     2
# 742                 0.28               22          3.647059     6
# 595                 5.18                1          0.600000     3
#
#       Added_lines  OWN_LINE
# 9              74  0.945946
# 970           115  0.807018
# 1382          134  0.537313
# 453           144  0.625000
# 885            36  1.000000
# ...           ...       ...
# 1512           74  0.351351
# 950            70  0.685714
# 1064           88  0.545455
# 742          2334  0.775685
# 595           168  0.594595
#
# [1234 rows x 10 columns]

# %%
X_test = X_test.loc[:, rfe.support_]
X_test
# Out:
#       CountLine  CountLineComment  CountLineCodeExe  CountStmtDecl  \
# 1519        163                62                39             38
# 695          61                31                 7              9
# 913          46                22                 6             10
# 25          191                72                37             28
# 460         120                49                23             19
# ...         ...               ...               ...            ...
# 233         373               163                94             38
# 106         106                53                 9             16
# 1498         38                24                 1              4
# 736          38                30                 0              4
# 1276         98                25                20             19
#
#       RatioCommentToCode  CountOutput_Max  CountOutput_Mean  ADEV  \
# 1519                0.77               17          6.000000     2
# 695                 1.48                3          2.000000     2
# 913                 1.10                2          2.000000     2
# 25                  0.73                6          3.000000     2
# 460                 0.86               17          6.666667     2
# ...                  ...              ...               ...   ...
# 233                 1.09                9          3.444444     3
# 106                 1.32                3          1.428571     4
# 1498                2.40                1          1.000000     2
# 736                 5.00                1          1.000000     2
# 1276                0.43                4          2.000000     3
#
#       Added_lines  OWN_LINE
# 1519          326  0.674847
# 695           122  0.295082
# 913            92  1.000000
# 25            384  0.864583
# 460           240  0.816667
# ...           ...       ...
# 233           795  0.981233
# 106           213  0.783019
# 1498           38  1.000000
# 736            76  0.473684
# 1276          200  0.744898
#
# [529 rows x 10 columns]

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9376181474480151
# Precision :  0.5555555555555556
# Recall :  0.14705882352941177
# F1 Score :  0.23255813953488372
# AUC :  0.5694890077243018

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9357277882797732
# Precision :  0.0
# Recall :  0.0
# F1 Score :  0.0
# AUC :  0.5
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9243856332703214
# Precision :  0.125
# Recall :  0.029411764705882353
# F1 Score :  0.047619047619047616
# AUC :  0.507635175282234

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9168241965973535
# Precision :  0.32142857142857145
# Recall :  0.2647058823529412
# F1 Score :  0.2903225806451613
# AUC :  0.6131610219845514

# %% [markdown]
# # SVM RFE 15

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,random_state=23)

# %%
from sklearn.feature_selection import RFE
rec_model = RandomForestClassifier()

rfe = RFE(rec_model, n_features_to_select=15)
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=RandomForestClassifier(), n_features_to_select=15)

# %%
X_train = X_train.loc[:, rfe.support_]
X_train
# Out:
#       CountLine  CountLineComment  CountLineCodeExe  CountStmtDecl  \
# 9            37                24                 1              5
# 970          57                31                 5              9
# 1382         67                24                19             13
# 453          72                37                 7             10
# 885          36                30                 0              2
# ...         ...               ...               ...            ...
# 1512         36                24                 1              5
# 950          35                22                 2              5
# 1064         44                24                 4              7
# 742        1167               231               349            204
# 595          74                57                 0              9
#
#       CountLineCode  RatioCommentToCode  CountSemicolon  CountClassCoupled  \
# 9                 9                2.67               3                  0
# 970              20                1.55               8                  1
# 1382             36                0.67              16                  3
# 453              28                1.32              10                  3
# 885               4                7.50               1                  0
# ...             ...                 ...             ...                ...
# 1512              9                2.67               4                  1
# 950              10                2.20               4                  1
# 1064             14                1.71               8                  2
# 742             832                0.28             330                 22
# 595              11                5.18               8                  3
#
#       CountOutput_Max  CountOutput_Mean  MaxNesting_Mean  COMM  ADEV  \
# 9                   1          1.000000         0.000000     3     3
# 970                 4          3.500000         0.000000     3     3
# 1382                7          5.000000         0.000000     2     2
# 453                 9          5.000000         2.200000     2     2
# 885                 0          0.000000         0.000000     1     1
# ...               ...               ...              ...   ...   ...
# 1512                3          3.000000         0.000000     2     2
# 950                 2          2.000000         0.000000     2     2
# 1064                6          6.000000         0.000000     2     2
# 742                22          3.647059         0.651685     6     6
# 595                 1          0.600000         0.000000     3     3
#
#       Added_lines  OWN_LINE
# 9              74  0.945946
# 970           115  0.807018
# 1382          134  0.537313
# 453           144  0.625000
# 885            36  1.000000
# ...           ...       ...
# 1512           74  0.351351
# 950            70  0.685714
# 1064           88  0.545455
# 742          2334  0.775685
# 595           168  0.594595
#
# [1234 rows x 15 columns]

# %%
X_test = X_test.loc[:, rfe.support_]
X_test
# Out:
#       CountLine  CountLineComment  CountLineCodeExe  CountStmtDecl  \
# 1519        163                62                39             38
# 695          61                31                 7              9
# 913          46                22                 6             10
# 25          191                72                37             28
# 460         120                49                23             19
# ...         ...               ...               ...            ...
# 233         373               163                94             38
# 106         106                53                 9             16
# 1498         38                24                 1              4
# 736          38                30                 0              4
# 1276         98                25                20             19
#
#       CountLineCode  RatioCommentToCode  CountSemicolon  CountClassCoupled  \
# 1519             81                0.77              52                 18
# 695              21                1.48               9                  0
# 913              20                1.10               9                  3
# 25               98                0.73              35                  5
# 460              57                0.86              27                  4
# ...             ...                 ...             ...                ...
# 233             150                1.09              77                  1
# 106              40                1.32              16                  5
# 1498             10                2.40               3                  0
# 736               6                5.00               3                  1
# 1276             58                0.43              21                  3
#
#       CountOutput_Max  CountOutput_Mean  MaxNesting_Mean  COMM  ADEV  \
# 1519               17          6.000000         0.000000     2     2
# 695                 3          2.000000         0.750000     2     2
# 913                 2          2.000000         0.000000     2     2
# 25                  6          3.000000         0.692308     2     2
# 460                17          6.666667         1.200000     2     2
# ...               ...               ...              ...   ...   ...
# 233                 9          3.444444         1.583333     3     3
# 106                 3          1.428571         0.400000     4     4
# 1498                1          1.000000         0.000000     2     2
# 736                 1          1.000000         0.000000     2     2
# 1276                4          2.000000         0.272727     3     3
#
#       Added_lines  OWN_LINE
# 1519          326  0.674847
# 695           122  0.295082
# 913            92  1.000000
# 25            384  0.864583
# 460           240  0.816667
# ...           ...       ...
# 233           795  0.981233
# 106           213  0.783019
# 1498           38  1.000000
# 736            76  0.473684
# 1276          200  0.744898
#
# [529 rows x 15 columns]

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.941398865784499
# Precision :  0.7142857142857143
# Recall :  0.14705882352941177
# F1 Score :  0.24390243902439024
# AUC :  0.5715092097445038

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9376181474480151
# Precision :  1.0
# Recall :  0.029411764705882353
# F1 Score :  0.05714285714285715
# AUC :  0.5147058823529411

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9319470699432892
# Precision :  0.4
# Recall :  0.11764705882352941
# F1 Score :  0.1818181818181818
# AUC :  0.5527629233511587

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9130434782608695
# Precision :  0.3
# Recall :  0.2647058823529412
# F1 Score :  0.28125
# AUC :  0.6111408199643493

# %% [markdown]
# # MRMR 10

# %%
from sklearn.feature_selection import f_regression

F = pd.Series(f_regression(X, Y)[0], index = X.columns)
corr = X.corr().abs().clip(.00001)

# %%
selected = []
feat_score = []
not_selected = list(X.columns)

# %%
K = 10

for i in range(K):
    
    # compute FCQ score for all the (currently) excluded features (this is Formula 2)
    score = F.loc[not_selected] / corr.loc[not_selected, selected].mean(axis = 1).fillna(.00001)
    
    # find best feature, add it to selected and remove it from not_selected
    best = score.index[score.argmax()]
    selected.append(best)
    feat_score.append(score[best])
    not_selected.remove(best)

# %%
selected
# Out:
# ['COMM',
#  'CountPath_Min',
#  'CountOutput_Max',
#  'ADEV',
#  'CountStmtDecl',
#  'DDEV',
#  'CountClassCoupled',
#  'CountLineCodeDecl',
#  'MAJOR_COMMIT',
#  'MaxCyclomaticModified']

# %%
X_new = X[selected]
X_new
# Out:
#       COMM  CountPath_Min  CountOutput_Max  ADEV  CountStmtDecl  DDEV  \
# 0        6              1               11     6             35     3
# 1        2              1                3     2             34     2
# 2        3              1                3     3             27     3
# 3        2              1                6     2             14     2
# 4        2              1                4     2             15     2
# ...    ...            ...              ...   ...            ...   ...
# 1758     2              1                0     2              3     2
# 1759     2              1                5     2             17     2
# 1760     4              1                8     4             18     3
# 1761     2              1               17     2             52     2
# 1762     4              1                1     4              4     3
#
#       CountClassCoupled  CountLineCodeDecl  MAJOR_COMMIT  \
# 0                     6                 35             3
# 1                     7                 34             2
# 2                     5                 27             3
# 3                     1                 14             2
# 4                     1                 15             2
# ...                 ...                ...           ...
# 1758                  1                  3             2
# 1759                  2                 16             2
# 1760                  1                 19             3
# 1761                  3                 51             2
# 1762                  0                  4             3
#
#       MaxCyclomaticModified
# 0                         8
# 1                         3
# 2                         2
# 3                         2
# 4                         2
# ...                     ...
# 1758                      1
# 1759                      3
# 1760                      3
# 1761                      9
# 1762                      1
#
# [1763 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9357277882797732
# Precision :  0.5
# Recall :  0.20588235294117646
# F1 Score :  0.2916666666666667
# AUC :  0.5958704693998812

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9357277882797732
# Precision :  0.0
# Recall :  0.0
# F1 Score :  0.0
# AUC :  0.5
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9338374291115312
# Precision :  0.45454545454545453
# Recall :  0.14705882352941177
# F1 Score :  0.22222222222222224
# AUC :  0.5674688057040997

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9168241965973535
# Precision :  0.3076923076923077
# Recall :  0.23529411764705882
# F1 Score :  0.26666666666666666
# AUC :  0.5994652406417113

# %% [markdown]
# # MRMR 15

# %%
from sklearn.feature_selection import f_regression

F = pd.Series(f_regression(X, Y)[0], index = X.columns)
corr = X.corr().abs().clip(.00001)

# %%
selected = []
feat_score = []
not_selected = list(X.columns)

# %%
K = 15

for i in range(K):
    
    # compute FCQ score for all the (currently) excluded features (this is Formula 2)
    score = F.loc[not_selected] / corr.loc[not_selected, selected].mean(axis = 1).fillna(.00001)
    
    # find best feature, add it to selected and remove it from not_selected
    best = score.index[score.argmax()]
    selected.append(best)
    feat_score.append(score[best])
    not_selected.remove(best)

# %%
selected
# Out:
# ['COMM',
#  'CountPath_Min',
#  'CountOutput_Max',
#  'ADEV',
#  'CountStmtDecl',
#  'DDEV',
#  'CountClassCoupled',
#  'CountLineCodeDecl',
#  'MAJOR_COMMIT',
#  'MaxCyclomaticModified',
#  'Added_lines',
#  'CountLineCode',
#  'CountLineBlank',
#  'MaxCyclomatic',
#  'CountLineCodeExe']

# %%
X_new = X[selected]
X_new
# Out:
#       COMM  CountPath_Min  CountOutput_Max  ADEV  CountStmtDecl  DDEV  \
# 0        6              1               11     6             35     3
# 1        2              1                3     2             34     2
# 2        3              1                3     3             27     3
# 3        2              1                6     2             14     2
# 4        2              1                4     2             15     2
# ...    ...            ...              ...   ...            ...   ...
# 1758     2              1                0     2              3     2
# 1759     2              1                5     2             17     2
# 1760     4              1                8     4             18     3
# 1761     2              1               17     2             52     2
# 1762     4              1                1     4              4     3
#
#       CountClassCoupled  CountLineCodeDecl  MAJOR_COMMIT  \
# 0                     6                 35             3
# 1                     7                 34             2
# 2                     5                 27             3
# 3                     1                 14             2
# 4                     1                 15             2
# ...                 ...                ...           ...
# 1758                  1                  3             2
# 1759                  2                 16             2
# 1760                  1                 19             3
# 1761                  3                 51             2
# 1762                  0                  4             3
#
#       MaxCyclomaticModified  Added_lines  CountLineCode  CountLineBlank  \
# 0                         8          396            106              15
# 1                         3          546             94              22
# 2                         2          463             67              17
# 3                         2          210             30              10
# 4                         2          258             33               9
# ...                     ...          ...            ...             ...
# 1758                      1           70              3               2
# 1759                      3          168             34              14
# 1760                      3          204             40              11
# 1761                      9          532            142              35
# 1762                      1           75              6               4
#
#       MaxCyclomatic  CountLineCodeExe
# 0                 8                40
# 1                 3                24
# 2                 2                15
# 3                 2                 8
# 4                 2                 9
# ...             ...               ...
# 1758              1                 0
# 1759              3                13
# 1760              3                17
# 1761              9                83
# 1762              1                 0
#
# [1763 rows x 15 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9338374291115312
# Precision :  0.47058823529411764
# Recall :  0.23529411764705882
# F1 Score :  0.3137254901960785
# AUC :  0.6085561497326204

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9338374291115312
# Precision :  0.46153846153846156
# Recall :  0.17647058823529413
# F1 Score :  0.25531914893617025
# AUC :  0.58116458704694

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9357277882797732
# Precision :  0.0
# Recall :  0.0
# F1 Score :  0.0
# AUC :  0.5
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9338374291115312
# Precision :  0.46153846153846156
# Recall :  0.17647058823529413
# F1 Score :  0.25531914893617025
# AUC :  0.58116458704694

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9111531190926276
# Precision :  0.27586206896551724
# Recall :  0.23529411764705882
# F1 Score :  0.253968253968254
# AUC :  0.5964349376114082

# %% [markdown]
# # MRMR HFS

# %%
def HSF(df, df_train):
    
    from copy import deepcopy
    col_list = list(df_train.columns)
    print(col_list)
    d = df_train.shape[1]
    SF = []
    merit = [0 for i in range(d)]
    merit_archive = [0 for i in range(d)]
    Total_FS = [0 for i in range(d)]

    rel_CF = RHFS(df, d, col_list)

    max_value = max(rel_CF)
    Feature_max_index = rel_CF.index(max_value)

    n = 0

    SF.append(Feature_max_index)

    merit_archive[n] = deepcopy(max_value)

    Total_FS[n] = deepcopy(SF)

    while n < d-1:

        for i in range(d):

            red_FF = SHFS(SF, df_train, i, col_list,d)

            top = (d + d*(sum(rel_CF)/len(rel_CF)))
            bottom = (d + (d*(d-1)*(sum(red_FF)/len(red_FF))))**(1/2)
            merit[i] = top/bottom

        for val in SF:
            merit[val] = -9999999

        max_value = max(merit)
        Feature_max_index = merit.index(max_value)

        if Feature_max_index not in SF:
            SF.append(Feature_max_index)

        n += 1
        
        Total_FS[n] = deepcopy(SF)

        merit_archive[n] = max_value

    index_val = merit_archive.index(max(merit_archive))

    Feature_subset = Total_FS[index_val]

    subset_list = []

    for val in Feature_subset:
        subset_list.append(col_list[val])
    return subset_list


def RHFS(df, d, col_list):
    rel_CF = [0 for i in range(d)]
    count = 0

    igain = IG(X,df['class'])

    for m in  range(d):
        mu = df[col_list[m]].mean()

        n_1 = df[df['class'] == 0].count()[1]
        mu_1 = df[col_list[m]][df['class'] == 0].mean()
        var_1 = df[col_list[m]][df['class'] == 0].var()

        n_2 = df[df['class'] == 1].count()[1]
        mu_2 = df[col_list[m]][df['class'] == 1].mean()
        var_2 = df[col_list[m]][df['class'] == 1].var()

        inter_class = n_1*(mu_1-mu)**2 + n_2*(mu_2-mu)**2
        intra_class = (n_1-1)*var_1 + (n_2-1)*var_2

        fscore = inter_class / intra_class

        rel_CF[count] = (1/2)*(fscore + igain[m])
        count += 1
    
    return rel_CF

        
        

def IG(col_1, col_2):
    from sklearn.feature_selection import mutual_info_classif
    gain = mutual_info_classif(col_1,col_2)
    return gain   

def relief(col_1,col_2):
    pass



def SHFS(SF, df_train, i, col_list,d):
    from itertools import combinations
    from copy import deepcopy
    red_FF = []
    temp_SF = deepcopy(SF)
    if i not in SF:
        temp_SF.append(i)
        P_pairs = list(combinations(temp_SF,2))
        for pair in P_pairs:

            ied_value = (IED(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            pc_value = (PC(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            cs_value = (CS(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2

            red_FF.append((1/3)*(ied_value + pc_value + cs_value))
            # red_FF.append((1/2)*(pc_value + cs_value))
    else:
        red_FF = [0]
    return red_FF

def IED(col_1, col_2):
    import numpy as np
    dist = np.linalg.norm(col_1 - col_2)
    return 1/dist

def PC(col_1, col_2):
    from scipy.stats import pearsonr
    corr, _ = pearsonr(col_1 , col_2)
    return corr

def CS(col_1, col_2):
    from scipy import spatial
    similarity = 1 - spatial.distance.cosine(col_1, col_2)
    return similarity

# %%
FS = HSF(df, X)
FS
# Out:
# ['CountDeclMethodPrivate', 'AvgLineCode', 'CountLine', 'MaxCyclomatic', 'CountDeclMethodDefault', 'AvgEssential', 'CountDeclClassVariable', 'SumCyclomaticStrict', 'AvgCyclomatic', 'AvgLine', 'CountDeclClassMethod', 'AvgLineComment', 'AvgCyclomaticModified', 'CountDeclFunction', 'CountLineComment', 'CountDeclClass', 'CountDeclMethod', 'SumCyclomaticModified', 'CountLineCodeDecl', 'CountDeclMethodProtected', 'CountDeclInstanceVariable', 'MaxCyclomaticStrict', 'CountDeclMethodPublic', 'CountLineCodeExe', 'SumCyclomatic', 'SumEssential', 'CountStmtDecl', 'CountLineCode', 'CountStmtExe', 'RatioCommentToCode', 'CountLineBlank', 'CountStmt', 'MaxCyclomaticModified', 'CountSemicolon', 'AvgLineBlank', 'CountDeclInstanceMethod', 'AvgCyclomaticStrict', 'PercentLackOfCohesion', 'MaxInheritanceTree', 'CountClassDerived', 'CountClassCoupled', 'CountClassBase', 'CountInput_Max', 'CountInput_Mean', 'CountInput_Min', 'CountOutput_Max', 'CountOutput_Mean', 'CountOutput_Min', 'CountPath_Max', 'CountPath_Mean', 'CountPath_Min', 'MaxNesting_Max', 'MaxNesting_Mean', 'MaxNesting_Min', 'COMM', 'ADEV', 'DDEV', 'Added_lines', 'Del_lines', 'OWN_LINE', 'OWN_COMMIT', 'MINOR_COMMIT', 'MINOR_LINE', 'MAJOR_COMMIT', 'MAJOR_LINE']
# C:\Users\acer\AppData\Local\Temp\ipykernel_14468\2073211282.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1/dist
# ['ADEV', 'CountPath_Min', 'CountPath_Max']

# %%
X_new = X[FS]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9224952741020794
# Precision :  0.3157894736842105
# Recall :  0.17647058823529413
# F1 Score :  0.22641509433962262
# AUC :  0.575103980986334

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9357277882797732
# Precision :  0.0
# Recall :  0.0
# F1 Score :  0.0
# AUC :  0.5
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9357277882797732
# Precision :  0.5
# Recall :  0.08823529411764706
# F1 Score :  0.15
# AUC :  0.5410873440285204

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.943289224952741
# Precision :  0.75
# Recall :  0.17647058823529413
# F1 Score :  0.2857142857142857
# AUC :  0.586215092097445

# %% [markdown]
# # HFS NEW

# %%
def HSF(df, df_train):
    
    from copy import deepcopy
    col_list = list(df_train.columns)
    print(col_list)
    d = df_train.shape[1]
    SF = []
    merit = [0 for i in range(d)]
    merit_archive = [0 for i in range(d)]
    Total_FS = [0 for i in range(d)]

    rel_CF = RHFS(df, d, col_list)

    max_value = max(rel_CF)
    Feature_max_index = rel_CF.index(max_value)

    n = 0

    SF.append(Feature_max_index)

    merit_archive[n] = deepcopy(max_value)

    Total_FS[n] = deepcopy(SF)

    while n < d-1:

        for i in range(d):

            red_FF = SHFS(SF, df_train, i, col_list,d)

            top = (d + d*(sum(rel_CF)/len(rel_CF)))
            bottom = (d - (sum(red_FF)/len(red_FF)))**(1/2)

            merit[i] = top/bottom

        for val in SF:
            merit[val] = -9999999

        max_value = max(merit)
        Feature_max_index = merit.index(max_value)

        if Feature_max_index not in SF:
            SF.append(Feature_max_index)

        n += 1
        
        Total_FS[n] = deepcopy(SF)

        merit_archive[n] = max_value

    index_val = merit_archive.index(max(merit_archive))

    Feature_subset = Total_FS[index_val]

    subset_list = []

    for val in Feature_subset:
        subset_list.append(col_list[val])
    return subset_list


def RHFS(df, d, col_list):
    rel_CF = [0 for i in range(d)]
    count = 0

    igain = IG(X,df['class'])

    for m in  range(d):
        mu = df[col_list[m]].mean()

        n_1 = df[df['class'] == 0].count()[1]
        mu_1 = df[col_list[m]][df['class'] == 0].mean()
        var_1 = df[col_list[m]][df['class'] == 0].var()

        n_2 = df[df['class'] == 1].count()[1]
        mu_2 = df[col_list[m]][df['class'] == 1].mean()
        var_2 = df[col_list[m]][df['class'] == 1].var()

        inter_class = n_1*(mu_1-mu)**2 + n_2*(mu_2-mu)**2
        intra_class = (n_1-1)*var_1 + (n_2-1)*var_2

        fscore = inter_class / intra_class

        rel_CF[count] = (1/2)*(fscore + igain[m])
        count += 1
    
    return rel_CF

        
        

def IG(col_1, col_2):
    from sklearn.feature_selection import mutual_info_classif
    gain = mutual_info_classif(col_1,col_2)
    return gain   

def relief(col_1,col_2):
    pass



def SHFS(SF, df_train, i, col_list,d):
    from itertools import combinations
    from copy import deepcopy
    red_FF = []
    temp_SF = deepcopy(SF)
    if i not in SF:
        temp_SF.append(i)
        P_pairs = list(combinations(temp_SF,2))
        for pair in P_pairs:

            ied_value = (IED(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            pc_value = (PC(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            cs_value = (CS(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2

            red_FF.append((1/3)*(ied_value + pc_value + cs_value))
            # red_FF.append((1/2)*(pc_value + cs_value))
    else:
        red_FF = [0]
    return red_FF

def IED(col_1, col_2):
    import numpy as np
    dist = np.linalg.norm(col_1 - col_2)
    return 1/dist

def PC(col_1, col_2):
    from scipy.stats import pearsonr
    corr, _ = pearsonr(col_1 , col_2)
    return corr

def CS(col_1, col_2):
    from scipy import spatial
    similarity = 1 - spatial.distance.cosine(col_1, col_2)
    return similarity

# %%
FS = HSF(df, X)
FS
# Out:
# ['CountDeclMethodPrivate', 'AvgLineCode', 'CountLine', 'MaxCyclomatic', 'CountDeclMethodDefault', 'AvgEssential', 'CountDeclClassVariable', 'SumCyclomaticStrict', 'AvgCyclomatic', 'AvgLine', 'CountDeclClassMethod', 'AvgLineComment', 'AvgCyclomaticModified', 'CountDeclFunction', 'CountLineComment', 'CountDeclClass', 'CountDeclMethod', 'SumCyclomaticModified', 'CountLineCodeDecl', 'CountDeclMethodProtected', 'CountDeclInstanceVariable', 'MaxCyclomaticStrict', 'CountDeclMethodPublic', 'CountLineCodeExe', 'SumCyclomatic', 'SumEssential', 'CountStmtDecl', 'CountLineCode', 'CountStmtExe', 'RatioCommentToCode', 'CountLineBlank', 'CountStmt', 'MaxCyclomaticModified', 'CountSemicolon', 'AvgLineBlank', 'CountDeclInstanceMethod', 'AvgCyclomaticStrict', 'PercentLackOfCohesion', 'MaxInheritanceTree', 'CountClassDerived', 'CountClassCoupled', 'CountClassBase', 'CountInput_Max', 'CountInput_Mean', 'CountInput_Min', 'CountOutput_Max', 'CountOutput_Mean', 'CountOutput_Min', 'CountPath_Max', 'CountPath_Mean', 'CountPath_Min', 'MaxNesting_Max', 'MaxNesting_Mean', 'MaxNesting_Min', 'COMM', 'ADEV', 'DDEV', 'Added_lines', 'Del_lines', 'OWN_LINE', 'OWN_COMMIT', 'MINOR_COMMIT', 'MINOR_LINE', 'MAJOR_COMMIT', 'MAJOR_LINE']
# C:\Users\acer\AppData\Local\Temp\ipykernel_14468\4067302685.py:125: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1/dist
# ['ADEV', 'DDEV', 'MAJOR_COMMIT']

# %%
X_new = X[FS]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9300567107750473
# Precision :  0.2857142857142857
# Recall :  0.058823529411764705
# F1 Score :  0.0975609756097561
# AUC :  0.5243612596553773

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9395085066162571
# Precision :  1.0
# Recall :  0.058823529411764705
# F1 Score :  0.1111111111111111
# AUC :  0.5294117647058824

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9357277882797732
# Precision :  0.5
# Recall :  0.08823529411764706
# F1 Score :  0.15
# AUC :  0.5410873440285204

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.9224952741020794
# Precision :  0.3793103448275862
# Recall :  0.3235294117647059
# F1 Score :  0.3492063492063492
# AUC :  0.6435828877005347
