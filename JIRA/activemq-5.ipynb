# %%
import pandas as pd

# %%
df = pd.read_csv('activemq-5.csv')
df
# Out:
#         id  CountDeclMethodPrivate  AvgLineCode  CountLine  MaxCyclomatic  \
# 0        1                       0           10        171              5
# 1        2                       0            8        123              5
# 2        3                       0            7        136              5
# 3        4                       0           29        241             17
# 4        5                       0           24        212             17
# ...    ...                     ...          ...        ...            ...
# 1879  1880                       0            5        215              6
# 1880  1881                       0            9        108              7
# 1881  1882                       0            9        180              8
# 1882  1883                       0            6         80              7
# 1883  1884                       0            9         64              4
#
#       CountDeclMethodDefault  AvgEssential  CountDeclClassVariable  \
# 0                          0             2                       0
# 1                          0             1                       1
# 2                          0             1                       1
# 3                          0             4                       5
# 4                          0             3                       5
# ...                      ...           ...                     ...
# 1879                       0             1                       0
# 1880                       0             1                       0
# 1881                       0             1                       0
# 1882                       0             1                       0
# 1883                       0             1                       0
#
#       SumCyclomaticStrict  AvgCyclomatic  ...  DDEV  Added_lines  Del_lines  \
# 0                      18              2  ...     1           32         18
# 1                      15              3  ...     2           30         28
# 2                      16              2  ...     1            8          8
# 3                      29              9  ...     1           76         76
# 4                      26              8  ...     1           76         76
# ...                   ...            ...  ...   ...          ...        ...
# 1879                   35              1  ...     2           25         41
# 1880                   16              3  ...     1           12         16
# 1881                   30              2  ...     2           16         19
# 1882                   13              2  ...     1            5          8
# 1883                    7              2  ...     1            7         11
#
#       OWN_LINE  OWN_COMMIT  MINOR_COMMIT  MINOR_LINE  MAJOR_COMMIT  \
# 0     1.000000    1.000000             0           1             1
# 1     0.983740    0.500000             0           1             2
# 2     1.000000    1.000000             0           1             1
# 3     1.000000    1.000000             0           1             1
# 4     1.000000    1.000000             0           1             1
# ...        ...         ...           ...         ...           ...
# 1879  0.846512    0.666667             0           2             2
# 1880  0.814815    1.000000             0           2             1
# 1881  0.866667    0.666667             0           2             2
# 1882  0.837500    1.000000             0           2             1
# 1883  0.750000    1.000000             0           2             1
#
#       MAJOR_LINE  RealBugCount
# 0              0             0
# 1              1             0
# 2              0             0
# 3              0             0
# 4              0             0
# ...          ...           ...
# 1879           1             1
# 1880           1             0
# 1881           2             1
# 1882           1             0
# 1883           1             0
#
# [1884 rows x 67 columns]

# %%
df.drop(['id'], axis=1, inplace=True)

# %%
df['RealBugCount'].unique()
# Out:
# array([ 0,  1,  2,  4, 10,  6,  8,  5,  9,  7, 14, 26,  3, 11],
#       dtype=int64)

# %%
df['RealBugCount'].replace([2,  4, 10,  6,  8,  5,  9,  7, 14, 26,  3, 11], 1, inplace=True)
df['RealBugCount'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df = df.rename({'RealBugCount':'class'}, axis=1)
df
# Out:
#       CountDeclMethodPrivate  AvgLineCode  CountLine  MaxCyclomatic  \
# 0                          0           10        171              5
# 1                          0            8        123              5
# 2                          0            7        136              5
# 3                          0           29        241             17
# 4                          0           24        212             17
# ...                      ...          ...        ...            ...
# 1879                       0            5        215              6
# 1880                       0            9        108              7
# 1881                       0            9        180              8
# 1882                       0            6         80              7
# 1883                       0            9         64              4
#
#       CountDeclMethodDefault  AvgEssential  CountDeclClassVariable  \
# 0                          0             2                       0
# 1                          0             1                       1
# 2                          0             1                       1
# 3                          0             4                       5
# 4                          0             3                       5
# ...                      ...           ...                     ...
# 1879                       0             1                       0
# 1880                       0             1                       0
# 1881                       0             1                       0
# 1882                       0             1                       0
# 1883                       0             1                       0
#
#       SumCyclomaticStrict  AvgCyclomatic  AvgLine  ...  DDEV  Added_lines  \
# 0                      18              2       18  ...     1           32
# 1                      15              3       17  ...     2           30
# 2                      16              2       13  ...     1            8
# 3                      29              9       53  ...     1           76
# 4                      26              8       44  ...     1           76
# ...                   ...            ...      ...  ...   ...          ...
# 1879                   35              1        5  ...     2           25
# 1880                   16              3       11  ...     1           12
# 1881                   30              2       10  ...     2           16
# 1882                   13              2        6  ...     1            5
# 1883                    7              2        9  ...     1            7
#
#       Del_lines  OWN_LINE  OWN_COMMIT  MINOR_COMMIT  MINOR_LINE  MAJOR_COMMIT  \
# 0            18  1.000000    1.000000             0           1             1
# 1            28  0.983740    0.500000             0           1             2
# 2             8  1.000000    1.000000             0           1             1
# 3            76  1.000000    1.000000             0           1             1
# 4            76  1.000000    1.000000             0           1             1
# ...         ...       ...         ...           ...         ...           ...
# 1879         41  0.846512    0.666667             0           2             2
# 1880         16  0.814815    1.000000             0           2             1
# 1881         19  0.866667    0.666667             0           2             2
# 1882          8  0.837500    1.000000             0           2             1
# 1883         11  0.750000    1.000000             0           2             1
#
#       MAJOR_LINE  class
# 0              0      0
# 1              1      0
# 2              0      0
# 3              0      0
# 4              0      0
# ...          ...    ...
# 1879           1      1
# 1880           1      0
# 1881           2      1
# 1882           1      0
# 1883           1      0
#
# [1884 rows x 66 columns]

# %%
df[df['class'] == 0]
# Out:
#       CountDeclMethodPrivate  AvgLineCode  CountLine  MaxCyclomatic  \
# 0                          0           10        171              5
# 1                          0            8        123              5
# 2                          0            7        136              5
# 3                          0           29        241             17
# 4                          0           24        212             17
# ...                      ...          ...        ...            ...
# 1877                       1           11        118              7
# 1878                       4            7        205              4
# 1880                       0            9        108              7
# 1882                       0            6         80              7
# 1883                       0            9         64              4
#
#       CountDeclMethodDefault  AvgEssential  CountDeclClassVariable  \
# 0                          0             2                       0
# 1                          0             1                       1
# 2                          0             1                       1
# 3                          0             4                       5
# 4                          0             3                       5
# ...                      ...           ...                     ...
# 1877                       0             1                       0
# 1878                       4             1                       1
# 1880                       0             1                       0
# 1882                       0             1                       0
# 1883                       0             1                       0
#
#       SumCyclomaticStrict  AvgCyclomatic  AvgLine  ...  DDEV  Added_lines  \
# 0                      18              2       18  ...     1           32
# 1                      15              3       17  ...     2           30
# 2                      16              2       13  ...     1            8
# 3                      29              9       53  ...     1           76
# 4                      26              8       44  ...     1           76
# ...                   ...            ...      ...  ...   ...          ...
# 1877                   14              3       13  ...     2           81
# 1878                   30              2        8  ...     2          109
# 1880                   16              3       11  ...     1           12
# 1882                   13              2        6  ...     1            5
# 1883                    7              2        9  ...     1            7
#
#       Del_lines  OWN_LINE  OWN_COMMIT  MINOR_COMMIT  MINOR_LINE  MAJOR_COMMIT  \
# 0            18  1.000000    1.000000             0           1             1
# 1            28  0.983740    0.500000             0           1             2
# 2             8  1.000000    1.000000             0           1             1
# 3            76  1.000000    1.000000             0           1             1
# 4            76  1.000000    1.000000             0           1             1
# ...         ...       ...         ...           ...         ...           ...
# 1877         86  1.000000    0.666667             0           1             2
# 1878        118  1.000000    0.666667             0           1             2
# 1880         16  0.814815    1.000000             0           2             1
# 1882          8  0.837500    1.000000             0           2             1
# 1883         11  0.750000    1.000000             0           2             1
#
#       MAJOR_LINE  class
# 0              0      0
# 1              1      0
# 2              0      0
# 3              0      0
# 4              0      0
# ...          ...    ...
# 1877           0      0
# 1878           0      0
# 1880           1      0
# 1882           1      0
# 1883           1      0
#
# [1591 rows x 66 columns]

# %%
X = df.drop(['class'], axis=1)
X
# Out:
#       CountDeclMethodPrivate  AvgLineCode  CountLine  MaxCyclomatic  \
# 0                          0           10        171              5
# 1                          0            8        123              5
# 2                          0            7        136              5
# 3                          0           29        241             17
# 4                          0           24        212             17
# ...                      ...          ...        ...            ...
# 1879                       0            5        215              6
# 1880                       0            9        108              7
# 1881                       0            9        180              8
# 1882                       0            6         80              7
# 1883                       0            9         64              4
#
#       CountDeclMethodDefault  AvgEssential  CountDeclClassVariable  \
# 0                          0             2                       0
# 1                          0             1                       1
# 2                          0             1                       1
# 3                          0             4                       5
# 4                          0             3                       5
# ...                      ...           ...                     ...
# 1879                       0             1                       0
# 1880                       0             1                       0
# 1881                       0             1                       0
# 1882                       0             1                       0
# 1883                       0             1                       0
#
#       SumCyclomaticStrict  AvgCyclomatic  AvgLine  ...  ADEV  DDEV  \
# 0                      18              2       18  ...     1     1
# 1                      15              3       17  ...     2     2
# 2                      16              2       13  ...     1     1
# 3                      29              9       53  ...     1     1
# 4                      26              8       44  ...     1     1
# ...                   ...            ...      ...  ...   ...   ...
# 1879                   35              1        5  ...     3     2
# 1880                   16              3       11  ...     2     1
# 1881                   30              2       10  ...     3     2
# 1882                   13              2        6  ...     2     1
# 1883                    7              2        9  ...     2     1
#
#       Added_lines  Del_lines  OWN_LINE  OWN_COMMIT  MINOR_COMMIT  MINOR_LINE  \
# 0              32         18  1.000000    1.000000             0           1
# 1              30         28  0.983740    0.500000             0           1
# 2               8          8  1.000000    1.000000             0           1
# 3              76         76  1.000000    1.000000             0           1
# 4              76         76  1.000000    1.000000             0           1
# ...           ...        ...       ...         ...           ...         ...
# 1879           25         41  0.846512    0.666667             0           2
# 1880           12         16  0.814815    1.000000             0           2
# 1881           16         19  0.866667    0.666667             0           2
# 1882            5          8  0.837500    1.000000             0           2
# 1883            7         11  0.750000    1.000000             0           2
#
#       MAJOR_COMMIT  MAJOR_LINE
# 0                1           0
# 1                2           1
# 2                1           0
# 3                1           0
# 4                1           0
# ...            ...         ...
# 1879             2           1
# 1880             1           1
# 1881             2           2
# 1882             1           1
# 1883             1           1
#
# [1884 rows x 65 columns]

# %%
Y = df['class']
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1879    1
# 1880    0
# 1881    1
# 1882    0
# 1883    0
# Name: class, Length: 1884, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import *

# %% [markdown]
# # All Features

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.833922261484099
# Precision :  0.6666666666666666
# Recall :  0.021052631578947368
# F1 Score :  0.04081632653061225
# AUC :  0.5094647446642083

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.833922261484099
# Precision :  0.6666666666666666
# Recall :  0.021052631578947368
# F1 Score :  0.04081632653061225
# AUC :  0.5094647446642083

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.833922261484099
# Precision :  0.5084745762711864
# Recall :  0.3157894736842105
# F1 Score :  0.38961038961038963
# AUC :  0.6271091742094089

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8162544169611308
# Precision :  0.449438202247191
# Recall :  0.42105263157894735
# F1 Score :  0.43478260869565216
# AUC :  0.6585093306514694

# %% [markdown]
# # PEARSON CORRELATION

# %%
cor = df.corr()
cor_target = abs(cor['class'])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.5]
relevant_features
# Out:
# DDEV            0.558552
# OWN_COMMIT      0.536354
# MAJOR_COMMIT    0.557679
# class           1.000000
# Name: class, dtype: float64

# %%
X_new = df[['DDEV', 'OWN_COMMIT', 'MAJOR_COMMIT']]
X_new
# Out:
#       DDEV  OWN_COMMIT  MAJOR_COMMIT
# 0        1    1.000000             1
# 1        2    0.500000             2
# 2        1    1.000000             1
# 3        1    1.000000             1
# 4        1    1.000000             1
# ...    ...         ...           ...
# 1879     2    0.666667             2
# 1880     1    1.000000             1
# 1881     2    0.666667             2
# 1882     1    1.000000             1
# 1883     1    1.000000             1
#
# [1884 rows x 3 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8409893992932862
# Precision :  0.5510204081632653
# Recall :  0.28421052631578947
# F1 Score :  0.375
# AUC :  0.6187506984020561

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8621908127208481
# Precision :  0.5726495726495726
# Recall :  0.7052631578947368
# F1 Score :  0.6320754716981132
# AUC :  0.7995530226840988

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8551236749116607
# Precision :  0.5942028985507246
# Recall :  0.43157894736842106
# F1 Score :  0.5
# AUC :  0.6860654821767795

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8621908127208481
# Precision :  0.5726495726495726
# Recall :  0.7052631578947368
# F1 Score :  0.6320754716981132
# AUC :  0.7995530226840988

# %% [markdown]
# # INFORMATION GAIN 10

# %%
from sklearn.feature_selection import mutual_info_classif
gain = mutual_info_classif(X,Y)
gain
# Out:
# array([0.03302383, 0.02369062, 0.09383593, 0.06654321, 0.        ,
#        0.00980968, 0.00770961, 0.09857885, 0.03386353, 0.01072747,
#        0.00499083, 0.02176305, 0.02853349, 0.07145416, 0.04861905,
#        0.0240998 , 0.06075636, 0.08095461, 0.09678595, 0.0240418 ,
#        0.05008176, 0.05268458, 0.05858647, 0.09081955, 0.09292974,
#        0.09209236, 0.09976837, 0.09728847, 0.08390034, 0.05428433,
#        0.06519473, 0.08502219, 0.05378635, 0.08465813, 0.012733  ,
#        0.07887456, 0.03294043, 0.02945019, 0.00406302, 0.00252153,
#        0.06242195, 0.02596142, 0.0293904 , 0.05575825, 0.        ,
#        0.06354297, 0.0592114 , 0.        , 0.05553652, 0.05459762,
#        0.01299619, 0.0603152 , 0.05637733, 0.00194851, 0.10747257,
#        0.10814189, 0.12863667, 0.1070533 , 0.09478333, 0.02523354,
#        0.13706166, 0.        , 0.01919622, 0.12623798, 0.01148641])

# %%
col_list = X.columns
col_list
# Out:
# Index(['CountDeclMethodPrivate', 'AvgLineCode', 'CountLine', 'MaxCyclomatic',
#        'CountDeclMethodDefault', 'AvgEssential', 'CountDeclClassVariable',
#        'SumCyclomaticStrict', 'AvgCyclomatic', 'AvgLine',
#        'CountDeclClassMethod', 'AvgLineComment', 'AvgCyclomaticModified',
#        'CountDeclFunction', 'CountLineComment', 'CountDeclClass',
#        'CountDeclMethod', 'SumCyclomaticModified', 'CountLineCodeDecl',
#        'CountDeclMethodProtected', 'CountDeclInstanceVariable',
#        'MaxCyclomaticStrict', 'CountDeclMethodPublic', 'CountLineCodeExe',
#        'SumCyclomatic', 'SumEssential', 'CountStmtDecl', 'CountLineCode',
#        'CountStmtExe', 'RatioCommentToCode', 'CountLineBlank', 'CountStmt',
#        'MaxCyclomaticModified', 'CountSemicolon', 'AvgLineBlank',
#        'CountDeclInstanceMethod', 'AvgCyclomaticStrict',
#        'PercentLackOfCohesion', 'MaxInheritanceTree', 'CountClassDerived',
#        'CountClassCoupled', 'CountClassBase', 'CountInput_Max',
#        'CountInput_Mean', 'CountInput_Min', 'CountOutput_Max',
#        'CountOutput_Mean', 'CountOutput_Min', 'CountPath_Max',
#        'CountPath_Mean', 'CountPath_Min', 'MaxNesting_Max', 'MaxNesting_Mean',
#        'MaxNesting_Min', 'COMM', 'ADEV', 'DDEV', 'Added_lines', 'Del_lines',
#        'OWN_LINE', 'OWN_COMMIT', 'MINOR_COMMIT', 'MINOR_LINE', 'MAJOR_COMMIT',
#        'MAJOR_LINE'],
#       dtype='object')

# %%
temp = pd.DataFrame(list(zip(col_list, gain)), columns =['col', 'score']) 
temp
# Out:
#                        col     score
# 0   CountDeclMethodPrivate  0.033024
# 1              AvgLineCode  0.023691
# 2                CountLine  0.093836
# 3            MaxCyclomatic  0.066543
# 4   CountDeclMethodDefault  0.000000
# ..                     ...       ...
# 60              OWN_COMMIT  0.137062
# 61            MINOR_COMMIT  0.000000
# 62              MINOR_LINE  0.019196
# 63            MAJOR_COMMIT  0.126238
# 64              MAJOR_LINE  0.011486
#
# [65 rows x 2 columns]

# %%
temp_sort = temp.sort_values(['score'], ascending=False)
temp_sort[:10]
# Out:
#                     col     score
# 60           OWN_COMMIT  0.137062
# 56                 DDEV  0.128637
# 63         MAJOR_COMMIT  0.126238
# 55                 ADEV  0.108142
# 54                 COMM  0.107473
# 57          Added_lines  0.107053
# 26        CountStmtDecl  0.099768
# 7   SumCyclomaticStrict  0.098579
# 27        CountLineCode  0.097288
# 18    CountLineCodeDecl  0.096786

# %%
FS = list(temp_sort['col'][:10])
FS
# Out:
# ['OWN_COMMIT',
#  'DDEV',
#  'MAJOR_COMMIT',
#  'ADEV',
#  'COMM',
#  'Added_lines',
#  'CountStmtDecl',
#  'SumCyclomaticStrict',
#  'CountLineCode',
#  'CountLineCodeDecl']

# %%
X_new = df[FS]
X_new
# Out:
#       OWN_COMMIT  DDEV  MAJOR_COMMIT  ADEV  COMM  Added_lines  CountStmtDecl  \
# 0       1.000000     1             1     1     1           32             26
# 1       0.500000     2             2     2     2           30             17
# 2       1.000000     1             1     1     1            8             20
# 3       1.000000     1             1     1     1           76             36
# 4       1.000000     1             1     1     1           76             34
# ...          ...   ...           ...   ...   ...          ...            ...
# 1879    0.666667     2             2     3     3           25             62
# 1880    1.000000     1             1     2     2           12             22
# 1881    0.666667     2             2     3     3           16             45
# 1882    1.000000     1             1     2     2            5             11
# 1883    1.000000     1             1     2     2            7             14
#
#       SumCyclomaticStrict  CountLineCode  CountLineCodeDecl
# 0                      18             88                 25
# 1                      15             53                 17
# 2                      16             65                 20
# 3                      29            143                 36
# 4                      26            126                 33
# ...                   ...            ...                ...
# 1879                   35            153                 61
# 1880                   16             68                 21
# 1881                   30            130                 41
# 1882                   13             51                 11
# 1883                    7             37                 14
#
# [1884 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8780918727915195
# Precision :  0.7241379310344828
# Recall :  0.4421052631578947
# F1 Score :  0.5490196078431373
# AUC :  0.7040674935747011

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8409893992932862
# Precision :  0.5609756097560976
# Recall :  0.24210526315789474
# F1 Score :  0.3382352941176471
# AUC :  0.6019443513241703

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8321554770318021
# Precision :  0.5
# Recall :  0.3473684210526316
# F1 Score :  0.4099378881987578
# AUC :  0.6386523633925578

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8445229681978799
# Precision :  0.5304347826086957
# Recall :  0.6421052631578947
# F1 Score :  0.580952380952381
# AUC :  0.7637277908146162

# %% [markdown]
# # INFORMATION GAIN 15

# %%
from sklearn.feature_selection import mutual_info_classif
gain = mutual_info_classif(X,Y)
gain
# Out:
# array([0.02751512, 0.04323811, 0.09744891, 0.06020235, 0.00550236,
#        0.01245084, 0.01627885, 0.09898542, 0.04113495, 0.03882886,
#        0.00347882, 0.01410233, 0.0429657 , 0.08389302, 0.04100743,
#        0.02621989, 0.0625558 , 0.08514634, 0.09218082, 0.02638469,
#        0.04665414, 0.07117395, 0.0604009 , 0.07839086, 0.09071309,
#        0.08734146, 0.09737916, 0.08939184, 0.08651827, 0.06651783,
#        0.07484651, 0.09628881, 0.06851995, 0.09158991, 0.        ,
#        0.06703902, 0.02022088, 0.03954924, 0.0033395 , 0.01360842,
#        0.06235067, 0.01700291, 0.03263899, 0.05865785, 0.01499391,
#        0.05693177, 0.05423206, 0.00402896, 0.06314991, 0.04381227,
#        0.01001721, 0.0558647 , 0.05746635, 0.0003817 , 0.10317722,
#        0.11455448, 0.13537447, 0.10652447, 0.09075732, 0.02161832,
#        0.13286306, 0.00489357, 0.01100249, 0.12775065, 0.02117754])

# %%
col_list = X.columns
col_list
# Out:
# Index(['CountDeclMethodPrivate', 'AvgLineCode', 'CountLine', 'MaxCyclomatic',
#        'CountDeclMethodDefault', 'AvgEssential', 'CountDeclClassVariable',
#        'SumCyclomaticStrict', 'AvgCyclomatic', 'AvgLine',
#        'CountDeclClassMethod', 'AvgLineComment', 'AvgCyclomaticModified',
#        'CountDeclFunction', 'CountLineComment', 'CountDeclClass',
#        'CountDeclMethod', 'SumCyclomaticModified', 'CountLineCodeDecl',
#        'CountDeclMethodProtected', 'CountDeclInstanceVariable',
#        'MaxCyclomaticStrict', 'CountDeclMethodPublic', 'CountLineCodeExe',
#        'SumCyclomatic', 'SumEssential', 'CountStmtDecl', 'CountLineCode',
#        'CountStmtExe', 'RatioCommentToCode', 'CountLineBlank', 'CountStmt',
#        'MaxCyclomaticModified', 'CountSemicolon', 'AvgLineBlank',
#        'CountDeclInstanceMethod', 'AvgCyclomaticStrict',
#        'PercentLackOfCohesion', 'MaxInheritanceTree', 'CountClassDerived',
#        'CountClassCoupled', 'CountClassBase', 'CountInput_Max',
#        'CountInput_Mean', 'CountInput_Min', 'CountOutput_Max',
#        'CountOutput_Mean', 'CountOutput_Min', 'CountPath_Max',
#        'CountPath_Mean', 'CountPath_Min', 'MaxNesting_Max', 'MaxNesting_Mean',
#        'MaxNesting_Min', 'COMM', 'ADEV', 'DDEV', 'Added_lines', 'Del_lines',
#        'OWN_LINE', 'OWN_COMMIT', 'MINOR_COMMIT', 'MINOR_LINE', 'MAJOR_COMMIT',
#        'MAJOR_LINE'],
#       dtype='object')

# %%
temp = pd.DataFrame(list(zip(col_list, gain)), columns =['col', 'score']) 
temp
# Out:
#                        col     score
# 0   CountDeclMethodPrivate  0.027515
# 1              AvgLineCode  0.043238
# 2                CountLine  0.097449
# 3            MaxCyclomatic  0.060202
# 4   CountDeclMethodDefault  0.005502
# ..                     ...       ...
# 60              OWN_COMMIT  0.132863
# 61            MINOR_COMMIT  0.004894
# 62              MINOR_LINE  0.011002
# 63            MAJOR_COMMIT  0.127751
# 64              MAJOR_LINE  0.021178
#
# [65 rows x 2 columns]

# %%
temp_sort = temp.sort_values(['score'], ascending=False)
temp_sort[:15]
# Out:
#                     col     score
# 56                 DDEV  0.135374
# 60           OWN_COMMIT  0.132863
# 63         MAJOR_COMMIT  0.127751
# 55                 ADEV  0.114554
# 57          Added_lines  0.106524
# 54                 COMM  0.103177
# 7   SumCyclomaticStrict  0.098985
# 2             CountLine  0.097449
# 26        CountStmtDecl  0.097379
# 31            CountStmt  0.096289
# 18    CountLineCodeDecl  0.092181
# 33       CountSemicolon  0.091590
# 58            Del_lines  0.090757
# 24        SumCyclomatic  0.090713
# 27        CountLineCode  0.089392

# %%
FS = list(temp_sort['col'][:15])
FS
# Out:
# ['DDEV',
#  'OWN_COMMIT',
#  'MAJOR_COMMIT',
#  'ADEV',
#  'Added_lines',
#  'COMM',
#  'SumCyclomaticStrict',
#  'CountLine',
#  'CountStmtDecl',
#  'CountStmt',
#  'CountLineCodeDecl',
#  'CountSemicolon',
#  'Del_lines',
#  'SumCyclomatic',
#  'CountLineCode']

# %%
X_new = df[FS]
X_new
# Out:
#       DDEV  OWN_COMMIT  MAJOR_COMMIT  ADEV  Added_lines  COMM  \
# 0        1    1.000000             1     1           32     1
# 1        2    0.500000             2     2           30     2
# 2        1    1.000000             1     1            8     1
# 3        1    1.000000             1     1           76     1
# 4        1    1.000000             1     1           76     1
# ...    ...         ...           ...   ...          ...   ...
# 1879     2    0.666667             2     3           25     3
# 1880     1    1.000000             1     2           12     2
# 1881     2    0.666667             2     3           16     3
# 1882     1    1.000000             1     2            5     2
# 1883     1    1.000000             1     2            7     2
#
#       SumCyclomaticStrict  CountLine  CountStmtDecl  CountStmt  \
# 0                      18        171             26         63
# 1                      15        123             17         41
# 2                      16        136             20         46
# 3                      29        241             36         90
# 4                      26        212             34         78
# ...                   ...        ...            ...        ...
# 1879                   35        215             62        114
# 1880                   16        108             22         51
# 1881                   30        180             45        102
# 1882                   13         80             11         36
# 1883                    7         64             14         27
#
#       CountLineCodeDecl  CountSemicolon  Del_lines  SumCyclomatic  \
# 0                    25              46         18             17
# 1                    17              29         28             13
# 2                    20              30          8             15
# 3                    36              64         76             26
# 4                    33              56         76             23
# ...                 ...             ...        ...            ...
# 1879                 61              79         41             34
# 1880                 21              35         16             15
# 1881                 41              71         19             30
# 1882                 11              22          8             13
# 1883                 14              19         11              7
#
#       CountLineCode
# 0                88
# 1                53
# 2                65
# 3               143
# 4               126
# ...             ...
# 1879            153
# 1880             68
# 1881            130
# 1882             51
# 1883             37
#
# [1884 rows x 15 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8780918727915195
# Precision :  0.7096774193548387
# Recall :  0.4631578947368421
# F1 Score :  0.5605095541401275
# AUC :  0.712470667113644

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.842756183745583
# Precision :  0.575
# Recall :  0.24210526315789474
# F1 Score :  0.34074074074074073
# AUC :  0.6030059224494357

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.842756183745583
# Precision :  0.55
# Recall :  0.3473684210526316
# F1 Score :  0.42580645161290326
# AUC :  0.6450217901441502

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8374558303886925
# Precision :  0.5176470588235295
# Recall :  0.4631578947368421
# F1 Score :  0.48888888888888893
# AUC :  0.68805453123254

# %% [markdown]
# # FISHER SCORE

# %%
FScore = []

for m in  range(len(col_list)):
        mu = df[col_list[m]].mean()

        n_1 = df[df['class'] == 0].count()[1]
        mu_1 = df[col_list[m]][df['class'] == 0].mean()
        var_1 = df[col_list[m]][df['class'] == 0].var()

        n_2 = df[df['class'] == 1].count()[1]
        mu_2 = df[col_list[m]][df['class'] == 1].mean()
        var_2 = df[col_list[m]][df['class'] == 1].var()

        inter_class = n_1*(mu_1-mu)**2 + n_2*(mu_2-mu)**2
        intra_class = (n_1-1)*var_1 + (n_2-1)*var_2

        FScore.append(inter_class / intra_class)

FScore
# Out:
# [0.04865100658847161,
#  0.01579110657433678,
#  0.2065324756040901,
#  0.10831289792788197,
#  0.009698112319002682,
#  0.008586358607243888,
#  0.02737082059234866,
#  0.23032565732814095,
#  0.030110354545708568,
#  0.009695575452795273,
#  0.0071411458454540295,
#  4.425648706917297e-06,
#  0.03053491207028976,
#  0.1971569513245595,
#  0.04823088962096352,
#  0.05658320951051594,
#  0.19687121879483133,
#  0.22900128618631962,
#  0.2500968153754289,
#  0.04850867521926162,
#  0.09667227798345383,
#  0.110338918617483,
#  0.13943644332698385,
#  0.1843269294063831,
#  0.22893976961148868,
#  0.2135719214303484,
#  0.253015672143984,
#  0.22836998446112405,
#  0.1831597521146032,
#  0.030919221142953687,
#  0.1573402719826417,
#  0.2247383806998949,
#  0.10965411435686538,
#  0.20682942909098015,
#  4.0836156056469945e-05,
#  0.18755093963111277,
#  0.029886450298755907,
#  0.029483082283609026,
#  0.011269183374079303,
#  0.002999857498440042,
#  0.1502487211207216,
#  0.05583494743341838,
#  0.03527962157392301,
#  0.005727459441929157,
#  0.0005548090169853941,
#  0.13897274921167732,
#  0.009295047222493736,
#  0.0017575472615263563,
#  9.314735178888576e-06,
#  0.0001214682850428515,
#  0.00019561676927115794,
#  0.13417198423390872,
#  0.0498444312631196,
#  0.0005891480659006255,
#  0.31144628723877144,
#  0.31144628723877144,
#  0.45344734205692677,
#  0.1817163939713277,
#  0.16074181549655747,
#  0.024075823888708842,
#  0.4038548347766573,
#  0.0028920542128377407,
#  0.012901719968194345,
#  0.4513908535111848,
#  0.07160830551792885]

# %%
temp = pd.DataFrame(list(zip(col_list, FScore)), columns =['col', 'score']) 
temp
# Out:
#                        col     score
# 0   CountDeclMethodPrivate  0.048651
# 1              AvgLineCode  0.015791
# 2                CountLine  0.206532
# 3            MaxCyclomatic  0.108313
# 4   CountDeclMethodDefault  0.009698
# ..                     ...       ...
# 60              OWN_COMMIT  0.403855
# 61            MINOR_COMMIT  0.002892
# 62              MINOR_LINE  0.012902
# 63            MAJOR_COMMIT  0.451391
# 64              MAJOR_LINE  0.071608
#
# [65 rows x 2 columns]

# %%
temp_sort = temp.sort_values(['score'], ascending=False)
temp_sort[:10]
# Out:
#                       col     score
# 56                   DDEV  0.453447
# 63           MAJOR_COMMIT  0.451391
# 60             OWN_COMMIT  0.403855
# 54                   COMM  0.311446
# 55                   ADEV  0.311446
# 26          CountStmtDecl  0.253016
# 18      CountLineCodeDecl  0.250097
# 7     SumCyclomaticStrict  0.230326
# 17  SumCyclomaticModified  0.229001
# 24          SumCyclomatic  0.228940

# %%
FS = list(temp_sort['col'][:10])
FS
# Out:
# ['DDEV',
#  'MAJOR_COMMIT',
#  'OWN_COMMIT',
#  'COMM',
#  'ADEV',
#  'CountStmtDecl',
#  'CountLineCodeDecl',
#  'SumCyclomaticStrict',
#  'SumCyclomaticModified',
#  'SumCyclomatic']

# %%
X_new = df[FS]
X_new
# Out:
#       DDEV  MAJOR_COMMIT  OWN_COMMIT  COMM  ADEV  CountStmtDecl  \
# 0        1             1    1.000000     1     1             26
# 1        2             2    0.500000     2     2             17
# 2        1             1    1.000000     1     1             20
# 3        1             1    1.000000     1     1             36
# 4        1             1    1.000000     1     1             34
# ...    ...           ...         ...   ...   ...            ...
# 1879     2             2    0.666667     3     3             62
# 1880     1             1    1.000000     2     2             22
# 1881     2             2    0.666667     3     3             45
# 1882     1             1    1.000000     2     2             11
# 1883     1             1    1.000000     2     2             14
#
#       CountLineCodeDecl  SumCyclomaticStrict  SumCyclomaticModified  \
# 0                    25                   18                     17
# 1                    17                   15                     13
# 2                    20                   16                     15
# 3                    36                   29                     26
# 4                    33                   26                     23
# ...                 ...                  ...                    ...
# 1879                 61                   35                     34
# 1880                 21                   16                     15
# 1881                 41                   30                     30
# 1882                 11                   13                     13
# 1883                 14                    7                      7
#
#       SumCyclomatic
# 0                17
# 1                13
# 2                15
# 3                26
# 4                23
# ...             ...
# 1879             34
# 1880             15
# 1881             30
# 1882             13
# 1883              7
#
# [1884 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.872791519434629
# Precision :  0.7017543859649122
# Recall :  0.42105263157894735
# F1 Score :  0.5263157894736842
# AUC :  0.692479606659962

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.842756183745583
# Precision :  0.5714285714285714
# Recall :  0.25263157894736843
# F1 Score :  0.35036496350364965
# AUC :  0.6072075092189071

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8392226148409894
# Precision :  0.5370370370370371
# Recall :  0.30526315789473685
# F1 Score :  0.389261744966443
# AUC :  0.6260923008157336

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8445229681978799
# Precision :  0.5321100917431193
# Recall :  0.6105263157894737
# F1 Score :  0.5686274509803921
# AUC :  0.7511230305062019

# %% [markdown]
# # SVM RFE 10

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,random_state=23)

# %%
from sklearn.feature_selection import RFE
rec_model = RandomForestClassifier()

rfe = RFE(rec_model, n_features_to_select=10)
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=RandomForestClassifier(), n_features_to_select=10)

# %%
X_train = X_train.loc[:, rfe.support_]
X_train
# Out:
#       CountLine  SumCyclomaticStrict  CountStmtDecl  CountLineCode  CountStmt  \
# 1403         42                    1              6             11          9
# 1022        193                   17             52            125        109
# 1112         87                    6             20             43         34
# 408          50                    5             10             23         17
# 1846         39                    2              7             13         10
# ...         ...                  ...            ...            ...        ...
# 1512         41                    4              8             18         13
# 950         465                   81            105            318        229
# 1064         55                    5             14             28         22
# 742         119                    8             26             56         45
# 595         155                    7             22             58         50
#
#       COMM  DDEV  Added_lines  OWN_LINE  OWN_COMMIT
# 1403     2     1           11  0.547619         1.0
# 1022     5     2          115  0.492228         0.8
# 1112     2     1           17  1.000000         1.0
# 408      2     1           17  0.580000         1.0
# 1846     1     1            1  0.820513         1.0
# ...    ...   ...          ...       ...         ...
# 1512     3     1            6  0.512195         1.0
# 950      5     1           78  0.789247         1.0
# 1064     3     1            5  0.800000         1.0
# 742      3     1           36  1.000000         1.0
# 595      2     1            5  0.522581         1.0
#
# [1318 rows x 10 columns]

# %%
X_test = X_test.loc[:, rfe.support_]
X_test
# Out:
#       CountLine  SumCyclomaticStrict  CountStmtDecl  CountLineCode  CountStmt  \
# 1450        255                   26             45            101         74
# 520         161                   21             37             87         65
# 350         144                   27             32             92         68
# 1189        147                   21             40            102         96
# 797         224                   38             36            171        115
# ...         ...                  ...            ...            ...        ...
# 472          82                    9             24             48         44
# 1405        116                   14             42             81         69
# 914          48                    3             10             19         15
# 1580        100                    2              8             41         38
# 353          32                    1              5              8          6
#
#       COMM  DDEV  Added_lines  OWN_LINE  OWN_COMMIT
# 1450     3     1          145  0.596078        1.00
# 520      3     1           43  0.608696        1.00
# 350      4     2           46  0.631944        0.75
# 1189     4     2           86  0.727891        0.50
# 797      4     1           51  0.709821        1.00
# ...    ...   ...          ...       ...         ...
# 472      3     1           11  0.560976        1.00
# 1405     3     1           46  0.517241        1.00
# 914      2     1            7  0.895833        1.00
# 1580     2     1            3  0.970000        1.00
# 353      1     1            1  0.500000        1.00
#
# [566 rows x 10 columns]

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8816254416961131
# Precision :  0.71875
# Recall :  0.4842105263157895
# F1 Score :  0.5786163522012578
# AUC :  0.7229969829031176

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8374558303886925
# Precision :  0.5365853658536586
# Recall :  0.23157894736842105
# F1 Score :  0.32352941176470584
# AUC :  0.5956196223041681

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8392226148409894
# Precision :  0.5303030303030303
# Recall :  0.3684210526315789
# F1 Score :  0.4347826086956521
# AUC :  0.6513018214325623

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8356890459363958
# Precision :  0.5108695652173914
# Recall :  0.49473684210526314
# F1 Score :  0.5026737967914439
# AUC :  0.6995977204156889

# %% [markdown]
# # SVM RFE 15

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,random_state=23)

# %%
from sklearn.feature_selection import RFE
rec_model = RandomForestClassifier()

rfe = RFE(rec_model, n_features_to_select=15)
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=RandomForestClassifier(), n_features_to_select=15)

# %%
X_train = X_train.loc[:, rfe.support_]
X_train
# Out:
#       CountLine  SumCyclomaticModified  CountLineCodeDecl  CountStmtDecl  \
# 1403         42                      1                  6              6
# 1022        193                     17                 47             52
# 1112         87                      6                 20             20
# 408          50                      5                 10             10
# 1846         39                      2                  7              7
# ...         ...                    ...                ...            ...
# 1512         41                      4                  8              8
# 950         465                     80                104            105
# 1064         55                      5                 14             14
# 742         119                      8                 25             26
# 595         155                      7                 22             22
#
#       CountLineCode  CountStmtExe  CountStmt  CountInput_Mean  \
# 1403             11             3          9         2.000000
# 1022            125            57        109         3.166667
# 1112             43            14         34         1.000000
# 408              23             7         17         2.000000
# 1846             13             3         10         2.000000
# ...             ...           ...        ...              ...
# 1512             18             5         13         0.500000
# 950             318           124        229         2.760000
# 1064             28             8         22         1.250000
# 742              56            19         45         4.666667
# 595              58            28         50         2.571429
#
#       CountOutput_Mean  ADEV  DDEV  Added_lines  OWN_LINE  OWN_COMMIT  \
# 1403          4.000000     2     1           11  0.547619         1.0
# 1022          6.833333     5     2          115  0.492228         0.8
# 1112          4.500000     2     1           17  1.000000         1.0
# 408           2.500000     2     1           17  0.580000         1.0
# 1846          1.500000     1     1            1  0.820513         1.0
# ...                ...   ...   ...          ...       ...         ...
# 1512          1.750000     3     1            6  0.512195         1.0
# 950           2.440000     5     1           78  0.789247         1.0
# 1064          2.500000     3     1            5  0.800000         1.0
# 742           7.666667     3     1           36  1.000000         1.0
# 595           6.142857     2     1            5  0.522581         1.0
#
#       MAJOR_COMMIT
# 1403             1
# 1022             2
# 1112             1
# 408              1
# 1846             1
# ...            ...
# 1512             1
# 950              1
# 1064             1
# 742              1
# 595              1
#
# [1318 rows x 15 columns]

# %%
X_test = X_test.loc[:, rfe.support_]
X_test
# Out:
#       CountLine  SumCyclomaticModified  CountLineCodeDecl  CountStmtDecl  \
# 1450        255                     25                 45             45
# 520         161                     20                 37             37
# 350         144                     23                 31             32
# 1189        147                     21                 31             40
# 797         224                     36                 35             36
# ...         ...                    ...                ...            ...
# 472          82                      9                 21             24
# 1405        116                     14                 41             42
# 914          48                      3                 10             10
# 1580        100                      2                  8              8
# 353          32                      1                  5              5
#
#       CountLineCode  CountStmtExe  CountStmt  CountInput_Mean  \
# 1450            101            29         74         2.727273
# 520              87            28         65         2.500000
# 350              92            36         68         5.764706
# 1189            102            56         96         3.400000
# 797             171            79        115         7.428571
# ...             ...           ...        ...              ...
# 472              48            20         44         2.500000
# 1405             81            27         69         1.875000
# 914              19             5         15         1.000000
# 1580             41            30         38         1.500000
# 353               8             1          6         4.000000
#
#       CountOutput_Mean  ADEV  DDEV  Added_lines  OWN_LINE  OWN_COMMIT  \
# 1450          1.590909     3     1          145  0.596078        1.00
# 520           1.750000     3     1           43  0.608696        1.00
# 350           2.117647     4     2           46  0.631944        0.75
# 1189          4.000000     4     2           86  0.727891        0.50
# 797           3.571429     4     1           51  0.709821        1.00
# ...                ...   ...   ...          ...       ...         ...
# 472           2.666667     3     1           11  0.560976        1.00
# 1405          3.750000     3     1           46  0.517241        1.00
# 914           2.000000     2     1            7  0.895833        1.00
# 1580          8.500000     2     1            3  0.970000        1.00
# 353           1.000000     1     1            1  0.500000        1.00
#
#       MAJOR_COMMIT
# 1450             1
# 520              1
# 350              2
# 1189             2
# 797              1
# ...            ...
# 472              1
# 1405             1
# 914              1
# 1580             1
# 353              1
#
# [566 rows x 15 columns]

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8816254416961131
# Precision :  0.71875
# Recall :  0.4842105263157895
# F1 Score :  0.5786163522012578
# AUC :  0.7229969829031176

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8409893992932862
# Precision :  0.5609756097560976
# Recall :  0.24210526315789474
# F1 Score :  0.3382352941176471
# AUC :  0.6019443513241703

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8321554770318021
# Precision :  0.5
# Recall :  0.3157894736842105
# F1 Score :  0.3870967741935484
# AUC :  0.6260476030841435

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.833922261484099
# Precision :  0.5051546391752577
# Recall :  0.5157894736842106
# F1 Score :  0.5104166666666667
# AUC :  0.7069393228293664

# %% [markdown]
# # MRMR 10

# %%
from sklearn.feature_selection import f_regression

F = pd.Series(f_regression(X, Y)[0], index = X.columns)
corr = X.corr().abs().clip(.00001)

# %%
selected = []
feat_score = []
not_selected = list(X.columns)

# %%
K = 10

for i in range(K):
    
    # compute FCQ score for all the (currently) excluded features (this is Formula 2)
    score = F.loc[not_selected] / corr.loc[not_selected, selected].mean(axis = 1).fillna(.00001)
    
    # find best feature, add it to selected and remove it from not_selected
    best = score.index[score.argmax()]
    selected.append(best)
    feat_score.append(score[best])
    not_selected.remove(best)

# %%
selected
# Out:
# ['DDEV',
#  'CountStmtDecl',
#  'MAJOR_COMMIT',
#  'OWN_COMMIT',
#  'COMM',
#  'ADEV',
#  'CountLineCodeDecl',
#  'SumCyclomaticStrict',
#  'CountLineCode',
#  'SumCyclomaticModified']

# %%
X_new = X[selected]
X_new
# Out:
#       DDEV  CountStmtDecl  MAJOR_COMMIT  OWN_COMMIT  COMM  ADEV  \
# 0        1             26             1    1.000000     1     1
# 1        2             17             2    0.500000     2     2
# 2        1             20             1    1.000000     1     1
# 3        1             36             1    1.000000     1     1
# 4        1             34             1    1.000000     1     1
# ...    ...            ...           ...         ...   ...   ...
# 1879     2             62             2    0.666667     3     3
# 1880     1             22             1    1.000000     2     2
# 1881     2             45             2    0.666667     3     3
# 1882     1             11             1    1.000000     2     2
# 1883     1             14             1    1.000000     2     2
#
#       CountLineCodeDecl  SumCyclomaticStrict  CountLineCode  \
# 0                    25                   18             88
# 1                    17                   15             53
# 2                    20                   16             65
# 3                    36                   29            143
# 4                    33                   26            126
# ...                 ...                  ...            ...
# 1879                 61                   35            153
# 1880                 21                   16             68
# 1881                 41                   30            130
# 1882                 11                   13             51
# 1883                 14                    7             37
#
#       SumCyclomaticModified
# 0                        17
# 1                        13
# 2                        15
# 3                        26
# 4                        23
# ...                     ...
# 1879                     34
# 1880                     15
# 1881                     30
# 1882                     13
# 1883                      7
#
# [1884 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8745583038869258
# Precision :  0.6935483870967742
# Recall :  0.45263157894736844
# F1 Score :  0.5477707006369427
# AUC :  0.7061459380936418

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8374558303886925
# Precision :  0.5333333333333333
# Recall :  0.25263157894736843
# F1 Score :  0.34285714285714286
# AUC :  0.6040227958431109

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.842756183745583
# Precision :  0.5535714285714286
# Recall :  0.3263157894736842
# F1 Score :  0.41059602649006627
# AUC :  0.6366186166052074

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.842756183745583
# Precision :  0.5272727272727272
# Recall :  0.6105263157894737
# F1 Score :  0.5658536585365853
# AUC :  0.7500614593809365

# %% [markdown]
# # MRMR 15

# %%
from sklearn.feature_selection import f_regression

F = pd.Series(f_regression(X, Y)[0], index = X.columns)
corr = X.corr().abs().clip(.00001)

# %%
selected = []
feat_score = []
not_selected = list(X.columns)

# %%
K = 15

for i in range(K):
    
    # compute FCQ score for all the (currently) excluded features (this is Formula 2)
    score = F.loc[not_selected] / corr.loc[not_selected, selected].mean(axis = 1).fillna(.00001)
    
    # find best feature, add it to selected and remove it from not_selected
    best = score.index[score.argmax()]
    selected.append(best)
    feat_score.append(score[best])
    not_selected.remove(best)

# %%
selected
# Out:
# ['DDEV',
#  'CountStmtDecl',
#  'MAJOR_COMMIT',
#  'OWN_COMMIT',
#  'COMM',
#  'ADEV',
#  'CountLineCodeDecl',
#  'SumCyclomaticStrict',
#  'CountLineCode',
#  'SumCyclomaticModified',
#  'CountStmt',
#  'SumCyclomatic',
#  'SumEssential',
#  'CountSemicolon',
#  'CountClassCoupled']

# %%
X_new = X[selected]
X_new
# Out:
#       DDEV  CountStmtDecl  MAJOR_COMMIT  OWN_COMMIT  COMM  ADEV  \
# 0        1             26             1    1.000000     1     1
# 1        2             17             2    0.500000     2     2
# 2        1             20             1    1.000000     1     1
# 3        1             36             1    1.000000     1     1
# 4        1             34             1    1.000000     1     1
# ...    ...            ...           ...         ...   ...   ...
# 1879     2             62             2    0.666667     3     3
# 1880     1             22             1    1.000000     2     2
# 1881     2             45             2    0.666667     3     3
# 1882     1             11             1    1.000000     2     2
# 1883     1             14             1    1.000000     2     2
#
#       CountLineCodeDecl  SumCyclomaticStrict  CountLineCode  \
# 0                    25                   18             88
# 1                    17                   15             53
# 2                    20                   16             65
# 3                    36                   29            143
# 4                    33                   26            126
# ...                 ...                  ...            ...
# 1879                 61                   35            153
# 1880                 21                   16             68
# 1881                 41                   30            130
# 1882                 11                   13             51
# 1883                 14                    7             37
#
#       SumCyclomaticModified  CountStmt  SumCyclomatic  SumEssential  \
# 0                        17         63             17            11
# 1                        13         41             13             7
# 2                        15         46             15             7
# 3                        26         90             26            12
# 4                        23         78             23             9
# ...                     ...        ...            ...           ...
# 1879                     34        114             34            24
# 1880                     15         51             15             6
# 1881                     30        102             30            15
# 1882                     13         36             13             7
# 1883                      7         27              7             3
#
#       CountSemicolon  CountClassCoupled
# 0                 46                  2
# 1                 29                  2
# 2                 30                  1
# 3                 64                  4
# 4                 56                  4
# ...              ...                ...
# 1879              79                  2
# 1880              35                  0
# 1881              71                  1
# 1882              22                  1
# 1883              19                  3
#
# [1884 rows x 15 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8763250883392226
# Precision :  0.6984126984126984
# Recall :  0.4631578947368421
# F1 Score :  0.5569620253164558
# AUC :  0.7114090959883786

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8392226148409894
# Precision :  0.5333333333333333
# Recall :  0.3368421052631579
# F1 Score :  0.41290322580645156
# AUC :  0.6386970611241479

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8374558303886925
# Precision :  0.5333333333333333
# Recall :  0.25263157894736843
# F1 Score :  0.34285714285714286
# AUC :  0.6040227958431109

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8392226148409894
# Precision :  0.5333333333333333
# Recall :  0.3368421052631579
# F1 Score :  0.41290322580645156
# AUC :  0.6386970611241479

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8356890459363958
# Precision :  0.5113636363636364
# Recall :  0.47368421052631576
# F1 Score :  0.4918032786885245
# AUC :  0.691194546876746

# %% [markdown]
# # MRMR HFS

# %%
def HSF(df, df_train):
    
    from copy import deepcopy
    col_list = list(df_train.columns)
    print(col_list)
    d = df_train.shape[1]
    SF = []
    merit = [0 for i in range(d)]
    merit_archive = [0 for i in range(d)]
    Total_FS = [0 for i in range(d)]

    rel_CF = RHFS(df, d, col_list)

    max_value = max(rel_CF)
    Feature_max_index = rel_CF.index(max_value)

    n = 0

    SF.append(Feature_max_index)

    merit_archive[n] = deepcopy(max_value)

    Total_FS[n] = deepcopy(SF)

    while n < d-1:

        for i in range(d):

            red_FF = SHFS(SF, df_train, i, col_list,d)

            top = (d + d*(sum(rel_CF)/len(rel_CF)))
            bottom = (d + (d*(d-1)*(sum(red_FF)/len(red_FF))))**(1/2)
            merit[i] = top/bottom

        for val in SF:
            merit[val] = -9999999

        max_value = max(merit)
        Feature_max_index = merit.index(max_value)

        if Feature_max_index not in SF:
            SF.append(Feature_max_index)

        n += 1
        
        Total_FS[n] = deepcopy(SF)

        merit_archive[n] = max_value

    index_val = merit_archive.index(max(merit_archive))

    Feature_subset = Total_FS[index_val]

    subset_list = []

    for val in Feature_subset:
        subset_list.append(col_list[val])
    return subset_list


def RHFS(df, d, col_list):
    rel_CF = [0 for i in range(d)]
    count = 0

    igain = IG(X,df['class'])

    for m in  range(d):
        mu = df[col_list[m]].mean()

        n_1 = df[df['class'] == 0].count()[1]
        mu_1 = df[col_list[m]][df['class'] == 0].mean()
        var_1 = df[col_list[m]][df['class'] == 0].var()

        n_2 = df[df['class'] == 1].count()[1]
        mu_2 = df[col_list[m]][df['class'] == 1].mean()
        var_2 = df[col_list[m]][df['class'] == 1].var()

        inter_class = n_1*(mu_1-mu)**2 + n_2*(mu_2-mu)**2
        intra_class = (n_1-1)*var_1 + (n_2-1)*var_2

        fscore = inter_class / intra_class

        rel_CF[count] = (1/2)*(fscore + igain[m])
        count += 1
    
    return rel_CF

        
        

def IG(col_1, col_2):
    from sklearn.feature_selection import mutual_info_classif
    gain = mutual_info_classif(col_1,col_2)
    return gain   

def relief(col_1,col_2):
    pass



def SHFS(SF, df_train, i, col_list,d):
    from itertools import combinations
    from copy import deepcopy
    red_FF = []
    temp_SF = deepcopy(SF)
    if i not in SF:
        temp_SF.append(i)
        P_pairs = list(combinations(temp_SF,2))
        for pair in P_pairs:

            ied_value = (IED(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            pc_value = (PC(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            cs_value = (CS(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2

            red_FF.append((1/3)*(ied_value + pc_value + cs_value))
            # red_FF.append((1/2)*(pc_value + cs_value))
    else:
        red_FF = [0]
    return red_FF

def IED(col_1, col_2):
    import numpy as np
    dist = np.linalg.norm(col_1 - col_2)
    return 1/dist

def PC(col_1, col_2):
    from scipy.stats import pearsonr
    corr, _ = pearsonr(col_1 , col_2)
    return corr

def CS(col_1, col_2):
    from scipy import spatial
    similarity = 1 - spatial.distance.cosine(col_1, col_2)
    return similarity

# %%
FS = HSF(df, X)
FS
# Out:
# ['CountDeclMethodPrivate', 'AvgLineCode', 'CountLine', 'MaxCyclomatic', 'CountDeclMethodDefault', 'AvgEssential', 'CountDeclClassVariable', 'SumCyclomaticStrict', 'AvgCyclomatic', 'AvgLine', 'CountDeclClassMethod', 'AvgLineComment', 'AvgCyclomaticModified', 'CountDeclFunction', 'CountLineComment', 'CountDeclClass', 'CountDeclMethod', 'SumCyclomaticModified', 'CountLineCodeDecl', 'CountDeclMethodProtected', 'CountDeclInstanceVariable', 'MaxCyclomaticStrict', 'CountDeclMethodPublic', 'CountLineCodeExe', 'SumCyclomatic', 'SumEssential', 'CountStmtDecl', 'CountLineCode', 'CountStmtExe', 'RatioCommentToCode', 'CountLineBlank', 'CountStmt', 'MaxCyclomaticModified', 'CountSemicolon', 'AvgLineBlank', 'CountDeclInstanceMethod', 'AvgCyclomaticStrict', 'PercentLackOfCohesion', 'MaxInheritanceTree', 'CountClassDerived', 'CountClassCoupled', 'CountClassBase', 'CountInput_Max', 'CountInput_Mean', 'CountInput_Min', 'CountOutput_Max', 'CountOutput_Mean', 'CountOutput_Min', 'CountPath_Max', 'CountPath_Mean', 'CountPath_Min', 'MaxNesting_Max', 'MaxNesting_Mean', 'MaxNesting_Min', 'COMM', 'ADEV', 'DDEV', 'Added_lines', 'Del_lines', 'OWN_LINE', 'OWN_COMMIT', 'MINOR_COMMIT', 'MINOR_LINE', 'MAJOR_COMMIT', 'MAJOR_LINE']
# C:\Users\acer\AppData\Local\Temp\ipykernel_9864\2073211282.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1/dist
# ['DDEV', 'CountPath_Mean']

# %%
X_new = X[FS]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8480565371024735
# Precision :  0.5671641791044776
# Recall :  0.4
# F1 Score :  0.46913580246913583
# AUC :  0.6692144373673036

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8321554770318021
# Precision :  0.0
# Recall :  0.0
# F1 Score :  0.0
# AUC :  0.5
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8480565371024735
# Precision :  0.5569620253164557
# Recall :  0.4631578947368421
# F1 Score :  0.5057471264367815
# AUC :  0.6944239579841324

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8604240282685512
# Precision :  0.5689655172413793
# Recall :  0.6947368421052632
# F1 Score :  0.6255924170616114
# AUC :  0.7942898647893619

# %% [markdown]
# # HFS NEW

# %%
def HSF(df, df_train):
    
    from copy import deepcopy
    col_list = list(df_train.columns)
    print(col_list)
    d = df_train.shape[1]
    SF = []
    merit = [0 for i in range(d)]
    merit_archive = [0 for i in range(d)]
    Total_FS = [0 for i in range(d)]

    rel_CF = RHFS(df, d, col_list)

    max_value = max(rel_CF)
    Feature_max_index = rel_CF.index(max_value)

    n = 0

    SF.append(Feature_max_index)

    merit_archive[n] = deepcopy(max_value)

    Total_FS[n] = deepcopy(SF)

    while n < d-1:

        for i in range(d):

            red_FF = SHFS(SF, df_train, i, col_list,d)

            top = (d + d*(sum(rel_CF)/len(rel_CF)))
            bottom = (d - (sum(red_FF)/len(red_FF)))**(1/2)

            merit[i] = top/bottom

        for val in SF:
            merit[val] = -9999999

        max_value = max(merit)
        Feature_max_index = merit.index(max_value)

        if Feature_max_index not in SF:
            SF.append(Feature_max_index)

        n += 1
        
        Total_FS[n] = deepcopy(SF)

        merit_archive[n] = max_value

    index_val = merit_archive.index(max(merit_archive))

    Feature_subset = Total_FS[index_val]

    subset_list = []

    for val in Feature_subset:
        subset_list.append(col_list[val])
    return subset_list


def RHFS(df, d, col_list):
    rel_CF = [0 for i in range(d)]
    count = 0

    igain = IG(X,df['class'])

    for m in  range(d):
        mu = df[col_list[m]].mean()

        n_1 = df[df['class'] == 0].count()[1]
        mu_1 = df[col_list[m]][df['class'] == 0].mean()
        var_1 = df[col_list[m]][df['class'] == 0].var()

        n_2 = df[df['class'] == 1].count()[1]
        mu_2 = df[col_list[m]][df['class'] == 1].mean()
        var_2 = df[col_list[m]][df['class'] == 1].var()

        inter_class = n_1*(mu_1-mu)**2 + n_2*(mu_2-mu)**2
        intra_class = (n_1-1)*var_1 + (n_2-1)*var_2

        fscore = inter_class / intra_class

        rel_CF[count] = (1/2)*(fscore + igain[m])
        count += 1
    
    return rel_CF

        
        

def IG(col_1, col_2):
    from sklearn.feature_selection import mutual_info_classif
    gain = mutual_info_classif(col_1,col_2)
    return gain   

def relief(col_1,col_2):
    pass



def SHFS(SF, df_train, i, col_list,d):
    from itertools import combinations
    from copy import deepcopy
    red_FF = []
    temp_SF = deepcopy(SF)
    if i not in SF:
        temp_SF.append(i)
        P_pairs = list(combinations(temp_SF,2))
        for pair in P_pairs:

            ied_value = (IED(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            pc_value = (PC(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            cs_value = (CS(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2

            red_FF.append((1/3)*(ied_value + pc_value + cs_value))
            # red_FF.append((1/2)*(pc_value + cs_value))
    else:
        red_FF = [0]
    return red_FF

def IED(col_1, col_2):
    import numpy as np
    dist = np.linalg.norm(col_1 - col_2)
    return 1/dist

def PC(col_1, col_2):
    from scipy.stats import pearsonr
    corr, _ = pearsonr(col_1 , col_2)
    return corr

def CS(col_1, col_2):
    from scipy import spatial
    similarity = 1 - spatial.distance.cosine(col_1, col_2)
    return similarity

# %%
FS = HSF(df, X)
FS
# Out:
# ['CountDeclMethodPrivate', 'AvgLineCode', 'CountLine', 'MaxCyclomatic', 'CountDeclMethodDefault', 'AvgEssential', 'CountDeclClassVariable', 'SumCyclomaticStrict', 'AvgCyclomatic', 'AvgLine', 'CountDeclClassMethod', 'AvgLineComment', 'AvgCyclomaticModified', 'CountDeclFunction', 'CountLineComment', 'CountDeclClass', 'CountDeclMethod', 'SumCyclomaticModified', 'CountLineCodeDecl', 'CountDeclMethodProtected', 'CountDeclInstanceVariable', 'MaxCyclomaticStrict', 'CountDeclMethodPublic', 'CountLineCodeExe', 'SumCyclomatic', 'SumEssential', 'CountStmtDecl', 'CountLineCode', 'CountStmtExe', 'RatioCommentToCode', 'CountLineBlank', 'CountStmt', 'MaxCyclomaticModified', 'CountSemicolon', 'AvgLineBlank', 'CountDeclInstanceMethod', 'AvgCyclomaticStrict', 'PercentLackOfCohesion', 'MaxInheritanceTree', 'CountClassDerived', 'CountClassCoupled', 'CountClassBase', 'CountInput_Max', 'CountInput_Mean', 'CountInput_Min', 'CountOutput_Max', 'CountOutput_Mean', 'CountOutput_Min', 'CountPath_Max', 'CountPath_Mean', 'CountPath_Min', 'MaxNesting_Max', 'MaxNesting_Mean', 'MaxNesting_Min', 'COMM', 'ADEV', 'DDEV', 'Added_lines', 'Del_lines', 'OWN_LINE', 'OWN_COMMIT', 'MINOR_COMMIT', 'MINOR_LINE', 'MAJOR_COMMIT', 'MAJOR_LINE']
# C:\Users\acer\AppData\Local\Temp\ipykernel_9864\4067302685.py:125: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1/dist
# ['MAJOR_COMMIT', 'DDEV']

# %%
X_new = X[FS]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8621908127208481
# Precision :  0.5726495726495726
# Recall :  0.7052631578947368
# F1 Score :  0.6320754716981132
# AUC :  0.7995530226840988

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8621908127208481
# Precision :  0.5726495726495726
# Recall :  0.7052631578947368
# F1 Score :  0.6320754716981132
# AUC :  0.7995530226840988

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8392226148409894
# Precision :  0.75
# Recall :  0.06315789473684211
# F1 Score :  0.11650485436893204
# AUC :  0.5294558051178903

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8621908127208481
# Precision :  0.5726495726495726
# Recall :  0.7052631578947368
# F1 Score :  0.6320754716981132
# AUC :  0.7995530226840988
