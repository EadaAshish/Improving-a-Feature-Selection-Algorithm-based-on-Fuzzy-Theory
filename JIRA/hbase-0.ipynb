# %%
import pandas as pd

# %%
df = pd.read_csv('hbase-0.csv')
df
# Out:
#         id  CountDeclMethodPrivate  AvgLineCode  CountLine  MaxCyclomatic  \
# 0        1                       6           21        487             12
# 1        2                       0            8        118              6
# 2        3                       2           12        412             10
# 3        4                       9           18        737             21
# 4        5                       0            4         84              2
# ...    ...                     ...          ...        ...            ...
# 1054  1055                       2            8        237              6
# 1055  1056                       0           13        113              1
# 1056  1057                       0           18        272              5
# 1057  1058                       0           11         50              1
# 1058  1059                       0            8        320              2
#
#       CountDeclMethodDefault  AvgEssential  CountDeclClassVariable  \
# 0                          0             1                       2
# 1                          0             1                       0
# 2                          0             1                       2
# 3                          3             2                       8
# 4                          2             1                       0
# ...                      ...           ...                     ...
# 1054                       0             1                       4
# 1055                       0             1                       2
# 1056                       0             1                       4
# 1057                       0             1                       0
# 1058                       0             1                       4
#
#       SumCyclomaticStrict  AvgCyclomatic  ...  DDEV  Added_lines  Del_lines  \
# 0                      69              4  ...     1           34        522
# 1                      15              2  ...     1            0        118
# 2                      46              2  ...     1           45        458
# 3                     122              4  ...     2           38        766
# 4                       6              1  ...     1            0         84
# ...                   ...            ...  ...   ...          ...        ...
# 1054                   25              2  ...     1           12          8
# 1055                    5              1  ...     2           34         16
# 1056                   25              3  ...     2          274          2
# 1057                    1              1  ...     1            5          0
# 1058                   25              1  ...     2           13          8
#
#       OWN_LINE  OWN_COMMIT  MINOR_COMMIT  MINOR_LINE  MAJOR_COMMIT  \
# 0     1.000000    1.000000             0           1             1
# 1     1.000000    1.000000             0           1             1
# 2     1.000000    1.000000             0           1             1
# 3     0.972900    0.800000             0           1             2
# 4     1.000000    1.000000             0           1             1
# ...        ...         ...           ...         ...           ...
# 1054  0.966245    1.000000             0           1             1
# 1055  0.840708    0.750000             0           2             2
# 1056  0.970588    0.666667             0           1             2
# 1057  0.880000    1.000000             0           2             1
# 1058  0.909375    0.666667             0           2             2
#
#       MAJOR_LINE  RealBugCount
# 0              0             1
# 1              0             0
# 2              0             0
# 3              2             0
# 4              0             0
# ...          ...           ...
# 1054           1             1
# 1055           0             5
# 1056           1             1
# 1057           0             0
# 1058           1             0
#
# [1059 rows x 67 columns]

# %%
df.drop(['id'], axis=1, inplace=True)

# %%
df['RealBugCount'].unique()
# Out:
# array([ 1,  0,  3,  2,  5,  6, 18,  4,  8,  7,  9, 15, 21, 10, 37, 11, 13,
#        17, 14, 12], dtype=int64)

# %%
df['RealBugCount'].replace([3,  2,  5,  6, 18,  4,  8,  7,  9, 15, 21, 10, 37, 11, 13, 17, 14, 12], 1, inplace=True)
df['RealBugCount'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df = df.rename({'RealBugCount':'class'}, axis=1)
df
# Out:
#       CountDeclMethodPrivate  AvgLineCode  CountLine  MaxCyclomatic  \
# 0                          6           21        487             12
# 1                          0            8        118              6
# 2                          2           12        412             10
# 3                          9           18        737             21
# 4                          0            4         84              2
# ...                      ...          ...        ...            ...
# 1054                       2            8        237              6
# 1055                       0           13        113              1
# 1056                       0           18        272              5
# 1057                       0           11         50              1
# 1058                       0            8        320              2
#
#       CountDeclMethodDefault  AvgEssential  CountDeclClassVariable  \
# 0                          0             1                       2
# 1                          0             1                       0
# 2                          0             1                       2
# 3                          3             2                       8
# 4                          2             1                       0
# ...                      ...           ...                     ...
# 1054                       0             1                       4
# 1055                       0             1                       2
# 1056                       0             1                       4
# 1057                       0             1                       0
# 1058                       0             1                       4
#
#       SumCyclomaticStrict  AvgCyclomatic  AvgLine  ...  DDEV  Added_lines  \
# 0                      69              4       27  ...     1           34
# 1                      15              2       10  ...     1            0
# 2                      46              2       16  ...     1           45
# 3                     122              4       20  ...     2           38
# 4                       6              1        5  ...     1            0
# ...                   ...            ...      ...  ...   ...          ...
# 1054                   25              2       10  ...     1           12
# 1055                    5              1       13  ...     2           34
# 1056                   25              3       24  ...     2          274
# 1057                    1              1       11  ...     1            5
# 1058                   25              1       11  ...     2           13
#
#       Del_lines  OWN_LINE  OWN_COMMIT  MINOR_COMMIT  MINOR_LINE  MAJOR_COMMIT  \
# 0           522  1.000000    1.000000             0           1             1
# 1           118  1.000000    1.000000             0           1             1
# 2           458  1.000000    1.000000             0           1             1
# 3           766  0.972900    0.800000             0           1             2
# 4            84  1.000000    1.000000             0           1             1
# ...         ...       ...         ...           ...         ...           ...
# 1054          8  0.966245    1.000000             0           1             1
# 1055         16  0.840708    0.750000             0           2             2
# 1056          2  0.970588    0.666667             0           1             2
# 1057          0  0.880000    1.000000             0           2             1
# 1058          8  0.909375    0.666667             0           2             2
#
#       MAJOR_LINE  class
# 0              0      1
# 1              0      0
# 2              0      0
# 3              2      0
# 4              0      0
# ...          ...    ...
# 1054           1      1
# 1055           0      1
# 1056           1      1
# 1057           0      0
# 1058           1      0
#
# [1059 rows x 66 columns]

# %%
df[df['class'] == 0]
# Out:
#       CountDeclMethodPrivate  AvgLineCode  CountLine  MaxCyclomatic  \
# 1                          0            8        118              6
# 2                          2           12        412             10
# 3                          9           18        737             21
# 4                          0            4         84              2
# 6                          0            1         85              1
# ...                      ...          ...        ...            ...
# 1051                       0           28        111              6
# 1052                       0           19         83              1
# 1053                       0           19        147              4
# 1057                       0           11         50              1
# 1058                       0            8        320              2
#
#       CountDeclMethodDefault  AvgEssential  CountDeclClassVariable  \
# 1                          0             1                       0
# 2                          0             1                       2
# 3                          3             2                       8
# 4                          2             1                       0
# 6                          0             1                       1
# ...                      ...           ...                     ...
# 1051                       0             1                       0
# 1052                       0             1                       3
# 1053                       0             1                       2
# 1057                       0             1                       0
# 1058                       0             1                       4
#
#       SumCyclomaticStrict  AvgCyclomatic  AvgLine  ...  DDEV  Added_lines  \
# 1                      15              2       10  ...     1            0
# 2                      46              2       16  ...     1           45
# 3                     122              4       20  ...     2           38
# 4                       6              1        5  ...     1            0
# 6                       4              1       11  ...     2           21
# ...                   ...            ...      ...  ...   ...          ...
# 1051                   13              4       33  ...     1            5
# 1052                    2              1       22  ...     3          158
# 1053                    7              2       22  ...     1            5
# 1057                    1              1       11  ...     1            5
# 1058                   25              1       11  ...     2           13
#
#       Del_lines  OWN_LINE  OWN_COMMIT  MINOR_COMMIT  MINOR_LINE  MAJOR_COMMIT  \
# 1           118  1.000000    1.000000             0           1             1
# 2           458  1.000000    1.000000             0           1             1
# 3           766  0.972900    0.800000             0           1             2
# 4            84  1.000000    1.000000             0           1             1
# 6            89  0.776471    0.666667             0           2             2
# ...         ...       ...         ...           ...         ...           ...
# 1051          0  0.927928    1.000000             0           1             1
# 1052          1  0.939759    0.500000             0           2             3
# 1053          0  0.823129    1.000000             0           2             1
# 1057          0  0.880000    1.000000             0           2             1
# 1058          8  0.909375    0.666667             0           2             2
#
#       MAJOR_LINE  class
# 1              0      0
# 2              0      0
# 3              2      0
# 4              0      0
# 6              0      0
# ...          ...    ...
# 1051           2      0
# 1052           0      0
# 1053           3      0
# 1057           0      0
# 1058           1      0
#
# [841 rows x 66 columns]

# %%
X = df.drop(['class'], axis=1)
X
# Out:
#       CountDeclMethodPrivate  AvgLineCode  CountLine  MaxCyclomatic  \
# 0                          6           21        487             12
# 1                          0            8        118              6
# 2                          2           12        412             10
# 3                          9           18        737             21
# 4                          0            4         84              2
# ...                      ...          ...        ...            ...
# 1054                       2            8        237              6
# 1055                       0           13        113              1
# 1056                       0           18        272              5
# 1057                       0           11         50              1
# 1058                       0            8        320              2
#
#       CountDeclMethodDefault  AvgEssential  CountDeclClassVariable  \
# 0                          0             1                       2
# 1                          0             1                       0
# 2                          0             1                       2
# 3                          3             2                       8
# 4                          2             1                       0
# ...                      ...           ...                     ...
# 1054                       0             1                       4
# 1055                       0             1                       2
# 1056                       0             1                       4
# 1057                       0             1                       0
# 1058                       0             1                       4
#
#       SumCyclomaticStrict  AvgCyclomatic  AvgLine  ...  ADEV  DDEV  \
# 0                      69              4       27  ...     2     1
# 1                      15              2       10  ...     1     1
# 2                      46              2       16  ...     3     1
# 3                     122              4       20  ...     5     2
# 4                       6              1        5  ...     1     1
# ...                   ...            ...      ...  ...   ...   ...
# 1054                   25              2       10  ...     3     1
# 1055                    5              1       13  ...     4     2
# 1056                   25              3       24  ...     3     2
# 1057                    1              1       11  ...     1     1
# 1058                   25              1       11  ...     3     2
#
#       Added_lines  Del_lines  OWN_LINE  OWN_COMMIT  MINOR_COMMIT  MINOR_LINE  \
# 0              34        522  1.000000    1.000000             0           1
# 1               0        118  1.000000    1.000000             0           1
# 2              45        458  1.000000    1.000000             0           1
# 3              38        766  0.972900    0.800000             0           1
# 4               0         84  1.000000    1.000000             0           1
# ...           ...        ...       ...         ...           ...         ...
# 1054           12          8  0.966245    1.000000             0           1
# 1055           34         16  0.840708    0.750000             0           2
# 1056          274          2  0.970588    0.666667             0           1
# 1057            5          0  0.880000    1.000000             0           2
# 1058           13          8  0.909375    0.666667             0           2
#
#       MAJOR_COMMIT  MAJOR_LINE
# 0                1           0
# 1                1           0
# 2                1           0
# 3                2           2
# 4                1           0
# ...            ...         ...
# 1054             1           1
# 1055             2           0
# 1056             2           1
# 1057             1           0
# 1058             2           1
#
# [1059 rows x 65 columns]

# %%
Y = df['class']
Y
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1054    1
# 1055    1
# 1056    1
# 1057    0
# 1058    0
# Name: class, Length: 1059, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import *

# %% [markdown]
# # All Features

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8144654088050315
# Precision :  0.0
# Recall :  0.0
# F1 Score :  0.0
# AUC :  0.4980769230769231

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8144654088050315
# Precision :  0.0
# Recall :  0.0
# F1 Score :  0.0
# AUC :  0.4980769230769231

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8207547169811321
# Precision :  0.5135135135135135
# Recall :  0.3275862068965517
# F1 Score :  0.4
# AUC :  0.6291777188328912

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.18238993710691823
# Precision :  0.17419354838709677
# Recall :  0.9310344827586207
# F1 Score :  0.2934782608695652
# AUC :  0.473209549071618

# %% [markdown]
# # PEARSON CORRELATION

# %%
cor = df.corr()
cor_target = abs(cor['class'])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.4]
relevant_features
# Out:
# CountClassCoupled    0.431366
# COMM                 0.439104
# ADEV                 0.439104
# DDEV                 0.476798
# MAJOR_COMMIT         0.460107
# class                1.000000
# Name: class, dtype: float64

# %%
X_new = df[['CountClassCoupled', 'COMM', 'ADEV', 'DDEV', 'MAJOR_COMMIT']]
X_new
# Out:
#       CountClassCoupled  COMM  ADEV  DDEV  MAJOR_COMMIT
# 0                    14     2     2     1             1
# 1                     2     1     1     1             1
# 2                    12     3     3     1             1
# 3                    15     5     5     2             2
# 4                     6     1     1     1             1
# ...                 ...   ...   ...   ...           ...
# 1054                  9     3     3     1             1
# 1055                  7     4     4     2             2
# 1056                  6     3     3     2             2
# 1057                  4     1     1     1             1
# 1058                 14     3     3     2             2
#
# [1059 rows x 5 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8459119496855346
# Precision :  0.5818181818181818
# Recall :  0.5517241379310345
# F1 Score :  0.5663716814159292
# AUC :  0.7316312997347479

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8427672955974843
# Precision :  0.6333333333333333
# Recall :  0.3275862068965517
# F1 Score :  0.43181818181818177
# AUC :  0.6426392572944297

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8490566037735849
# Precision :  0.6136363636363636
# Recall :  0.46551724137931033
# F1 Score :  0.5294117647058822
# AUC :  0.7000663129973475

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8333333333333334
# Precision :  0.543859649122807
# Recall :  0.5344827586206896
# F1 Score :  0.5391304347826087
# AUC :  0.7172413793103447

# %% [markdown]
# # INFORMATION GAIN 10

# %%
from sklearn.feature_selection import mutual_info_classif
gain = mutual_info_classif(X,Y)
gain
# Out:
# array([0.04786386, 0.0509185 , 0.08353364, 0.04400331, 0.02122599,
#        0.00165054, 0.04089929, 0.0574486 , 0.02738645, 0.0446138 ,
#        0.03283633, 0.03092994, 0.02098993, 0.05326061, 0.04899711,
#        0.0480472 , 0.05488748, 0.06030737, 0.08002384, 0.0190344 ,
#        0.01881986, 0.02776484, 0.04776472, 0.07249801, 0.0569658 ,
#        0.07481443, 0.08954471, 0.07419063, 0.06873896, 0.01651357,
#        0.05390123, 0.0810317 , 0.04226038, 0.06017846, 0.        ,
#        0.02694283, 0.01565001, 0.0274649 , 0.        , 0.01557918,
#        0.09973347, 0.0269299 , 0.01125949, 0.03206988, 0.01012946,
#        0.07918774, 0.06115902, 0.00828279, 0.04392378, 0.02461524,
#        0.00479565, 0.0345371 , 0.03050837, 0.00873432, 0.14885373,
#        0.16394553, 0.12223091, 0.09188659, 0.08948873, 0.04361898,
#        0.10567655, 0.03461936, 0.00020024, 0.14233202, 0.06470698])

# %%
col_list = X.columns
col_list
# Out:
# Index(['CountDeclMethodPrivate', 'AvgLineCode', 'CountLine', 'MaxCyclomatic',
#        'CountDeclMethodDefault', 'AvgEssential', 'CountDeclClassVariable',
#        'SumCyclomaticStrict', 'AvgCyclomatic', 'AvgLine',
#        'CountDeclClassMethod', 'AvgLineComment', 'AvgCyclomaticModified',
#        'CountDeclFunction', 'CountLineComment', 'CountDeclClass',
#        'CountDeclMethod', 'SumCyclomaticModified', 'CountLineCodeDecl',
#        'CountDeclMethodProtected', 'CountDeclInstanceVariable',
#        'MaxCyclomaticStrict', 'CountDeclMethodPublic', 'CountLineCodeExe',
#        'SumCyclomatic', 'SumEssential', 'CountStmtDecl', 'CountLineCode',
#        'CountStmtExe', 'RatioCommentToCode', 'CountLineBlank', 'CountStmt',
#        'MaxCyclomaticModified', 'CountSemicolon', 'AvgLineBlank',
#        'CountDeclInstanceMethod', 'AvgCyclomaticStrict',
#        'PercentLackOfCohesion', 'MaxInheritanceTree', 'CountClassDerived',
#        'CountClassCoupled', 'CountClassBase', 'CountInput_Max',
#        'CountInput_Mean', 'CountInput_Min', 'CountOutput_Max',
#        'CountOutput_Mean', 'CountOutput_Min', 'CountPath_Max',
#        'CountPath_Mean', 'CountPath_Min', 'MaxNesting_Max', 'MaxNesting_Mean',
#        'MaxNesting_Min', 'COMM', 'ADEV', 'DDEV', 'Added_lines', 'Del_lines',
#        'OWN_LINE', 'OWN_COMMIT', 'MINOR_COMMIT', 'MINOR_LINE', 'MAJOR_COMMIT',
#        'MAJOR_LINE'],
#       dtype='object')

# %%
temp = pd.DataFrame(list(zip(col_list, gain)), columns =['col', 'score']) 
temp
# Out:
#                        col     score
# 0   CountDeclMethodPrivate  0.047864
# 1              AvgLineCode  0.050919
# 2                CountLine  0.083534
# 3            MaxCyclomatic  0.044003
# 4   CountDeclMethodDefault  0.021226
# ..                     ...       ...
# 60              OWN_COMMIT  0.105677
# 61            MINOR_COMMIT  0.034619
# 62              MINOR_LINE  0.000200
# 63            MAJOR_COMMIT  0.142332
# 64              MAJOR_LINE  0.064707
#
# [65 rows x 2 columns]

# %%
temp_sort = temp.sort_values(['score'], ascending=False)
temp_sort[:10]
# Out:
#                   col     score
# 55               ADEV  0.163946
# 54               COMM  0.148854
# 63       MAJOR_COMMIT  0.142332
# 56               DDEV  0.122231
# 60         OWN_COMMIT  0.105677
# 40  CountClassCoupled  0.099733
# 57        Added_lines  0.091887
# 26      CountStmtDecl  0.089545
# 58          Del_lines  0.089489
# 2           CountLine  0.083534

# %%
FS = list(temp_sort['col'][:10])
FS
# Out:
# ['ADEV',
#  'COMM',
#  'MAJOR_COMMIT',
#  'DDEV',
#  'OWN_COMMIT',
#  'CountClassCoupled',
#  'Added_lines',
#  'CountStmtDecl',
#  'Del_lines',
#  'CountLine']

# %%
X_new = df[FS]
X_new
# Out:
#       ADEV  COMM  MAJOR_COMMIT  DDEV  OWN_COMMIT  CountClassCoupled  \
# 0        2     2             1     1    1.000000                 14
# 1        1     1             1     1    1.000000                  2
# 2        3     3             1     1    1.000000                 12
# 3        5     5             2     2    0.800000                 15
# 4        1     1             1     1    1.000000                  6
# ...    ...   ...           ...   ...         ...                ...
# 1054     3     3             1     1    1.000000                  9
# 1055     4     4             2     2    0.750000                  7
# 1056     3     3             2     2    0.666667                  6
# 1057     1     1             1     1    1.000000                  4
# 1058     3     3             2     2    0.666667                 14
#
#       Added_lines  CountStmtDecl  Del_lines  CountLine
# 0              34             90        522        487
# 1               0             24        118        118
# 2              45             95        458        412
# 3              38            142        766        737
# 4               0             16         84         84
# ...           ...            ...        ...        ...
# 1054           12             53          8        237
# 1055           34             25         16        113
# 1056          274             51          2        272
# 1057            5             13          0         50
# 1058           13             75          8        320
#
# [1059 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8364779874213837
# Precision :  0.5652173913043478
# Recall :  0.4482758620689655
# F1 Score :  0.4999999999999999
# AUC :  0.6856763925729443

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8270440251572327
# Precision :  0.8
# Recall :  0.06896551724137931
# F1 Score :  0.12698412698412698
# AUC :  0.5325596816976127

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8176100628930818
# Precision :  0.5
# Recall :  0.3275862068965517
# F1 Score :  0.3958333333333333
# AUC :  0.6272546419098143

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8050314465408805
# Precision :  0.4782608695652174
# Recall :  0.7586206896551724
# F1 Score :  0.5866666666666667
# AUC :  0.7870026525198939

# %% [markdown]
# # INFORMATION GAIN 15

# %%
from sklearn.feature_selection import mutual_info_classif
gain = mutual_info_classif(X,Y)
gain
# Out:
# array([0.04656672, 0.04758916, 0.08077056, 0.03184749, 0.01505545,
#        0.        , 0.04036584, 0.05456847, 0.0066594 , 0.04480206,
#        0.03492072, 0.0241241 , 0.03410238, 0.04105651, 0.06562342,
#        0.04120356, 0.04288565, 0.06561559, 0.0749866 , 0.02534676,
#        0.03212344, 0.04053655, 0.04438527, 0.07299203, 0.05820264,
#        0.07187883, 0.09170053, 0.07865928, 0.06072969, 0.01933395,
#        0.06416204, 0.07378363, 0.04395697, 0.06602697, 0.03507642,
#        0.04887992, 0.01761257, 0.01026625, 0.00548722, 0.        ,
#        0.11099889, 0.        , 0.05218212, 0.03202677, 0.02483251,
#        0.07825454, 0.06044321, 0.        , 0.04339343, 0.02243955,
#        0.00086694, 0.02979884, 0.02156815, 0.00456828, 0.1630369 ,
#        0.14379134, 0.11569261, 0.09617515, 0.08902643, 0.04460402,
#        0.10523879, 0.02893658, 0.01668003, 0.11974485, 0.05884044])

# %%
col_list = X.columns
col_list
# Out:
# Index(['CountDeclMethodPrivate', 'AvgLineCode', 'CountLine', 'MaxCyclomatic',
#        'CountDeclMethodDefault', 'AvgEssential', 'CountDeclClassVariable',
#        'SumCyclomaticStrict', 'AvgCyclomatic', 'AvgLine',
#        'CountDeclClassMethod', 'AvgLineComment', 'AvgCyclomaticModified',
#        'CountDeclFunction', 'CountLineComment', 'CountDeclClass',
#        'CountDeclMethod', 'SumCyclomaticModified', 'CountLineCodeDecl',
#        'CountDeclMethodProtected', 'CountDeclInstanceVariable',
#        'MaxCyclomaticStrict', 'CountDeclMethodPublic', 'CountLineCodeExe',
#        'SumCyclomatic', 'SumEssential', 'CountStmtDecl', 'CountLineCode',
#        'CountStmtExe', 'RatioCommentToCode', 'CountLineBlank', 'CountStmt',
#        'MaxCyclomaticModified', 'CountSemicolon', 'AvgLineBlank',
#        'CountDeclInstanceMethod', 'AvgCyclomaticStrict',
#        'PercentLackOfCohesion', 'MaxInheritanceTree', 'CountClassDerived',
#        'CountClassCoupled', 'CountClassBase', 'CountInput_Max',
#        'CountInput_Mean', 'CountInput_Min', 'CountOutput_Max',
#        'CountOutput_Mean', 'CountOutput_Min', 'CountPath_Max',
#        'CountPath_Mean', 'CountPath_Min', 'MaxNesting_Max', 'MaxNesting_Mean',
#        'MaxNesting_Min', 'COMM', 'ADEV', 'DDEV', 'Added_lines', 'Del_lines',
#        'OWN_LINE', 'OWN_COMMIT', 'MINOR_COMMIT', 'MINOR_LINE', 'MAJOR_COMMIT',
#        'MAJOR_LINE'],
#       dtype='object')

# %%
temp = pd.DataFrame(list(zip(col_list, gain)), columns =['col', 'score']) 
temp
# Out:
#                        col     score
# 0   CountDeclMethodPrivate  0.046567
# 1              AvgLineCode  0.047589
# 2                CountLine  0.080771
# 3            MaxCyclomatic  0.031847
# 4   CountDeclMethodDefault  0.015055
# ..                     ...       ...
# 60              OWN_COMMIT  0.105239
# 61            MINOR_COMMIT  0.028937
# 62              MINOR_LINE  0.016680
# 63            MAJOR_COMMIT  0.119745
# 64              MAJOR_LINE  0.058840
#
# [65 rows x 2 columns]

# %%
temp_sort = temp.sort_values(['score'], ascending=False)
temp_sort[:15]
# Out:
#                   col     score
# 54               COMM  0.163037
# 55               ADEV  0.143791
# 63       MAJOR_COMMIT  0.119745
# 56               DDEV  0.115693
# 40  CountClassCoupled  0.110999
# 60         OWN_COMMIT  0.105239
# 57        Added_lines  0.096175
# 26      CountStmtDecl  0.091701
# 58          Del_lines  0.089026
# 2           CountLine  0.080771
# 27      CountLineCode  0.078659
# 45    CountOutput_Max  0.078255
# 18  CountLineCodeDecl  0.074987
# 31          CountStmt  0.073784
# 23   CountLineCodeExe  0.072992

# %%
FS = list(temp_sort['col'][:15])
FS
# Out:
# ['COMM',
#  'ADEV',
#  'MAJOR_COMMIT',
#  'DDEV',
#  'CountClassCoupled',
#  'OWN_COMMIT',
#  'Added_lines',
#  'CountStmtDecl',
#  'Del_lines',
#  'CountLine',
#  'CountLineCode',
#  'CountOutput_Max',
#  'CountLineCodeDecl',
#  'CountStmt',
#  'CountLineCodeExe']

# %%
X_new = df[FS]
X_new
# Out:
#       COMM  ADEV  MAJOR_COMMIT  DDEV  CountClassCoupled  OWN_COMMIT  \
# 0        2     2             1     1                 14    1.000000
# 1        1     1             1     1                  2    1.000000
# 2        3     3             1     1                 12    1.000000
# 3        5     5             2     2                 15    0.800000
# 4        1     1             1     1                  6    1.000000
# ...    ...   ...           ...   ...                ...         ...
# 1054     3     3             1     1                  9    1.000000
# 1055     4     4             2     2                  7    0.750000
# 1056     3     3             2     2                  6    0.666667
# 1057     1     1             1     1                  4    1.000000
# 1058     3     3             2     2                 14    0.666667
#
#       Added_lines  CountStmtDecl  Del_lines  CountLine  CountLineCode  \
# 0              34             90        522        487            349
# 1               0             24        118        118             75
# 2              45             95        458        412            280
# 3              38            142        766        737            588
# 4               0             16         84         84             37
# ...           ...            ...        ...        ...            ...
# 1054           12             53          8        237            169
# 1055           34             25         16        113             82
# 1056          274             51          2        272            189
# 1057            5             13          0         50             25
# 1058           13             75          8        320            222
#
#       CountOutput_Max  CountLineCodeDecl  CountStmt  CountLineCodeExe
# 0                  31                110        234               215
# 1                   9                 27         53                42
# 2                  25                132        187               143
# 3                  32                171        398               381
# 4                   4                 20         24                10
# ...               ...                ...        ...               ...
# 1054               13                 62        131                94
# 1055               19                 32         65                52
# 1056               15                 65        131               118
# 1057                7                 16         19                11
# 1058               32                 94        171               123
#
# [1059 rows x 15 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8553459119496856
# Precision :  0.6428571428571429
# Recall :  0.46551724137931033
# F1 Score :  0.5399999999999999
# AUC :  0.7039124668435013

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8270440251572327
# Precision :  0.8
# Recall :  0.06896551724137931
# F1 Score :  0.12698412698412698
# AUC :  0.5325596816976127

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8081761006289309
# Precision :  0.46808510638297873
# Recall :  0.3793103448275862
# F1 Score :  0.41904761904761906
# AUC :  0.6415782493368701

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.5817610062893082
# Precision :  0.292817679558011
# Recall :  0.9137931034482759
# F1 Score :  0.4435146443514645
# AUC :  0.7107427055702917

# %% [markdown]
# # FISHER SCORE

# %%
FScore = []

for m in  range(len(col_list)):
        mu = df[col_list[m]].mean()

        n_1 = df[df['class'] == 0].count()[1]
        mu_1 = df[col_list[m]][df['class'] == 0].mean()
        var_1 = df[col_list[m]][df['class'] == 0].var()

        n_2 = df[df['class'] == 1].count()[1]
        mu_2 = df[col_list[m]][df['class'] == 1].mean()
        var_2 = df[col_list[m]][df['class'] == 1].var()

        inter_class = n_1*(mu_1-mu)**2 + n_2*(mu_2-mu)**2
        intra_class = (n_1-1)*var_1 + (n_2-1)*var_2

        FScore.append(inter_class / intra_class)

FScore
# Out:
# [0.024384746134826496,
#  0.0255114302253111,
#  0.005079116211448901,
#  0.07693003222333583,
#  0.020487917599741175,
#  0.0022878281366879227,
#  0.0016396530626357159,
#  0.0006073310675673296,
#  0.009667131153043554,
#  0.032228110271701235,
#  0.00471610220873393,
#  0.017386018542205107,
#  0.010514757308352957,
#  0.00043458578771920706,
#  0.0381569964534331,
#  0.00012661042437986213,
#  0.0003838674043320183,
#  0.0007322269782130984,
#  0.009163374712989357,
#  0.0036361548454451223,
#  0.0026608921048459073,
#  0.05490787624995542,
#  4.363285050626759e-05,
#  0.004494229456024583,
#  0.0005796340847173138,
#  0.0003626309062072873,
#  0.007726872312200573,
#  0.0031080522306027765,
#  0.0021095904670659486,
#  0.0023885668315447536,
#  0.002501979686897615,
#  0.0034636500003403176,
#  0.08114514900936667,
#  0.005500239551509988,
#  0.004610229029630051,
#  0.0002568532999232317,
#  0.008431265107680268,
#  0.03754796687125171,
#  0.0013845211737264283,
#  0.0011076600317556013,
#  0.22861671352099563,
#  0.004769585062660614,
#  0.011102013216321368,
#  0.007499936070607424,
#  0.015018530369540938,
#  0.17624512354559407,
#  0.0417788962712563,
#  0.004195509591337111,
#  2.980659090167416e-05,
#  0.00020782595251373395,
#  0.0005651735062826788,
#  0.07040497058908902,
#  0.014890987429864763,
#  0.003924579812902732,
#  0.23886949655946202,
#  0.23886949655946202,
#  0.29422338966025796,
#  0.0015763206695373314,
#  0.002835933618371383,
#  0.060291210823807825,
#  0.0490045381807294,
#  0.049976125780853975,
#  0.05993808774911381,
#  0.2685497521991023,
#  0.1563978148489611]

# %%
temp = pd.DataFrame(list(zip(col_list, FScore)), columns =['col', 'score']) 
temp
# Out:
#                        col     score
# 0   CountDeclMethodPrivate  0.024385
# 1              AvgLineCode  0.025511
# 2                CountLine  0.005079
# 3            MaxCyclomatic  0.076930
# 4   CountDeclMethodDefault  0.020488
# ..                     ...       ...
# 60              OWN_COMMIT  0.049005
# 61            MINOR_COMMIT  0.049976
# 62              MINOR_LINE  0.059938
# 63            MAJOR_COMMIT  0.268550
# 64              MAJOR_LINE  0.156398
#
# [65 rows x 2 columns]

# %%
temp_sort = temp.sort_values(['score'], ascending=False)
temp_sort[:10]
# Out:
#                       col     score
# 56                   DDEV  0.294223
# 63           MAJOR_COMMIT  0.268550
# 55                   ADEV  0.238869
# 54                   COMM  0.238869
# 40      CountClassCoupled  0.228617
# 45        CountOutput_Max  0.176245
# 64             MAJOR_LINE  0.156398
# 32  MaxCyclomaticModified  0.081145
# 3           MaxCyclomatic  0.076930
# 51         MaxNesting_Max  0.070405

# %%
FS = list(temp_sort['col'][:10])
FS
# Out:
# ['DDEV',
#  'MAJOR_COMMIT',
#  'ADEV',
#  'COMM',
#  'CountClassCoupled',
#  'CountOutput_Max',
#  'MAJOR_LINE',
#  'MaxCyclomaticModified',
#  'MaxCyclomatic',
#  'MaxNesting_Max']

# %%
X_new = df[FS]
X_new
# Out:
#       DDEV  MAJOR_COMMIT  ADEV  COMM  CountClassCoupled  CountOutput_Max  \
# 0        1             1     2     2                 14               31
# 1        1             1     1     1                  2                9
# 2        1             1     3     3                 12               25
# 3        2             2     5     5                 15               32
# 4        1             1     1     1                  6                4
# ...    ...           ...   ...   ...                ...              ...
# 1054     1             1     3     3                  9               13
# 1055     2             2     4     4                  7               19
# 1056     2             2     3     3                  6               15
# 1057     1             1     1     1                  4                7
# 1058     2             2     3     3                 14               32
#
#       MAJOR_LINE  MaxCyclomaticModified  MaxCyclomatic  MaxNesting_Max
# 0              0                     12             12               6
# 1              0                      6              6               3
# 2              0                     10             10               3
# 3              2                     21             21               4
# 4              0                      2              2               6
# ...          ...                    ...            ...             ...
# 1054           1                      6              6               4
# 1055           0                      1              1               0
# 1056           1                      5              5               3
# 1057           0                      1              1               0
# 1058           1                      2              2               1
#
# [1059 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8144654088050315
# Precision :  0.4909090909090909
# Recall :  0.46551724137931033
# F1 Score :  0.47787610619469023
# AUC :  0.6789124668435013

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.839622641509434
# Precision :  0.6129032258064516
# Recall :  0.3275862068965517
# F1 Score :  0.42696629213483145
# AUC :  0.6407161803713527

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8301886792452831
# Precision :  0.5454545454545454
# Recall :  0.41379310344827586
# F1 Score :  0.47058823529411764
# AUC :  0.6684350132625995

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.839622641509434
# Precision :  0.5573770491803278
# Recall :  0.5862068965517241
# F1 Score :  0.5714285714285715
# AUC :  0.7411803713527852

# %% [markdown]
# # SVM RFE 10

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,random_state=23)

# %%
from sklearn.feature_selection import RFE
rec_model = RandomForestClassifier()

rfe = RFE(rec_model, n_features_to_select=10)
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=RandomForestClassifier(), n_features_to_select=10)

# %%
X_train = X_train.loc[:, rfe.support_]
X_train
# Out:
#      CountLine  CountLineComment  CountLineCodeExe  CountStmtDecl  \
# 301        302                61                96             69
# 885         54                27                 6             12
# 0          487               106               215             90
# 293        132                64                27             21
# 423         34                28                 0              3
# ..         ...               ...               ...            ...
# 237        428               114               135             99
# 31         255                42               123             59
# 950        257                51               101             76
# 742         38                31                 0              5
# 595         50                18                 9              9
#
#      CountClassCoupled  CountInput_Mean  COMM  ADEV  Added_lines  Del_lines
# 301                  4         2.350000     4     4          313         12
# 885                  4         2.000000     1     1           15          4
# 0                   14         6.533333     2     2           34        522
# 293                  8         5.000000     4     4            8          5
# 423                  0         1.000000     1     1            3          0
# ..                 ...              ...   ...   ...          ...        ...
# 237                  7         3.448276     4     4           24         21
# 31                   8         3.333333     2     2            8        259
# 950                 17         5.818182     1     1            5          0
# 742                  0         2.000000     0     0            0          0
# 595                  0         1.800000     1     1            2          1
#
# [741 rows x 10 columns]

# %%
X_test = X_test.loc[:, rfe.support_]
X_test
# Out:
#      CountLine  CountLineComment  CountLineCodeExe  CountStmtDecl  \
# 694        107                62                17             18
# 441         69                25                 7             13
# 684         57                39                 0              8
# 207        148                41                43             26
# 328        191                40                72             49
# ..         ...               ...               ...            ...
# 807        397                80               173             77
# 858         95                17                35             25
# 390         43                28                 3              6
# 713        178                57                66             45
# 517        149                65                32             31
#
#      CountClassCoupled  CountInput_Mean  COMM  ADEV  Added_lines  Del_lines
# 694                  5         3.600000     8     8          143         65
# 441                  2         1.166667     3     3           25          0
# 684                  0         1.000000     1     1            3          0
# 207                  0         2.700000     1     1            2          0
# 328                 16         8.000000     5     5           17          5
# ..                 ...              ...   ...   ...          ...        ...
# 807                  9         3.571429     9     9           31         19
# 858                  9         1.750000     3     3          104          3
# 390                  0         4.000000     1     1            5          0
# 713                 19         2.800000     3     3           37         28
# 517                  9         9.500000     1     1            2          0
#
# [318 rows x 10 columns]

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8584905660377359
# Precision :  0.6444444444444445
# Recall :  0.5
# F1 Score :  0.5631067961165049
# AUC :  0.7192307692307691

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8270440251572327
# Precision :  0.8
# Recall :  0.06896551724137931
# F1 Score :  0.12698412698412698
# AUC :  0.5325596816976127

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8333333333333334
# Precision :  0.5641025641025641
# Recall :  0.3793103448275862
# F1 Score :  0.4536082474226804
# AUC :  0.6569628647214855

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.6981132075471698
# Precision :  0.36231884057971014
# Recall :  0.8620689655172413
# F1 Score :  0.5102040816326531
# AUC :  0.7618037135278514

# %% [markdown]
# # SVM RFE 15

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,random_state=23)

# %%
from sklearn.feature_selection import RFE
rec_model = RandomForestClassifier()

rfe = RFE(rec_model, n_features_to_select=15)
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=RandomForestClassifier(), n_features_to_select=15)

# %%
X_train = X_train.loc[:, rfe.support_]
X_train
# Out:
#      CountLine  CountLineComment  CountLineCodeDecl  CountLineCodeExe  \
# 301        302                61                 94                96
# 885         54                27                 12                 6
# 0          487               106                110               215
# 293        132                64                 26                27
# 423         34                28                  3                 0
# ..         ...               ...                ...               ...
# 237        428               114                101               135
# 31         255                42                 62               123
# 950        257                51                 81               101
# 742         38                31                  5                 0
# 595         50                18                 11                 9
#
#      CountLineCode  CountStmt  CountClassCoupled  CountInput_Max  \
# 301            212        114                  4               7
# 885             21         18                  4               3
# 0              349        234                 14              15
# 293             61         41                  8               7
# 423              4          3                  0               1
# ..             ...        ...                ...             ...
# 237            256        186                  7              10
# 31             181        155                  8               6
# 950            173        140                 17              17
# 742              5          5                  0               2
# 595             25         15                  0               5
#
#      CountOutput_Mean  COMM  ADEV  Added_lines  Del_lines  OWN_LINE  \
# 301          3.050000     4     4          313         12  0.827815
# 885          2.000000     1     1           15          4  0.818182
# 0            9.400000     2     2           34        522  1.000000
# 293          5.666667     4     4            8          5  0.522727
# 423          0.000000     1     1            3          0  0.647059
# ..                ...   ...   ...          ...        ...       ...
# 237          3.241379     4     4           24         21  0.826698
# 31           7.000000     2     2            8        259  0.968627
# 950          5.545455     1     1            5          0  0.859922
# 742          1.000000     0     0            0          0  1.000000
# 595          1.200000     1     1            2          1  1.000000
#
#      MAJOR_COMMIT
# 301             4
# 885             1
# 0               1
# 293             1
# 423             1
# ..            ...
# 237             3
# 31              2
# 950             1
# 742             0
# 595             1
#
# [741 rows x 15 columns]

# %%
X_test = X_test.loc[:, rfe.support_]
X_test
# Out:
#      CountLine  CountLineComment  CountLineCodeDecl  CountLineCodeExe  \
# 694        107                62                 20                17
# 441         69                25                 21                 7
# 684         57                39                 10                 0
# 207        148                41                 36                43
# 328        191                40                 57                72
# ..         ...               ...                ...               ...
# 807        397                80                 83               173
# 858         95                17                 27                35
# 390         43                28                  6                 3
# 713        178                57                 51                66
# 517        149                65                 32                32
#
#      CountLineCode  CountStmt  CountClassCoupled  CountInput_Max  \
# 694             39         30                  5               6
# 441             35         19                  2               5
# 684             11          8                  0               1
# 207             89         64                  0               9
# 328            133         97                 16              14
# ..             ...        ...                ...             ...
# 807            254        202                  9              12
# 858             63         48                  9               3
# 390             11          8                  0               5
# 713            108         71                 19               8
# 517             70         54                  9              16
#
#      CountOutput_Mean  COMM  ADEV  Added_lines  Del_lines  OWN_LINE  \
# 694          3.800000     8     8          143         65  0.869159
# 441          1.333333     3     3           25          0  0.637681
# 684          1.000000     1     1            3          0  1.000000
# 207          2.700000     1     1            2          0  1.000000
# 328         12.250000     5     5           17          5  1.000000
# ..                ...   ...   ...          ...        ...       ...
# 807          5.785714     9     9           31         19  0.962217
# 858         10.500000     3     3          104          3  1.000000
# 390          1.000000     1     1            5          0  1.000000
# 713         11.000000     3     3           37         28  0.983146
# 517          6.500000     1     1            2          0  1.000000
#
#      MAJOR_COMMIT
# 694             1
# 441             3
# 684             1
# 207             1
# 328             3
# ..            ...
# 807             4
# 858             1
# 390             1
# 713             1
# 517             1
#
# [318 rows x 15 columns]

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8584905660377359
# Precision :  0.6444444444444445
# Recall :  0.5
# F1 Score :  0.5631067961165049
# AUC :  0.7192307692307691

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8270440251572327
# Precision :  0.8
# Recall :  0.06896551724137931
# F1 Score :  0.12698412698412698
# AUC :  0.5325596816976127

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8113207547169812
# Precision :  0.4807692307692308
# Recall :  0.43103448275862066
# F1 Score :  0.45454545454545453
# AUC :  0.6635941644562333

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.4968553459119497
# Precision :  0.2571428571428571
# Recall :  0.9310344827586207
# F1 Score :  0.40298507462686567
# AUC :  0.6655172413793103

# %% [markdown]
# # MRMR 10

# %%
from sklearn.feature_selection import f_regression

F = pd.Series(f_regression(X, Y)[0], index = X.columns)
corr = X.corr().abs().clip(.00001)

# %%
selected = []
feat_score = []
not_selected = list(X.columns)

# %%
K = 10

for i in range(K):
    
    # compute FCQ score for all the (currently) excluded features (this is Formula 2)
    score = F.loc[not_selected] / corr.loc[not_selected, selected].mean(axis = 1).fillna(.00001)
    
    # find best feature, add it to selected and remove it from not_selected
    best = score.index[score.argmax()]
    selected.append(best)
    feat_score.append(score[best])
    not_selected.remove(best)

# %%
selected
# Out:
# ['DDEV',
#  'CountClassCoupled',
#  'MAJOR_COMMIT',
#  'COMM',
#  'CountOutput_Max',
#  'ADEV',
#  'MAJOR_LINE',
#  'MaxNesting_Max',
#  'OWN_LINE',
#  'OWN_COMMIT']

# %%
X_new = X[selected]
X_new
# Out:
#       DDEV  CountClassCoupled  MAJOR_COMMIT  COMM  CountOutput_Max  ADEV  \
# 0        1                 14             1     2               31     2
# 1        1                  2             1     1                9     1
# 2        1                 12             1     3               25     3
# 3        2                 15             2     5               32     5
# 4        1                  6             1     1                4     1
# ...    ...                ...           ...   ...              ...   ...
# 1054     1                  9             1     3               13     3
# 1055     2                  7             2     4               19     4
# 1056     2                  6             2     3               15     3
# 1057     1                  4             1     1                7     1
# 1058     2                 14             2     3               32     3
#
#       MAJOR_LINE  MaxNesting_Max  OWN_LINE  OWN_COMMIT
# 0              0               6  1.000000    1.000000
# 1              0               3  1.000000    1.000000
# 2              0               3  1.000000    1.000000
# 3              2               4  0.972900    0.800000
# 4              0               6  1.000000    1.000000
# ...          ...             ...       ...         ...
# 1054           1               4  0.966245    1.000000
# 1055           0               0  0.840708    0.750000
# 1056           1               3  0.970588    0.666667
# 1057           0               0  0.880000    1.000000
# 1058           1               1  0.909375    0.666667
#
# [1059 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8144654088050315
# Precision :  0.49056603773584906
# Recall :  0.4482758620689655
# F1 Score :  0.46846846846846846
# AUC :  0.6722148541114058

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8490566037735849
# Precision :  0.6785714285714286
# Recall :  0.3275862068965517
# F1 Score :  0.441860465116279
# AUC :  0.6464854111405834

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8490566037735849
# Precision :  0.625
# Recall :  0.43103448275862066
# F1 Score :  0.5102040816326531
# AUC :  0.6866710875331564

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8459119496855346
# Precision :  0.5789473684210527
# Recall :  0.5689655172413793
# F1 Score :  0.5739130434782609
# AUC :  0.7383289124668435

# %% [markdown]
# # MRMR 15

# %%
from sklearn.feature_selection import f_regression

F = pd.Series(f_regression(X, Y)[0], index = X.columns)
corr = X.corr().abs().clip(.00001)

# %%
selected = []
feat_score = []
not_selected = list(X.columns)

# %%
K = 15

for i in range(K):
    
    # compute FCQ score for all the (currently) excluded features (this is Formula 2)
    score = F.loc[not_selected] / corr.loc[not_selected, selected].mean(axis = 1).fillna(.00001)
    
    # find best feature, add it to selected and remove it from not_selected
    best = score.index[score.argmax()]
    selected.append(best)
    feat_score.append(score[best])
    not_selected.remove(best)

# %%
selected
# Out:
# ['DDEV',
#  'CountClassCoupled',
#  'MAJOR_COMMIT',
#  'COMM',
#  'CountOutput_Max',
#  'ADEV',
#  'MAJOR_LINE',
#  'MaxNesting_Max',
#  'OWN_LINE',
#  'OWN_COMMIT',
#  'MaxCyclomaticModified',
#  'CountOutput_Mean',
#  'MINOR_LINE',
#  'MaxCyclomatic',
#  'CountInput_Min']

# %%
X_new = X[selected]
X_new
# Out:
#       DDEV  CountClassCoupled  MAJOR_COMMIT  COMM  CountOutput_Max  ADEV  \
# 0        1                 14             1     2               31     2
# 1        1                  2             1     1                9     1
# 2        1                 12             1     3               25     3
# 3        2                 15             2     5               32     5
# 4        1                  6             1     1                4     1
# ...    ...                ...           ...   ...              ...   ...
# 1054     1                  9             1     3               13     3
# 1055     2                  7             2     4               19     4
# 1056     2                  6             2     3               15     3
# 1057     1                  4             1     1                7     1
# 1058     2                 14             2     3               32     3
#
#       MAJOR_LINE  MaxNesting_Max  OWN_LINE  OWN_COMMIT  MaxCyclomaticModified  \
# 0              0               6  1.000000    1.000000                     12
# 1              0               3  1.000000    1.000000                      6
# 2              0               3  1.000000    1.000000                     10
# 3              2               4  0.972900    0.800000                     21
# 4              0               6  1.000000    1.000000                      2
# ...          ...             ...       ...         ...                    ...
# 1054           1               4  0.966245    1.000000                      6
# 1055           0               0  0.840708    0.750000                      1
# 1056           1               3  0.970588    0.666667                      5
# 1057           0               0  0.880000    1.000000                      1
# 1058           1               1  0.909375    0.666667                      2
#
#       CountOutput_Mean  MINOR_LINE  MaxCyclomatic  CountInput_Min
# 0             9.400000           1             12               0
# 1             3.428571           1              6               1
# 2             5.833333           1             10               0
# 3             7.321429           1             21               0
# 4             1.400000           1              2               0
# ...                ...         ...            ...             ...
# 1054          3.800000           1              6               1
# 1055          4.600000           2              1               0
# 1056          8.625000           1              5               2
# 1057          7.000000           2              1               2
# 1058          4.105263           2              2               0
#
# [1059 rows x 15 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8364779874213837
# Precision :  0.5625
# Recall :  0.46551724137931033
# F1 Score :  0.5094339622641509
# AUC :  0.6923740053050398

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8270440251572327
# Precision :  0.5333333333333333
# Recall :  0.41379310344827586
# F1 Score :  0.4660194174757281
# AUC :  0.6665119363395225

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8427672955974843
# Precision :  0.625
# Recall :  0.3448275862068966
# F1 Score :  0.4444444444444445
# AUC :  0.6493368700265252

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8270440251572327
# Precision :  0.5333333333333333
# Recall :  0.41379310344827586
# F1 Score :  0.4660194174757281
# AUC :  0.6665119363395225

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8427672955974843
# Precision :  0.5625
# Recall :  0.6206896551724138
# F1 Score :  0.5901639344262296
# AUC :  0.756498673740053

# %% [markdown]
# # MRMR HFS

# %%
def HSF(df, df_train):
    
    from copy import deepcopy
    col_list = list(df_train.columns)
    print(col_list)
    d = df_train.shape[1]
    SF = []
    merit = [0 for i in range(d)]
    merit_archive = [0 for i in range(d)]
    Total_FS = [0 for i in range(d)]

    rel_CF = RHFS(df, d, col_list)

    max_value = max(rel_CF)
    Feature_max_index = rel_CF.index(max_value)

    n = 0

    SF.append(Feature_max_index)

    merit_archive[n] = deepcopy(max_value)

    Total_FS[n] = deepcopy(SF)

    while n < d-1:

        for i in range(d):

            red_FF = SHFS(SF, df_train, i, col_list,d)

            top = (d + d*(sum(rel_CF)/len(rel_CF)))
            bottom = (d + (d*(d-1)*(sum(red_FF)/len(red_FF))))**(1/2)
            merit[i] = top/bottom

        for val in SF:
            merit[val] = -9999999

        max_value = max(merit)
        Feature_max_index = merit.index(max_value)

        if Feature_max_index not in SF:
            SF.append(Feature_max_index)

        n += 1
        
        Total_FS[n] = deepcopy(SF)

        merit_archive[n] = max_value

    index_val = merit_archive.index(max(merit_archive))

    Feature_subset = Total_FS[index_val]

    subset_list = []

    for val in Feature_subset:
        subset_list.append(col_list[val])
    return subset_list


def RHFS(df, d, col_list):
    rel_CF = [0 for i in range(d)]
    count = 0

    igain = IG(X,df['class'])

    for m in  range(d):
        mu = df[col_list[m]].mean()

        n_1 = df[df['class'] == 0].count()[1]
        mu_1 = df[col_list[m]][df['class'] == 0].mean()
        var_1 = df[col_list[m]][df['class'] == 0].var()

        n_2 = df[df['class'] == 1].count()[1]
        mu_2 = df[col_list[m]][df['class'] == 1].mean()
        var_2 = df[col_list[m]][df['class'] == 1].var()

        inter_class = n_1*(mu_1-mu)**2 + n_2*(mu_2-mu)**2
        intra_class = (n_1-1)*var_1 + (n_2-1)*var_2

        fscore = inter_class / intra_class

        rel_CF[count] = (1/2)*(fscore + igain[m])
        count += 1
    
    return rel_CF

        
        

def IG(col_1, col_2):
    from sklearn.feature_selection import mutual_info_classif
    gain = mutual_info_classif(col_1,col_2)
    return gain   

def relief(col_1,col_2):
    pass



def SHFS(SF, df_train, i, col_list,d):
    from itertools import combinations
    from copy import deepcopy
    red_FF = []
    temp_SF = deepcopy(SF)
    if i not in SF:
        temp_SF.append(i)
        P_pairs = list(combinations(temp_SF,2))
        for pair in P_pairs:

            ied_value = (IED(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            pc_value = (PC(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            cs_value = (CS(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2

            red_FF.append((1/3)*(ied_value + pc_value + cs_value))
            # red_FF.append((1/2)*(pc_value + cs_value))
    else:
        red_FF = [0]
    return red_FF

def IED(col_1, col_2):
    import numpy as np
    dist = np.linalg.norm(col_1 - col_2)
    return 1/dist

def PC(col_1, col_2):
    from scipy.stats import pearsonr
    corr, _ = pearsonr(col_1 , col_2)
    return corr

def CS(col_1, col_2):
    from scipy import spatial
    similarity = 1 - spatial.distance.cosine(col_1, col_2)
    return similarity

# %%
FS = HSF(df, X)
FS
# Out:
# ['CountDeclMethodPrivate', 'AvgLineCode', 'CountLine', 'MaxCyclomatic', 'CountDeclMethodDefault', 'AvgEssential', 'CountDeclClassVariable', 'SumCyclomaticStrict', 'AvgCyclomatic', 'AvgLine', 'CountDeclClassMethod', 'AvgLineComment', 'AvgCyclomaticModified', 'CountDeclFunction', 'CountLineComment', 'CountDeclClass', 'CountDeclMethod', 'SumCyclomaticModified', 'CountLineCodeDecl', 'CountDeclMethodProtected', 'CountDeclInstanceVariable', 'MaxCyclomaticStrict', 'CountDeclMethodPublic', 'CountLineCodeExe', 'SumCyclomatic', 'SumEssential', 'CountStmtDecl', 'CountLineCode', 'CountStmtExe', 'RatioCommentToCode', 'CountLineBlank', 'CountStmt', 'MaxCyclomaticModified', 'CountSemicolon', 'AvgLineBlank', 'CountDeclInstanceMethod', 'AvgCyclomaticStrict', 'PercentLackOfCohesion', 'MaxInheritanceTree', 'CountClassDerived', 'CountClassCoupled', 'CountClassBase', 'CountInput_Max', 'CountInput_Mean', 'CountInput_Min', 'CountOutput_Max', 'CountOutput_Mean', 'CountOutput_Min', 'CountPath_Max', 'CountPath_Mean', 'CountPath_Min', 'MaxNesting_Max', 'MaxNesting_Mean', 'MaxNesting_Min', 'COMM', 'ADEV', 'DDEV', 'Added_lines', 'Del_lines', 'OWN_LINE', 'OWN_COMMIT', 'MINOR_COMMIT', 'MINOR_LINE', 'MAJOR_COMMIT', 'MAJOR_LINE']
# C:\Users\acer\AppData\Local\Temp\ipykernel_12760\2073211282.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1/dist
# ['DDEV',
#  'CountPath_Min',
#  'CountPath_Mean',
#  'RatioCommentToCode',
#  'CountDeclMethodPublic']

# %%
X_new = X[FS]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8207547169811321
# Precision :  0.5102040816326531
# Recall :  0.43103448275862066
# F1 Score :  0.4672897196261682
# AUC :  0.6693633952254641

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8176100628930818
# Precision :  0.0
# Recall :  0.0
# F1 Score :  0.0
# AUC :  0.5
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7987421383647799
# Precision :  0.4166666666666667
# Recall :  0.25862068965517243
# F1 Score :  0.3191489361702128
# AUC :  0.5889257294429708

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.3113207547169811
# Precision :  0.2029520295202952
# Recall :  0.9482758620689655
# F1 Score :  0.3343465045592705
# AUC :  0.5587533156498674

# %% [markdown]
# # HFS NEW

# %%
def HSF(df, df_train):
    
    from copy import deepcopy
    col_list = list(df_train.columns)
    print(col_list)
    d = df_train.shape[1]
    SF = []
    merit = [0 for i in range(d)]
    merit_archive = [0 for i in range(d)]
    Total_FS = [0 for i in range(d)]

    rel_CF = RHFS(df, d, col_list)

    max_value = max(rel_CF)
    Feature_max_index = rel_CF.index(max_value)

    n = 0

    SF.append(Feature_max_index)

    merit_archive[n] = deepcopy(max_value)

    Total_FS[n] = deepcopy(SF)

    while n < d-1:

        for i in range(d):

            red_FF = SHFS(SF, df_train, i, col_list,d)

            top = (d + d*(sum(rel_CF)/len(rel_CF)))
            bottom = (d - (sum(red_FF)/len(red_FF)))**(1/2)

            merit[i] = top/bottom

        for val in SF:
            merit[val] = -9999999

        max_value = max(merit)
        Feature_max_index = merit.index(max_value)

        if Feature_max_index not in SF:
            SF.append(Feature_max_index)

        n += 1
        
        Total_FS[n] = deepcopy(SF)

        merit_archive[n] = max_value

    index_val = merit_archive.index(max(merit_archive))

    Feature_subset = Total_FS[index_val]

    subset_list = []

    for val in Feature_subset:
        subset_list.append(col_list[val])
    return subset_list


def RHFS(df, d, col_list):
    rel_CF = [0 for i in range(d)]
    count = 0

    igain = IG(X,df['class'])

    for m in  range(d):
        mu = df[col_list[m]].mean()

        n_1 = df[df['class'] == 0].count()[1]
        mu_1 = df[col_list[m]][df['class'] == 0].mean()
        var_1 = df[col_list[m]][df['class'] == 0].var()

        n_2 = df[df['class'] == 1].count()[1]
        mu_2 = df[col_list[m]][df['class'] == 1].mean()
        var_2 = df[col_list[m]][df['class'] == 1].var()

        inter_class = n_1*(mu_1-mu)**2 + n_2*(mu_2-mu)**2
        intra_class = (n_1-1)*var_1 + (n_2-1)*var_2

        fscore = inter_class / intra_class

        rel_CF[count] = (1/2)*(fscore + igain[m])
        count += 1
    
    return rel_CF

        
        

def IG(col_1, col_2):
    from sklearn.feature_selection import mutual_info_classif
    gain = mutual_info_classif(col_1,col_2)
    return gain   

def relief(col_1,col_2):
    pass



def SHFS(SF, df_train, i, col_list,d):
    from itertools import combinations
    from copy import deepcopy
    red_FF = []
    temp_SF = deepcopy(SF)
    if i not in SF:
        temp_SF.append(i)
        P_pairs = list(combinations(temp_SF,2))
        for pair in P_pairs:

            ied_value = (IED(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            pc_value = (PC(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            cs_value = (CS(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2

            red_FF.append((1/3)*(ied_value + pc_value + cs_value))
            # red_FF.append((1/2)*(pc_value + cs_value))
    else:
        red_FF = [0]
    return red_FF

def IED(col_1, col_2):
    import numpy as np
    dist = np.linalg.norm(col_1 - col_2)
    return 1/dist

def PC(col_1, col_2):
    from scipy.stats import pearsonr
    corr, _ = pearsonr(col_1 , col_2)
    return corr

def CS(col_1, col_2):
    from scipy import spatial
    similarity = 1 - spatial.distance.cosine(col_1, col_2)
    return similarity

# %%
FS = HSF(df, X)
FS
# Out:
# ['CountDeclMethodPrivate', 'AvgLineCode', 'CountLine', 'MaxCyclomatic', 'CountDeclMethodDefault', 'AvgEssential', 'CountDeclClassVariable', 'SumCyclomaticStrict', 'AvgCyclomatic', 'AvgLine', 'CountDeclClassMethod', 'AvgLineComment', 'AvgCyclomaticModified', 'CountDeclFunction', 'CountLineComment', 'CountDeclClass', 'CountDeclMethod', 'SumCyclomaticModified', 'CountLineCodeDecl', 'CountDeclMethodProtected', 'CountDeclInstanceVariable', 'MaxCyclomaticStrict', 'CountDeclMethodPublic', 'CountLineCodeExe', 'SumCyclomatic', 'SumEssential', 'CountStmtDecl', 'CountLineCode', 'CountStmtExe', 'RatioCommentToCode', 'CountLineBlank', 'CountStmt', 'MaxCyclomaticModified', 'CountSemicolon', 'AvgLineBlank', 'CountDeclInstanceMethod', 'AvgCyclomaticStrict', 'PercentLackOfCohesion', 'MaxInheritanceTree', 'CountClassDerived', 'CountClassCoupled', 'CountClassBase', 'CountInput_Max', 'CountInput_Mean', 'CountInput_Min', 'CountOutput_Max', 'CountOutput_Mean', 'CountOutput_Min', 'CountPath_Max', 'CountPath_Mean', 'CountPath_Min', 'MaxNesting_Max', 'MaxNesting_Mean', 'MaxNesting_Min', 'COMM', 'ADEV', 'DDEV', 'Added_lines', 'Del_lines', 'OWN_LINE', 'OWN_COMMIT', 'MINOR_COMMIT', 'MINOR_LINE', 'MAJOR_COMMIT', 'MAJOR_LINE']
# C:\Users\acer\AppData\Local\Temp\ipykernel_12760\4067302685.py:125: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1/dist
# ['DDEV', 'MAJOR_COMMIT']

# %%
X_new = X[FS]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8364779874213837
# Precision :  0.6071428571428571
# Recall :  0.29310344827586204
# F1 Score :  0.3953488372093023
# AUC :  0.6253978779840849

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8364779874213837
# Precision :  0.6071428571428571
# Recall :  0.29310344827586204
# F1 Score :  0.3953488372093023
# AUC :  0.6253978779840849

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8333333333333334
# Precision :  0.6190476190476191
# Recall :  0.22413793103448276
# F1 Score :  0.3291139240506329
# AUC :  0.596684350132626

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8081761006289309
# Precision :  0.4810126582278481
# Recall :  0.6551724137931034
# F1 Score :  0.5547445255474452
# AUC :  0.7487400530503978
