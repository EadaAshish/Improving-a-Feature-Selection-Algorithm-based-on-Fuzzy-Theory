# %%
import pandas as pd

# %%
df = pd.read_csv('derby-10.csv')
df
# Out:
#         id  CountDeclMethodPrivate  AvgLineCode  CountLine  MaxCyclomatic  \
# 0        1                       0           46        741             42
# 1        2                       3           51        315             17
# 2        3                       2           13        186              3
# 3        4                       0            4        137              4
# 4        5                       0            4        134              4
# ...    ...                     ...          ...        ...            ...
# 2700  2701                       1           13        224              9
# 2701  2702                       1           22        195              9
# 2702  2703                       0            5         36              1
# 2703  2704                       0           13         74              4
# 2704  2705                       7           33        646             17
#
#       CountDeclMethodDefault  AvgEssential  CountDeclClassVariable  \
# 0                          0             5                       1
# 1                          0             1                       0
# 2                          0             1                      12
# 3                          0             1                       0
# 4                          0             1                       0
# ...                      ...           ...                     ...
# 2700                       0             1                       1
# 2701                       0             1                       0
# 2702                       0             1                       0
# 2703                       0             1                       0
# 2704                       0             4                       3
#
#       SumCyclomaticStrict  AvgCyclomatic  ...  DDEV  Added_lines  Del_lines  \
# 0                     135             10  ...     0            0          0
# 1                      34              8  ...     0            0          0
# 2                       5              2  ...     0            0          0
# 3                      15              1  ...     0            0          0
# 4                      15              1  ...     0            0          0
# ...                   ...            ...  ...   ...          ...        ...
# 2700                   34              3  ...     0            0          0
# 2701                   22              4  ...     0            0          0
# 2702                    1              1  ...     0            0          0
# 2703                   11              4  ...     0            0          0
# 2704                  100              6  ...     0            0          0
#
#       OWN_LINE  OWN_COMMIT  MINOR_COMMIT  MINOR_LINE  MAJOR_COMMIT  \
# 0     0.975709         0.0             0           1             0
# 1     0.933333         0.0             0           1             0
# 2     0.967742         0.0             0           1             0
# 3     0.956204         0.0             0           1             0
# 4     0.955224         0.0             0           1             0
# ...        ...         ...           ...         ...           ...
# 2700  0.973214         0.0             0           1             0
# 2701  0.958974         0.0             0           1             0
# 2702  0.833333         0.0             0           2             0
# 2703  0.918919         0.0             0           2             0
# 2704  1.000000         0.0             0           1             0
#
#       MAJOR_LINE  RealBugCount
# 0              2             0
# 1              2             0
# 2              1             0
# 3              1             0
# 4              1             0
# ...          ...           ...
# 2700           1             0
# 2701           2             0
# 2702           0             0
# 2703           0             0
# 2704           0             0
#
# [2705 rows x 67 columns]

# %%
df.drop(['id'], axis=1, inplace=True)

# %%
df['RealBugCount'].unique()
# Out:
# array([ 0,  2,  8,  9,  1, 11,  4,  6,  5, 15,  3,  7, 19, 20, 10, 22, 12,
#        13, 14], dtype=int64)

# %%
df['RealBugCount'].replace([2,  8,  9,  1, 11,  4,  6,  5, 15,  3,  7, 19, 20, 10, 22, 12, 13, 14], 1, inplace=True)
df['RealBugCount'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df = df.rename({'RealBugCount':'class'}, axis=1)
df
# Out:
#       CountDeclMethodPrivate  AvgLineCode  CountLine  MaxCyclomatic  \
# 0                          0           46        741             42
# 1                          3           51        315             17
# 2                          2           13        186              3
# 3                          0            4        137              4
# 4                          0            4        134              4
# ...                      ...          ...        ...            ...
# 2700                       1           13        224              9
# 2701                       1           22        195              9
# 2702                       0            5         36              1
# 2703                       0           13         74              4
# 2704                       7           33        646             17
#
#       CountDeclMethodDefault  AvgEssential  CountDeclClassVariable  \
# 0                          0             5                       1
# 1                          0             1                       0
# 2                          0             1                      12
# 3                          0             1                       0
# 4                          0             1                       0
# ...                      ...           ...                     ...
# 2700                       0             1                       1
# 2701                       0             1                       0
# 2702                       0             1                       0
# 2703                       0             1                       0
# 2704                       0             4                       3
#
#       SumCyclomaticStrict  AvgCyclomatic  AvgLine  ...  DDEV  Added_lines  \
# 0                     135             10       56  ...     0            0
# 1                      34              8       56  ...     0            0
# 2                       5              2       18  ...     0            0
# 3                      15              1        8  ...     0            0
# 4                      15              1        8  ...     0            0
# ...                   ...            ...      ...  ...   ...          ...
# 2700                   34              3       16  ...     0            0
# 2701                   22              4       27  ...     0            0
# 2702                    1              1        6  ...     0            0
# 2703                   11              4       13  ...     0            0
# 2704                  100              6       41  ...     0            0
#
#       Del_lines  OWN_LINE  OWN_COMMIT  MINOR_COMMIT  MINOR_LINE  MAJOR_COMMIT  \
# 0             0  0.975709         0.0             0           1             0
# 1             0  0.933333         0.0             0           1             0
# 2             0  0.967742         0.0             0           1             0
# 3             0  0.956204         0.0             0           1             0
# 4             0  0.955224         0.0             0           1             0
# ...         ...       ...         ...           ...         ...           ...
# 2700          0  0.973214         0.0             0           1             0
# 2701          0  0.958974         0.0             0           1             0
# 2702          0  0.833333         0.0             0           2             0
# 2703          0  0.918919         0.0             0           2             0
# 2704          0  1.000000         0.0             0           1             0
#
#       MAJOR_LINE  class
# 0              2      0
# 1              2      0
# 2              1      0
# 3              1      0
# 4              1      0
# ...          ...    ...
# 2700           1      0
# 2701           2      0
# 2702           0      0
# 2703           0      0
# 2704           0      0
#
# [2705 rows x 66 columns]

# %%
df[df['class'] == 0]
# Out:
#       CountDeclMethodPrivate  AvgLineCode  CountLine  MaxCyclomatic  \
# 0                          0           46        741             42
# 1                          3           51        315             17
# 2                          2           13        186              3
# 3                          0            4        137              4
# 4                          0            4        134              4
# ...                      ...          ...        ...            ...
# 2700                       1           13        224              9
# 2701                       1           22        195              9
# 2702                       0            5         36              1
# 2703                       0           13         74              4
# 2704                       7           33        646             17
#
#       CountDeclMethodDefault  AvgEssential  CountDeclClassVariable  \
# 0                          0             5                       1
# 1                          0             1                       0
# 2                          0             1                      12
# 3                          0             1                       0
# 4                          0             1                       0
# ...                      ...           ...                     ...
# 2700                       0             1                       1
# 2701                       0             1                       0
# 2702                       0             1                       0
# 2703                       0             1                       0
# 2704                       0             4                       3
#
#       SumCyclomaticStrict  AvgCyclomatic  AvgLine  ...  DDEV  Added_lines  \
# 0                     135             10       56  ...     0            0
# 1                      34              8       56  ...     0            0
# 2                       5              2       18  ...     0            0
# 3                      15              1        8  ...     0            0
# 4                      15              1        8  ...     0            0
# ...                   ...            ...      ...  ...   ...          ...
# 2700                   34              3       16  ...     0            0
# 2701                   22              4       27  ...     0            0
# 2702                    1              1        6  ...     0            0
# 2703                   11              4       13  ...     0            0
# 2704                  100              6       41  ...     0            0
#
#       Del_lines  OWN_LINE  OWN_COMMIT  MINOR_COMMIT  MINOR_LINE  MAJOR_COMMIT  \
# 0             0  0.975709         0.0             0           1             0
# 1             0  0.933333         0.0             0           1             0
# 2             0  0.967742         0.0             0           1             0
# 3             0  0.956204         0.0             0           1             0
# 4             0  0.955224         0.0             0           1             0
# ...         ...       ...         ...           ...         ...           ...
# 2700          0  0.973214         0.0             0           1             0
# 2701          0  0.958974         0.0             0           1             0
# 2702          0  0.833333         0.0             0           2             0
# 2703          0  0.918919         0.0             0           2             0
# 2704          0  1.000000         0.0             0           1             0
#
#       MAJOR_LINE  class
# 0              2      0
# 1              2      0
# 2              1      0
# 3              1      0
# 4              1      0
# ...          ...    ...
# 2700           1      0
# 2701           2      0
# 2702           0      0
# 2703           0      0
# 2704           0      0
#
# [2322 rows x 66 columns]

# %%
X = df.drop(['class'], axis=1)
X
# Out:
#       CountDeclMethodPrivate  AvgLineCode  CountLine  MaxCyclomatic  \
# 0                          0           46        741             42
# 1                          3           51        315             17
# 2                          2           13        186              3
# 3                          0            4        137              4
# 4                          0            4        134              4
# ...                      ...          ...        ...            ...
# 2700                       1           13        224              9
# 2701                       1           22        195              9
# 2702                       0            5         36              1
# 2703                       0           13         74              4
# 2704                       7           33        646             17
#
#       CountDeclMethodDefault  AvgEssential  CountDeclClassVariable  \
# 0                          0             5                       1
# 1                          0             1                       0
# 2                          0             1                      12
# 3                          0             1                       0
# 4                          0             1                       0
# ...                      ...           ...                     ...
# 2700                       0             1                       1
# 2701                       0             1                       0
# 2702                       0             1                       0
# 2703                       0             1                       0
# 2704                       0             4                       3
#
#       SumCyclomaticStrict  AvgCyclomatic  AvgLine  ...  ADEV  DDEV  \
# 0                     135             10       56  ...     0     0
# 1                      34              8       56  ...     0     0
# 2                       5              2       18  ...     0     0
# 3                      15              1        8  ...     0     0
# 4                      15              1        8  ...     0     0
# ...                   ...            ...      ...  ...   ...   ...
# 2700                   34              3       16  ...     0     0
# 2701                   22              4       27  ...     0     0
# 2702                    1              1        6  ...     0     0
# 2703                   11              4       13  ...     0     0
# 2704                  100              6       41  ...     0     0
#
#       Added_lines  Del_lines  OWN_LINE  OWN_COMMIT  MINOR_COMMIT  MINOR_LINE  \
# 0               0          0  0.975709         0.0             0           1
# 1               0          0  0.933333         0.0             0           1
# 2               0          0  0.967742         0.0             0           1
# 3               0          0  0.956204         0.0             0           1
# 4               0          0  0.955224         0.0             0           1
# ...           ...        ...       ...         ...           ...         ...
# 2700            0          0  0.973214         0.0             0           1
# 2701            0          0  0.958974         0.0             0           1
# 2702            0          0  0.833333         0.0             0           2
# 2703            0          0  0.918919         0.0             0           2
# 2704            0          0  1.000000         0.0             0           1
#
#       MAJOR_COMMIT  MAJOR_LINE
# 0                0           2
# 1                0           2
# 2                0           1
# 3                0           1
# 4                0           1
# ...            ...         ...
# 2700             0           1
# 2701             0           2
# 2702             0           0
# 2703             0           0
# 2704             0           0
#
# [2705 rows x 65 columns]

# %%
Y = df['class']
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2700    0
# 2701    0
# 2702    0
# 2703    0
# 2704    0
# Name: class, Length: 2705, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import *

# %% [markdown]
# # All Features

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8596059113300493
# Precision :  0.0
# Recall :  0.0
# F1 Score :  0.0
# AUC :  0.5
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8596059113300493
# Precision :  0.0
# Recall :  0.0
# F1 Score :  0.0
# AUC :  0.5
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8300492610837439
# Precision :  0.3
# Recall :  0.15789473684210525
# F1 Score :  0.20689655172413793
# AUC :  0.5488614085356658

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8596059113300493
# Precision :  0.5
# Recall :  0.02631578947368421
# F1 Score :  0.05
# AUC :  0.5110088976021716

# %% [markdown]
# # PEARSON CORRELATION

# %%
cor = df.corr()
cor_target = abs(cor['class'])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.34]
relevant_features
# Out:
# CountLine                0.349892
# SumCyclomaticModified    0.342120
# SumCyclomatic            0.341507
# CountLineCode            0.341171
# CountClassCoupled        0.352687
# MAJOR_LINE               0.394876
# class                    1.000000
# Name: class, dtype: float64

# %%
X_new = df[['CountLine', 'SumCyclomaticModified', 'SumCyclomatic', 'CountLineCode', 'CountClassCoupled', 'MAJOR_LINE']]
X_new
# Out:
#       CountLine  SumCyclomaticModified  SumCyclomatic  CountLineCode  \
# 0           741                    109            109            547
# 1           315                     33             33            228
# 2           186                      5              5             86
# 3           137                     15             15             57
# 4           134                     15             15             56
# ...         ...                    ...            ...            ...
# 2700        224                     31             31            155
# 2701        195                     20             20            143
# 2702         36                      1              1             11
# 2703         74                     11             11             48
# 2704        646                     78             78            482
#
#       CountClassCoupled  MAJOR_LINE
# 0                     3           2
# 1                     1           2
# 2                     2           1
# 3                     0           1
# 4                     0           1
# ...                 ...         ...
# 2700                  8           1
# 2701                  7           2
# 2702                  1           0
# 2703                  0           0
# 2704                  0           0
#
# [2705 rows x 6 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8633004926108374
# Precision :  0.5245901639344263
# Recall :  0.2807017543859649
# F1 Score :  0.36571428571428566
# AUC :  0.6195772382245011

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.854679802955665
# Precision :  0.4473684210526316
# Recall :  0.14912280701754385
# F1 Score :  0.22368421052631582
# AUC :  0.5595184235660785

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8251231527093597
# Precision :  0.3333333333333333
# Recall :  0.24561403508771928
# F1 Score :  0.2828282828282828
# AUC :  0.5826924043633438

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8485221674876847
# Precision :  0.4470588235294118
# Recall :  0.3333333333333333
# F1 Score :  0.38190954773869346
# AUC :  0.6329990448901623

# %% [markdown]
# # INFORMATION GAIN 10

# %%
from sklearn.feature_selection import mutual_info_classif
gain = mutual_info_classif(X,Y)
gain
# Out:
# array([0.06055717, 0.0323637 , 0.06749765, 0.0445665 , 0.00960441,
#        0.        , 0.        , 0.06654156, 0.02942952, 0.02599905,
#        0.01388524, 0.01155048, 0.00997539, 0.05583788, 0.0697822 ,
#        0.00573492, 0.06246198, 0.06884543, 0.0637012 , 0.00845552,
#        0.02629114, 0.03159116, 0.03083389, 0.06604466, 0.06429612,
#        0.06008697, 0.07041683, 0.07282042, 0.06402337, 0.0216598 ,
#        0.06896133, 0.08455502, 0.05135125, 0.06417064, 0.01351667,
#        0.05110742, 0.01592858, 0.0364457 , 0.00292208, 0.        ,
#        0.0574364 , 0.0120502 , 0.02334588, 0.02729426, 0.00677216,
#        0.05035922, 0.04300066, 0.00949586, 0.0524427 , 0.04279874,
#        0.        , 0.05842321, 0.03608473, 0.        , 0.03179738,
#        0.0369253 , 0.0281502 , 0.01722186, 0.02460588, 0.04426843,
#        0.01911773, 0.        , 0.01889655, 0.02973414, 0.05525307])

# %%
col_list = X.columns
col_list
# Out:
# Index(['CountDeclMethodPrivate', 'AvgLineCode', 'CountLine', 'MaxCyclomatic',
#        'CountDeclMethodDefault', 'AvgEssential', 'CountDeclClassVariable',
#        'SumCyclomaticStrict', 'AvgCyclomatic', 'AvgLine',
#        'CountDeclClassMethod', 'AvgLineComment', 'AvgCyclomaticModified',
#        'CountDeclFunction', 'CountLineComment', 'CountDeclClass',
#        'CountDeclMethod', 'SumCyclomaticModified', 'CountLineCodeDecl',
#        'CountDeclMethodProtected', 'CountDeclInstanceVariable',
#        'MaxCyclomaticStrict', 'CountDeclMethodPublic', 'CountLineCodeExe',
#        'SumCyclomatic', 'SumEssential', 'CountStmtDecl', 'CountLineCode',
#        'CountStmtExe', 'RatioCommentToCode', 'CountLineBlank', 'CountStmt',
#        'MaxCyclomaticModified', 'CountSemicolon', 'AvgLineBlank',
#        'CountDeclInstanceMethod', 'AvgCyclomaticStrict',
#        'PercentLackOfCohesion', 'MaxInheritanceTree', 'CountClassDerived',
#        'CountClassCoupled', 'CountClassBase', 'CountInput_Max',
#        'CountInput_Mean', 'CountInput_Min', 'CountOutput_Max',
#        'CountOutput_Mean', 'CountOutput_Min', 'CountPath_Max',
#        'CountPath_Mean', 'CountPath_Min', 'MaxNesting_Max', 'MaxNesting_Mean',
#        'MaxNesting_Min', 'COMM', 'ADEV', 'DDEV', 'Added_lines', 'Del_lines',
#        'OWN_LINE', 'OWN_COMMIT', 'MINOR_COMMIT', 'MINOR_LINE', 'MAJOR_COMMIT',
#        'MAJOR_LINE'],
#       dtype='object')

# %%
temp = pd.DataFrame(list(zip(col_list, gain)), columns =['col', 'score']) 
temp
# Out:
#                        col     score
# 0   CountDeclMethodPrivate  0.060557
# 1              AvgLineCode  0.032364
# 2                CountLine  0.067498
# 3            MaxCyclomatic  0.044566
# 4   CountDeclMethodDefault  0.009604
# ..                     ...       ...
# 60              OWN_COMMIT  0.019118
# 61            MINOR_COMMIT  0.000000
# 62              MINOR_LINE  0.018897
# 63            MAJOR_COMMIT  0.029734
# 64              MAJOR_LINE  0.055253
#
# [65 rows x 2 columns]

# %%
temp_sort = temp.sort_values(['score'], ascending=False)
temp_sort[:10]
# Out:
#                       col     score
# 31              CountStmt  0.084555
# 27          CountLineCode  0.072820
# 26          CountStmtDecl  0.070417
# 14       CountLineComment  0.069782
# 30         CountLineBlank  0.068961
# 17  SumCyclomaticModified  0.068845
# 2               CountLine  0.067498
# 7     SumCyclomaticStrict  0.066542
# 23       CountLineCodeExe  0.066045
# 24          SumCyclomatic  0.064296

# %%
FS = list(temp_sort['col'][:10])
FS
# Out:
# ['CountStmt',
#  'CountLineCode',
#  'CountStmtDecl',
#  'CountLineComment',
#  'CountLineBlank',
#  'SumCyclomaticModified',
#  'CountLine',
#  'SumCyclomaticStrict',
#  'CountLineCodeExe',
#  'SumCyclomatic']

# %%
X_new = df[FS]
X_new
# Out:
#       CountStmt  CountLineCode  CountStmtDecl  CountLineComment  \
# 0           344            547            106                91
# 1           146            228             58                70
# 2            57             86             34                78
# 3            42             57             22                61
# 4            42             56             22                59
# ...         ...            ...            ...               ...
# 2700        109            155             58                36
# 2701        123            143             63                30
# 2702          9             11              8                15
# 2703         39             48             22                15
# 2704        305            482             92               128
#
#       CountLineBlank  SumCyclomaticModified  CountLine  SumCyclomaticStrict  \
# 0                104                    109        741                  135
# 1                 25                     33        315                   34
# 2                 24                      5        186                    5
# 3                 19                     15        137                   15
# 4                 19                     15        134                   15
# ...              ...                    ...        ...                  ...
# 2700              33                     31        224                   34
# 2701              22                     20        195                   22
# 2702              10                      1         36                    1
# 2703              11                     11         74                   11
# 2704              45                     78        646                  100
#
#       CountLineCodeExe  SumCyclomatic
# 0                  335            109
# 1                  142             33
# 2                   67              5
# 3                   25             15
# 4                   24             15
# ...                ...            ...
# 2700                90             31
# 2701                88             20
# 2702                 3              1
# 2703                26             11
# 2704               319             78
#
# [2705 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8485221674876847
# Precision :  0.4307692307692308
# Recall :  0.24561403508771928
# F1 Score :  0.3128491620111732
# AUC :  0.5963027195495902

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.853448275862069
# Precision :  0.4418604651162791
# Recall :  0.16666666666666666
# F1 Score :  0.24203821656050953
# AUC :  0.5661413562559694

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8275862068965517
# Precision :  0.3488372093023256
# Recall :  0.2631578947368421
# F1 Score :  0.3
# AUC :  0.5914643341879052

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8448275862068966
# Precision :  0.4166666666666667
# Recall :  0.2631578947368421
# F1 Score :  0.3225806451612903
# AUC :  0.6014929874830343

# %% [markdown]
# # INFORMATION GAIN 15

# %%
from sklearn.feature_selection import mutual_info_classif
gain = mutual_info_classif(X,Y)
gain
# Out:
# array([0.0603452 , 0.02759871, 0.07018881, 0.03904982, 0.        ,
#        0.        , 0.01783251, 0.06595742, 0.03156241, 0.02495395,
#        0.01374945, 0.01054162, 0.02265172, 0.05335655, 0.06301698,
#        0.01833239, 0.06399736, 0.06564268, 0.06203889, 0.03316031,
#        0.03137946, 0.04472354, 0.03906853, 0.06771857, 0.06003227,
#        0.06308912, 0.06140141, 0.08040052, 0.0621414 , 0.02131611,
#        0.06727551, 0.08184418, 0.04290642, 0.06099244, 0.00886772,
#        0.05278969, 0.01806552, 0.04352512, 0.00391539, 0.        ,
#        0.05035115, 0.02396007, 0.0315468 , 0.02964517, 0.00857886,
#        0.05054327, 0.03735525, 0.00641105, 0.04921568, 0.04358697,
#        0.        , 0.04540293, 0.03633974, 0.00776717, 0.02967021,
#        0.03227522, 0.02133131, 0.01548234, 0.02787831, 0.03991506,
#        0.02370861, 0.        , 0.02250825, 0.0247686 , 0.06801225])

# %%
col_list = X.columns
col_list
# Out:
# Index(['CountDeclMethodPrivate', 'AvgLineCode', 'CountLine', 'MaxCyclomatic',
#        'CountDeclMethodDefault', 'AvgEssential', 'CountDeclClassVariable',
#        'SumCyclomaticStrict', 'AvgCyclomatic', 'AvgLine',
#        'CountDeclClassMethod', 'AvgLineComment', 'AvgCyclomaticModified',
#        'CountDeclFunction', 'CountLineComment', 'CountDeclClass',
#        'CountDeclMethod', 'SumCyclomaticModified', 'CountLineCodeDecl',
#        'CountDeclMethodProtected', 'CountDeclInstanceVariable',
#        'MaxCyclomaticStrict', 'CountDeclMethodPublic', 'CountLineCodeExe',
#        'SumCyclomatic', 'SumEssential', 'CountStmtDecl', 'CountLineCode',
#        'CountStmtExe', 'RatioCommentToCode', 'CountLineBlank', 'CountStmt',
#        'MaxCyclomaticModified', 'CountSemicolon', 'AvgLineBlank',
#        'CountDeclInstanceMethod', 'AvgCyclomaticStrict',
#        'PercentLackOfCohesion', 'MaxInheritanceTree', 'CountClassDerived',
#        'CountClassCoupled', 'CountClassBase', 'CountInput_Max',
#        'CountInput_Mean', 'CountInput_Min', 'CountOutput_Max',
#        'CountOutput_Mean', 'CountOutput_Min', 'CountPath_Max',
#        'CountPath_Mean', 'CountPath_Min', 'MaxNesting_Max', 'MaxNesting_Mean',
#        'MaxNesting_Min', 'COMM', 'ADEV', 'DDEV', 'Added_lines', 'Del_lines',
#        'OWN_LINE', 'OWN_COMMIT', 'MINOR_COMMIT', 'MINOR_LINE', 'MAJOR_COMMIT',
#        'MAJOR_LINE'],
#       dtype='object')

# %%
temp = pd.DataFrame(list(zip(col_list, gain)), columns =['col', 'score']) 
temp
# Out:
#                        col     score
# 0   CountDeclMethodPrivate  0.060345
# 1              AvgLineCode  0.027599
# 2                CountLine  0.070189
# 3            MaxCyclomatic  0.039050
# 4   CountDeclMethodDefault  0.000000
# ..                     ...       ...
# 60              OWN_COMMIT  0.023709
# 61            MINOR_COMMIT  0.000000
# 62              MINOR_LINE  0.022508
# 63            MAJOR_COMMIT  0.024769
# 64              MAJOR_LINE  0.068012
#
# [65 rows x 2 columns]

# %%
temp_sort = temp.sort_values(['score'], ascending=False)
temp_sort[:15]
# Out:
#                       col     score
# 31              CountStmt  0.081844
# 27          CountLineCode  0.080401
# 2               CountLine  0.070189
# 64             MAJOR_LINE  0.068012
# 23       CountLineCodeExe  0.067719
# 30         CountLineBlank  0.067276
# 7     SumCyclomaticStrict  0.065957
# 17  SumCyclomaticModified  0.065643
# 16        CountDeclMethod  0.063997
# 25           SumEssential  0.063089
# 14       CountLineComment  0.063017
# 28           CountStmtExe  0.062141
# 18      CountLineCodeDecl  0.062039
# 26          CountStmtDecl  0.061401
# 33         CountSemicolon  0.060992

# %%
FS = list(temp_sort['col'][:15])
FS
# Out:
# ['CountStmt',
#  'CountLineCode',
#  'CountLine',
#  'MAJOR_LINE',
#  'CountLineCodeExe',
#  'CountLineBlank',
#  'SumCyclomaticStrict',
#  'SumCyclomaticModified',
#  'CountDeclMethod',
#  'SumEssential',
#  'CountLineComment',
#  'CountStmtExe',
#  'CountLineCodeDecl',
#  'CountStmtDecl',
#  'CountSemicolon']

# %%
X_new = df[FS]
X_new
# Out:
#       CountStmt  CountLineCode  CountLine  MAJOR_LINE  CountLineCodeExe  \
# 0           344            547        741           2               335
# 1           146            228        315           2               142
# 2            57             86        186           1                67
# 3            42             57        137           1                25
# 4            42             56        134           1                24
# ...         ...            ...        ...         ...               ...
# 2700        109            155        224           1                90
# 2701        123            143        195           2                88
# 2702          9             11         36           0                 3
# 2703         39             48         74           0                26
# 2704        305            482        646           0               319
#
#       CountLineBlank  SumCyclomaticStrict  SumCyclomaticModified  \
# 0                104                  135                    109
# 1                 25                   34                     33
# 2                 24                    5                      5
# 3                 19                   15                     15
# 4                 19                   15                     15
# ...              ...                  ...                    ...
# 2700              33                   34                     31
# 2701              22                   22                     20
# 2702              10                    1                      1
# 2703              11                   11                     11
# 2704              45                  100                     78
#
#       CountDeclMethod  SumEssential  CountLineComment  CountStmtExe  \
# 0                  11            59                91           238
# 1                   4             4                70            88
# 2                   3             3                78            23
# 3                  11            11                61            20
# 4                  11            11                59            20
# ...               ...           ...               ...           ...
# 2700                9             9                36            51
# 2701                5             5                30            60
# 2702                1             1                15             1
# 2703                3             3                15            17
# 2704               14            49               128           213
#
#       CountLineCodeDecl  CountStmtDecl  CountSemicolon
# 0                    98            106             236
# 1                    54             58             115
# 2                    36             34              51
# 3                    21             22              26
# 4                    21             22              26
# ...                 ...            ...             ...
# 2700                 60             58              79
# 2701                 61             63             102
# 2702                  8              8               7
# 2703                 21             22              27
# 2704                 94             92             227
#
# [2705 rows x 15 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8497536945812808
# Precision :  0.42857142857142855
# Recall :  0.21052631578947367
# F1 Score :  0.2823529411764706
# AUC :  0.582340521791585

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.853448275862069
# Precision :  0.4418604651162791
# Recall :  0.16666666666666666
# F1 Score :  0.24203821656050953
# AUC :  0.5661413562559694

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8288177339901478
# Precision :  0.35294117647058826
# Recall :  0.2631578947368421
# F1 Score :  0.30150753768844224
# AUC :  0.5921806665661288

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8448275862068966
# Precision :  0.4230769230769231
# Recall :  0.2894736842105263
# F1 Score :  0.34375
# AUC :  0.6125018850852059

# %% [markdown]
# # FISHER SCORE

# %%
FScore = []

for m in  range(len(col_list)):
        mu = df[col_list[m]].mean()

        n_1 = df[df['class'] == 0].count()[1]
        mu_1 = df[col_list[m]][df['class'] == 0].mean()
        var_1 = df[col_list[m]][df['class'] == 0].var()

        n_2 = df[df['class'] == 1].count()[1]
        mu_2 = df[col_list[m]][df['class'] == 1].mean()
        var_2 = df[col_list[m]][df['class'] == 1].var()

        inter_class = n_1*(mu_1-mu)**2 + n_2*(mu_2-mu)**2
        intra_class = (n_1-1)*var_1 + (n_2-1)*var_2

        FScore.append(inter_class / intra_class)

FScore
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_10544\1507033413.py:17: RuntimeWarning: invalid value encountered in double_scalars
#   FScore.append(inter_class / intra_class)
# [0.08311291034111429,
#  0.010792801233186074,
#  0.13950254225766992,
#  0.06645754715540504,
#  0.02270076757271433,
#  0.009226394258587074,
#  0.0031076228111968722,
#  0.12998593492680402,
#  0.015555445955797872,
#  0.010334627585678283,
#  0.005940163914563191,
#  0.00978228272031088,
#  0.015472727038440395,
#  0.08962957302950503,
#  0.11256639931496376,
#  0.0313477769433086,
#  0.08961422975679005,
#  0.13256178418865214,
#  0.12321404520065272,
#  0.024172684024052232,
#  0.014886541849934862,
#  0.06746159494219678,
#  0.04514307993364423,
#  0.10676530521612493,
#  0.1320247727625789,
#  0.11687809150299021,
#  0.12833323464600802,
#  0.13173092074354728,
#  0.10779305566160771,
#  0.01584826237053315,
#  0.08295130541476678,
#  0.12548779233964202,
#  0.07423041481537423,
#  0.11077520707131235,
#  0.0044450455124818095,
#  0.10008417742344883,
#  0.01773433719530474,
#  0.0532544294742544,
#  0.009676245846836826,
#  0.001987240667115715,
#  0.14205845121385802,
#  0.038895691884463894,
#  0.00858634862530599,
#  0.0010838017599071475,
#  0.001246323056760259,
#  0.11603740251483069,
#  0.030442383919242918,
#  0.004227273745453448,
#  0.004160436311808103,
#  0.000666460195440997,
#  9.399866157761446e-05,
#  0.09408708824898619,
#  0.017860673276466604,
#  0.0028715915599392666,
#  0.07816360034900098,
#  0.07816360034900098,
#  0.051549053304487946,
#  0.0031339103038736144,
#  0.020341059677021267,
#  0.05710116896801844,
#  0.021805334589535735,
#  nan,
#  0.044749067200053214,
#  0.051549053304487946,
#  0.18473159131356434]

# %%
temp = pd.DataFrame(list(zip(col_list, FScore)), columns =['col', 'score']) 
temp
# Out:
#                        col     score
# 0   CountDeclMethodPrivate  0.083113
# 1              AvgLineCode  0.010793
# 2                CountLine  0.139503
# 3            MaxCyclomatic  0.066458
# 4   CountDeclMethodDefault  0.022701
# ..                     ...       ...
# 60              OWN_COMMIT  0.021805
# 61            MINOR_COMMIT       NaN
# 62              MINOR_LINE  0.044749
# 63            MAJOR_COMMIT  0.051549
# 64              MAJOR_LINE  0.184732
#
# [65 rows x 2 columns]

# %%
temp_sort = temp.sort_values(['score'], ascending=False)
temp_sort[:10]
# Out:
#                       col     score
# 64             MAJOR_LINE  0.184732
# 40      CountClassCoupled  0.142058
# 2               CountLine  0.139503
# 17  SumCyclomaticModified  0.132562
# 24          SumCyclomatic  0.132025
# 27          CountLineCode  0.131731
# 7     SumCyclomaticStrict  0.129986
# 26          CountStmtDecl  0.128333
# 31              CountStmt  0.125488
# 18      CountLineCodeDecl  0.123214

# %%
FS = list(temp_sort['col'][:10])
FS
# Out:
# ['MAJOR_LINE',
#  'CountClassCoupled',
#  'CountLine',
#  'SumCyclomaticModified',
#  'SumCyclomatic',
#  'CountLineCode',
#  'SumCyclomaticStrict',
#  'CountStmtDecl',
#  'CountStmt',
#  'CountLineCodeDecl']

# %%
X_new = df[FS]
X_new
# Out:
#       MAJOR_LINE  CountClassCoupled  CountLine  SumCyclomaticModified  \
# 0              2                  3        741                    109
# 1              2                  1        315                     33
# 2              1                  2        186                      5
# 3              1                  0        137                     15
# 4              1                  0        134                     15
# ...          ...                ...        ...                    ...
# 2700           1                  8        224                     31
# 2701           2                  7        195                     20
# 2702           0                  1         36                      1
# 2703           0                  0         74                     11
# 2704           0                  0        646                     78
#
#       SumCyclomatic  CountLineCode  SumCyclomaticStrict  CountStmtDecl  \
# 0               109            547                  135            106
# 1                33            228                   34             58
# 2                 5             86                    5             34
# 3                15             57                   15             22
# 4                15             56                   15             22
# ...             ...            ...                  ...            ...
# 2700             31            155                   34             58
# 2701             20            143                   22             63
# 2702              1             11                    1              8
# 2703             11             48                   11             22
# 2704             78            482                  100             92
#
#       CountStmt  CountLineCodeDecl
# 0           344                 98
# 1           146                 54
# 2            57                 36
# 3            42                 21
# 4            42                 21
# ...         ...                ...
# 2700        109                 60
# 2701        123                 61
# 2702          9                  8
# 2703         39                 21
# 2704        305                 94
#
# [2705 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8583743842364532
# Precision :  0.49122807017543857
# Recall :  0.24561403508771928
# F1 Score :  0.32748538011695905
# AUC :  0.6020333785753782

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8571428571428571
# Precision :  0.47619047619047616
# Recall :  0.17543859649122806
# F1 Score :  0.2564102564102564
# AUC :  0.5719599859246971

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8238916256157636
# Precision :  0.3253012048192771
# Recall :  0.23684210526315788
# F1 Score :  0.2741116751269035
# AUC :  0.5783064394510632

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8448275862068966
# Precision :  0.42857142857142855
# Recall :  0.3157894736842105
# F1 Score :  0.36363636363636365
# AUC :  0.6235107826873776

# %% [markdown]
# # SVM RFE 10

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,random_state=23)

# %%
from sklearn.feature_selection import RFE
rec_model = RandomForestClassifier()

rfe = RFE(rec_model, n_features_to_select=10)
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=RandomForestClassifier(), n_features_to_select=10)

# %%
X_train = X_train.loc[:, rfe.support_]
X_train
# Out:
#       CountLine  SumCyclomaticStrict  CountLineComment  CountLineCode  \
# 745          34                    1                20              6
# 1547       1184                  108               254            739
# 2312        216                   22                45            135
# 1134       1105                   63               649            364
# 1039        117                    7                41             56
# ...         ...                  ...               ...            ...
# 1512        442                   46               121            251
# 1993        368                   16               137            199
# 1064        441                   26               174            194
# 742          89                    5                65             11
# 595         106                    7                81             11
#
#       CountStmtExe  RatioCommentToCode  CountLineBlank  CountStmt  \
# 745              0                3.33               8          4
# 1547           254                0.34             193        391
# 2312            58                0.33              38         93
# 1134           123                1.78             105        202
# 1039            15                0.73              20         36
# ...            ...                 ...             ...        ...
# 1512            88                0.48              70        156
# 1993           105                0.69              32        158
# 1064            70                0.90              73        122
# 742              0                5.91              13         10
# 595              0                7.36              14          9
#
#       CountOutput_Mean  OWN_LINE
# 745           0.000000  0.823529
# 1547          8.550000  0.863176
# 2312          4.500000  0.972222
# 1134          5.458333  0.464253
# 1039          9.333333  0.948718
# ...                ...       ...
# 1512          6.846154  0.640271
# 1993          8.000000  0.929348
# 1064          8.857143  0.977324
# 742           1.000000  1.000000
# 595           0.857143  0.924528
#
# [1893 rows x 10 columns]

# %%
X_test = X_test.loc[:, rfe.support_]
X_test
# Out:
#       CountLine  SumCyclomaticStrict  CountLineComment  CountLineCode  \
# 2488         97                    0                21             40
# 343          42                    2                22             11
# 2089        139                   14                51             70
# 2387        325                   33               120            155
# 1078        125                    5                35             63
# ...         ...                  ...               ...            ...
# 2346        339                   33                52            238
# 468         113                   15                26             64
# 326         444                   56               154            221
# 974        1179                   98               397            688
# 2647        157                   29                22            121
#
#       CountStmtExe  RatioCommentToCode  CountLineBlank  CountStmt  \
# 2488             0                0.53              36         39
# 343              0                2.00               9          8
# 2089            27                0.73              20         57
# 2387            65                0.77              50        108
# 1078             4                0.56              27         29
# ...            ...                 ...             ...        ...
# 2346            87                0.22              49        146
# 468             19                0.41              23         34
# 326             58                0.70              69        125
# 974            185                0.58             121        314
# 2647            29                0.18              14         90
#
#       CountOutput_Mean  OWN_LINE
# 2488          0.000000  1.000000
# 343           0.000000  0.690476
# 2089          3.000000  1.000000
# 2387          5.857143  0.950769
# 1078          1.600000  0.952000
# ...                ...       ...
# 2346          3.375000  0.637168
# 468           3.000000  0.946903
# 326           2.290909  0.560811
# 974           4.857143  0.942324
# 2647          3.034483  0.904459
#
# [812 rows x 10 columns]

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8559113300492611
# Precision :  0.47761194029850745
# Recall :  0.2807017543859649
# F1 Score :  0.3535911602209944
# AUC :  0.6152792439551601

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.853448275862069
# Precision :  0.4418604651162791
# Recall :  0.16666666666666666
# F1 Score :  0.24203821656050953
# AUC :  0.5661413562559694

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8251231527093597
# Precision :  0.3372093023255814
# Recall :  0.2543859649122807
# F1 Score :  0.29
# AUC :  0.5863620368974012

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8411330049261084
# Precision :  0.4050632911392405
# Recall :  0.2807017543859649
# F1 Score :  0.3316062176165803
# AUC :  0.6066832554164782

# %% [markdown]
# # SVM RFE 15

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,random_state=23)

# %%
from sklearn.feature_selection import RFE
rec_model = RandomForestClassifier()

rfe = RFE(rec_model, n_features_to_select=15)
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=RandomForestClassifier(), n_features_to_select=15)

# %%
X_train = X_train.loc[:, rfe.support_]
X_train
# Out:
#       CountLine  SumCyclomaticStrict  CountLineComment  SumCyclomaticModified  \
# 745          34                    1                20                      1
# 1547       1184                  108               254                    101
# 2312        216                   22                45                     19
# 1134       1105                   63               649                     57
# 1039        117                    7                41                      7
# ...         ...                  ...               ...                    ...
# 1512        442                   46               121                     43
# 1993        368                   16               137                     16
# 1064        441                   26               174                     22
# 742          89                    5                65                      5
# 595         106                    7                81                      7
#
#       CountLineCodeExe  CountLineCode  CountStmtExe  RatioCommentToCode  \
# 745                  0              6             0                3.33
# 1547               395            739           254                0.34
# 2312                85            135            58                0.33
# 1134               191            364           123                1.78
# 1039                23             56            15                0.73
# ...                ...            ...           ...                 ...
# 1512               148            251            88                0.48
# 1993               154            199           105                0.69
# 1064                85            194            70                0.90
# 742                  1             11             0                5.91
# 595                  0             11             0                7.36
#
#       CountLineBlank  CountStmt  CountSemicolon  CountInput_Mean  \
# 745                8          4               3         4.000000
# 1547             193        391             293         6.750000
# 2312              38         93              73         4.000000
# 1134             105        202             146         4.041667
# 1039              20         36              28         1.666667
# ...              ...        ...             ...              ...
# 1512              70        156             113         5.076923
# 1993              32        158             141         1.500000
# 1064              73        122              99         6.000000
# 742               13         10               9         2.200000
# 595               14          9               8         4.714286
#
#       CountOutput_Mean  CountPath_Mean  OWN_LINE
# 745           0.000000        1.000000  0.823529
# 1547          8.550000       36.850000  0.863176
# 2312          4.500000        2.300000  0.972222
# 1134          5.458333        4.416667  0.464253
# 1039          9.333333        4.666667  0.948718
# ...                ...             ...       ...
# 1512          6.846154       17.923077  0.640271
# 1993          8.000000        1.333333  0.929348
# 1064          8.857143       22.714286  0.977324
# 742           1.000000        1.000000  1.000000
# 595           0.857143        1.000000  0.924528
#
# [1893 rows x 15 columns]

# %%
X_test = X_test.loc[:, rfe.support_]
X_test
# Out:
#       CountLine  SumCyclomaticStrict  CountLineComment  SumCyclomaticModified  \
# 2488         97                    0                21                      0
# 343          42                    2                22                      2
# 2089        139                   14                51                     13
# 2387        325                   33               120                     30
# 1078        125                    5                35                      5
# ...         ...                  ...               ...                    ...
# 2346        339                   33                52                     33
# 468         113                   15                26                     14
# 326         444                   56               154                     56
# 974        1179                   98               397                     94
# 2647        157                   29                22                     29
#
#       CountLineCodeExe  CountLineCode  CountStmtExe  RatioCommentToCode  \
# 2488                37             40             0                0.53
# 343                  0             11             0                2.00
# 2089                34             70            27                0.73
# 2387                86            155            65                0.77
# 1078                16             63             4                0.56
# ...                ...            ...           ...                 ...
# 2346               149            238            87                0.22
# 468                 30             64            19                0.41
# 326                 60            221            58                0.70
# 974                365            688           185                0.58
# 2647                58            121            29                0.18
#
#       CountLineBlank  CountStmt  CountSemicolon  CountInput_Mean  \
# 2488              36         39              38         0.000000
# 343                9          8               7         2.000000
# 2089              20         57              43         1.600000
# 2387              50        108              76         4.142857
# 1078              27         29              23         2.600000
# ...              ...        ...             ...              ...
# 2346              49        146             115         3.041667
# 468               23         34              19         2.833333
# 326               69        125              68         1.963636
# 974              121        314             224        10.285714
# 2647              14         90              60         2.931034
#
#       CountOutput_Mean  CountPath_Mean  OWN_LINE
# 2488          0.000000        0.000000  1.000000
# 343           0.000000        1.000000  0.690476
# 2089          3.000000        1.300000  1.000000
# 2387          5.857143      310.714286  0.950769
# 1078          1.600000        1.000000  0.952000
# ...                ...             ...       ...
# 2346          3.375000        1.250000  0.637168
# 468           3.000000        2.500000  0.946903
# 326           2.290909        1.018182  0.560811
# 974           4.857143        4.828571  0.942324
# 2647          3.034483        1.000000  0.904459
#
# [812 rows x 15 columns]

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8583743842364532
# Precision :  0.49206349206349204
# Recall :  0.2719298245614035
# F1 Score :  0.3502824858757062
# AUC :  0.6130422761775499

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8596059113300493
# Precision :  0.0
# Recall :  0.0
# F1 Score :  0.0
# AUC :  0.5
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8386699507389163
# Precision :  0.38961038961038963
# Recall :  0.2631578947368421
# F1 Score :  0.31413612565445026
# AUC :  0.5979113255919167

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8522167487684729
# Precision :  0.4375
# Recall :  0.18421052631578946
# F1 Score :  0.25925925925925924
# AUC :  0.5727642889458603

# %% [markdown]
# # MRMR 10

# %%
from sklearn.feature_selection import f_regression

F = pd.Series(f_regression(X, Y)[0], index = X.columns)
corr = X.corr().abs().clip(.00001)
# Out:
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\sklearn\feature_selection\_univariate_selection.py:289: RuntimeWarning: invalid value encountered in true_divide
#   correlation_coefficient /= X_norms

# %%
selected = []
feat_score = []
not_selected = list(X.columns)

# %%
K = 10

for i in range(K):
    
    # compute FCQ score for all the (currently) excluded features (this is Formula 2)
    score = F.loc[not_selected] / corr.loc[not_selected, selected].mean(axis = 1).fillna(.00001)
    
    # find best feature, add it to selected and remove it from not_selected
    best = score.index[score.argmax()]
    selected.append(best)
    feat_score.append(score[best])
    not_selected.remove(best)

# %%
selected
# Out:
# ['MAJOR_LINE',
#  'MaxInheritanceTree',
#  'COMM',
#  'SumCyclomaticModified',
#  'MINOR_LINE',
#  'MaxNesting_Max',
#  'CountClassCoupled',
#  'CountLine',
#  'ADEV',
#  'SumEssential']

# %%
X_new = X[selected]
X_new
# Out:
#       MAJOR_LINE  MaxInheritanceTree  COMM  SumCyclomaticModified  MINOR_LINE  \
# 0              2                   1     0                    109           1
# 1              2                   1     0                     33           1
# 2              1                   1     0                      5           1
# 3              1                   1     0                     15           1
# 4              1                   1     0                     15           1
# ...          ...                 ...   ...                    ...         ...
# 2700           1                   1     0                     31           1
# 2701           2                   1     0                     20           1
# 2702           0                   1     0                      1           2
# 2703           0                   1     0                     11           2
# 2704           0                   1     0                     78           1
#
#       MaxNesting_Max  CountClassCoupled  CountLine  ADEV  SumEssential
# 0                  8                  3        741     0            59
# 1                  6                  1        315     0             4
# 2                  1                  2        186     0             3
# 3                  2                  0        137     0            11
# 4                  2                  0        134     0            11
# ...              ...                ...        ...   ...           ...
# 2700               6                  8        224     0             9
# 2701               3                  7        195     0             5
# 2702               0                  1         36     0             1
# 2703               3                  0         74     0             3
# 2704               6                  0        646     0            49
#
# [2705 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8669950738916257
# Precision :  0.5394736842105263
# Recall :  0.35964912280701755
# F1 Score :  0.43157894736842106
# AUC :  0.6547529281656863

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8571428571428571
# Precision :  0.475
# Recall :  0.16666666666666666
# F1 Score :  0.24675324675324675
# AUC :  0.5682903533906399

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8399014778325123
# Precision :  0.3888888888888889
# Recall :  0.24561403508771928
# F1 Score :  0.30107526881720426
# AUC :  0.5912883929020257

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8559113300492611
# Precision :  0.4854368932038835
# Recall :  0.43859649122807015
# F1 Score :  0.4608294930875576
# AUC :  0.6813326295681899

# %% [markdown]
# # MRMR 15

# %%
from sklearn.feature_selection import f_regression

F = pd.Series(f_regression(X, Y)[0], index = X.columns)
corr = X.corr().abs().clip(.00001)
# Out:
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\sklearn\feature_selection\_univariate_selection.py:289: RuntimeWarning: invalid value encountered in true_divide
#   correlation_coefficient /= X_norms

# %%
selected = []
feat_score = []
not_selected = list(X.columns)

# %%
K = 15

for i in range(K):
    
    # compute FCQ score for all the (currently) excluded features (this is Formula 2)
    score = F.loc[not_selected] / corr.loc[not_selected, selected].mean(axis = 1).fillna(.00001)
    
    # find best feature, add it to selected and remove it from not_selected
    best = score.index[score.argmax()]
    selected.append(best)
    feat_score.append(score[best])
    not_selected.remove(best)

# %%
selected
# Out:
# ['MAJOR_LINE',
#  'MaxInheritanceTree',
#  'COMM',
#  'SumCyclomaticModified',
#  'MINOR_LINE',
#  'MaxNesting_Max',
#  'CountClassCoupled',
#  'CountLine',
#  'ADEV',
#  'SumEssential',
#  'CountDeclClass',
#  'CountOutput_Max',
#  'OWN_LINE',
#  'SumCyclomatic',
#  'CountLineCode']

# %%
X_new = X[selected]
X_new
# Out:
#       MAJOR_LINE  MaxInheritanceTree  COMM  SumCyclomaticModified  MINOR_LINE  \
# 0              2                   1     0                    109           1
# 1              2                   1     0                     33           1
# 2              1                   1     0                      5           1
# 3              1                   1     0                     15           1
# 4              1                   1     0                     15           1
# ...          ...                 ...   ...                    ...         ...
# 2700           1                   1     0                     31           1
# 2701           2                   1     0                     20           1
# 2702           0                   1     0                      1           2
# 2703           0                   1     0                     11           2
# 2704           0                   1     0                     78           1
#
#       MaxNesting_Max  CountClassCoupled  CountLine  ADEV  SumEssential  \
# 0                  8                  3        741     0            59
# 1                  6                  1        315     0             4
# 2                  1                  2        186     0             3
# 3                  2                  0        137     0            11
# 4                  2                  0        134     0            11
# ...              ...                ...        ...   ...           ...
# 2700               6                  8        224     0             9
# 2701               3                  7        195     0             5
# 2702               0                  1         36     0             1
# 2703               3                  0         74     0             3
# 2704               6                  0        646     0            49
#
#       CountDeclClass  CountOutput_Max  OWN_LINE  SumCyclomatic  CountLineCode
# 0                  1               23  0.975709            109            547
# 1                  1               26  0.933333             33            228
# 2                  1                9  0.967742              5             86
# 3                  1                4  0.956204             15             57
# 4                  1                4  0.955224             15             56
# ...              ...              ...       ...            ...            ...
# 2700               3               16  0.973214             31            155
# 2701               1               17  0.958974             20            143
# 2702               1                5  0.833333              1             11
# 2703               1                6  0.918919             11             48
# 2704               1               15  1.000000             78            482
#
# [2705 rows x 15 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8719211822660099
# Precision :  0.5735294117647058
# Recall :  0.34210526315789475
# F1 Score :  0.4285714285714286
# AUC :  0.650278992610466

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8362068965517241
# Precision :  0.379746835443038
# Recall :  0.2631578947368421
# F1 Score :  0.3108808290155441
# AUC :  0.5964786608354697

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.853448275862069
# Precision :  0.4358974358974359
# Recall :  0.14912280701754385
# F1 Score :  0.2222222222222222
# AUC :  0.558802091187855

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8362068965517241
# Precision :  0.379746835443038
# Recall :  0.2631578947368421
# F1 Score :  0.3108808290155441
# AUC :  0.5964786608354697

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.854679802955665
# Precision :  0.48214285714285715
# Recall :  0.47368421052631576
# F1 Score :  0.47787610619469023
# AUC :  0.6952948273261951

# %% [markdown]
# # MRMR HFS

# %%
def HSF(df, df_train):
    
    from copy import deepcopy
    col_list = list(df_train.columns)
    print(col_list)
    d = df_train.shape[1]
    SF = []
    merit = [0 for i in range(d)]
    merit_archive = [0 for i in range(d)]
    Total_FS = [0 for i in range(d)]

    rel_CF = RHFS(df, d, col_list)

    max_value = max(rel_CF)
    Feature_max_index = rel_CF.index(max_value)

    n = 0

    SF.append(Feature_max_index)

    merit_archive[n] = deepcopy(max_value)

    Total_FS[n] = deepcopy(SF)

    while n < d-1:

        for i in range(d):

            red_FF = SHFS(SF, df_train, i, col_list,d)

            top = (d + d*(sum(rel_CF)/len(rel_CF)))
            bottom = (d + (d*(d-1)*(sum(red_FF)/len(red_FF))))**(1/2)
            merit[i] = top/bottom

        for val in SF:
            merit[val] = -9999999

        max_value = max(merit)
        Feature_max_index = merit.index(max_value)

        if Feature_max_index not in SF:
            SF.append(Feature_max_index)

        n += 1
        
        Total_FS[n] = deepcopy(SF)

        merit_archive[n] = max_value

    index_val = merit_archive.index(max(merit_archive))

    Feature_subset = Total_FS[index_val]

    subset_list = []

    for val in Feature_subset:
        subset_list.append(col_list[val])
    return subset_list


def RHFS(df, d, col_list):
    rel_CF = [0 for i in range(d)]
    count = 0

    igain = IG(X,df['class'])

    for m in  range(d):
        mu = df[col_list[m]].mean()

        n_1 = df[df['class'] == 0].count()[1]
        mu_1 = df[col_list[m]][df['class'] == 0].mean()
        var_1 = df[col_list[m]][df['class'] == 0].var()

        n_2 = df[df['class'] == 1].count()[1]
        mu_2 = df[col_list[m]][df['class'] == 1].mean()
        var_2 = df[col_list[m]][df['class'] == 1].var()

        inter_class = n_1*(mu_1-mu)**2 + n_2*(mu_2-mu)**2
        intra_class = (n_1-1)*var_1 + (n_2-1)*var_2

        fscore = inter_class / intra_class

        rel_CF[count] = (1/2)*(fscore + igain[m])
        count += 1
    
    return rel_CF

        
        

def IG(col_1, col_2):
    from sklearn.feature_selection import mutual_info_classif
    gain = mutual_info_classif(col_1,col_2)
    return gain   

def relief(col_1,col_2):
    pass



def SHFS(SF, df_train, i, col_list,d):
    from itertools import combinations
    from copy import deepcopy
    red_FF = []
    temp_SF = deepcopy(SF)
    if i not in SF:
        temp_SF.append(i)
        P_pairs = list(combinations(temp_SF,2))
        for pair in P_pairs:

            ied_value = (IED(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            pc_value = (PC(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            cs_value = (CS(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2

            red_FF.append((1/3)*(ied_value + pc_value + cs_value))
            # red_FF.append((1/2)*(pc_value + cs_value))
    else:
        red_FF = [0]
    return red_FF

def IED(col_1, col_2):
    import numpy as np
    dist = np.linalg.norm(col_1 - col_2)
    return 1/dist

def PC(col_1, col_2):
    from scipy.stats import pearsonr
    corr, _ = pearsonr(col_1 , col_2)
    return corr

def CS(col_1, col_2):
    from scipy import spatial
    similarity = 1 - spatial.distance.cosine(col_1, col_2)
    return similarity

# %%
FS = HSF(df, X)
FS
# Out:
# ['CountDeclMethodPrivate', 'AvgLineCode', 'CountLine', 'MaxCyclomatic', 'CountDeclMethodDefault', 'AvgEssential', 'CountDeclClassVariable', 'SumCyclomaticStrict', 'AvgCyclomatic', 'AvgLine', 'CountDeclClassMethod', 'AvgLineComment', 'AvgCyclomaticModified', 'CountDeclFunction', 'CountLineComment', 'CountDeclClass', 'CountDeclMethod', 'SumCyclomaticModified', 'CountLineCodeDecl', 'CountDeclMethodProtected', 'CountDeclInstanceVariable', 'MaxCyclomaticStrict', 'CountDeclMethodPublic', 'CountLineCodeExe', 'SumCyclomatic', 'SumEssential', 'CountStmtDecl', 'CountLineCode', 'CountStmtExe', 'RatioCommentToCode', 'CountLineBlank', 'CountStmt', 'MaxCyclomaticModified', 'CountSemicolon', 'AvgLineBlank', 'CountDeclInstanceMethod', 'AvgCyclomaticStrict', 'PercentLackOfCohesion', 'MaxInheritanceTree', 'CountClassDerived', 'CountClassCoupled', 'CountClassBase', 'CountInput_Max', 'CountInput_Mean', 'CountInput_Min', 'CountOutput_Max', 'CountOutput_Mean', 'CountOutput_Min', 'CountPath_Max', 'CountPath_Mean', 'CountPath_Min', 'MaxNesting_Max', 'MaxNesting_Mean', 'MaxNesting_Min', 'COMM', 'ADEV', 'DDEV', 'Added_lines', 'Del_lines', 'OWN_LINE', 'OWN_COMMIT', 'MINOR_COMMIT', 'MINOR_LINE', 'MAJOR_COMMIT', 'MAJOR_LINE']
# C:\Users\acer\AppData\Local\Temp\ipykernel_10544\2073211282.py:81: RuntimeWarning: invalid value encountered in double_scalars
#   fscore = inter_class / intra_class
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\scipy\stats\_stats_py.py:4068: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\scipy\spatial\distance.py:630: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)
# ['MAJOR_LINE']

# %%
X_new = X[FS]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8719211822660099
# Precision :  0.7083333333333334
# Recall :  0.14912280701754385
# F1 Score :  0.24637681159420288
# AUC :  0.5695470768612074

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8719211822660099
# Precision :  0.7083333333333334
# Recall :  0.14912280701754385
# F1 Score :  0.24637681159420288
# AUC :  0.5695470768612074

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8719211822660099
# Precision :  0.7083333333333334
# Recall :  0.14912280701754385
# F1 Score :  0.24637681159420288
# AUC :  0.5695470768612074

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.853448275862069
# Precision :  0.4666666666666667
# Recall :  0.30701754385964913
# F1 Score :  0.37037037037037046
# AUC :  0.6248554768008848

# %% [markdown]
# # HFS NEW

# %%
def HSF(df, df_train):
    
    from copy import deepcopy
    col_list = list(df_train.columns)
    print(col_list)
    d = df_train.shape[1]
    SF = []
    merit = [0 for i in range(d)]
    merit_archive = [0 for i in range(d)]
    Total_FS = [0 for i in range(d)]

    rel_CF = RHFS(df, d, col_list)

    max_value = max(rel_CF)
    Feature_max_index = rel_CF.index(max_value)

    n = 0

    SF.append(Feature_max_index)

    merit_archive[n] = deepcopy(max_value)

    Total_FS[n] = deepcopy(SF)

    while n < d-1:

        for i in range(d):

            red_FF = SHFS(SF, df_train, i, col_list,d)

            top = (d + d*(sum(rel_CF)/len(rel_CF)))
            bottom = (d - (sum(red_FF)/len(red_FF)))**(1/2)

            merit[i] = top/bottom

        for val in SF:
            merit[val] = -9999999

        max_value = max(merit)
        Feature_max_index = merit.index(max_value)

        if Feature_max_index not in SF:
            SF.append(Feature_max_index)

        n += 1
        
        Total_FS[n] = deepcopy(SF)

        merit_archive[n] = max_value

    index_val = merit_archive.index(max(merit_archive))

    Feature_subset = Total_FS[index_val]

    subset_list = []

    for val in Feature_subset:
        subset_list.append(col_list[val])
    return subset_list


def RHFS(df, d, col_list):
    rel_CF = [0 for i in range(d)]
    count = 0

    igain = IG(X,df['class'])

    for m in  range(d):
        mu = df[col_list[m]].mean()

        n_1 = df[df['class'] == 0].count()[1]
        mu_1 = df[col_list[m]][df['class'] == 0].mean()
        var_1 = df[col_list[m]][df['class'] == 0].var()

        n_2 = df[df['class'] == 1].count()[1]
        mu_2 = df[col_list[m]][df['class'] == 1].mean()
        var_2 = df[col_list[m]][df['class'] == 1].var()

        inter_class = n_1*(mu_1-mu)**2 + n_2*(mu_2-mu)**2
        intra_class = (n_1-1)*var_1 + (n_2-1)*var_2

        fscore = inter_class / intra_class

        rel_CF[count] = (1/2)*(fscore + igain[m])
        count += 1
    
    return rel_CF

        
        

def IG(col_1, col_2):
    from sklearn.feature_selection import mutual_info_classif
    gain = mutual_info_classif(col_1,col_2)
    return gain   

def relief(col_1,col_2):
    pass



def SHFS(SF, df_train, i, col_list,d):
    from itertools import combinations
    from copy import deepcopy
    red_FF = []
    temp_SF = deepcopy(SF)
    if i not in SF:
        temp_SF.append(i)
        P_pairs = list(combinations(temp_SF,2))
        for pair in P_pairs:

            ied_value = (IED(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            pc_value = (PC(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            cs_value = (CS(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2

            red_FF.append((1/3)*(ied_value + pc_value + cs_value))
            # red_FF.append((1/2)*(pc_value + cs_value))
    else:
        red_FF = [0]
    return red_FF

def IED(col_1, col_2):
    import numpy as np
    dist = np.linalg.norm(col_1 - col_2)
    return 1/dist

def PC(col_1, col_2):
    from scipy.stats import pearsonr
    corr, _ = pearsonr(col_1 , col_2)
    return corr

def CS(col_1, col_2):
    from scipy import spatial
    similarity = 1 - spatial.distance.cosine(col_1, col_2)
    return similarity

# %%
FS = HSF(df, X)
FS
# Out:
# ['CountDeclMethodPrivate', 'AvgLineCode', 'CountLine', 'MaxCyclomatic', 'CountDeclMethodDefault', 'AvgEssential', 'CountDeclClassVariable', 'SumCyclomaticStrict', 'AvgCyclomatic', 'AvgLine', 'CountDeclClassMethod', 'AvgLineComment', 'AvgCyclomaticModified', 'CountDeclFunction', 'CountLineComment', 'CountDeclClass', 'CountDeclMethod', 'SumCyclomaticModified', 'CountLineCodeDecl', 'CountDeclMethodProtected', 'CountDeclInstanceVariable', 'MaxCyclomaticStrict', 'CountDeclMethodPublic', 'CountLineCodeExe', 'SumCyclomatic', 'SumEssential', 'CountStmtDecl', 'CountLineCode', 'CountStmtExe', 'RatioCommentToCode', 'CountLineBlank', 'CountStmt', 'MaxCyclomaticModified', 'CountSemicolon', 'AvgLineBlank', 'CountDeclInstanceMethod', 'AvgCyclomaticStrict', 'PercentLackOfCohesion', 'MaxInheritanceTree', 'CountClassDerived', 'CountClassCoupled', 'CountClassBase', 'CountInput_Max', 'CountInput_Mean', 'CountInput_Min', 'CountOutput_Max', 'CountOutput_Mean', 'CountOutput_Min', 'CountPath_Max', 'CountPath_Mean', 'CountPath_Min', 'MaxNesting_Max', 'MaxNesting_Mean', 'MaxNesting_Min', 'COMM', 'ADEV', 'DDEV', 'Added_lines', 'Del_lines', 'OWN_LINE', 'OWN_COMMIT', 'MINOR_COMMIT', 'MINOR_LINE', 'MAJOR_COMMIT', 'MAJOR_LINE']
# C:\Users\acer\AppData\Local\Temp\ipykernel_10544\4067302685.py:82: RuntimeWarning: invalid value encountered in double_scalars
#   fscore = inter_class / intra_class
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\scipy\stats\_stats_py.py:4068: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\scipy\spatial\distance.py:630: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)
# ['MAJOR_LINE']

# %%
X_new = X[FS]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8719211822660099
# Precision :  0.7083333333333334
# Recall :  0.14912280701754385
# F1 Score :  0.24637681159420288
# AUC :  0.5695470768612074

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8719211822660099
# Precision :  0.7083333333333334
# Recall :  0.14912280701754385
# F1 Score :  0.24637681159420288
# AUC :  0.5695470768612074

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8719211822660099
# Precision :  0.7083333333333334
# Recall :  0.14912280701754385
# F1 Score :  0.24637681159420288
# AUC :  0.5695470768612074

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.853448275862069
# Precision :  0.4666666666666667
# Recall :  0.30701754385964913
# F1 Score :  0.37037037037037046
# AUC :  0.6248554768008848
