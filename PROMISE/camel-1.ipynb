# %%
import pandas as pd

# %%
df = pd.read_csv('camel-1.csv')
df
# Out:
#       id  wmc  dit  noc  cbo  rfc  lcom  ca  ce  npm  ...       dam  moa  \
# 0      1    8    2    0    8   31    28   1   7    1  ...  0.000000    0
# 1      2    5    0    0    9   17    10   2   8    2  ...  0.000000    0
# 2      3    1    1    0    0    1     0   0   0    1  ...  0.000000    0
# 3      4   13    3    0   41   73    50   5  41    5  ...  0.714286    0
# 4      5    7    2    0    6   13    17   4   2    7  ...  1.000000    1
# ..   ...  ...  ...  ...  ...  ...   ...  ..  ..  ...  ...       ...  ...
# 867  868   47    1    0    7   81   829   5   3   45  ...  0.857143    0
# 868  869    3    1    0    4    9     1   1   3    3  ...  1.000000    0
# 869  870    3    2    0    1    5     3   0   1    3  ...  0.000000    0
# 870  871   20    1    0   18   86   188  14   4   12  ...  1.000000    0
# 871  872    2    5    0    4    7     0   2   2    2  ...  1.000000    1
#
#           mfa       cam  ic  cbm        amc  max_cc  avg_cc  defects
# 0    0.588235  0.347222   1    1  48.250000       7  3.1250        1
# 1    0.000000  0.450000   0    0  18.400000       2  1.0000        0
# 2    0.000000  1.000000   0    0   0.000000       1  1.0000        0
# 3    0.645161  0.250000   1    1  24.923077       5  1.6154        0
# 4    0.333333  0.428571   0    0   5.285714       1  0.8571        0
# ..        ...       ...  ..  ...        ...     ...     ...      ...
# 867  0.000000  0.183511   0    0  13.446809       9  1.4468        0
# 868  0.000000  0.500000   0    0  14.333333       2  1.0000        0
# 869  0.956522  0.666667   1    2   3.000000       1  0.3333        0
# 870  0.000000  0.276316   0    0  35.900000      11  2.5000        1
# 871  0.944444  0.666667   0    0  11.000000       1  0.5000        0
#
# [872 rows x 22 columns]

# %%
df.drop(['id'], axis=1, inplace=True)

# %%
df['defects'].unique()
# Out:
# array([ 1,  0,  4,  2,  6,  3,  5,  8,  7, 17, 13, 10], dtype=int64)

# %%
df['defects'].replace([4,  2,  6,  3,  5,  8,  7, 17, 13, 10], 1, inplace=True)
df['defects'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df = df.rename({'defects':'class'}, axis=1)
df
# Out:
#      wmc  dit  noc  cbo  rfc  lcom  ca  ce  npm     lcom3  ...       dam  moa  \
# 0      8    2    0    8   31    28   1   7    1  2.000000  ...  0.000000    0
# 1      5    0    0    9   17    10   2   8    2  2.000000  ...  0.000000    0
# 2      1    1    0    0    1     0   0   0    1  2.000000  ...  0.000000    0
# 3     13    3    0   41   73    50   5  41    5  0.892857  ...  0.714286    0
# 4      7    2    0    6   13    17   4   2    7  0.750000  ...  1.000000    1
# ..   ...  ...  ...  ...  ...   ...  ..  ..  ...       ...  ...       ...  ...
# 867   47    1    0    7   81   829   5   3   45  0.939959  ...  0.857143    0
# 868    3    1    0    4    9     1   1   3    3  0.000000  ...  1.000000    0
# 869    3    2    0    1    5     3   0   1    3  2.000000  ...  0.000000    0
# 870   20    1    0   18   86   188  14   4   12  0.894737  ...  1.000000    0
# 871    2    5    0    4    7     0   2   2    2  0.000000  ...  1.000000    1
#
#           mfa       cam  ic  cbm        amc  max_cc  avg_cc  class
# 0    0.588235  0.347222   1    1  48.250000       7  3.1250      1
# 1    0.000000  0.450000   0    0  18.400000       2  1.0000      0
# 2    0.000000  1.000000   0    0   0.000000       1  1.0000      0
# 3    0.645161  0.250000   1    1  24.923077       5  1.6154      0
# 4    0.333333  0.428571   0    0   5.285714       1  0.8571      0
# ..        ...       ...  ..  ...        ...     ...     ...    ...
# 867  0.000000  0.183511   0    0  13.446809       9  1.4468      0
# 868  0.000000  0.500000   0    0  14.333333       2  1.0000      0
# 869  0.956522  0.666667   1    2   3.000000       1  0.3333      0
# 870  0.000000  0.276316   0    0  35.900000      11  2.5000      1
# 871  0.944444  0.666667   0    0  11.000000       1  0.5000      0
#
# [872 rows x 21 columns]

# %%
df[df['class'] == 0]
# Out:
#      wmc  dit  noc  cbo  rfc  lcom  ca  ce  npm     lcom3  ...       dam  moa  \
# 1      5    0    0    9   17    10   2   8    2  2.000000  ...  0.000000    0
# 2      1    1    0    0    1     0   0   0    1  2.000000  ...  0.000000    0
# 3     13    3    0   41   73    50   5  41    5  0.892857  ...  0.714286    0
# 4      7    2    0    6   13    17   4   2    7  0.750000  ...  1.000000    1
# 5      6    1    6   11   14    15   7   4    5  2.000000  ...  0.000000    0
# ..   ...  ...  ...  ...  ...   ...  ..  ..  ...       ...  ...       ...  ...
# 866    3    3    0    8    9     0   2   8    2  0.500000  ...  1.000000    3
# 867   47    1    0    7   81   829   5   3   45  0.939959  ...  0.857143    0
# 868    3    1    0    4    9     1   1   3    3  0.000000  ...  1.000000    0
# 869    3    2    0    1    5     3   0   1    3  2.000000  ...  0.000000    0
# 871    2    5    0    4    7     0   2   2    2  0.000000  ...  1.000000    1
#
#           mfa       cam  ic  cbm        amc  max_cc  avg_cc  class
# 1    0.000000  0.450000   0    0  18.400000       2  1.0000      0
# 2    0.000000  1.000000   0    0   0.000000       1  1.0000      0
# 3    0.645161  0.250000   1    1  24.923077       5  1.6154      0
# 4    0.333333  0.428571   0    0   5.285714       1  0.8571      0
# 5    0.000000  0.541667   0    0   7.666667       2  1.0000      0
# ..        ...       ...  ..  ...        ...     ...     ...    ...
# 866  0.909091  0.400000   0    0  12.666667       2  1.0000      0
# 867  0.000000  0.183511   0    0  13.446809       9  1.4468      0
# 868  0.000000  0.500000   0    0  14.333333       2  1.0000      0
# 869  0.956522  0.666667   1    2   3.000000       1  0.3333      0
# 871  0.944444  0.666667   0    0  11.000000       1  0.5000      0
#
# [727 rows x 21 columns]

# %%
X = df.drop(['class'], axis=1)
X
# Out:
#      wmc  dit  noc  cbo  rfc  lcom  ca  ce  npm     lcom3  loc       dam  moa  \
# 0      8    2    0    8   31    28   1   7    1  2.000000  394  0.000000    0
# 1      5    0    0    9   17    10   2   8    2  2.000000   97  0.000000    0
# 2      1    1    0    0    1     0   0   0    1  2.000000    1  0.000000    0
# 3     13    3    0   41   73    50   5  41    5  0.892857  344  0.714286    0
# 4      7    2    0    6   13    17   4   2    7  0.750000   46  1.000000    1
# ..   ...  ...  ...  ...  ...   ...  ..  ..  ...       ...  ...       ...  ...
# 867   47    1    0    7   81   829   5   3   45  0.939959  700  0.857143    0
# 868    3    1    0    4    9     1   1   3    3  0.000000   47  1.000000    0
# 869    3    2    0    1    5     3   0   1    3  2.000000   12  0.000000    0
# 870   20    1    0   18   86   188  14   4   12  0.894737  739  1.000000    0
# 871    2    5    0    4    7     0   2   2    2  0.000000   25  1.000000    1
#
#           mfa       cam  ic  cbm        amc  max_cc  avg_cc
# 0    0.588235  0.347222   1    1  48.250000       7  3.1250
# 1    0.000000  0.450000   0    0  18.400000       2  1.0000
# 2    0.000000  1.000000   0    0   0.000000       1  1.0000
# 3    0.645161  0.250000   1    1  24.923077       5  1.6154
# 4    0.333333  0.428571   0    0   5.285714       1  0.8571
# ..        ...       ...  ..  ...        ...     ...     ...
# 867  0.000000  0.183511   0    0  13.446809       9  1.4468
# 868  0.000000  0.500000   0    0  14.333333       2  1.0000
# 869  0.956522  0.666667   1    2   3.000000       1  0.3333
# 870  0.000000  0.276316   0    0  35.900000      11  2.5000
# 871  0.944444  0.666667   0    0  11.000000       1  0.5000
#
# [872 rows x 20 columns]

# %%
Y = df['class']
Y
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 867    0
# 868    0
# 869    0
# 870    1
# 871    0
# Name: class, Length: 872, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import *

# %% [markdown]
# # All Features

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8129770992366412
# Precision :  0.0
# Recall :  0.0
# F1 Score :  0.0
# AUC :  0.5
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8129770992366412
# Precision :  0.0
# Recall :  0.0
# F1 Score :  0.0
# AUC :  0.5
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8015267175572519
# Precision :  0.4117647058823529
# Recall :  0.14285714285714285
# F1 Score :  0.21212121212121207
# AUC :  0.5479543930248155

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7633587786259542
# Precision :  0.3488372093023256
# Recall :  0.30612244897959184
# F1 Score :  0.32608695652173914
# AUC :  0.5873335249592796

# %% [markdown]
# # PEARSON CORRELATION

# %%
cor = df.corr()
cor_target = abs(cor['class'])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.15]
relevant_features
# Out:
# wmc       0.240715
# cbo       0.155480
# rfc       0.234290
# npm       0.237417
# loc       0.229576
# cam       0.200975
# max_cc    0.174361
# class     1.000000
# Name: class, dtype: float64

# %%
X_new = df[['wmc', 'cbo', 'rfc', 'npm', 'loc', 'cam', 'max_cc']]
X_new
# Out:
#      wmc  cbo  rfc  npm  loc       cam  max_cc
# 0      8    8   31    1  394  0.347222       7
# 1      5    9   17    2   97  0.450000       2
# 2      1    0    1    1    1  1.000000       1
# 3     13   41   73    5  344  0.250000       5
# 4      7    6   13    7   46  0.428571       1
# ..   ...  ...  ...  ...  ...       ...     ...
# 867   47    7   81   45  700  0.183511       9
# 868    3    4    9    3   47  0.500000       2
# 869    3    1    5    3   12  0.666667       1
# 870   20   18   86   12  739  0.276316      11
# 871    2    4    7    2   25  0.666667       1
#
# [872 rows x 7 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8396946564885496
# Precision :  0.7692307692307693
# Recall :  0.20408163265306123
# F1 Score :  0.3225806451612903
# AUC :  0.5949985628054039

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8091603053435115
# Precision :  0.0
# Recall :  0.0
# F1 Score :  0.0
# AUC :  0.49765258215962443

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7748091603053435
# Precision :  0.25
# Recall :  0.10204081632653061
# F1 Score :  0.14492753623188406
# AUC :  0.5158091405576314

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7748091603053435
# Precision :  0.375
# Recall :  0.30612244897959184
# F1 Score :  0.33707865168539325
# AUC :  0.5943757784804062

# %% [markdown]
# # INFORMATION GAIN 10

# %%
from sklearn.feature_selection import mutual_info_classif
gain = mutual_info_classif(X,Y)
gain
# Out:
# array([0.02696576, 0.02429774, 0.00659684, 0.01294686, 0.01835095,
#        0.04462066, 0.0330265 , 0.00252407, 0.0468203 , 0.00634526,
#        0.02233171, 0.        , 0.0138275 , 0.        , 0.02092909,
#        0.00505917, 0.02293621, 0.01842217, 0.00310332, 0.00408659])

# %%
col_list = X.columns
col_list
# Out:
# Index(['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom', 'ca', 'ce', 'npm', 'lcom3',
#        'loc', 'dam', 'moa', 'mfa', 'cam', 'ic', 'cbm', 'amc', 'max_cc',
#        'avg_cc'],
#       dtype='object')

# %%
temp = pd.DataFrame(list(zip(col_list, gain)), columns =['col', 'score']) 
temp
# Out:
#        col     score
# 0      wmc  0.026966
# 1      dit  0.024298
# 2      noc  0.006597
# 3      cbo  0.012947
# 4      rfc  0.018351
# 5     lcom  0.044621
# 6       ca  0.033026
# 7       ce  0.002524
# 8      npm  0.046820
# 9    lcom3  0.006345
# 10     loc  0.022332
# 11     dam  0.000000
# 12     moa  0.013827
# 13     mfa  0.000000
# 14     cam  0.020929
# 15      ic  0.005059
# 16     cbm  0.022936
# 17     amc  0.018422
# 18  max_cc  0.003103
# 19  avg_cc  0.004087

# %%
temp_sort = temp.sort_values(['score'], ascending=False)
temp_sort[:10]
# Out:
#      col     score
# 8    npm  0.046820
# 5   lcom  0.044621
# 6     ca  0.033026
# 0    wmc  0.026966
# 1    dit  0.024298
# 16   cbm  0.022936
# 10   loc  0.022332
# 14   cam  0.020929
# 17   amc  0.018422
# 4    rfc  0.018351

# %%
FS = list(temp_sort['col'][:10])
FS
# Out:
# ['npm', 'lcom', 'ca', 'wmc', 'dit', 'cbm', 'loc', 'cam', 'amc', 'rfc']

# %%
X_new = df[FS]
X_new
# Out:
#      npm  lcom  ca  wmc  dit  cbm  loc       cam        amc  rfc
# 0      1    28   1    8    2    1  394  0.347222  48.250000   31
# 1      2    10   2    5    0    0   97  0.450000  18.400000   17
# 2      1     0   0    1    1    0    1  1.000000   0.000000    1
# 3      5    50   5   13    3    1  344  0.250000  24.923077   73
# 4      7    17   4    7    2    0   46  0.428571   5.285714   13
# ..   ...   ...  ..  ...  ...  ...  ...       ...        ...  ...
# 867   45   829   5   47    1    0  700  0.183511  13.446809   81
# 868    3     1   1    3    1    0   47  0.500000  14.333333    9
# 869    3     3   0    3    2    2   12  0.666667   3.000000    5
# 870   12   188  14   20    1    0  739  0.276316  35.900000   86
# 871    2     0   2    2    5    0   25  0.666667  11.000000    7
#
# [872 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.816793893129771
# Precision :  0.5294117647058824
# Recall :  0.1836734693877551
# F1 Score :  0.27272727272727276
# AUC :  0.5730573919708729

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8129770992366412
# Precision :  0.0
# Recall :  0.0
# F1 Score :  0.0
# AUC :  0.5
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8053435114503816
# Precision :  0.42857142857142855
# Recall :  0.12244897959183673
# F1 Score :  0.19047619047619047
# AUC :  0.5424451470729137

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7862595419847328
# Precision :  0.3939393939393939
# Recall :  0.2653061224489796
# F1 Score :  0.3170731707317074
# AUC :  0.5857047044169781

# %% [markdown]
# # INFORMATION GAIN 15

# %%
from sklearn.feature_selection import mutual_info_classif
gain = mutual_info_classif(X,Y)
gain
# Out:
# array([0.03755021, 0.01657442, 0.00421856, 0.00719512, 0.02319613,
#        0.04015399, 0.02810398, 0.02980305, 0.0292018 , 0.01168584,
#        0.02042877, 0.00985507, 0.00174733, 0.00155153, 0.02076725,
#        0.        , 0.00310408, 0.02084902, 0.00859829, 0.01010555])

# %%
col_list = X.columns
col_list
# Out:
# Index(['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom', 'ca', 'ce', 'npm', 'lcom3',
#        'loc', 'dam', 'moa', 'mfa', 'cam', 'ic', 'cbm', 'amc', 'max_cc',
#        'avg_cc'],
#       dtype='object')

# %%
temp = pd.DataFrame(list(zip(col_list, gain)), columns =['col', 'score']) 
temp
# Out:
#        col     score
# 0      wmc  0.037550
# 1      dit  0.016574
# 2      noc  0.004219
# 3      cbo  0.007195
# 4      rfc  0.023196
# 5     lcom  0.040154
# 6       ca  0.028104
# 7       ce  0.029803
# 8      npm  0.029202
# 9    lcom3  0.011686
# 10     loc  0.020429
# 11     dam  0.009855
# 12     moa  0.001747
# 13     mfa  0.001552
# 14     cam  0.020767
# 15      ic  0.000000
# 16     cbm  0.003104
# 17     amc  0.020849
# 18  max_cc  0.008598
# 19  avg_cc  0.010106

# %%
temp_sort = temp.sort_values(['score'], ascending=False)
temp_sort[:15]
# Out:
#        col     score
# 5     lcom  0.040154
# 0      wmc  0.037550
# 7       ce  0.029803
# 8      npm  0.029202
# 6       ca  0.028104
# 4      rfc  0.023196
# 17     amc  0.020849
# 14     cam  0.020767
# 10     loc  0.020429
# 1      dit  0.016574
# 9    lcom3  0.011686
# 19  avg_cc  0.010106
# 11     dam  0.009855
# 18  max_cc  0.008598
# 3      cbo  0.007195

# %%
FS = list(temp_sort['col'][:15])
FS
# Out:
# ['lcom',
#  'wmc',
#  'ce',
#  'npm',
#  'ca',
#  'rfc',
#  'amc',
#  'cam',
#  'loc',
#  'dit',
#  'lcom3',
#  'avg_cc',
#  'dam',
#  'max_cc',
#  'cbo']

# %%
X_new = df[FS]
X_new
# Out:
#      lcom  wmc  ce  npm  ca  rfc        amc       cam  loc  dit     lcom3  \
# 0      28    8   7    1   1   31  48.250000  0.347222  394    2  2.000000
# 1      10    5   8    2   2   17  18.400000  0.450000   97    0  2.000000
# 2       0    1   0    1   0    1   0.000000  1.000000    1    1  2.000000
# 3      50   13  41    5   5   73  24.923077  0.250000  344    3  0.892857
# 4      17    7   2    7   4   13   5.285714  0.428571   46    2  0.750000
# ..    ...  ...  ..  ...  ..  ...        ...       ...  ...  ...       ...
# 867   829   47   3   45   5   81  13.446809  0.183511  700    1  0.939959
# 868     1    3   3    3   1    9  14.333333  0.500000   47    1  0.000000
# 869     3    3   1    3   0    5   3.000000  0.666667   12    2  2.000000
# 870   188   20   4   12  14   86  35.900000  0.276316  739    1  0.894737
# 871     0    2   2    2   2    7  11.000000  0.666667   25    5  0.000000
#
#      avg_cc       dam  max_cc  cbo
# 0    3.1250  0.000000       7    8
# 1    1.0000  0.000000       2    9
# 2    1.0000  0.000000       1    0
# 3    1.6154  0.714286       5   41
# 4    0.8571  1.000000       1    6
# ..      ...       ...     ...  ...
# 867  1.4468  0.857143       9    7
# 868  1.0000  1.000000       2    4
# 869  0.3333  0.000000       1    1
# 870  2.5000  1.000000      11   18
# 871  0.5000  1.000000       1    4
#
# [872 rows x 15 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8320610687022901
# Precision :  0.7272727272727273
# Recall :  0.16326530612244897
# F1 Score :  0.26666666666666666
# AUC :  0.5745903995400977

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8129770992366412
# Precision :  0.0
# Recall :  0.0
# F1 Score :  0.0
# AUC :  0.5
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7977099236641222
# Precision :  0.375
# Recall :  0.12244897959183673
# F1 Score :  0.1846153846153846
# AUC :  0.5377503113921625

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7786259541984732
# Precision :  0.3783783783783784
# Recall :  0.2857142857142857
# F1 Score :  0.32558139534883723
# AUC :  0.5888665325285043

# %% [markdown]
# # FISHER SCORE

# %%
FScore = []

for m in  range(len(col_list)):
        mu = df[col_list[m]].mean()

        n_1 = df[df['class'] == 0].count()[1]
        mu_1 = df[col_list[m]][df['class'] == 0].mean()
        var_1 = df[col_list[m]][df['class'] == 0].var()

        n_2 = df[df['class'] == 1].count()[1]
        mu_2 = df[col_list[m]][df['class'] == 1].mean()
        var_2 = df[col_list[m]][df['class'] == 1].var()

        inter_class = n_1*(mu_1-mu)**2 + n_2*(mu_2-mu)**2
        intra_class = (n_1-1)*var_1 + (n_2-1)*var_2

        FScore.append(inter_class / intra_class)

FScore
# Out:
# [0.0615078675790374,
#  0.0029688126945121543,
#  0.018088880090088633,
#  0.024772813264949897,
#  0.058079819818262886,
#  0.014243042071851352,
#  0.015901276416914956,
#  0.013452555524105693,
#  0.05973388355592481,
#  0.002118027800789546,
#  0.055637336893961685,
#  0.005352963255146524,
#  0.011299055487470136,
#  0.0015052055333984263,
#  0.04209120712993962,
#  0.014154799607692482,
#  0.01614468070324366,
#  0.007371149012985105,
#  0.031354932235540124,
#  0.010883656930089058]

# %%
temp = pd.DataFrame(list(zip(col_list, FScore)), columns =['col', 'score']) 
temp
# Out:
#        col     score
# 0      wmc  0.061508
# 1      dit  0.002969
# 2      noc  0.018089
# 3      cbo  0.024773
# 4      rfc  0.058080
# 5     lcom  0.014243
# 6       ca  0.015901
# 7       ce  0.013453
# 8      npm  0.059734
# 9    lcom3  0.002118
# 10     loc  0.055637
# 11     dam  0.005353
# 12     moa  0.011299
# 13     mfa  0.001505
# 14     cam  0.042091
# 15      ic  0.014155
# 16     cbm  0.016145
# 17     amc  0.007371
# 18  max_cc  0.031355
# 19  avg_cc  0.010884

# %%
temp_sort = temp.sort_values(['score'], ascending=False)
temp_sort[:10]
# Out:
#        col     score
# 0      wmc  0.061508
# 8      npm  0.059734
# 4      rfc  0.058080
# 10     loc  0.055637
# 14     cam  0.042091
# 18  max_cc  0.031355
# 3      cbo  0.024773
# 2      noc  0.018089
# 16     cbm  0.016145
# 6       ca  0.015901

# %%
FS = list(temp_sort['col'][:10])
FS
# Out:
# ['wmc', 'npm', 'rfc', 'loc', 'cam', 'max_cc', 'cbo', 'noc', 'cbm', 'ca']

# %%
X_new = df[FS]
X_new
# Out:
#      wmc  npm  rfc  loc       cam  max_cc  cbo  noc  cbm  ca
# 0      8    1   31  394  0.347222       7    8    0    1   1
# 1      5    2   17   97  0.450000       2    9    0    0   2
# 2      1    1    1    1  1.000000       1    0    0    0   0
# 3     13    5   73  344  0.250000       5   41    0    1   5
# 4      7    7   13   46  0.428571       1    6    0    0   4
# ..   ...  ...  ...  ...       ...     ...  ...  ...  ...  ..
# 867   47   45   81  700  0.183511       9    7    0    0   5
# 868    3    3    9   47  0.500000       2    4    0    0   1
# 869    3    3    5   12  0.666667       1    1    0    2   0
# 870   20   12   86  739  0.276316      11   18    0    0  14
# 871    2    2    7   25  0.666667       1    4    0    0   2
#
# [872 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8396946564885496
# Precision :  0.7692307692307693
# Recall :  0.20408163265306123
# F1 Score :  0.3225806451612903
# AUC :  0.5949985628054039

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8091603053435115
# Precision :  0.0
# Recall :  0.0
# F1 Score :  0.0
# AUC :  0.49765258215962443

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7977099236641222
# Precision :  0.35714285714285715
# Recall :  0.10204081632653061
# F1 Score :  0.15873015873015872
# AUC :  0.529893647599885

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7824427480916031
# Precision :  0.4
# Recall :  0.32653061224489793
# F1 Score :  0.35955056179775274
# AUC :  0.6069272779534349

# %% [markdown]
# # SVM RFE 10

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,random_state=23)

# %%
from sklearn.feature_selection import RFE
rec_model = RandomForestClassifier()

rfe = RFE(rec_model, n_features_to_select=10)
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=RandomForestClassifier(), n_features_to_select=10)

# %%
X_train = X_train.loc[:, rfe.support_]
X_train
# Out:
#      wmc  cbo  rfc  lcom  ce  loc       mfa       cam        amc  avg_cc
# 58     4    4   13     4   3   39  0.000000  0.500000   8.500000  0.5000
# 133   49   20   93  1044  17  620  0.000000  0.128728  11.346939  1.4082
# 414    5    9   11     4   8   53  0.884615  0.342857   9.200000  0.6000
# 583   10   27   19     3   4   81  0.619048  0.500000   7.000000  0.8000
# 526   18   20   18   153  17   18  0.000000  0.238095   0.000000  1.0000
# ..   ...  ...  ...   ...  ..  ...       ...       ...        ...     ...
# 31     2    6   10     0   5   46  0.000000  0.666667  21.500000  0.5000
# 488    1    0    1     0   0    1  0.000000  1.000000   0.000000  1.0000
# 40     3    6    7     0   5   29  0.909091  0.533333   8.333333  0.6667
# 742    8   10   27    14  10  120  0.793103  0.291667  13.625000  0.7500
# 595    4    5    6     0   4   21  0.750000  0.500000   4.000000  0.7500
#
# [610 rows x 10 columns]

# %%
X_test = X_test.loc[:, rfe.support_]
X_test
# Out:
#      wmc  cbo  rfc  lcom  ce  loc       mfa       cam        amc  avg_cc
# 157    5    6   12    10   5   28  0.974522  0.600000   4.600000  0.8000
# 390    1    0    1     0   0    1  0.000000  1.000000   0.000000  1.0000
# 535    1    0    1     0   0    1  0.000000  1.000000   0.000000  1.0000
# 809    4    9   12     6   6   47  0.928571  0.416667  10.750000  1.2500
# 419   13   14   52    60  13  341  0.000000  0.240385  24.769231  1.2308
# ..   ...  ...  ...   ...  ..  ...       ...       ...        ...     ...
# 578    2    3    4     1   3   12  0.971429  0.666667   4.500000  0.5000
# 492    4    1   13     0   1   47  0.894737  0.500000  10.250000  0.7500
# 148    8   31   42    14  30  207  0.000000  0.350000  24.500000  0.8750
# 124    4   11    7     0   6   34  0.950000  0.541667   7.250000  0.5000
# 64     9    9   31    22   8  140  0.000000  0.285714  13.888889  1.2222
#
# [262 rows x 10 columns]

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.816793893129771
# Precision :  0.5294117647058824
# Recall :  0.1836734693877551
# F1 Score :  0.27272727272727276
# AUC :  0.5730573919708729

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8129770992366412
# Precision :  0.0
# Recall :  0.0
# F1 Score :  0.0
# AUC :  0.5
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7977099236641222
# Precision :  0.375
# Recall :  0.12244897959183673
# F1 Score :  0.1846153846153846
# AUC :  0.5377503113921625

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7595419847328244
# Precision :  0.325
# Recall :  0.2653061224489796
# F1 Score :  0.29213483146067415
# AUC :  0.5692727795343488

# %% [markdown]
# # SVM RFE 15

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,random_state=23)

# %%
from sklearn.feature_selection import RFE
rec_model = RandomForestClassifier()

rfe = RFE(rec_model, n_features_to_select=15)
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=RandomForestClassifier(), n_features_to_select=15)

# %%
X_train = X_train.loc[:, rfe.support_]
X_train
# Out:
#      wmc  cbo  rfc  lcom  ca  ce  npm     lcom3  loc       mfa       cam  cbm  \
# 58     4    4   13     4   1   3    2  0.333333   39  0.000000  0.500000    0
# 133   49   20   93  1044   8  17   42  0.915278  620  0.000000  0.128728    0
# 414    5    9   11     4   2   8    5  0.500000   53  0.884615  0.342857    0
# 583   10   27   19     3  23   4    7  0.111111   81  0.619048  0.500000    1
# 526   18   20   18   153  12  17   18  2.000000   18  0.000000  0.238095    0
# ..   ...  ...  ...   ...  ..  ..  ...       ...  ...       ...       ...  ...
# 31     2    6   10     0   1   5    2  0.000000   46  0.000000  0.666667    0
# 488    1    0    1     0   0   0    1  2.000000    1  0.000000  1.000000    0
# 40     3    6    7     0   1   5    3  0.000000   29  0.909091  0.533333    0
# 742    8   10   27    14   2  10    4  0.714286  120  0.793103  0.291667    0
# 595    4    5    6     0   1   4    3  0.333333   21  0.750000  0.500000    1
#
#            amc  max_cc  avg_cc
# 58    8.500000       1  0.5000
# 133  11.346939       6  1.4082
# 414   9.200000       1  0.6000
# 583   7.000000       1  0.8000
# 526   0.000000       1  1.0000
# ..         ...     ...     ...
# 31   21.500000       1  0.5000
# 488   0.000000       1  1.0000
# 40    8.333333       1  0.6667
# 742  13.625000       1  0.7500
# 595   4.000000       1  0.7500
#
# [610 rows x 15 columns]

# %%
X_test = X_test.loc[:, rfe.support_]
X_test
# Out:
#      wmc  cbo  rfc  lcom  ca  ce  npm     lcom3  loc       mfa       cam  cbm  \
# 157    5    6   12    10   1   5    5  2.000000   28  0.974522  0.600000    1
# 390    1    0    1     0   0   0    1  2.000000    1  0.000000  1.000000    0
# 535    1    0    1     0   0   0    1  2.000000    1  0.000000  1.000000    0
# 809    4    9   12     6   4   6    4  2.000000   47  0.928571  0.416667    0
# 419   13   14   52    60   2  13    3  0.833333  341  0.000000  0.240385    0
# ..   ...  ...  ...   ...  ..  ..  ...       ...  ...       ...       ...  ...
# 578    2    3    4     1   1   3    1  2.000000   12  0.971429  0.666667    1
# 492    4    1   13     0   0   1    3  0.833333   47  0.894737  0.500000    0
# 148    8   31   42    14   5  30    6  0.761905  207  0.000000  0.350000    0
# 124    4   11    7     0   7   6    4  0.000000   34  0.950000  0.541667    0
# 64     9    9   31    22   1   8    5  0.812500  140  0.000000  0.285714    0
#
#            amc  max_cc  avg_cc
# 157   4.600000       1  0.8000
# 390   0.000000       1  1.0000
# 535   0.000000       1  1.0000
# 809  10.750000       4  1.2500
# 419  24.769231       5  1.2308
# ..         ...     ...     ...
# 578   4.500000       1  0.5000
# 492  10.250000       2  0.7500
# 148  24.500000       1  0.8750
# 124   7.250000       1  0.5000
# 64   13.888889       3  1.2222
#
# [262 rows x 15 columns]

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8320610687022901
# Precision :  0.7777777777777778
# Recall :  0.14285714285714285
# F1 Score :  0.24137931034482757
# AUC :  0.5667337357478203

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8129770992366412
# Precision :  0.0
# Recall :  0.0
# F1 Score :  0.0
# AUC :  0.5
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7977099236641222
# Precision :  0.375
# Recall :  0.12244897959183673
# F1 Score :  0.1846153846153846
# AUC :  0.5377503113921625

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7557251908396947
# Precision :  0.3170731707317073
# Recall :  0.2653061224489796
# F1 Score :  0.2888888888888889
# AUC :  0.5669253616939733

# %% [markdown]
# # MRMR 10

# %%
from sklearn.feature_selection import f_regression

F = pd.Series(f_regression(X, Y)[0], index = X.columns)
corr = X.corr().abs().clip(.00001)

# %%
selected = []
feat_score = []
not_selected = list(X.columns)

# %%
K = 10

for i in range(K):
    
    # compute FCQ score for all the (currently) excluded features (this is Formula 2)
    score = F.loc[not_selected] / corr.loc[not_selected, selected].mean(axis = 1).fillna(.00001)
    
    # find best feature, add it to selected and remove it from not_selected
    best = score.index[score.argmax()]
    selected.append(best)
    feat_score.append(score[best])
    not_selected.remove(best)

# %%
selected
# Out:
# ['wmc', 'dit', 'noc', 'amc', 'npm', 'cam', 'cbo', 'loc', 'cbm', 'rfc']

# %%
X_new = X[selected]
X_new
# Out:
#      wmc  dit  noc        amc  npm       cam  cbo  loc  cbm  rfc
# 0      8    2    0  48.250000    1  0.347222    8  394    1   31
# 1      5    0    0  18.400000    2  0.450000    9   97    0   17
# 2      1    1    0   0.000000    1  1.000000    0    1    0    1
# 3     13    3    0  24.923077    5  0.250000   41  344    1   73
# 4      7    2    0   5.285714    7  0.428571    6   46    0   13
# ..   ...  ...  ...        ...  ...       ...  ...  ...  ...  ...
# 867   47    1    0  13.446809   45  0.183511    7  700    0   81
# 868    3    1    0  14.333333    3  0.500000    4   47    0    9
# 869    3    2    0   3.000000    3  0.666667    1   12    2    5
# 870   20    1    0  35.900000   12  0.276316   18  739    0   86
# 871    2    5    0  11.000000    2  0.666667    4   25    0    7
#
# [872 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.816793893129771
# Precision :  0.5333333333333333
# Recall :  0.16326530612244897
# F1 Score :  0.25
# AUC :  0.5652007281785953

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8091603053435115
# Precision :  0.0
# Recall :  0.0
# F1 Score :  0.0
# AUC :  0.49765258215962443

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7977099236641222
# Precision :  0.375
# Recall :  0.12244897959183673
# F1 Score :  0.1846153846153846
# AUC :  0.5377503113921625

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7709923664122137
# Precision :  0.37209302325581395
# Recall :  0.32653061224489793
# F1 Score :  0.34782608695652173
# AUC :  0.5998850244323081

# %% [markdown]
# # MRMR 15

# %%
from sklearn.feature_selection import f_regression

F = pd.Series(f_regression(X, Y)[0], index = X.columns)
corr = X.corr().abs().clip(.00001)

# %%
selected = []
feat_score = []
not_selected = list(X.columns)

# %%
K = 15

for i in range(K):
    
    # compute FCQ score for all the (currently) excluded features (this is Formula 2)
    score = F.loc[not_selected] / corr.loc[not_selected, selected].mean(axis = 1).fillna(.00001)
    
    # find best feature, add it to selected and remove it from not_selected
    best = score.index[score.argmax()]
    selected.append(best)
    feat_score.append(score[best])
    not_selected.remove(best)

# %%
selected
# Out:
# ['wmc',
#  'dit',
#  'noc',
#  'amc',
#  'npm',
#  'cam',
#  'cbo',
#  'loc',
#  'cbm',
#  'rfc',
#  'max_cc',
#  'ca',
#  'ic',
#  'moa',
#  'avg_cc']

# %%
X_new = X[selected]
X_new
# Out:
#      wmc  dit  noc        amc  npm       cam  cbo  loc  cbm  rfc  max_cc  ca  \
# 0      8    2    0  48.250000    1  0.347222    8  394    1   31       7   1
# 1      5    0    0  18.400000    2  0.450000    9   97    0   17       2   2
# 2      1    1    0   0.000000    1  1.000000    0    1    0    1       1   0
# 3     13    3    0  24.923077    5  0.250000   41  344    1   73       5   5
# 4      7    2    0   5.285714    7  0.428571    6   46    0   13       1   4
# ..   ...  ...  ...        ...  ...       ...  ...  ...  ...  ...     ...  ..
# 867   47    1    0  13.446809   45  0.183511    7  700    0   81       9   5
# 868    3    1    0  14.333333    3  0.500000    4   47    0    9       2   1
# 869    3    2    0   3.000000    3  0.666667    1   12    2    5       1   0
# 870   20    1    0  35.900000   12  0.276316   18  739    0   86      11  14
# 871    2    5    0  11.000000    2  0.666667    4   25    0    7       1   2
#
#      ic  moa  avg_cc
# 0     1    0  3.1250
# 1     0    0  1.0000
# 2     0    0  1.0000
# 3     1    0  1.6154
# 4     0    1  0.8571
# ..   ..  ...     ...
# 867   0    0  1.4468
# 868   0    0  1.0000
# 869   1    0  0.3333
# 870   0    0  2.5000
# 871   0    1  0.5000
#
# [872 rows x 15 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8244274809160306
# Precision :  0.6363636363636364
# Recall :  0.14285714285714285
# F1 Score :  0.23333333333333328
# AUC :  0.562038900067069

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8053435114503816
# Precision :  0.4375
# Recall :  0.14285714285714285
# F1 Score :  0.2153846153846154
# AUC :  0.5503018108651911

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8091603053435115
# Precision :  0.0
# Recall :  0.0
# F1 Score :  0.0
# AUC :  0.49765258215962443

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8053435114503816
# Precision :  0.4375
# Recall :  0.14285714285714285
# F1 Score :  0.2153846153846154
# AUC :  0.5503018108651911

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7748091603053435
# Precision :  0.38636363636363635
# Recall :  0.3469387755102041
# F1 Score :  0.3655913978494624
# AUC :  0.6100891060649611

# %% [markdown]
# # MRMR HFS

# %%
def HSF(df, df_train):
    
    from copy import deepcopy
    col_list = list(df_train.columns)
    print(col_list)
    d = df_train.shape[1]
    SF = []
    merit = [0 for i in range(d)]
    merit_archive = [0 for i in range(d)]
    Total_FS = [0 for i in range(d)]

    rel_CF = RHFS(df, d, col_list)

    max_value = max(rel_CF)
    Feature_max_index = rel_CF.index(max_value)

    n = 0

    SF.append(Feature_max_index)

    merit_archive[n] = deepcopy(max_value)

    Total_FS[n] = deepcopy(SF)

    while n < d-1:

        for i in range(d):

            red_FF = SHFS(SF, df_train, i, col_list,d)

            top = (d + d*(sum(rel_CF)/len(rel_CF)))
            bottom = (d + (d*(d-1)*(sum(red_FF)/len(red_FF))))**(1/2)
            merit[i] = top/bottom

        for val in SF:
            merit[val] = -9999999

        max_value = max(merit)
        Feature_max_index = merit.index(max_value)

        if Feature_max_index not in SF:
            SF.append(Feature_max_index)

        n += 1
        
        Total_FS[n] = deepcopy(SF)

        merit_archive[n] = max_value

    index_val = merit_archive.index(max(merit_archive))

    Feature_subset = Total_FS[index_val]

    subset_list = []

    for val in Feature_subset:
        subset_list.append(col_list[val])
    return subset_list


def RHFS(df, d, col_list):
    rel_CF = [0 for i in range(d)]
    count = 0

    igain = IG(X,df['class'])

    for m in  range(d):
        mu = df[col_list[m]].mean()

        n_1 = df[df['class'] == 0].count()[1]
        mu_1 = df[col_list[m]][df['class'] == 0].mean()
        var_1 = df[col_list[m]][df['class'] == 0].var()

        n_2 = df[df['class'] == 1].count()[1]
        mu_2 = df[col_list[m]][df['class'] == 1].mean()
        var_2 = df[col_list[m]][df['class'] == 1].var()

        inter_class = n_1*(mu_1-mu)**2 + n_2*(mu_2-mu)**2
        intra_class = (n_1-1)*var_1 + (n_2-1)*var_2

        fscore = inter_class / intra_class

        rel_CF[count] = (1/2)*(fscore + igain[m])
        count += 1
    
    return rel_CF

        
        

def IG(col_1, col_2):
    from sklearn.feature_selection import mutual_info_classif
    gain = mutual_info_classif(col_1,col_2)
    return gain   

def relief(col_1,col_2):
    pass



def SHFS(SF, df_train, i, col_list,d):
    from itertools import combinations
    from copy import deepcopy
    red_FF = []
    temp_SF = deepcopy(SF)
    if i not in SF:
        temp_SF.append(i)
        P_pairs = list(combinations(temp_SF,2))
        for pair in P_pairs:

            ied_value = (IED(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            pc_value = (PC(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            cs_value = (CS(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2

            red_FF.append((1/3)*(ied_value + pc_value + cs_value))
            # red_FF.append((1/2)*(pc_value + cs_value))
    else:
        red_FF = [0]
    return red_FF

def IED(col_1, col_2):
    import numpy as np
    dist = np.linalg.norm(col_1 - col_2)
    return 1/dist

def PC(col_1, col_2):
    from scipy.stats import pearsonr
    corr, _ = pearsonr(col_1 , col_2)
    return corr

def CS(col_1, col_2):
    from scipy import spatial
    similarity = 1 - spatial.distance.cosine(col_1, col_2)
    return similarity

# %%
FS = HSF(df, X)
FS
# Out:
# ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom', 'ca', 'ce', 'npm', 'lcom3', 'loc', 'dam', 'moa', 'mfa', 'cam', 'ic', 'cbm', 'amc', 'max_cc', 'avg_cc']
# ['wmc', 'noc', 'ca', 'cbm']

# %%
X_new = X[FS]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7824427480916031
# Precision :  0.3181818181818182
# Recall :  0.14285714285714285
# F1 Score :  0.19718309859154928
# AUC :  0.5362173038229375

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8129770992366412
# Precision :  0.0
# Recall :  0.0
# F1 Score :  0.0
# AUC :  0.5
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8129770992366412
# Precision :  0.5
# Recall :  0.12244897959183673
# F1 Score :  0.19672131147540983
# AUC :  0.5471399827536648

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7862595419847328
# Precision :  0.34782608695652173
# Recall :  0.16326530612244897
# F1 Score :  0.22222222222222224
# AUC :  0.5464213854555907

# %% [markdown]
# # HFS NEW

# %%
def HSF(df, df_train):
    
    from copy import deepcopy
    col_list = list(df_train.columns)
    print(col_list)
    d = df_train.shape[1]
    SF = []
    merit = [0 for i in range(d)]
    merit_archive = [0 for i in range(d)]
    Total_FS = [0 for i in range(d)]

    rel_CF = RHFS(df, d, col_list)

    max_value = max(rel_CF)
    Feature_max_index = rel_CF.index(max_value)

    n = 0

    SF.append(Feature_max_index)

    merit_archive[n] = deepcopy(max_value)

    Total_FS[n] = deepcopy(SF)

    while n < d-1:

        for i in range(d):

            red_FF = SHFS(SF, df_train, i, col_list,d)

            top = (d + d*(sum(rel_CF)/len(rel_CF)))
            bottom = (d - (sum(red_FF)/len(red_FF)))**(1/2)

            merit[i] = top/bottom

        for val in SF:
            merit[val] = -9999999

        max_value = max(merit)
        Feature_max_index = merit.index(max_value)

        if Feature_max_index not in SF:
            SF.append(Feature_max_index)

        n += 1
        
        Total_FS[n] = deepcopy(SF)

        merit_archive[n] = max_value

    index_val = merit_archive.index(max(merit_archive))

    Feature_subset = Total_FS[index_val]

    subset_list = []

    for val in Feature_subset:
        subset_list.append(col_list[val])
    return subset_list


def RHFS(df, d, col_list):
    rel_CF = [0 for i in range(d)]
    count = 0

    igain = IG(X,df['class'])

    for m in  range(d):
        mu = df[col_list[m]].mean()

        n_1 = df[df['class'] == 0].count()[1]
        mu_1 = df[col_list[m]][df['class'] == 0].mean()
        var_1 = df[col_list[m]][df['class'] == 0].var()

        n_2 = df[df['class'] == 1].count()[1]
        mu_2 = df[col_list[m]][df['class'] == 1].mean()
        var_2 = df[col_list[m]][df['class'] == 1].var()

        inter_class = n_1*(mu_1-mu)**2 + n_2*(mu_2-mu)**2
        intra_class = (n_1-1)*var_1 + (n_2-1)*var_2

        fscore = inter_class / intra_class

        rel_CF[count] = (1/2)*(fscore + igain[m])
        count += 1
    
    return rel_CF

        
        

def IG(col_1, col_2):
    from sklearn.feature_selection import mutual_info_classif
    gain = mutual_info_classif(col_1,col_2)
    return gain   

def relief(col_1,col_2):
    pass



def SHFS(SF, df_train, i, col_list,d):
    from itertools import combinations
    from copy import deepcopy
    red_FF = []
    temp_SF = deepcopy(SF)
    if i not in SF:
        temp_SF.append(i)
        P_pairs = list(combinations(temp_SF,2))
        for pair in P_pairs:

            ied_value = (IED(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            pc_value = (PC(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            cs_value = (CS(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2

            red_FF.append((1/3)*(ied_value + pc_value + cs_value))
            # red_FF.append((1/2)*(pc_value + cs_value))
    else:
        red_FF = [0]
    return red_FF

def IED(col_1, col_2):
    import numpy as np
    dist = np.linalg.norm(col_1 - col_2)
    return 1/dist

def PC(col_1, col_2):
    from scipy.stats import pearsonr
    corr, _ = pearsonr(col_1 , col_2)
    return corr

def CS(col_1, col_2):
    from scipy import spatial
    similarity = 1 - spatial.distance.cosine(col_1, col_2)
    return similarity

# %%
FS = HSF(df, X)
FS
# Out:
# ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom', 'ca', 'ce', 'npm', 'lcom3', 'loc', 'dam', 'moa', 'mfa', 'cam', 'ic', 'cbm', 'amc', 'max_cc', 'avg_cc']
# ['wmc', 'npm']

# %%
X_new = X[FS]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7977099236641222
# Precision :  0.4090909090909091
# Recall :  0.1836734693877551
# F1 Score :  0.2535211267605634
# AUC :  0.5613203027689949

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8129770992366412
# Precision :  0.0
# Recall :  0.0
# F1 Score :  0.0
# AUC :  0.5
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7938931297709924
# Precision :  0.2222222222222222
# Recall :  0.04081632653061224
# F1 Score :  0.06896551724137931
# AUC :  0.503976238382677

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8091603053435115
# Precision :  0.4782608695652174
# Recall :  0.22448979591836735
# F1 Score :  0.3055555555555556
# AUC :  0.5840758838746767
