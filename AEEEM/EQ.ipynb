# %%
import pandas as pd

# %%
df = pd.read_csv('EQ.csv')
df
# Out:
#       id  ck_oo_numberOfPrivateMethods  LDHH_lcom  LDHH_fanIn  \
# 0      1                             3   0.002547    0.002555
# 1      2                            37   0.008643    0.004756
# 2      3                             3   0.001479    0.009143
# 3      4                            10   0.005642    0.005395
# 4      5                             1   0.001350    0.000000
# ..   ...                           ...        ...         ...
# 319  320                             1   0.000000    0.000000
# 320  321                             1   0.000000    0.000000
# 321  322                             2   0.004633    0.018031
# 322  323                             0   0.000000    0.000000
# 323  324                             0   0.000000    0.000000
#
#      numberOfNonTrivialBugsFoundUntil:  WCHU_numberOfPublicAttributes  \
# 0                                    4                           0.00
# 1                                   71                           0.00
# 2                                    5                           1.01
# 3                                   38                           0.00
# 4                                    1                           1.01
# ..                                 ...                            ...
# 319                                  1                           0.00
# 320                                  0                           0.00
# 321                                 27                           2.02
# 322                                  1                           0.00
# 323                                  1                           0.00
#
#      WCHU_numberOfAttributes  CvsWEntropy  LDHH_numberOfPublicMethods  \
# 0                       3.04     0.393707                    0.003049
# 1                      14.37     2.093750                    0.001481
# 2                       3.08     0.484675                    0.000000
# 3                       1.06     0.811584                    0.000876
# 4                       1.01     0.031940                    0.000876
# ..                       ...          ...                         ...
# 319                     0.00     0.052387                    0.000000
# 320                     0.00     0.000000                    0.000000
# 321                     2.02     0.727254                    0.003060
# 322                     0.00     0.000000                    0.000000
# 323                     0.00     0.000000                    0.000000
#
#      WCHU_fanIn  ...  LDHH_fanOut  LDHH_numberOfMethodsInherited  LDHH_rfc  \
# 0          1.01  ...     0.005627                       0.000000  0.004406
# 1          2.02  ...     0.018761                       0.001486  0.060301
# 2          6.17  ...     0.003117                       0.001486  0.002325
# 3          6.07  ...     0.020376                       0.002338  0.030608
# 4          0.00  ...     0.000566                       0.003017  0.001492
# ..          ...  ...          ...                            ...       ...
# 319        0.00  ...     0.004607                       0.000000  0.000000
# 320        0.00  ...     0.000000                       0.000000  0.000000
# 321       11.14  ...     0.011596                       0.004215  0.018394
# 322        0.00  ...     0.000000                       0.000000  0.000000
# 323        0.00  ...     0.000000                       0.000000  0.000000
#
#      ck_oo_numberOfMethodsInherited  ck_oo_numberOfPublicMethods  LDHH_cbo  \
# 0                                 8                            8  0.008431
# 1                                 7                            7  0.021602
# 2                                 7                            2  0.011859
# 3                                17                           10  0.020478
# 4                                22                            7  0.000652
# ..                              ...                          ...       ...
# 319                              16                            1  0.004539
# 320                               7                            1  0.000000
# 321                              30                           27  0.025180
# 322                               9                            2  0.000000
# 323                               9                            2  0.000000
#
#      WCHU_numberOfLinesOfCode  CvsExpEntropy  LDHH_numberOfMethods  class
# 0                        3.50       0.103594              0.003611  buggy
# 1                       43.12       0.328692              0.009906  buggy
# 2                        4.68       0.125841              0.001655  clean
# 3                       24.06       0.170416              0.007000  buggy
# 4                        2.13       0.055912              0.001572  buggy
# ..                        ...            ...                   ...    ...
# 319                      1.04       0.041507              0.000000  clean
# 320                      0.00       0.000000              0.000000  clean
# 321                     23.19       0.267032              0.004671  buggy
# 322                      0.00       0.000000              0.000000  clean
# 323                      0.00       0.000000              0.000000  clean
#
# [324 rows x 63 columns]

# %%
codes = {'buggy' : 1, 'clean' : 0}
for i in df.columns:
    df[i] = df[i].replace(codes)
df
# Out:
#       id  ck_oo_numberOfPrivateMethods  LDHH_lcom  LDHH_fanIn  \
# 0      1                             3   0.002547    0.002555
# 1      2                            37   0.008643    0.004756
# 2      3                             3   0.001479    0.009143
# 3      4                            10   0.005642    0.005395
# 4      5                             1   0.001350    0.000000
# ..   ...                           ...        ...         ...
# 319  320                             1   0.000000    0.000000
# 320  321                             1   0.000000    0.000000
# 321  322                             2   0.004633    0.018031
# 322  323                             0   0.000000    0.000000
# 323  324                             0   0.000000    0.000000
#
#      numberOfNonTrivialBugsFoundUntil:  WCHU_numberOfPublicAttributes  \
# 0                                    4                           0.00
# 1                                   71                           0.00
# 2                                    5                           1.01
# 3                                   38                           0.00
# 4                                    1                           1.01
# ..                                 ...                            ...
# 319                                  1                           0.00
# 320                                  0                           0.00
# 321                                 27                           2.02
# 322                                  1                           0.00
# 323                                  1                           0.00
#
#      WCHU_numberOfAttributes  CvsWEntropy  LDHH_numberOfPublicMethods  \
# 0                       3.04     0.393707                    0.003049
# 1                      14.37     2.093750                    0.001481
# 2                       3.08     0.484675                    0.000000
# 3                       1.06     0.811584                    0.000876
# 4                       1.01     0.031940                    0.000876
# ..                       ...          ...                         ...
# 319                     0.00     0.052387                    0.000000
# 320                     0.00     0.000000                    0.000000
# 321                     2.02     0.727254                    0.003060
# 322                     0.00     0.000000                    0.000000
# 323                     0.00     0.000000                    0.000000
#
#      WCHU_fanIn  ...  LDHH_fanOut  LDHH_numberOfMethodsInherited  LDHH_rfc  \
# 0          1.01  ...     0.005627                       0.000000  0.004406
# 1          2.02  ...     0.018761                       0.001486  0.060301
# 2          6.17  ...     0.003117                       0.001486  0.002325
# 3          6.07  ...     0.020376                       0.002338  0.030608
# 4          0.00  ...     0.000566                       0.003017  0.001492
# ..          ...  ...          ...                            ...       ...
# 319        0.00  ...     0.004607                       0.000000  0.000000
# 320        0.00  ...     0.000000                       0.000000  0.000000
# 321       11.14  ...     0.011596                       0.004215  0.018394
# 322        0.00  ...     0.000000                       0.000000  0.000000
# 323        0.00  ...     0.000000                       0.000000  0.000000
#
#      ck_oo_numberOfMethodsInherited  ck_oo_numberOfPublicMethods  LDHH_cbo  \
# 0                                 8                            8  0.008431
# 1                                 7                            7  0.021602
# 2                                 7                            2  0.011859
# 3                                17                           10  0.020478
# 4                                22                            7  0.000652
# ..                              ...                          ...       ...
# 319                              16                            1  0.004539
# 320                               7                            1  0.000000
# 321                              30                           27  0.025180
# 322                               9                            2  0.000000
# 323                               9                            2  0.000000
#
#      WCHU_numberOfLinesOfCode  CvsExpEntropy  LDHH_numberOfMethods  class
# 0                        3.50       0.103594              0.003611      1
# 1                       43.12       0.328692              0.009906      1
# 2                        4.68       0.125841              0.001655      0
# 3                       24.06       0.170416              0.007000      1
# 4                        2.13       0.055912              0.001572      1
# ..                        ...            ...                   ...    ...
# 319                      1.04       0.041507              0.000000      0
# 320                      0.00       0.000000              0.000000      0
# 321                     23.19       0.267032              0.004671      1
# 322                      0.00       0.000000              0.000000      0
# 323                      0.00       0.000000              0.000000      0
#
# [324 rows x 63 columns]

# %%
df = df.rename({'AgingRelatedBugs':'class'}, axis=1)
df
# Out:
#       id  ck_oo_numberOfPrivateMethods  LDHH_lcom  LDHH_fanIn  \
# 0      1                             3   0.002547    0.002555
# 1      2                            37   0.008643    0.004756
# 2      3                             3   0.001479    0.009143
# 3      4                            10   0.005642    0.005395
# 4      5                             1   0.001350    0.000000
# ..   ...                           ...        ...         ...
# 319  320                             1   0.000000    0.000000
# 320  321                             1   0.000000    0.000000
# 321  322                             2   0.004633    0.018031
# 322  323                             0   0.000000    0.000000
# 323  324                             0   0.000000    0.000000
#
#      numberOfNonTrivialBugsFoundUntil:  WCHU_numberOfPublicAttributes  \
# 0                                    4                           0.00
# 1                                   71                           0.00
# 2                                    5                           1.01
# 3                                   38                           0.00
# 4                                    1                           1.01
# ..                                 ...                            ...
# 319                                  1                           0.00
# 320                                  0                           0.00
# 321                                 27                           2.02
# 322                                  1                           0.00
# 323                                  1                           0.00
#
#      WCHU_numberOfAttributes  CvsWEntropy  LDHH_numberOfPublicMethods  \
# 0                       3.04     0.393707                    0.003049
# 1                      14.37     2.093750                    0.001481
# 2                       3.08     0.484675                    0.000000
# 3                       1.06     0.811584                    0.000876
# 4                       1.01     0.031940                    0.000876
# ..                       ...          ...                         ...
# 319                     0.00     0.052387                    0.000000
# 320                     0.00     0.000000                    0.000000
# 321                     2.02     0.727254                    0.003060
# 322                     0.00     0.000000                    0.000000
# 323                     0.00     0.000000                    0.000000
#
#      WCHU_fanIn  ...  LDHH_fanOut  LDHH_numberOfMethodsInherited  LDHH_rfc  \
# 0          1.01  ...     0.005627                       0.000000  0.004406
# 1          2.02  ...     0.018761                       0.001486  0.060301
# 2          6.17  ...     0.003117                       0.001486  0.002325
# 3          6.07  ...     0.020376                       0.002338  0.030608
# 4          0.00  ...     0.000566                       0.003017  0.001492
# ..          ...  ...          ...                            ...       ...
# 319        0.00  ...     0.004607                       0.000000  0.000000
# 320        0.00  ...     0.000000                       0.000000  0.000000
# 321       11.14  ...     0.011596                       0.004215  0.018394
# 322        0.00  ...     0.000000                       0.000000  0.000000
# 323        0.00  ...     0.000000                       0.000000  0.000000
#
#      ck_oo_numberOfMethodsInherited  ck_oo_numberOfPublicMethods  LDHH_cbo  \
# 0                                 8                            8  0.008431
# 1                                 7                            7  0.021602
# 2                                 7                            2  0.011859
# 3                                17                           10  0.020478
# 4                                22                            7  0.000652
# ..                              ...                          ...       ...
# 319                              16                            1  0.004539
# 320                               7                            1  0.000000
# 321                              30                           27  0.025180
# 322                               9                            2  0.000000
# 323                               9                            2  0.000000
#
#      WCHU_numberOfLinesOfCode  CvsExpEntropy  LDHH_numberOfMethods  class
# 0                        3.50       0.103594              0.003611      1
# 1                       43.12       0.328692              0.009906      1
# 2                        4.68       0.125841              0.001655      0
# 3                       24.06       0.170416              0.007000      1
# 4                        2.13       0.055912              0.001572      1
# ..                        ...            ...                   ...    ...
# 319                      1.04       0.041507              0.000000      0
# 320                      0.00       0.000000              0.000000      0
# 321                     23.19       0.267032              0.004671      1
# 322                      0.00       0.000000              0.000000      0
# 323                      0.00       0.000000              0.000000      0
#
# [324 rows x 63 columns]

# %%
df[df['class'] == 0]
# Out:
#       id  ck_oo_numberOfPrivateMethods  LDHH_lcom  LDHH_fanIn  \
# 2      3                             3   0.001479    0.009143
# 5      6                             0   0.000000    0.000000
# 7      8                             0   0.000000    0.000000
# 10    11                             0   0.003337    0.002402
# 12    13                             0   0.000000    0.000000
# ..   ...                           ...        ...         ...
# 318  319                             0   0.000000    0.000000
# 319  320                             1   0.000000    0.000000
# 320  321                             1   0.000000    0.000000
# 322  323                             0   0.000000    0.000000
# 323  324                             0   0.000000    0.000000
#
#      numberOfNonTrivialBugsFoundUntil:  WCHU_numberOfPublicAttributes  \
# 2                                    5                           1.01
# 5                                    1                           0.00
# 7                                    1                           0.00
# 10                                   2                           1.02
# 12                                   1                           0.00
# ..                                 ...                            ...
# 318                                  1                           0.00
# 319                                  1                           0.00
# 320                                  0                           0.00
# 322                                  1                           0.00
# 323                                  1                           0.00
#
#      WCHU_numberOfAttributes  CvsWEntropy  LDHH_numberOfPublicMethods  \
# 2                       3.08     0.484675                         0.0
# 5                       0.00     0.000000                         0.0
# 7                       0.00     0.000000                         0.0
# 10                      0.00     0.034083                         0.0
# 12                      0.00     0.000000                         0.0
# ..                       ...          ...                         ...
# 318                     0.00     0.000000                         0.0
# 319                     0.00     0.052387                         0.0
# 320                     0.00     0.000000                         0.0
# 322                     0.00     0.000000                         0.0
# 323                     0.00     0.000000                         0.0
#
#      WCHU_fanIn  ...  LDHH_fanOut  LDHH_numberOfMethodsInherited  LDHH_rfc  \
# 2          6.17  ...     0.003117                       0.001486  0.002325
# 5          0.00  ...     0.000000                       0.000000  0.000000
# 7          0.00  ...     0.000000                       0.000000  0.000000
# 10         2.03  ...     0.000000                       0.001486  0.003050
# 12         0.00  ...     0.000000                       0.000000  0.000000
# ..          ...  ...          ...                            ...       ...
# 318        0.00  ...     0.000000                       0.000000  0.000000
# 319        0.00  ...     0.004607                       0.000000  0.000000
# 320        0.00  ...     0.000000                       0.000000  0.000000
# 322        0.00  ...     0.000000                       0.000000  0.000000
# 323        0.00  ...     0.000000                       0.000000  0.000000
#
#      ck_oo_numberOfMethodsInherited  ck_oo_numberOfPublicMethods  LDHH_cbo  \
# 2                                 7                            2  0.011859
# 5                                 7                            0  0.000000
# 7                                 9                            2  0.000000
# 10                                7                            5  0.002415
# 12                                7                            2  0.000000
# ..                              ...                          ...       ...
# 318                               7                            0  0.000000
# 319                              16                            1  0.004539
# 320                               7                            1  0.000000
# 322                               9                            2  0.000000
# 323                               9                            2  0.000000
#
#      WCHU_numberOfLinesOfCode  CvsExpEntropy  LDHH_numberOfMethods  class
# 2                        4.68       0.125841              0.001655      0
# 5                        0.00       0.000000              0.000000      0
# 7                        0.00       0.000000              0.000000      0
# 10                       0.00       0.068437              0.003508      0
# 12                       0.00       0.000000              0.000000      0
# ..                        ...            ...                   ...    ...
# 318                      0.00       0.000000              0.000000      0
# 319                      1.04       0.041507              0.000000      0
# 320                      0.00       0.000000              0.000000      0
# 322                      0.00       0.000000              0.000000      0
# 323                      0.00       0.000000              0.000000      0
#
# [195 rows x 63 columns]

# %%
X = df.drop(['class'], axis=1)
X
# Out:
#       id  ck_oo_numberOfPrivateMethods  LDHH_lcom  LDHH_fanIn  \
# 0      1                             3   0.002547    0.002555
# 1      2                            37   0.008643    0.004756
# 2      3                             3   0.001479    0.009143
# 3      4                            10   0.005642    0.005395
# 4      5                             1   0.001350    0.000000
# ..   ...                           ...        ...         ...
# 319  320                             1   0.000000    0.000000
# 320  321                             1   0.000000    0.000000
# 321  322                             2   0.004633    0.018031
# 322  323                             0   0.000000    0.000000
# 323  324                             0   0.000000    0.000000
#
#      numberOfNonTrivialBugsFoundUntil:  WCHU_numberOfPublicAttributes  \
# 0                                    4                           0.00
# 1                                   71                           0.00
# 2                                    5                           1.01
# 3                                   38                           0.00
# 4                                    1                           1.01
# ..                                 ...                            ...
# 319                                  1                           0.00
# 320                                  0                           0.00
# 321                                 27                           2.02
# 322                                  1                           0.00
# 323                                  1                           0.00
#
#      WCHU_numberOfAttributes  CvsWEntropy  LDHH_numberOfPublicMethods  \
# 0                       3.04     0.393707                    0.003049
# 1                      14.37     2.093750                    0.001481
# 2                       3.08     0.484675                    0.000000
# 3                       1.06     0.811584                    0.000876
# 4                       1.01     0.031940                    0.000876
# ..                       ...          ...                         ...
# 319                     0.00     0.052387                    0.000000
# 320                     0.00     0.000000                    0.000000
# 321                     2.02     0.727254                    0.003060
# 322                     0.00     0.000000                    0.000000
# 323                     0.00     0.000000                    0.000000
#
#      WCHU_fanIn  ...  numberOfBugsFoundUntil:  LDHH_fanOut  \
# 0          1.01  ...                        4     0.005627
# 1          2.02  ...                       78     0.018761
# 2          6.17  ...                        5     0.003117
# 3          6.07  ...                       40     0.020376
# 4          0.00  ...                        1     0.000566
# ..          ...  ...                      ...          ...
# 319        0.00  ...                        2     0.004607
# 320        0.00  ...                        0     0.000000
# 321       11.14  ...                       28     0.011596
# 322        0.00  ...                        1     0.000000
# 323        0.00  ...                        1     0.000000
#
#      LDHH_numberOfMethodsInherited  LDHH_rfc  ck_oo_numberOfMethodsInherited  \
# 0                         0.000000  0.004406                               8
# 1                         0.001486  0.060301                               7
# 2                         0.001486  0.002325                               7
# 3                         0.002338  0.030608                              17
# 4                         0.003017  0.001492                              22
# ..                             ...       ...                             ...
# 319                       0.000000  0.000000                              16
# 320                       0.000000  0.000000                               7
# 321                       0.004215  0.018394                              30
# 322                       0.000000  0.000000                               9
# 323                       0.000000  0.000000                               9
#
#      ck_oo_numberOfPublicMethods  LDHH_cbo  WCHU_numberOfLinesOfCode  \
# 0                              8  0.008431                      3.50
# 1                              7  0.021602                     43.12
# 2                              2  0.011859                      4.68
# 3                             10  0.020478                     24.06
# 4                              7  0.000652                      2.13
# ..                           ...       ...                       ...
# 319                            1  0.004539                      1.04
# 320                            1  0.000000                      0.00
# 321                           27  0.025180                     23.19
# 322                            2  0.000000                      0.00
# 323                            2  0.000000                      0.00
#
#      CvsExpEntropy  LDHH_numberOfMethods
# 0         0.103594              0.003611
# 1         0.328692              0.009906
# 2         0.125841              0.001655
# 3         0.170416              0.007000
# 4         0.055912              0.001572
# ..             ...                   ...
# 319       0.041507              0.000000
# 320       0.000000              0.000000
# 321       0.267032              0.004671
# 322       0.000000              0.000000
# 323       0.000000              0.000000
#
# [324 rows x 62 columns]

# %%
Y = df['class']
Y
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      1
#       ..
# 319    0
# 320    0
# 321    1
# 322    0
# 323    0
# Name: class, Length: 324, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import *

# %% [markdown]
# # All Features

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7755102040816326
# Precision :  0.6785714285714286
# Recall :  0.59375
# F1 Score :  0.6333333333333334
# AUC :  0.7286931818181819

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7755102040816326
# Precision :  0.6785714285714286
# Recall :  0.59375
# F1 Score :  0.6333333333333334
# AUC :  0.7286931818181819

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7142857142857143
# Precision :  0.5588235294117647
# Recall :  0.59375
# F1 Score :  0.5757575757575757
# AUC :  0.6832386363636364

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7857142857142857
# Precision :  0.72
# Recall :  0.5625
# F1 Score :  0.631578947368421
# AUC :  0.7282196969696969

# %% [markdown]
# # PEARSON CORRELATION

# %%
cor = df.corr()
cor_target = abs(cor['class'])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.45]
relevant_features
# Out:
# CvsEntropy       0.496103
# CvsLogEntropy    0.501539
# CvsLinEntropy    0.479509
# class            1.000000
# Name: class, dtype: float64

# %%
X_new = df[['CvsEntropy', 'CvsLogEntropy', 'CvsLinEntropy']]
X_new
# Out:
#      CvsEntropy  CvsLogEntropy  CvsLinEntropy
# 0      10.13220       0.308139       0.043005
# 1      38.28120       1.128230       0.149026
# 2       9.49506       0.287726       0.043268
# 3      27.58140       0.756585       0.080838
# 4       7.55094       0.204387       0.022540
# ..          ...            ...            ...
# 319     3.61726       0.111739       0.014914
# 320     0.00000       0.000000       0.000000
# 321    30.36980       0.885730       0.114620
# 322     0.00000       0.000000       0.000000
# 323     0.00000       0.000000       0.000000
#
# [324 rows x 3 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7653061224489796
# Precision :  0.6285714285714286
# Recall :  0.6875
# F1 Score :  0.6567164179104478
# AUC :  0.7452651515151515

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7551020408163265
# Precision :  0.6
# Recall :  0.75
# F1 Score :  0.6666666666666665
# AUC :  0.7537878787878788

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7551020408163265
# Precision :  0.6111111111111112
# Recall :  0.6875
# F1 Score :  0.6470588235294118
# AUC :  0.7376893939393939

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7959183673469388
# Precision :  0.7307692307692307
# Recall :  0.59375
# F1 Score :  0.6551724137931033
# AUC :  0.743844696969697

# %% [markdown]
# # INFORMATION GAIN 10

# %%
from sklearn.feature_selection import mutual_info_classif
gain = mutual_info_classif(X,Y)
gain
# Out:
# array([0.00000000e+00, 3.63556951e-02, 8.38994890e-02, 9.44564223e-02,
#        1.78574479e-01, 3.42176784e-02, 8.34504229e-02, 1.21964786e-01,
#        7.44734295e-02, 9.76059128e-02, 1.02078384e-01, 2.20704569e-01,
#        0.00000000e+00, 3.59358760e-02, 6.60842138e-02, 4.63127878e-02,
#        8.93107375e-03, 5.58549611e-02, 1.56172557e-01, 7.91102136e-02,
#        9.42956323e-02, 1.98772445e-01, 6.48284688e-03, 1.31357915e-02,
#        1.17595276e-01, 1.00230260e-01, 2.20386550e-01, 9.48131938e-03,
#        1.34581363e-01, 1.31248714e-03, 6.36772248e-02, 6.19923403e-03,
#        1.33975218e-02, 1.37533843e-01, 6.44675182e-02, 1.20629989e-01,
#        1.31351829e-01, 1.08417116e-01, 1.24380591e-01, 1.22758275e-01,
#        3.95329325e-02, 1.37981897e-01, 1.20145065e-01, 1.43320563e-01,
#        1.52010637e-02, 4.29767700e-02, 5.37847140e-02, 1.14197838e-01,
#        9.70958789e-05, 1.10838574e-01, 1.25841306e-01, 9.57401772e-02,
#        1.12308332e-01, 8.45766891e-02, 8.56393795e-02, 1.27878746e-01,
#        1.16050814e-01, 1.21597970e-01, 1.24905005e-01, 9.24016842e-02,
#        2.21694608e-01, 1.07032082e-01])

# %%
col_list = X.columns
col_list
# Out:
# Index(['id', 'ck_oo_numberOfPrivateMethods', 'LDHH_lcom', 'LDHH_fanIn',
#        'numberOfNonTrivialBugsFoundUntil:', 'WCHU_numberOfPublicAttributes',
#        'WCHU_numberOfAttributes', 'CvsWEntropy', 'LDHH_numberOfPublicMethods',
#        'WCHU_fanIn', 'LDHH_numberOfPrivateAttributes', 'CvsEntropy',
#        'LDHH_numberOfPublicAttributes', 'WCHU_numberOfPrivateMethods',
#        'WCHU_numberOfMethods', 'ck_oo_numberOfPublicAttributes', 'ck_oo_noc',
#        'numberOfCriticalBugsFoundUntil:', 'ck_oo_wmc',
#        'LDHH_numberOfPrivateMethods', 'WCHU_numberOfPrivateAttributes',
#        'CvsLogEntropy', 'WCHU_noc', 'LDHH_numberOfAttributesInherited',
#        'WCHU_wmc', 'ck_oo_fanOut', 'ck_oo_numberOfLinesOfCode',
#        'ck_oo_numberOfAttributesInherited', 'ck_oo_numberOfMethods',
#        'ck_oo_dit', 'ck_oo_fanIn', 'LDHH_noc', 'WCHU_dit', 'ck_oo_lcom',
#        'WCHU_numberOfAttributesInherited', 'ck_oo_rfc', 'LDHH_wmc',
#        'LDHH_numberOfAttributes', 'LDHH_numberOfLinesOfCode', 'WCHU_fanOut',
#        'WCHU_lcom', 'ck_oo_cbo', 'WCHU_rfc', 'ck_oo_numberOfAttributes',
#        'numberOfHighPriorityBugsFoundUntil:',
#        'ck_oo_numberOfPrivateAttributes', 'numberOfMajorBugsFoundUntil:',
#        'WCHU_numberOfPublicMethods', 'LDHH_dit', 'WCHU_cbo', 'CvsLinEntropy',
#        'WCHU_numberOfMethodsInherited', 'numberOfBugsFoundUntil:',
#        'LDHH_fanOut', 'LDHH_numberOfMethodsInherited', 'LDHH_rfc',
#        'ck_oo_numberOfMethodsInherited', 'ck_oo_numberOfPublicMethods',
#        'LDHH_cbo', 'WCHU_numberOfLinesOfCode', 'CvsExpEntropy',
#        'LDHH_numberOfMethods'],
#       dtype='object')

# %%
temp = pd.DataFrame(list(zip(col_list, gain)), columns =['col', 'score']) 
temp
# Out:
#                                   col     score
# 0                                  id  0.000000
# 1        ck_oo_numberOfPrivateMethods  0.036356
# 2                           LDHH_lcom  0.083899
# 3                          LDHH_fanIn  0.094456
# 4   numberOfNonTrivialBugsFoundUntil:  0.178574
# ..                                ...       ...
# 57        ck_oo_numberOfPublicMethods  0.121598
# 58                           LDHH_cbo  0.124905
# 59           WCHU_numberOfLinesOfCode  0.092402
# 60                      CvsExpEntropy  0.221695
# 61               LDHH_numberOfMethods  0.107032
#
# [62 rows x 2 columns]

# %%
temp_sort = temp.sort_values(['score'], ascending=False)
temp_sort[:10]
# Out:
#                                   col     score
# 60                      CvsExpEntropy  0.221695
# 11                         CvsEntropy  0.220705
# 26          ck_oo_numberOfLinesOfCode  0.220387
# 21                      CvsLogEntropy  0.198772
# 4   numberOfNonTrivialBugsFoundUntil:  0.178574
# 18                          ck_oo_wmc  0.156173
# 43           ck_oo_numberOfAttributes  0.143321
# 41                          ck_oo_cbo  0.137982
# 33                         ck_oo_lcom  0.137534
# 28              ck_oo_numberOfMethods  0.134581

# %%
FS = list(temp_sort['col'][:10])
FS
# Out:
# ['CvsExpEntropy',
#  'CvsEntropy',
#  'ck_oo_numberOfLinesOfCode',
#  'CvsLogEntropy',
#  'numberOfNonTrivialBugsFoundUntil:',
#  'ck_oo_wmc',
#  'ck_oo_numberOfAttributes',
#  'ck_oo_cbo',
#  'ck_oo_lcom',
#  'ck_oo_numberOfMethods']

# %%
X_new = df[FS]
X_new
# Out:
#      CvsExpEntropy  CvsEntropy  ck_oo_numberOfLinesOfCode  CvsLogEntropy  \
# 0         0.103594    10.13220                        125       0.308139
# 1         0.328692    38.28120                       1217       1.128230
# 2         0.125841     9.49506                        214       0.287726
# 3         0.170416    27.58140                        535       0.756585
# 4         0.055912     7.55094                         31       0.204387
# ..             ...         ...                        ...            ...
# 319       0.041507     3.61726                        173       0.111739
# 320       0.000000     0.00000                         27       0.000000
# 321       0.267032    30.36980                        712       0.885730
# 322       0.000000     0.00000                         15       0.000000
# 323       0.000000     0.00000                          6       0.000000
#
#      numberOfNonTrivialBugsFoundUntil:  ck_oo_wmc  ck_oo_numberOfAttributes  \
# 0                                    4         33                        11
# 1                                   71        300                        67
# 2                                    5         48                         7
# 3                                   38        187                         1
# 4                                    1         10                         1
# ..                                 ...        ...                       ...
# 319                                  1         23                        14
# 320                                  0          7                         0
# 321                                 27        142                         7
# 322                                  1          2                         0
# 323                                  1          2                         0
#
#      ck_oo_cbo  ck_oo_lcom  ck_oo_numberOfMethods
# 0            7          55                     11
# 1           54        1128                     48
# 2           26          28                      8
# 3           39         300                     25
# 4            2          28                      8
# ..         ...         ...                    ...
# 319         10          66                     12
# 320          5           1                      2
# 321         57        1953                     63
# 322          2           1                      2
# 323          2           1                      2
#
# [324 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8163265306122449
# Precision :  0.7058823529411765
# Recall :  0.75
# F1 Score :  0.7272727272727272
# AUC :  0.7992424242424243

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7653061224489796
# Precision :  0.6551724137931034
# Recall :  0.59375
# F1 Score :  0.6229508196721311
# AUC :  0.7211174242424243

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7244897959183674
# Precision :  0.5581395348837209
# Recall :  0.75
# F1 Score :  0.6399999999999999
# AUC :  0.7310606060606062

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7959183673469388
# Precision :  0.75
# Recall :  0.5625
# F1 Score :  0.6428571428571429
# AUC :  0.7357954545454545

# %% [markdown]
# # INFORMATION GAIN 15

# %%
from sklearn.feature_selection import mutual_info_classif
gain = mutual_info_classif(X,Y)
gain
# Out:
# array([0.        , 0.05016508, 0.09913697, 0.13314011, 0.10853428,
#        0.02420841, 0.07752851, 0.11447998, 0.1171412 , 0.06958488,
#        0.04285255, 0.20190979, 0.04619908, 0.0188743 , 0.07395096,
#        0.        , 0.05180021, 0.07295388, 0.1406212 , 0.00085433,
#        0.11795795, 0.19915901, 0.05055508, 0.00748801, 0.1116487 ,
#        0.06788415, 0.19734402, 0.01696788, 0.13760515, 0.0654715 ,
#        0.06984503, 0.        , 0.0025494 , 0.13767434, 0.        ,
#        0.11724928, 0.16956959, 0.08070742, 0.15553729, 0.1008738 ,
#        0.1036459 , 0.12446123, 0.12268378, 0.14133688, 0.03218154,
#        0.11798669, 0.07059034, 0.0409881 , 0.02904988, 0.10713108,
#        0.12729561, 0.09323835, 0.11881223, 0.12256376, 0.08469918,
#        0.17674814, 0.0717034 , 0.13310677, 0.13896281, 0.10507203,
#        0.23999605, 0.14283314])

# %%
col_list = X.columns
col_list
# Out:
# Index(['id', 'ck_oo_numberOfPrivateMethods', 'LDHH_lcom', 'LDHH_fanIn',
#        'numberOfNonTrivialBugsFoundUntil:', 'WCHU_numberOfPublicAttributes',
#        'WCHU_numberOfAttributes', 'CvsWEntropy', 'LDHH_numberOfPublicMethods',
#        'WCHU_fanIn', 'LDHH_numberOfPrivateAttributes', 'CvsEntropy',
#        'LDHH_numberOfPublicAttributes', 'WCHU_numberOfPrivateMethods',
#        'WCHU_numberOfMethods', 'ck_oo_numberOfPublicAttributes', 'ck_oo_noc',
#        'numberOfCriticalBugsFoundUntil:', 'ck_oo_wmc',
#        'LDHH_numberOfPrivateMethods', 'WCHU_numberOfPrivateAttributes',
#        'CvsLogEntropy', 'WCHU_noc', 'LDHH_numberOfAttributesInherited',
#        'WCHU_wmc', 'ck_oo_fanOut', 'ck_oo_numberOfLinesOfCode',
#        'ck_oo_numberOfAttributesInherited', 'ck_oo_numberOfMethods',
#        'ck_oo_dit', 'ck_oo_fanIn', 'LDHH_noc', 'WCHU_dit', 'ck_oo_lcom',
#        'WCHU_numberOfAttributesInherited', 'ck_oo_rfc', 'LDHH_wmc',
#        'LDHH_numberOfAttributes', 'LDHH_numberOfLinesOfCode', 'WCHU_fanOut',
#        'WCHU_lcom', 'ck_oo_cbo', 'WCHU_rfc', 'ck_oo_numberOfAttributes',
#        'numberOfHighPriorityBugsFoundUntil:',
#        'ck_oo_numberOfPrivateAttributes', 'numberOfMajorBugsFoundUntil:',
#        'WCHU_numberOfPublicMethods', 'LDHH_dit', 'WCHU_cbo', 'CvsLinEntropy',
#        'WCHU_numberOfMethodsInherited', 'numberOfBugsFoundUntil:',
#        'LDHH_fanOut', 'LDHH_numberOfMethodsInherited', 'LDHH_rfc',
#        'ck_oo_numberOfMethodsInherited', 'ck_oo_numberOfPublicMethods',
#        'LDHH_cbo', 'WCHU_numberOfLinesOfCode', 'CvsExpEntropy',
#        'LDHH_numberOfMethods'],
#       dtype='object')

# %%
temp = pd.DataFrame(list(zip(col_list, gain)), columns =['col', 'score']) 
temp
# Out:
#                                   col     score
# 0                                  id  0.000000
# 1        ck_oo_numberOfPrivateMethods  0.050165
# 2                           LDHH_lcom  0.099137
# 3                          LDHH_fanIn  0.133140
# 4   numberOfNonTrivialBugsFoundUntil:  0.108534
# ..                                ...       ...
# 57        ck_oo_numberOfPublicMethods  0.133107
# 58                           LDHH_cbo  0.138963
# 59           WCHU_numberOfLinesOfCode  0.105072
# 60                      CvsExpEntropy  0.239996
# 61               LDHH_numberOfMethods  0.142833
#
# [62 rows x 2 columns]

# %%
temp_sort = temp.sort_values(['score'], ascending=False)
temp_sort[:15]
# Out:
#                             col     score
# 60                CvsExpEntropy  0.239996
# 11                   CvsEntropy  0.201910
# 21                CvsLogEntropy  0.199159
# 26    ck_oo_numberOfLinesOfCode  0.197344
# 55                     LDHH_rfc  0.176748
# 36                     LDHH_wmc  0.169570
# 38     LDHH_numberOfLinesOfCode  0.155537
# 61         LDHH_numberOfMethods  0.142833
# 43     ck_oo_numberOfAttributes  0.141337
# 18                    ck_oo_wmc  0.140621
# 58                     LDHH_cbo  0.138963
# 33                   ck_oo_lcom  0.137674
# 28        ck_oo_numberOfMethods  0.137605
# 3                    LDHH_fanIn  0.133140
# 57  ck_oo_numberOfPublicMethods  0.133107

# %%
FS = list(temp_sort['col'][:15])
FS
# Out:
# ['CvsExpEntropy',
#  'CvsEntropy',
#  'CvsLogEntropy',
#  'ck_oo_numberOfLinesOfCode',
#  'LDHH_rfc',
#  'LDHH_wmc',
#  'LDHH_numberOfLinesOfCode',
#  'LDHH_numberOfMethods',
#  'ck_oo_numberOfAttributes',
#  'ck_oo_wmc',
#  'LDHH_cbo',
#  'ck_oo_lcom',
#  'ck_oo_numberOfMethods',
#  'LDHH_fanIn',
#  'ck_oo_numberOfPublicMethods']

# %%
X_new = df[FS]
X_new
# Out:
#      CvsExpEntropy  CvsEntropy  CvsLogEntropy  ck_oo_numberOfLinesOfCode  \
# 0         0.103594    10.13220       0.308139                        125
# 1         0.328692    38.28120       1.128230                       1217
# 2         0.125841     9.49506       0.287726                        214
# 3         0.170416    27.58140       0.756585                        535
# 4         0.055912     7.55094       0.204387                         31
# ..             ...         ...            ...                        ...
# 319       0.041507     3.61726       0.111739                        173
# 320       0.000000     0.00000       0.000000                         27
# 321       0.267032    30.36980       0.885730                        712
# 322       0.000000     0.00000       0.000000                         15
# 323       0.000000     0.00000       0.000000                          6
#
#      LDHH_rfc  LDHH_wmc  LDHH_numberOfLinesOfCode  LDHH_numberOfMethods  \
# 0    0.004406  0.004387                  0.004354              0.003611
# 1    0.060301  0.041329                  0.061578              0.009906
# 2    0.002325  0.004660                  0.002221              0.001655
# 3    0.030608  0.028494                  0.034402              0.007000
# 4    0.001492  0.001433                  0.001485              0.001572
# ..        ...       ...                       ...                   ...
# 319  0.000000  0.000000                  0.002018              0.000000
# 320  0.000000  0.000000                  0.000000              0.000000
# 321  0.018394  0.016286                  0.029488              0.004671
# 322  0.000000  0.000000                  0.000000              0.000000
# 323  0.000000  0.000000                  0.000000              0.000000
#
#      ck_oo_numberOfAttributes  ck_oo_wmc  LDHH_cbo  ck_oo_lcom  \
# 0                          11         33  0.008431          55
# 1                          67        300  0.021602        1128
# 2                           7         48  0.011859          28
# 3                           1        187  0.020478         300
# 4                           1         10  0.000652          28
# ..                        ...        ...       ...         ...
# 319                        14         23  0.004539          66
# 320                         0          7  0.000000           1
# 321                         7        142  0.025180        1953
# 322                         0          2  0.000000           1
# 323                         0          2  0.000000           1
#
#      ck_oo_numberOfMethods  LDHH_fanIn  ck_oo_numberOfPublicMethods
# 0                       11    0.002555                            8
# 1                       48    0.004756                            7
# 2                        8    0.009143                            2
# 3                       25    0.005395                           10
# 4                        8    0.000000                            7
# ..                     ...         ...                          ...
# 319                     12    0.000000                            1
# 320                      2    0.000000                            1
# 321                     63    0.018031                           27
# 322                      2    0.000000                            2
# 323                      2    0.000000                            2
#
# [324 rows x 15 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7959183673469388
# Precision :  0.6666666666666666
# Recall :  0.75
# F1 Score :  0.7058823529411765
# AUC :  0.784090909090909

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7653061224489796
# Precision :  0.6551724137931034
# Recall :  0.59375
# F1 Score :  0.6229508196721311
# AUC :  0.7211174242424243

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7244897959183674
# Precision :  0.5641025641025641
# Recall :  0.6875
# F1 Score :  0.619718309859155
# AUC :  0.7149621212121212

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7448979591836735
# Precision :  0.64
# Recall :  0.5
# F1 Score :  0.5614035087719298
# AUC :  0.6818181818181818

# %% [markdown]
# # FISHER SCORE

# %%
FScore = []

for m in  range(len(col_list)):
        mu = df[col_list[m]].mean()

        n_1 = df[df['class'] == 0].count()[1]
        mu_1 = df[col_list[m]][df['class'] == 0].mean()
        var_1 = df[col_list[m]][df['class'] == 0].var()

        n_2 = df[df['class'] == 1].count()[1]
        mu_2 = df[col_list[m]][df['class'] == 1].mean()
        var_2 = df[col_list[m]][df['class'] == 1].var()

        inter_class = n_1*(mu_1-mu)**2 + n_2*(mu_2-mu)**2
        intra_class = (n_1-1)*var_1 + (n_2-1)*var_2

        FScore.append(inter_class / intra_class)

FScore
# Out:
# [0.009965007928362198,
#  0.07408895884250197,
#  0.10823756179494291,
#  0.11256984970099963,
#  0.13257678787037322,
#  0.01796051269758418,
#  0.11264124614441502,
#  0.15765797107403856,
#  0.06961205798767417,
#  0.11824877952555156,
#  0.05200320574158478,
#  0.32646743987448235,
#  0.011730357467406262,
#  0.0695082173791427,
#  0.14955246938728334,
#  0.000590964477930594,
#  0.010883944257222776,
#  0.09425266786309473,
#  0.16403526549321754,
#  0.059330533331267914,
#  0.10756586502782496,
#  0.3360782950766037,
#  0.011873884513136888,
#  0.0196903779636844,
#  0.16230784075332658,
#  0.1883191610486982,
#  0.15168452101111915,
#  0.03560945923311358,
#  0.22468283190240482,
#  0.0577350623157229,
#  0.10960661352365066,
#  0.0073259195978732546,
#  0.014598099964436315,
#  0.11014119855773429,
#  0.054262475500488475,
#  0.13264558915839766,
#  0.16799353561585956,
#  0.06170831197997498,
#  0.18943034628220962,
#  0.1559501159530758,
#  0.12210157221592115,
#  0.2521768256213113,
#  0.1551165980741823,
#  0.042488926641928236,
#  0.034532483302975106,
#  0.08529818027613406,
#  0.10160327371551678,
#  0.13782178027033773,
#  0.0023236187670523083,
#  0.19705560938957584,
#  0.29858110615623007,
#  0.1102623084418207,
#  0.13151371882843826,
#  0.15676663416313008,
#  0.08725089153301264,
#  0.16528640104268927,
#  0.11096996598169612,
#  0.1483339142443375,
#  0.19554038317556655,
#  0.16370359847151794,
#  0.21450096181825723,
#  0.112390763561782]

# %%
temp = pd.DataFrame(list(zip(col_list, FScore)), columns =['col', 'score']) 
temp
# Out:
#                                   col     score
# 0                                  id  0.009965
# 1        ck_oo_numberOfPrivateMethods  0.074089
# 2                           LDHH_lcom  0.108238
# 3                          LDHH_fanIn  0.112570
# 4   numberOfNonTrivialBugsFoundUntil:  0.132577
# ..                                ...       ...
# 57        ck_oo_numberOfPublicMethods  0.148334
# 58                           LDHH_cbo  0.195540
# 59           WCHU_numberOfLinesOfCode  0.163704
# 60                      CvsExpEntropy  0.214501
# 61               LDHH_numberOfMethods  0.112391
#
# [62 rows x 2 columns]

# %%
temp_sort = temp.sort_values(['score'], ascending=False)
temp_sort[:10]
# Out:
#                          col     score
# 21             CvsLogEntropy  0.336078
# 11                CvsEntropy  0.326467
# 50             CvsLinEntropy  0.298581
# 41                 ck_oo_cbo  0.252177
# 28     ck_oo_numberOfMethods  0.224683
# 60             CvsExpEntropy  0.214501
# 49                  WCHU_cbo  0.197056
# 58                  LDHH_cbo  0.195540
# 38  LDHH_numberOfLinesOfCode  0.189430
# 25              ck_oo_fanOut  0.188319

# %%
FS = list(temp_sort['col'][:10])
FS
# Out:
# ['CvsLogEntropy',
#  'CvsEntropy',
#  'CvsLinEntropy',
#  'ck_oo_cbo',
#  'ck_oo_numberOfMethods',
#  'CvsExpEntropy',
#  'WCHU_cbo',
#  'LDHH_cbo',
#  'LDHH_numberOfLinesOfCode',
#  'ck_oo_fanOut']

# %%
X_new = df[FS]
X_new
# Out:
#      CvsLogEntropy  CvsEntropy  CvsLinEntropy  ck_oo_cbo  \
# 0         0.308139    10.13220       0.043005          7
# 1         1.128230    38.28120       0.149026         54
# 2         0.287726     9.49506       0.043268         26
# 3         0.756585    27.58140       0.080838         39
# 4         0.204387     7.55094       0.022540          2
# ..             ...         ...            ...        ...
# 319       0.111739     3.61726       0.014914         10
# 320       0.000000     0.00000       0.000000          5
# 321       0.885730    30.36980       0.114620         57
# 322       0.000000     0.00000       0.000000          2
# 323       0.000000     0.00000       0.000000          2
#
#      ck_oo_numberOfMethods  CvsExpEntropy  WCHU_cbo  LDHH_cbo  \
# 0                       11       0.103594      3.05  0.008431
# 1                       48       0.328692     16.31  0.021602
# 2                        8       0.125841      8.28  0.011859
# 3                       25       0.170416     11.13  0.020478
# 4                        8       0.055912      1.01  0.000652
# ..                     ...            ...       ...       ...
# 319                     12       0.041507      1.01  0.004539
# 320                      2       0.000000      0.00  0.000000
# 321                     63       0.267032     16.21  0.025180
# 322                      2       0.000000      0.00  0.000000
# 323                      2       0.000000      0.00  0.000000
#
#      LDHH_numberOfLinesOfCode  ck_oo_fanOut
# 0                    0.004354             5
# 1                    0.061578            53
# 2                    0.002221            16
# 3                    0.034402            37
# 4                    0.001485             1
# ..                        ...           ...
# 319                  0.002018            10
# 320                  0.000000             3
# 321                  0.029488            31
# 322                  0.000000             2
# 323                  0.000000             2
#
# [324 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7346938775510204
# Precision :  0.5833333333333334
# Recall :  0.65625
# F1 Score :  0.6176470588235293
# AUC :  0.7144886363636364

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7653061224489796
# Precision :  0.6046511627906976
# Recall :  0.8125
# F1 Score :  0.6933333333333334
# AUC :  0.7774621212121212

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7346938775510204
# Precision :  0.5882352941176471
# Recall :  0.625
# F1 Score :  0.6060606060606061
# AUC :  0.7064393939393939

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7857142857142857
# Precision :  0.6774193548387096
# Recall :  0.65625
# F1 Score :  0.6666666666666667
# AUC :  0.7523674242424242

# %% [markdown]
# # SVM RFE 10

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,random_state=23)

# %%
from sklearn.feature_selection import RFE
rec_model = RandomForestClassifier()

rfe = RFE(rec_model, n_features_to_select=10)
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=RandomForestClassifier(), n_features_to_select=10)

# %%
X_train = X_train.loc[:, rfe.support_]
X_train
# Out:
#      CvsWEntropy  CvsEntropy  ck_oo_wmc  CvsLogEntropy  \
# 165     0.000000     0.00000         10       0.000000
# 101     0.214961     8.82648          3       0.215315
# 26      0.000000     0.00000          2       0.000000
# 218     0.350290    12.90010         69       0.327427
# 196     0.000000     0.00000          4       0.000000
# ..           ...         ...        ...            ...
# 237     0.053039     3.20237          9       0.091181
# 31      0.000000     0.00000          0       0.000000
# 40      0.159366     5.38882         22       0.126580
# 230     0.000000     0.00000          0       0.000000
# 83      0.401919     8.96461         31       0.216101
#
#      ck_oo_numberOfLinesOfCode  ck_oo_numberOfMethods  ck_oo_lcom  ck_oo_rfc  \
# 165                         30                      8          28         18
# 101                         11                      3           3          3
# 26                           9                      2           1          8
# 218                        318                     14          91        120
# 196                         21                      3           3         18
# ..                         ...                    ...         ...        ...
# 237                         44                      4           6         14
# 31                           0                      1           0          1
# 40                          76                     10          45         29
# 230                          0                      1           0          1
# 83                         103                     21         210         49
#
#      CvsLinEntropy  CvsExpEntropy
# 165       0.000000       0.000000
# 101       0.015146       0.007314
# 26        0.000000       0.000000
# 218       0.029479       0.056252
# 196       0.000000       0.000000
# ..             ...            ...
# 237       0.010063       0.020623
# 31        0.000000       0.000000
# 40        0.007778       0.001539
# 230       0.000000       0.000000
# 83        0.014448       0.004497
#
# [226 rows x 10 columns]

# %%
X_test = X_test.loc[:, rfe.support_]
X_test
# Out:
#      CvsWEntropy  CvsEntropy  ck_oo_wmc  CvsLogEntropy  \
# 183     0.026890     2.67030         56       0.130870
# 2       0.484675     9.49506         48       0.287726
# 131     0.237714    11.02020         22       0.341038
# 18      0.661068    19.44670         98       0.507472
# 309     0.231255     7.76010         38       0.206167
# ..           ...         ...        ...            ...
# 122     0.004036     1.27192         22       0.031256
# 72      0.308881    15.07000        149       0.428910
# 207     0.697616    15.15370         72       0.425571
# 273     0.189308     4.27896         26       0.224980
# 51      0.116132     9.69600         29       0.248248
#
#      ck_oo_numberOfLinesOfCode  ck_oo_numberOfMethods  ck_oo_lcom  ck_oo_rfc  \
# 183                        203                     15         105         99
# 2                          214                      8          28         79
# 131                        103                     18         153         44
# 18                         248                     19         171        171
# 309                        120                     20         190         54
# ..                         ...                    ...         ...        ...
# 122                         94                     10          45         72
# 72                         654                     35         595        220
# 207                        244                     19         171        149
# 273                         77                      7          21         36
# 51                         116                      8          28         61
#
#      CvsLinEntropy  CvsExpEntropy
# 183       0.034787       0.129104
# 2         0.043268       0.125841
# 131       0.053542       0.152795
# 18        0.048074       0.088626
# 309       0.019181       0.027731
# ..             ...            ...
# 122       0.002174       0.000405
# 72        0.054762       0.126098
# 207       0.050497       0.109464
# 273       0.062831       0.215324
# 51        0.023880       0.055093
#
# [98 rows x 10 columns]

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7857142857142857
# Precision :  0.6666666666666666
# Recall :  0.6875
# F1 Score :  0.676923076923077
# AUC :  0.7604166666666666

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7653061224489796
# Precision :  0.6551724137931034
# Recall :  0.59375
# F1 Score :  0.6229508196721311
# AUC :  0.7211174242424243

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7346938775510204
# Precision :  0.575
# Recall :  0.71875
# F1 Score :  0.6388888888888888
# AUC :  0.7305871212121212

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7959183673469388
# Precision :  0.7727272727272727
# Recall :  0.53125
# F1 Score :  0.6296296296296297
# AUC :  0.7277462121212122

# %% [markdown]
# # SVM RFE 15

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,random_state=23)

# %%
from sklearn.feature_selection import RFE
rec_model = RandomForestClassifier()

rfe = RFE(rec_model, n_features_to_select=15)
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=RandomForestClassifier(), n_features_to_select=15)

# %%
X_train = X_train.loc[:, rfe.support_]
X_train
# Out:
#       id  CvsWEntropy  CvsEntropy  ck_oo_wmc  CvsLogEntropy  \
# 165  166     0.000000     0.00000         10       0.000000
# 101  102     0.214961     8.82648          3       0.215315
# 26    27     0.000000     0.00000          2       0.000000
# 218  219     0.350290    12.90010         69       0.327427
# 196  197     0.000000     0.00000          4       0.000000
# ..   ...          ...         ...        ...            ...
# 237  238     0.053039     3.20237          9       0.091181
# 31    32     0.000000     0.00000          0       0.000000
# 40    41     0.159366     5.38882         22       0.126580
# 230  231     0.000000     0.00000          0       0.000000
# 83    84     0.401919     8.96461         31       0.216101
#
#      ck_oo_numberOfLinesOfCode  ck_oo_numberOfMethods  ck_oo_lcom  ck_oo_rfc  \
# 165                         30                      8          28         18
# 101                         11                      3           3          3
# 26                           9                      2           1          8
# 218                        318                     14          91        120
# 196                         21                      3           3         18
# ..                         ...                    ...         ...        ...
# 237                         44                      4           6         14
# 31                           0                      1           0          1
# 40                          76                     10          45         29
# 230                          0                      1           0          1
# 83                         103                     21         210         49
#
#      LDHH_numberOfLinesOfCode  ck_oo_cbo  CvsLinEntropy  \
# 165                  0.000000          7       0.000000
# 101                  0.000000         27       0.015146
# 26                   0.000000          4       0.000000
# 218                  0.004385         23       0.029479
# 196                  0.000000          5       0.000000
# ..                        ...        ...            ...
# 237                  0.002746          3       0.010063
# 31                   0.000000          1       0.000000
# 40                   0.000831          7       0.007778
# 230                  0.000000          1       0.000000
# 83                   0.002664         11       0.014448
#
#      ck_oo_numberOfMethodsInherited  WCHU_numberOfLinesOfCode  CvsExpEntropy
# 165                              19                      0.00       0.000000
# 101                              15                      0.00       0.007314
# 26                                9                      0.00       0.000000
# 218                              12                      7.65       0.056252
# 196                              17                      0.00       0.000000
# ..                              ...                       ...            ...
# 237                              10                      1.15       0.020623
# 31                                7                      0.00       0.000000
# 40                               33                      1.08       0.001539
# 230                               7                      0.00       0.000000
# 83                                0                      3.58       0.004497
#
# [226 rows x 15 columns]

# %%
X_test = X_test.loc[:, rfe.support_]
X_test
# Out:
#       id  CvsWEntropy  CvsEntropy  ck_oo_wmc  CvsLogEntropy  \
# 183  184     0.026890     2.67030         56       0.130870
# 2      3     0.484675     9.49506         48       0.287726
# 131  132     0.237714    11.02020         22       0.341038
# 18    19     0.661068    19.44670         98       0.507472
# 309  310     0.231255     7.76010         38       0.206167
# ..   ...          ...         ...        ...            ...
# 122  123     0.004036     1.27192         22       0.031256
# 72    73     0.308881    15.07000        149       0.428910
# 207  208     0.697616    15.15370         72       0.425571
# 273  274     0.189308     4.27896         26       0.224980
# 51    52     0.116132     9.69600         29       0.248248
#
#      ck_oo_numberOfLinesOfCode  ck_oo_numberOfMethods  ck_oo_lcom  ck_oo_rfc  \
# 183                        203                     15         105         99
# 2                          214                      8          28         79
# 131                        103                     18         153         44
# 18                         248                     19         171        171
# 309                        120                     20         190         54
# ..                         ...                    ...         ...        ...
# 122                         94                     10          45         72
# 72                         654                     35         595        220
# 207                        244                     19         171        149
# 273                         77                      7          21         36
# 51                         116                      8          28         61
#
#      LDHH_numberOfLinesOfCode  ck_oo_cbo  CvsLinEntropy  \
# 183                  0.000000         27       0.034787
# 2                    0.002221         26       0.043268
# 131                  0.007718         18       0.053542
# 18                   0.018578         16       0.048074
# 309                  0.002970         12       0.019181
# ..                        ...        ...            ...
# 122                  0.000000         14       0.002174
# 72                   0.011845         35       0.054762
# 207                  0.015335         18       0.050497
# 273                  0.019898         17       0.062831
# 51                   0.011311         14       0.023880
#
#      ck_oo_numberOfMethodsInherited  WCHU_numberOfLinesOfCode  CvsExpEntropy
# 183                              19                      0.00       0.129104
# 2                                 7                      4.68       0.125841
# 131                             111                      5.48       0.152795
# 18                               15                     17.64       0.088626
# 309                              42                      3.08       0.027731
# ..                              ...                       ...            ...
# 122                               7                      0.00       0.000405
# 72                               26                      6.87       0.126098
# 207                               7                     10.20       0.109464
# 273                              11                      3.29       0.215324
# 51                               12                      6.65       0.055093
#
# [98 rows x 15 columns]

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8163265306122449
# Precision :  0.6944444444444444
# Recall :  0.78125
# F1 Score :  0.7352941176470588
# AUC :  0.8072916666666666

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7755102040816326
# Precision :  0.6785714285714286
# Recall :  0.59375
# F1 Score :  0.6333333333333334
# AUC :  0.7286931818181819

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7244897959183674
# Precision :  0.5714285714285714
# Recall :  0.625
# F1 Score :  0.5970149253731343
# AUC :  0.6988636363636364

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7959183673469388
# Precision :  0.75
# Recall :  0.5625
# F1 Score :  0.6428571428571429
# AUC :  0.7357954545454545

# %% [markdown]
# # MRMR 10

# %%
from sklearn.feature_selection import f_regression

F = pd.Series(f_regression(X, Y)[0], index = X.columns)
corr = X.corr().abs().clip(.00001)

# %%
selected = []
feat_score = []
not_selected = list(X.columns)

# %%
K = 10

for i in range(K):
    
    # compute FCQ score for all the (currently) excluded features (this is Formula 2)
    score = F.loc[not_selected] / corr.loc[not_selected, selected].mean(axis = 1).fillna(.00001)
    
    # find best feature, add it to selected and remove it from not_selected
    best = score.index[score.argmax()]
    selected.append(best)
    feat_score.append(score[best])
    not_selected.remove(best)

# %%
selected
# Out:
# ['CvsLogEntropy',
#  'LDHH_noc',
#  'ck_oo_numberOfMethodsInherited',
#  'ck_oo_cbo',
#  'CvsEntropy',
#  'CvsLinEntropy',
#  'ck_oo_numberOfPublicMethods',
#  'CvsExpEntropy',
#  'LDHH_fanIn',
#  'ck_oo_numberOfMethods']

# %%
X_new = X[selected]
X_new
# Out:
#      CvsLogEntropy  LDHH_noc  ck_oo_numberOfMethodsInherited  ck_oo_cbo  \
# 0         0.308139       0.0                               8          7
# 1         1.128230       0.0                               7         54
# 2         0.287726       0.0                               7         26
# 3         0.756585       0.0                              17         39
# 4         0.204387       0.0                              22          2
# ..             ...       ...                             ...        ...
# 319       0.111739       0.0                              16         10
# 320       0.000000       0.0                               7          5
# 321       0.885730       0.0                              30         57
# 322       0.000000       0.0                               9          2
# 323       0.000000       0.0                               9          2
#
#      CvsEntropy  CvsLinEntropy  ck_oo_numberOfPublicMethods  CvsExpEntropy  \
# 0      10.13220       0.043005                            8       0.103594
# 1      38.28120       0.149026                            7       0.328692
# 2       9.49506       0.043268                            2       0.125841
# 3      27.58140       0.080838                           10       0.170416
# 4       7.55094       0.022540                            7       0.055912
# ..          ...            ...                          ...            ...
# 319     3.61726       0.014914                            1       0.041507
# 320     0.00000       0.000000                            1       0.000000
# 321    30.36980       0.114620                           27       0.267032
# 322     0.00000       0.000000                            2       0.000000
# 323     0.00000       0.000000                            2       0.000000
#
#      LDHH_fanIn  ck_oo_numberOfMethods
# 0      0.002555                     11
# 1      0.004756                     48
# 2      0.009143                      8
# 3      0.005395                     25
# 4      0.000000                      8
# ..          ...                    ...
# 319    0.000000                     12
# 320    0.000000                      2
# 321    0.018031                     63
# 322    0.000000                      2
# 323    0.000000                      2
#
# [324 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7959183673469388
# Precision :  0.6578947368421053
# Recall :  0.78125
# F1 Score :  0.7142857142857143
# AUC :  0.7921401515151515

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.6938775510204082
# Precision :  0.5263157894736842
# Recall :  0.625
# F1 Score :  0.5714285714285714
# AUC :  0.6761363636363636

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7653061224489796
# Precision :  0.6285714285714286
# Recall :  0.6875
# F1 Score :  0.6567164179104478
# AUC :  0.7452651515151515

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7448979591836735
# Precision :  0.6060606060606061
# Recall :  0.625
# F1 Score :  0.6153846153846154
# AUC :  0.7140151515151515

# %% [markdown]
# # MRMR 15

# %%
from sklearn.feature_selection import f_regression

F = pd.Series(f_regression(X, Y)[0], index = X.columns)
corr = X.corr().abs().clip(.00001)

# %%
selected = []
feat_score = []
not_selected = list(X.columns)

# %%
K = 15

for i in range(K):
    
    # compute FCQ score for all the (currently) excluded features (this is Formula 2)
    score = F.loc[not_selected] / corr.loc[not_selected, selected].mean(axis = 1).fillna(.00001)
    
    # find best feature, add it to selected and remove it from not_selected
    best = score.index[score.argmax()]
    selected.append(best)
    feat_score.append(score[best])
    not_selected.remove(best)

# %%
selected
# Out:
# ['CvsLogEntropy',
#  'LDHH_noc',
#  'ck_oo_numberOfMethodsInherited',
#  'ck_oo_cbo',
#  'CvsEntropy',
#  'CvsLinEntropy',
#  'ck_oo_numberOfPublicMethods',
#  'CvsExpEntropy',
#  'LDHH_fanIn',
#  'ck_oo_numberOfMethods',
#  'WCHU_numberOfMethodsInherited',
#  'LDHH_cbo',
#  'ck_oo_numberOfAttributesInherited',
#  'ck_oo_fanOut',
#  'ck_oo_dit']

# %%
X_new = X[selected]
X_new
# Out:
#      CvsLogEntropy  LDHH_noc  ck_oo_numberOfMethodsInherited  ck_oo_cbo  \
# 0         0.308139       0.0                               8          7
# 1         1.128230       0.0                               7         54
# 2         0.287726       0.0                               7         26
# 3         0.756585       0.0                              17         39
# 4         0.204387       0.0                              22          2
# ..             ...       ...                             ...        ...
# 319       0.111739       0.0                              16         10
# 320       0.000000       0.0                               7          5
# 321       0.885730       0.0                              30         57
# 322       0.000000       0.0                               9          2
# 323       0.000000       0.0                               9          2
#
#      CvsEntropy  CvsLinEntropy  ck_oo_numberOfPublicMethods  CvsExpEntropy  \
# 0      10.13220       0.043005                            8       0.103594
# 1      38.28120       0.149026                            7       0.328692
# 2       9.49506       0.043268                            2       0.125841
# 3      27.58140       0.080838                           10       0.170416
# 4       7.55094       0.022540                            7       0.055912
# ..          ...            ...                          ...            ...
# 319     3.61726       0.014914                            1       0.041507
# 320     0.00000       0.000000                            1       0.000000
# 321    30.36980       0.114620                           27       0.267032
# 322     0.00000       0.000000                            2       0.000000
# 323     0.00000       0.000000                            2       0.000000
#
#      LDHH_fanIn  ck_oo_numberOfMethods  WCHU_numberOfMethodsInherited  \
# 0      0.002555                     11                           1.01
# 1      0.004756                     48                           1.01
# 2      0.009143                      8                           1.01
# 3      0.005395                     25                           2.02
# 4      0.000000                      8                           3.05
# ..          ...                    ...                            ...
# 319    0.000000                     12                           0.00
# 320    0.000000                      2                           0.00
# 321    0.018031                     63                           4.05
# 322    0.000000                      2                           0.00
# 323    0.000000                      2                           0.00
#
#      LDHH_cbo  ck_oo_numberOfAttributesInherited  ck_oo_fanOut  ck_oo_dit
# 0    0.008431                                  0             5          1
# 1    0.021602                                  0            53          1
# 2    0.011859                                  0            16          1
# 3    0.020478                                  1            37          1
# 4    0.000652                                  1             1          2
# ..        ...                                ...           ...        ...
# 319  0.004539                                  0            10          1
# 320  0.000000                                  0             3          1
# 321  0.025180                                  9            31          1
# 322  0.000000                                  0             2          1
# 323  0.000000                                  0             2          1
#
# [324 rows x 15 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7857142857142857
# Precision :  0.6486486486486487
# Recall :  0.75
# F1 Score :  0.6956521739130435
# AUC :  0.7765151515151515

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7244897959183674
# Precision :  0.5675675675675675
# Recall :  0.65625
# F1 Score :  0.6086956521739131
# AUC :  0.7069128787878788

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7346938775510204
# Precision :  0.5882352941176471
# Recall :  0.625
# F1 Score :  0.6060606060606061
# AUC :  0.7064393939393939

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7244897959183674
# Precision :  0.5675675675675675
# Recall :  0.65625
# F1 Score :  0.6086956521739131
# AUC :  0.7069128787878788

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7653061224489796
# Precision :  0.6363636363636364
# Recall :  0.65625
# F1 Score :  0.6461538461538462
# AUC :  0.7372159090909091

# %% [markdown]
# # MRMR HFS

# %%
def HSF(df, df_train):
    
    from copy import deepcopy
    col_list = list(df_train.columns)
    print(col_list)
    d = df_train.shape[1]
    SF = []
    merit = [0 for i in range(d)]
    merit_archive = [0 for i in range(d)]
    Total_FS = [0 for i in range(d)]

    rel_CF = RHFS(df, d, col_list)

    max_value = max(rel_CF)
    Feature_max_index = rel_CF.index(max_value)

    n = 0

    SF.append(Feature_max_index)

    merit_archive[n] = deepcopy(max_value)

    Total_FS[n] = deepcopy(SF)

    while n < d-1:

        for i in range(d):

            red_FF = SHFS(SF, df_train, i, col_list,d)

            top = (d + d*(sum(rel_CF)/len(rel_CF)))
            bottom = (d + (d*(d-1)*(sum(red_FF)/len(red_FF))))**(1/2)
            merit[i] = top/bottom

        for val in SF:
            merit[val] = -9999999

        max_value = max(merit)
        Feature_max_index = merit.index(max_value)

        if Feature_max_index not in SF:
            SF.append(Feature_max_index)

        n += 1
        
        Total_FS[n] = deepcopy(SF)

        merit_archive[n] = max_value

    index_val = merit_archive.index(max(merit_archive))

    Feature_subset = Total_FS[index_val]

    subset_list = []

    for val in Feature_subset:
        subset_list.append(col_list[val])
    return subset_list


def RHFS(df, d, col_list):
    rel_CF = [0 for i in range(d)]
    count = 0

    igain = IG(X,df['class'])

    for m in  range(d):
        mu = df[col_list[m]].mean()

        n_1 = df[df['class'] == 0].count()[1]
        mu_1 = df[col_list[m]][df['class'] == 0].mean()
        var_1 = df[col_list[m]][df['class'] == 0].var()

        n_2 = df[df['class'] == 1].count()[1]
        mu_2 = df[col_list[m]][df['class'] == 1].mean()
        var_2 = df[col_list[m]][df['class'] == 1].var()

        inter_class = n_1*(mu_1-mu)**2 + n_2*(mu_2-mu)**2
        intra_class = (n_1-1)*var_1 + (n_2-1)*var_2

        fscore = inter_class / intra_class

        rel_CF[count] = (1/2)*(fscore + igain[m])
        count += 1
    
    return rel_CF

        
        

def IG(col_1, col_2):
    from sklearn.feature_selection import mutual_info_classif
    gain = mutual_info_classif(col_1,col_2)
    return gain   

def relief(col_1,col_2):
    pass



def SHFS(SF, df_train, i, col_list,d):
    from itertools import combinations
    from copy import deepcopy
    red_FF = []
    temp_SF = deepcopy(SF)
    if i not in SF:
        temp_SF.append(i)
        P_pairs = list(combinations(temp_SF,2))
        for pair in P_pairs:

            ied_value = (IED(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            pc_value = (PC(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            cs_value = (CS(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2

            red_FF.append((1/3)*(ied_value + pc_value + cs_value))
            # red_FF.append((1/2)*(pc_value + cs_value))
    else:
        red_FF = [0]
    return red_FF

def IED(col_1, col_2):
    import numpy as np
    dist = np.linalg.norm(col_1 - col_2)
    return 1/dist

def PC(col_1, col_2):
    from scipy.stats import pearsonr
    corr, _ = pearsonr(col_1 , col_2)
    return corr

def CS(col_1, col_2):
    from scipy import spatial
    similarity = 1 - spatial.distance.cosine(col_1, col_2)
    return similarity

# %%
FS = HSF(df, X)
FS
# Out:
# ['id', 'ck_oo_numberOfPrivateMethods', 'LDHH_lcom', 'LDHH_fanIn', 'numberOfNonTrivialBugsFoundUntil:', 'WCHU_numberOfPublicAttributes', 'WCHU_numberOfAttributes', 'CvsWEntropy', 'LDHH_numberOfPublicMethods', 'WCHU_fanIn', 'LDHH_numberOfPrivateAttributes', 'CvsEntropy', 'LDHH_numberOfPublicAttributes', 'WCHU_numberOfPrivateMethods', 'WCHU_numberOfMethods', 'ck_oo_numberOfPublicAttributes', 'ck_oo_noc', 'numberOfCriticalBugsFoundUntil:', 'ck_oo_wmc', 'LDHH_numberOfPrivateMethods', 'WCHU_numberOfPrivateAttributes', 'CvsLogEntropy', 'WCHU_noc', 'LDHH_numberOfAttributesInherited', 'WCHU_wmc', 'ck_oo_fanOut', 'ck_oo_numberOfLinesOfCode', 'ck_oo_numberOfAttributesInherited', 'ck_oo_numberOfMethods', 'ck_oo_dit', 'ck_oo_fanIn', 'LDHH_noc', 'WCHU_dit', 'ck_oo_lcom', 'WCHU_numberOfAttributesInherited', 'ck_oo_rfc', 'LDHH_wmc', 'LDHH_numberOfAttributes', 'LDHH_numberOfLinesOfCode', 'WCHU_fanOut', 'WCHU_lcom', 'ck_oo_cbo', 'WCHU_rfc', 'ck_oo_numberOfAttributes', 'numberOfHighPriorityBugsFoundUntil:', 'ck_oo_numberOfPrivateAttributes', 'numberOfMajorBugsFoundUntil:', 'WCHU_numberOfPublicMethods', 'LDHH_dit', 'WCHU_cbo', 'CvsLinEntropy', 'WCHU_numberOfMethodsInherited', 'numberOfBugsFoundUntil:', 'LDHH_fanOut', 'LDHH_numberOfMethodsInherited', 'LDHH_rfc', 'ck_oo_numberOfMethodsInherited', 'ck_oo_numberOfPublicMethods', 'LDHH_cbo', 'WCHU_numberOfLinesOfCode', 'CvsExpEntropy', 'LDHH_numberOfMethods']
# ['CvsLogEntropy', 'ck_oo_numberOfPublicAttributes']

# %%
X_new = X[FS]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7653061224489796
# Precision :  0.6216216216216216
# Recall :  0.71875
# F1 Score :  0.6666666666666667
# AUC :  0.7533143939393938

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.673469387755102
# Precision :  0.5
# Recall :  0.0625
# F1 Score :  0.1111111111111111
# AUC :  0.5160984848484849

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7755102040816326
# Precision :  0.6388888888888888
# Recall :  0.71875
# F1 Score :  0.676470588235294
# AUC :  0.7608901515151515

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7959183673469388
# Precision :  0.7
# Recall :  0.65625
# F1 Score :  0.6774193548387096
# AUC :  0.7599431818181819

# %% [markdown]
# # HFS NEW

# %%
def HSF(df, df_train):
    
    from copy import deepcopy
    col_list = list(df_train.columns)
    print(col_list)
    d = df_train.shape[1]
    SF = []
    merit = [0 for i in range(d)]
    merit_archive = [0 for i in range(d)]
    Total_FS = [0 for i in range(d)]

    rel_CF = RHFS(df, d, col_list)

    max_value = max(rel_CF)
    Feature_max_index = rel_CF.index(max_value)

    n = 0

    SF.append(Feature_max_index)

    merit_archive[n] = deepcopy(max_value)

    Total_FS[n] = deepcopy(SF)

    while n < d-1:

        for i in range(d):

            red_FF = SHFS(SF, df_train, i, col_list,d)

            top = (d + d*(sum(rel_CF)/len(rel_CF)))
            bottom = (d - (sum(red_FF)/len(red_FF)))**(1/2)

            merit[i] = top/bottom

        for val in SF:
            merit[val] = -9999999

        max_value = max(merit)
        Feature_max_index = merit.index(max_value)

        if Feature_max_index not in SF:
            SF.append(Feature_max_index)

        n += 1
        
        Total_FS[n] = deepcopy(SF)

        merit_archive[n] = max_value

    index_val = merit_archive.index(max(merit_archive))

    Feature_subset = Total_FS[index_val]

    subset_list = []

    for val in Feature_subset:
        subset_list.append(col_list[val])
    return subset_list


def RHFS(df, d, col_list):
    rel_CF = [0 for i in range(d)]
    count = 0

    igain = IG(X,df['class'])

    for m in  range(d):
        mu = df[col_list[m]].mean()

        n_1 = df[df['class'] == 0].count()[1]
        mu_1 = df[col_list[m]][df['class'] == 0].mean()
        var_1 = df[col_list[m]][df['class'] == 0].var()

        n_2 = df[df['class'] == 1].count()[1]
        mu_2 = df[col_list[m]][df['class'] == 1].mean()
        var_2 = df[col_list[m]][df['class'] == 1].var()

        inter_class = n_1*(mu_1-mu)**2 + n_2*(mu_2-mu)**2
        intra_class = (n_1-1)*var_1 + (n_2-1)*var_2

        fscore = inter_class / intra_class

        rel_CF[count] = (1/2)*(fscore + igain[m])
        count += 1
    
    return rel_CF

        
        

def IG(col_1, col_2):
    from sklearn.feature_selection import mutual_info_classif
    gain = mutual_info_classif(col_1,col_2)
    return gain   

def relief(col_1,col_2):
    pass



def SHFS(SF, df_train, i, col_list,d):
    from itertools import combinations
    from copy import deepcopy
    red_FF = []
    temp_SF = deepcopy(SF)
    if i not in SF:
        temp_SF.append(i)
        P_pairs = list(combinations(temp_SF,2))
        for pair in P_pairs:

            ied_value = (IED(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            pc_value = (PC(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            cs_value = (CS(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2

            red_FF.append((1/3)*(ied_value + pc_value + cs_value))
            # red_FF.append((1/2)*(pc_value + cs_value))
    else:
        red_FF = [0]
    return red_FF

def IED(col_1, col_2):
    import numpy as np
    dist = np.linalg.norm(col_1 - col_2)
    return 1/dist

def PC(col_1, col_2):
    from scipy.stats import pearsonr
    corr, _ = pearsonr(col_1 , col_2)
    return corr

def CS(col_1, col_2):
    from scipy import spatial
    similarity = 1 - spatial.distance.cosine(col_1, col_2)
    return similarity

# %%
FS = HSF(df, X)
FS
# Out:
# ['id', 'ck_oo_numberOfPrivateMethods', 'LDHH_lcom', 'LDHH_fanIn', 'numberOfNonTrivialBugsFoundUntil:', 'WCHU_numberOfPublicAttributes', 'WCHU_numberOfAttributes', 'CvsWEntropy', 'LDHH_numberOfPublicMethods', 'WCHU_fanIn', 'LDHH_numberOfPrivateAttributes', 'CvsEntropy', 'LDHH_numberOfPublicAttributes', 'WCHU_numberOfPrivateMethods', 'WCHU_numberOfMethods', 'ck_oo_numberOfPublicAttributes', 'ck_oo_noc', 'numberOfCriticalBugsFoundUntil:', 'ck_oo_wmc', 'LDHH_numberOfPrivateMethods', 'WCHU_numberOfPrivateAttributes', 'CvsLogEntropy', 'WCHU_noc', 'LDHH_numberOfAttributesInherited', 'WCHU_wmc', 'ck_oo_fanOut', 'ck_oo_numberOfLinesOfCode', 'ck_oo_numberOfAttributesInherited', 'ck_oo_numberOfMethods', 'ck_oo_dit', 'ck_oo_fanIn', 'LDHH_noc', 'WCHU_dit', 'ck_oo_lcom', 'WCHU_numberOfAttributesInherited', 'ck_oo_rfc', 'LDHH_wmc', 'LDHH_numberOfAttributes', 'LDHH_numberOfLinesOfCode', 'WCHU_fanOut', 'WCHU_lcom', 'ck_oo_cbo', 'WCHU_rfc', 'ck_oo_numberOfAttributes', 'numberOfHighPriorityBugsFoundUntil:', 'ck_oo_numberOfPrivateAttributes', 'numberOfMajorBugsFoundUntil:', 'WCHU_numberOfPublicMethods', 'LDHH_dit', 'WCHU_cbo', 'CvsLinEntropy', 'WCHU_numberOfMethodsInherited', 'numberOfBugsFoundUntil:', 'LDHH_fanOut', 'LDHH_numberOfMethodsInherited', 'LDHH_rfc', 'ck_oo_numberOfMethodsInherited', 'ck_oo_numberOfPublicMethods', 'LDHH_cbo', 'WCHU_numberOfLinesOfCode', 'CvsExpEntropy', 'LDHH_numberOfMethods']
# C:\Users\acer\AppData\Local\Temp\ipykernel_2068\4067302685.py:32: RuntimeWarning: invalid value encountered in double_scalars
#   bottom = (d - (sum(red_FF)/len(red_FF)))**(1/2)
# ['CvsEntropy',
#  'CvsLogEntropy',
#  'CvsLinEntropy',
#  'LDHH_numberOfLinesOfCode',
#  'LDHH_rfc',
#  'LDHH_wmc',
#  'LDHH_fanOut',
#  'LDHH_cbo',
#  'LDHH_numberOfMethods',
#  'LDHH_numberOfPrivateMethods',
#  'LDHH_numberOfPublicMethods',
#  'LDHH_dit',
#  'LDHH_numberOfPublicAttributes',
#  'LDHH_numberOfAttributesInherited',
#  'LDHH_numberOfPrivateAttributes',
#  'LDHH_numberOfAttributes',
#  'LDHH_numberOfMethodsInherited',
#  'LDHH_fanIn',
#  'CvsExpEntropy',
#  'WCHU_rfc',
#  'WCHU_numberOfLinesOfCode',
#  'WCHU_wmc',
#  'LDHH_lcom']

# %%
X_new = X[FS]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7244897959183674
# Precision :  0.5641025641025641
# Recall :  0.6875
# F1 Score :  0.619718309859155
# AUC :  0.7149621212121212

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7551020408163265
# Precision :  0.5909090909090909
# Recall :  0.8125
# F1 Score :  0.6842105263157896
# AUC :  0.7698863636363635

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7755102040816326
# Precision :  0.6190476190476191
# Recall :  0.8125
# F1 Score :  0.7027027027027026
# AUC :  0.7850378787878788

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.7653061224489796
# Precision :  0.6666666666666666
# Recall :  0.5625
# F1 Score :  0.6101694915254238
# AUC :  0.7130681818181818
