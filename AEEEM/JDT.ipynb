# %%
import pandas as pd

# %%
df = pd.read_csv('JDT.csv')
df
# Out:
#       id  ck_oo_numberOfPrivateMethods  LDHH_lcom  LDHH_fanIn  \
# 0      1                             0   0.000934    0.000000
# 1      2                             0   0.000741    0.000000
# 2      3                             0   0.000000    0.000000
# 3      4                             0   0.001529    0.015913
# 4      5                             0   0.000000    0.000000
# ..   ...                           ...        ...         ...
# 992  993                             1   0.001008    0.001694
# 993  994                             0   0.000000    0.002725
# 994  995                             0   0.000000    0.000000
# 995  996                             0   0.000000    0.000000
# 996  997                             0   0.000000    0.000000
#
#      numberOfNonTrivialBugsFoundUntil:  WCHU_numberOfPublicAttributes  \
# 0                                    4                           0.00
# 1                                    3                           0.00
# 2                                    4                           0.00
# 3                                   35                           0.00
# 4                                    2                           1.01
# ..                                 ...                            ...
# 992                                  2                           0.00
# 993                                  0                           0.00
# 994                                  2                           0.00
# 995                                 16                           2.02
# 996                                  1                           0.00
#
#      WCHU_numberOfAttributes  CvsWEntropy  LDHH_numberOfPublicMethods  \
# 0                       0.00     0.004517                    0.000000
# 1                       0.00     0.014817                    0.000910
# 2                       1.01     0.024575                    0.000000
# 3                       0.00     0.347495                    0.001650
# 4                       1.01     0.012120                    0.000000
# ..                       ...          ...                         ...
# 992                     0.00     0.035075                    0.001642
# 993                     0.00     0.002208                    0.000000
# 994                     0.00     0.002781                    0.000000
# 995                     2.02     0.028787                    0.000000
# 996                     0.00     0.002386                    0.000000
#
#      WCHU_fanIn  ...  LDHH_fanOut  LDHH_numberOfMethodsInherited  LDHH_rfc  \
# 0          0.00  ...     0.000993                       0.025009  0.000969
# 1          0.00  ...     0.000889                       0.001487  0.002523
# 2          0.00  ...     0.002827                       0.021650  0.003656
# 3          2.03  ...     0.010602                       0.012864  0.060975
# 4          0.00  ...     0.005223                       0.023725  0.006207
# ..          ...  ...          ...                            ...       ...
# 992        1.01  ...     0.000000                       0.027085  0.001533
# 993        3.05  ...     0.000000                       0.001487  0.000000
# 994        0.00  ...     0.000000                       0.013750  0.000845
# 995        0.00  ...     0.000000                       0.002695  0.006602
# 996        0.00  ...     0.000000                       0.001487  0.000000
#
#      ck_oo_numberOfMethodsInherited  ck_oo_numberOfPublicMethods  LDHH_cbo  \
# 0                               127                            4  0.001007
# 1                                 8                            9  0.000967
# 2                                45                            1  0.002917
# 3                                94                           21  0.027947
# 4                                73                            0  0.007285
# ..                              ...                          ...       ...
# 992                              95                            7  0.001812
# 993                               8                            0  0.002859
# 994                              85                            1  0.000000
# 995                              38                            6  0.000000
# 996                               8                            2  0.000000
#
#      WCHU_numberOfLinesOfCode  CvsExpEntropy  LDHH_numberOfMethods  class
# 0                        1.03       0.198199              0.001036  clean
# 1                        2.06       0.239334              0.000923  clean
# 2                        1.20       0.187460              0.000000  clean
# 3                       24.14       0.392389              0.001669  buggy
# 4                        2.15       0.047726              0.000000  clean
# ..                        ...            ...                   ...    ...
# 992                      1.06       0.018379              0.001525  clean
# 993                      0.00       0.001031              0.000000  clean
# 994                      0.00       0.001125              0.000000  clean
# 995                      7.74       0.015277              0.000000  clean
# 996                      0.00       0.001130              0.000000  clean
#
# [997 rows x 63 columns]

# %%
codes = {'buggy' : 1, 'clean' : 0}
for i in df.columns:
    df[i] = df[i].replace(codes)
df
# Out:
#       id  ck_oo_numberOfPrivateMethods  LDHH_lcom  LDHH_fanIn  \
# 0      1                             0   0.000934    0.000000
# 1      2                             0   0.000741    0.000000
# 2      3                             0   0.000000    0.000000
# 3      4                             0   0.001529    0.015913
# 4      5                             0   0.000000    0.000000
# ..   ...                           ...        ...         ...
# 992  993                             1   0.001008    0.001694
# 993  994                             0   0.000000    0.002725
# 994  995                             0   0.000000    0.000000
# 995  996                             0   0.000000    0.000000
# 996  997                             0   0.000000    0.000000
#
#      numberOfNonTrivialBugsFoundUntil:  WCHU_numberOfPublicAttributes  \
# 0                                    4                           0.00
# 1                                    3                           0.00
# 2                                    4                           0.00
# 3                                   35                           0.00
# 4                                    2                           1.01
# ..                                 ...                            ...
# 992                                  2                           0.00
# 993                                  0                           0.00
# 994                                  2                           0.00
# 995                                 16                           2.02
# 996                                  1                           0.00
#
#      WCHU_numberOfAttributes  CvsWEntropy  LDHH_numberOfPublicMethods  \
# 0                       0.00     0.004517                    0.000000
# 1                       0.00     0.014817                    0.000910
# 2                       1.01     0.024575                    0.000000
# 3                       0.00     0.347495                    0.001650
# 4                       1.01     0.012120                    0.000000
# ..                       ...          ...                         ...
# 992                     0.00     0.035075                    0.001642
# 993                     0.00     0.002208                    0.000000
# 994                     0.00     0.002781                    0.000000
# 995                     2.02     0.028787                    0.000000
# 996                     0.00     0.002386                    0.000000
#
#      WCHU_fanIn  ...  LDHH_fanOut  LDHH_numberOfMethodsInherited  LDHH_rfc  \
# 0          0.00  ...     0.000993                       0.025009  0.000969
# 1          0.00  ...     0.000889                       0.001487  0.002523
# 2          0.00  ...     0.002827                       0.021650  0.003656
# 3          2.03  ...     0.010602                       0.012864  0.060975
# 4          0.00  ...     0.005223                       0.023725  0.006207
# ..          ...  ...          ...                            ...       ...
# 992        1.01  ...     0.000000                       0.027085  0.001533
# 993        3.05  ...     0.000000                       0.001487  0.000000
# 994        0.00  ...     0.000000                       0.013750  0.000845
# 995        0.00  ...     0.000000                       0.002695  0.006602
# 996        0.00  ...     0.000000                       0.001487  0.000000
#
#      ck_oo_numberOfMethodsInherited  ck_oo_numberOfPublicMethods  LDHH_cbo  \
# 0                               127                            4  0.001007
# 1                                 8                            9  0.000967
# 2                                45                            1  0.002917
# 3                                94                           21  0.027947
# 4                                73                            0  0.007285
# ..                              ...                          ...       ...
# 992                              95                            7  0.001812
# 993                               8                            0  0.002859
# 994                              85                            1  0.000000
# 995                              38                            6  0.000000
# 996                               8                            2  0.000000
#
#      WCHU_numberOfLinesOfCode  CvsExpEntropy  LDHH_numberOfMethods  class
# 0                        1.03       0.198199              0.001036      0
# 1                        2.06       0.239334              0.000923      0
# 2                        1.20       0.187460              0.000000      0
# 3                       24.14       0.392389              0.001669      1
# 4                        2.15       0.047726              0.000000      0
# ..                        ...            ...                   ...    ...
# 992                      1.06       0.018379              0.001525      0
# 993                      0.00       0.001031              0.000000      0
# 994                      0.00       0.001125              0.000000      0
# 995                      7.74       0.015277              0.000000      0
# 996                      0.00       0.001130              0.000000      0
#
# [997 rows x 63 columns]

# %%
df = df.rename({'AgingRelatedBugs':'class'}, axis=1)
df
# Out:
#       id  ck_oo_numberOfPrivateMethods  LDHH_lcom  LDHH_fanIn  \
# 0      1                             0   0.000934    0.000000
# 1      2                             0   0.000741    0.000000
# 2      3                             0   0.000000    0.000000
# 3      4                             0   0.001529    0.015913
# 4      5                             0   0.000000    0.000000
# ..   ...                           ...        ...         ...
# 992  993                             1   0.001008    0.001694
# 993  994                             0   0.000000    0.002725
# 994  995                             0   0.000000    0.000000
# 995  996                             0   0.000000    0.000000
# 996  997                             0   0.000000    0.000000
#
#      numberOfNonTrivialBugsFoundUntil:  WCHU_numberOfPublicAttributes  \
# 0                                    4                           0.00
# 1                                    3                           0.00
# 2                                    4                           0.00
# 3                                   35                           0.00
# 4                                    2                           1.01
# ..                                 ...                            ...
# 992                                  2                           0.00
# 993                                  0                           0.00
# 994                                  2                           0.00
# 995                                 16                           2.02
# 996                                  1                           0.00
#
#      WCHU_numberOfAttributes  CvsWEntropy  LDHH_numberOfPublicMethods  \
# 0                       0.00     0.004517                    0.000000
# 1                       0.00     0.014817                    0.000910
# 2                       1.01     0.024575                    0.000000
# 3                       0.00     0.347495                    0.001650
# 4                       1.01     0.012120                    0.000000
# ..                       ...          ...                         ...
# 992                     0.00     0.035075                    0.001642
# 993                     0.00     0.002208                    0.000000
# 994                     0.00     0.002781                    0.000000
# 995                     2.02     0.028787                    0.000000
# 996                     0.00     0.002386                    0.000000
#
#      WCHU_fanIn  ...  LDHH_fanOut  LDHH_numberOfMethodsInherited  LDHH_rfc  \
# 0          0.00  ...     0.000993                       0.025009  0.000969
# 1          0.00  ...     0.000889                       0.001487  0.002523
# 2          0.00  ...     0.002827                       0.021650  0.003656
# 3          2.03  ...     0.010602                       0.012864  0.060975
# 4          0.00  ...     0.005223                       0.023725  0.006207
# ..          ...  ...          ...                            ...       ...
# 992        1.01  ...     0.000000                       0.027085  0.001533
# 993        3.05  ...     0.000000                       0.001487  0.000000
# 994        0.00  ...     0.000000                       0.013750  0.000845
# 995        0.00  ...     0.000000                       0.002695  0.006602
# 996        0.00  ...     0.000000                       0.001487  0.000000
#
#      ck_oo_numberOfMethodsInherited  ck_oo_numberOfPublicMethods  LDHH_cbo  \
# 0                               127                            4  0.001007
# 1                                 8                            9  0.000967
# 2                                45                            1  0.002917
# 3                                94                           21  0.027947
# 4                                73                            0  0.007285
# ..                              ...                          ...       ...
# 992                              95                            7  0.001812
# 993                               8                            0  0.002859
# 994                              85                            1  0.000000
# 995                              38                            6  0.000000
# 996                               8                            2  0.000000
#
#      WCHU_numberOfLinesOfCode  CvsExpEntropy  LDHH_numberOfMethods  class
# 0                        1.03       0.198199              0.001036      0
# 1                        2.06       0.239334              0.000923      0
# 2                        1.20       0.187460              0.000000      0
# 3                       24.14       0.392389              0.001669      1
# 4                        2.15       0.047726              0.000000      0
# ..                        ...            ...                   ...    ...
# 992                      1.06       0.018379              0.001525      0
# 993                      0.00       0.001031              0.000000      0
# 994                      0.00       0.001125              0.000000      0
# 995                      7.74       0.015277              0.000000      0
# 996                      0.00       0.001130              0.000000      0
#
# [997 rows x 63 columns]

# %%
df[df['class'] == 0]
# Out:
#       id  ck_oo_numberOfPrivateMethods  LDHH_lcom  LDHH_fanIn  \
# 0      1                             0   0.000934    0.000000
# 1      2                             0   0.000741    0.000000
# 2      3                             0   0.000000    0.000000
# 4      5                             0   0.000000    0.000000
# 7      8                             4   0.000000    0.000000
# ..   ...                           ...        ...         ...
# 992  993                             1   0.001008    0.001694
# 993  994                             0   0.000000    0.002725
# 994  995                             0   0.000000    0.000000
# 995  996                             0   0.000000    0.000000
# 996  997                             0   0.000000    0.000000
#
#      numberOfNonTrivialBugsFoundUntil:  WCHU_numberOfPublicAttributes  \
# 0                                    4                           0.00
# 1                                    3                           0.00
# 2                                    4                           0.00
# 4                                    2                           1.01
# 7                                    2                           0.00
# ..                                 ...                            ...
# 992                                  2                           0.00
# 993                                  0                           0.00
# 994                                  2                           0.00
# 995                                 16                           2.02
# 996                                  1                           0.00
#
#      WCHU_numberOfAttributes  CvsWEntropy  LDHH_numberOfPublicMethods  \
# 0                       0.00     0.004517                    0.000000
# 1                       0.00     0.014817                    0.000910
# 2                       1.01     0.024575                    0.000000
# 4                       1.01     0.012120                    0.000000
# 7                       1.01     0.007528                    0.000000
# ..                       ...          ...                         ...
# 992                     0.00     0.035075                    0.001642
# 993                     0.00     0.002208                    0.000000
# 994                     0.00     0.002781                    0.000000
# 995                     2.02     0.028787                    0.000000
# 996                     0.00     0.002386                    0.000000
#
#      WCHU_fanIn  ...  LDHH_fanOut  LDHH_numberOfMethodsInherited  LDHH_rfc  \
# 0          0.00  ...     0.000993                       0.025009  0.000969
# 1          0.00  ...     0.000889                       0.001487  0.002523
# 2          0.00  ...     0.002827                       0.021650  0.003656
# 4          0.00  ...     0.005223                       0.023725  0.006207
# 7          0.00  ...     0.000000                       0.000000  0.000000
# ..          ...  ...          ...                            ...       ...
# 992        1.01  ...     0.000000                       0.027085  0.001533
# 993        3.05  ...     0.000000                       0.001487  0.000000
# 994        0.00  ...     0.000000                       0.013750  0.000845
# 995        0.00  ...     0.000000                       0.002695  0.006602
# 996        0.00  ...     0.000000                       0.001487  0.000000
#
#      ck_oo_numberOfMethodsInherited  ck_oo_numberOfPublicMethods  LDHH_cbo  \
# 0                               127                            4  0.001007
# 1                                 8                            9  0.000967
# 2                                45                            1  0.002917
# 4                                73                            0  0.007285
# 7                                 8                            0  0.000000
# ..                              ...                          ...       ...
# 992                              95                            7  0.001812
# 993                               8                            0  0.002859
# 994                              85                            1  0.000000
# 995                              38                            6  0.000000
# 996                               8                            2  0.000000
#
#      WCHU_numberOfLinesOfCode  CvsExpEntropy  LDHH_numberOfMethods  class
# 0                        1.03       0.198199              0.001036      0
# 1                        2.06       0.239334              0.000923      0
# 2                        1.20       0.187460              0.000000      0
# 4                        2.15       0.047726              0.000000      0
# 7                        1.02       0.140566              0.000000      0
# ..                        ...            ...                   ...    ...
# 992                      1.06       0.018379              0.001525      0
# 993                      0.00       0.001031              0.000000      0
# 994                      0.00       0.001125              0.000000      0
# 995                      7.74       0.015277              0.000000      0
# 996                      0.00       0.001130              0.000000      0
#
# [791 rows x 63 columns]

# %%
X = df.drop(['class'], axis=1)
X
# Out:
#       id  ck_oo_numberOfPrivateMethods  LDHH_lcom  LDHH_fanIn  \
# 0      1                             0   0.000934    0.000000
# 1      2                             0   0.000741    0.000000
# 2      3                             0   0.000000    0.000000
# 3      4                             0   0.001529    0.015913
# 4      5                             0   0.000000    0.000000
# ..   ...                           ...        ...         ...
# 992  993                             1   0.001008    0.001694
# 993  994                             0   0.000000    0.002725
# 994  995                             0   0.000000    0.000000
# 995  996                             0   0.000000    0.000000
# 996  997                             0   0.000000    0.000000
#
#      numberOfNonTrivialBugsFoundUntil:  WCHU_numberOfPublicAttributes  \
# 0                                    4                           0.00
# 1                                    3                           0.00
# 2                                    4                           0.00
# 3                                   35                           0.00
# 4                                    2                           1.01
# ..                                 ...                            ...
# 992                                  2                           0.00
# 993                                  0                           0.00
# 994                                  2                           0.00
# 995                                 16                           2.02
# 996                                  1                           0.00
#
#      WCHU_numberOfAttributes  CvsWEntropy  LDHH_numberOfPublicMethods  \
# 0                       0.00     0.004517                    0.000000
# 1                       0.00     0.014817                    0.000910
# 2                       1.01     0.024575                    0.000000
# 3                       0.00     0.347495                    0.001650
# 4                       1.01     0.012120                    0.000000
# ..                       ...          ...                         ...
# 992                     0.00     0.035075                    0.001642
# 993                     0.00     0.002208                    0.000000
# 994                     0.00     0.002781                    0.000000
# 995                     2.02     0.028787                    0.000000
# 996                     0.00     0.002386                    0.000000
#
#      WCHU_fanIn  ...  numberOfBugsFoundUntil:  LDHH_fanOut  \
# 0          0.00  ...                        4     0.000993
# 1          0.00  ...                        4     0.000889
# 2          0.00  ...                        4     0.002827
# 3          2.03  ...                       40     0.010602
# 4          0.00  ...                        2     0.005223
# ..          ...  ...                      ...          ...
# 992        1.01  ...                        2     0.000000
# 993        3.05  ...                        0     0.000000
# 994        0.00  ...                        2     0.000000
# 995        0.00  ...                       18     0.000000
# 996        0.00  ...                        1     0.000000
#
#      LDHH_numberOfMethodsInherited  LDHH_rfc  ck_oo_numberOfMethodsInherited  \
# 0                         0.025009  0.000969                             127
# 1                         0.001487  0.002523                               8
# 2                         0.021650  0.003656                              45
# 3                         0.012864  0.060975                              94
# 4                         0.023725  0.006207                              73
# ..                             ...       ...                             ...
# 992                       0.027085  0.001533                              95
# 993                       0.001487  0.000000                               8
# 994                       0.013750  0.000845                              85
# 995                       0.002695  0.006602                              38
# 996                       0.001487  0.000000                               8
#
#      ck_oo_numberOfPublicMethods  LDHH_cbo  WCHU_numberOfLinesOfCode  \
# 0                              4  0.001007                      1.03
# 1                              9  0.000967                      2.06
# 2                              1  0.002917                      1.20
# 3                             21  0.027947                     24.14
# 4                              0  0.007285                      2.15
# ..                           ...       ...                       ...
# 992                            7  0.001812                      1.06
# 993                            0  0.002859                      0.00
# 994                            1  0.000000                      0.00
# 995                            6  0.000000                      7.74
# 996                            2  0.000000                      0.00
#
#      CvsExpEntropy  LDHH_numberOfMethods
# 0         0.198199              0.001036
# 1         0.239334              0.000923
# 2         0.187460              0.000000
# 3         0.392389              0.001669
# 4         0.047726              0.000000
# ..             ...                   ...
# 992       0.018379              0.001525
# 993       0.001031              0.000000
# 994       0.001125              0.000000
# 995       0.015277              0.000000
# 996       0.001130              0.000000
#
# [997 rows x 62 columns]

# %%
Y = df['class']
Y
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 992    0
# 993    0
# 994    0
# 995    0
# 996    0
# Name: class, Length: 997, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import *

# %% [markdown]
# # All Features

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8466666666666667
# Precision :  0.6521739130434783
# Recall :  0.2830188679245283
# F1 Score :  0.3947368421052632
# AUC :  0.6253151019784584

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8466666666666667
# Precision :  0.6521739130434783
# Recall :  0.2830188679245283
# F1 Score :  0.3947368421052632
# AUC :  0.6253151019784584

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8466666666666667
# Precision :  0.5897435897435898
# Recall :  0.4339622641509434
# F1 Score :  0.5
# AUC :  0.6845924681078605

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.87
# Precision :  0.6590909090909091
# Recall :  0.5471698113207547
# F1 Score :  0.5979381443298969
# AUC :  0.7432205331907418

# %% [markdown]
# # PEARSON CORRELATION

# %%
cor = df.corr()
cor_target = abs(cor['class'])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.5]
relevant_features
# Out:
# CvsEntropy    0.552337
# WCHU_wmc      0.503000
# WCHU_rfc      0.507400
# LDHH_rfc      0.505288
# class         1.000000
# Name: class, dtype: float64

# %%
X_new = df[['CvsEntropy', 'WCHU_wmc', 'WCHU_rfc', 'LDHH_rfc']]
X_new
# Out:
#      CvsEntropy  WCHU_wmc  WCHU_rfc  LDHH_rfc
# 0       8.73596      1.02      1.05  0.000969
# 1       7.99162      2.04      2.13  0.002523
# 2       8.89835      2.08      2.03  0.003656
# 3      30.88470     16.75     18.65  0.060975
# 4       2.80457      2.11      2.08  0.006207
# ..          ...       ...       ...       ...
# 992     6.88643      1.02      1.02  0.001533
# 993     4.07501      0.00      0.00  0.000000
# 994     6.92698      0.00      1.01  0.000845
# 995    16.46420      6.13      6.19  0.006602
# 996     5.11540      0.00      0.00  0.000000
#
# [997 rows x 4 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8466666666666667
# Precision :  0.5777777777777777
# Recall :  0.49056603773584906
# F1 Score :  0.5306122448979591
# AUC :  0.706821480406386

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.88
# Precision :  0.7575757575757576
# Recall :  0.4716981132075472
# F1 Score :  0.5813953488372093
# AUC :  0.719654724619968

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.87
# Precision :  0.6590909090909091
# Recall :  0.5471698113207547
# F1 Score :  0.5979381443298969
# AUC :  0.7432205331907418

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8866666666666667
# Precision :  0.7111111111111111
# Recall :  0.6037735849056604
# F1 Score :  0.6530612244897959
# AUC :  0.7755710029791459

# %% [markdown]
# # INFORMATION GAIN 10

# %%
from sklearn.feature_selection import mutual_info_classif
gain = mutual_info_classif(X,Y)
gain
# Out:
# array([0.0014526 , 0.03926498, 0.07828913, 0.02255392, 0.13758956,
#        0.05938619, 0.0623725 , 0.11998708, 0.04946317, 0.03323466,
#        0.01124455, 0.14532255, 0.04012678, 0.03010451, 0.06640785,
#        0.04520791, 0.01373779, 0.05623273, 0.11529156, 0.05733238,
#        0.03135147, 0.14744832, 0.0041182 , 0.07294199, 0.13913819,
#        0.12707756, 0.11659893, 0.06002463, 0.05362385, 0.        ,
#        0.0515972 , 0.00928545, 0.00700164, 0.03504217, 0.07578792,
#        0.10884738, 0.12367136, 0.05743138, 0.13304194, 0.10872979,
#        0.07914486, 0.09771974, 0.14329175, 0.04971111, 0.05434177,
#        0.01710495, 0.1048259 , 0.06040742, 0.00714276, 0.07090158,
#        0.15320621, 0.04477849, 0.13617288, 0.09257347, 0.05236021,
#        0.13869561, 0.04099564, 0.03258399, 0.06768322, 0.12200678,
#        0.14366492, 0.09187698])

# %%
col_list = X.columns
col_list
# Out:
# Index(['id', 'ck_oo_numberOfPrivateMethods', 'LDHH_lcom', 'LDHH_fanIn',
#        'numberOfNonTrivialBugsFoundUntil:', 'WCHU_numberOfPublicAttributes',
#        'WCHU_numberOfAttributes', 'CvsWEntropy', 'LDHH_numberOfPublicMethods',
#        'WCHU_fanIn', 'LDHH_numberOfPrivateAttributes', 'CvsEntropy',
#        'LDHH_numberOfPublicAttributes', 'WCHU_numberOfPrivateMethods',
#        'WCHU_numberOfMethods', 'ck_oo_numberOfPublicAttributes', 'ck_oo_noc',
#        'numberOfCriticalBugsFoundUntil:', 'ck_oo_wmc',
#        'LDHH_numberOfPrivateMethods', 'WCHU_numberOfPrivateAttributes',
#        'CvsLogEntropy', 'WCHU_noc', 'LDHH_numberOfAttributesInherited',
#        'WCHU_wmc', 'ck_oo_fanOut', 'ck_oo_numberOfLinesOfCode',
#        'ck_oo_numberOfAttributesInherited', 'ck_oo_numberOfMethods',
#        'ck_oo_dit', 'ck_oo_fanIn', 'LDHH_noc', 'WCHU_dit', 'ck_oo_lcom',
#        'WCHU_numberOfAttributesInherited', 'ck_oo_rfc', 'LDHH_wmc',
#        'LDHH_numberOfAttributes', 'LDHH_numberOfLinesOfCode', 'WCHU_fanOut',
#        'WCHU_lcom', 'ck_oo_cbo', 'WCHU_rfc', 'ck_oo_numberOfAttributes',
#        'numberOfHighPriorityBugsFoundUntil:',
#        'ck_oo_numberOfPrivateAttributes', 'numberOfMajorBugsFoundUntil:',
#        'WCHU_numberOfPublicMethods', 'LDHH_dit', 'WCHU_cbo', 'CvsLinEntropy',
#        'WCHU_numberOfMethodsInherited', 'numberOfBugsFoundUntil:',
#        'LDHH_fanOut', 'LDHH_numberOfMethodsInherited', 'LDHH_rfc',
#        'ck_oo_numberOfMethodsInherited', 'ck_oo_numberOfPublicMethods',
#        'LDHH_cbo', 'WCHU_numberOfLinesOfCode', 'CvsExpEntropy',
#        'LDHH_numberOfMethods'],
#       dtype='object')

# %%
temp = pd.DataFrame(list(zip(col_list, gain)), columns =['col', 'score']) 
temp
# Out:
#                                   col     score
# 0                                  id  0.001453
# 1        ck_oo_numberOfPrivateMethods  0.039265
# 2                           LDHH_lcom  0.078289
# 3                          LDHH_fanIn  0.022554
# 4   numberOfNonTrivialBugsFoundUntil:  0.137590
# ..                                ...       ...
# 57        ck_oo_numberOfPublicMethods  0.032584
# 58                           LDHH_cbo  0.067683
# 59           WCHU_numberOfLinesOfCode  0.122007
# 60                      CvsExpEntropy  0.143665
# 61               LDHH_numberOfMethods  0.091877
#
# [62 rows x 2 columns]

# %%
temp_sort = temp.sort_values(['score'], ascending=False)
temp_sort[:10]
# Out:
#                                   col     score
# 50                      CvsLinEntropy  0.153206
# 21                      CvsLogEntropy  0.147448
# 11                         CvsEntropy  0.145323
# 60                      CvsExpEntropy  0.143665
# 42                           WCHU_rfc  0.143292
# 24                           WCHU_wmc  0.139138
# 55                           LDHH_rfc  0.138696
# 4   numberOfNonTrivialBugsFoundUntil:  0.137590
# 52            numberOfBugsFoundUntil:  0.136173
# 38           LDHH_numberOfLinesOfCode  0.133042

# %%
FS = list(temp_sort['col'][:10])
FS
# Out:
# ['CvsLinEntropy',
#  'CvsLogEntropy',
#  'CvsEntropy',
#  'CvsExpEntropy',
#  'WCHU_rfc',
#  'WCHU_wmc',
#  'LDHH_rfc',
#  'numberOfNonTrivialBugsFoundUntil:',
#  'numberOfBugsFoundUntil:',
#  'LDHH_numberOfLinesOfCode']

# %%
X_new = df[FS]
X_new
# Out:
#      CvsLinEntropy  CvsLogEntropy  CvsEntropy  CvsExpEntropy  WCHU_rfc  \
# 0         0.134499       8.111400     8.73596       0.198199      1.05
# 1         0.157613       8.150060     7.99162       0.239334      2.13
# 2         0.133644       8.120360     8.89835       0.187460      2.03
# 3         0.221639       8.774240    30.88470       0.392389     18.65
# 4         0.014004       0.091119     2.80457       0.047726      2.08
# ..             ...            ...         ...            ...       ...
# 992       0.015043       0.177039     6.88643       0.018379      1.02
# 993       0.006219       0.097153     4.07501       0.001031      0.00
# 994       0.009727       0.161994     6.92698       0.001125      1.01
# 995       0.028620       0.403196    16.46420       0.015277      6.19
# 996       0.007694       0.121597     5.11540       0.001130      0.00
#
#      WCHU_wmc  LDHH_rfc  numberOfNonTrivialBugsFoundUntil:  \
# 0        1.02  0.000969                                  4
# 1        2.04  0.002523                                  3
# 2        2.08  0.003656                                  4
# 3       16.75  0.060975                                 35
# 4        2.11  0.006207                                  2
# ..        ...       ...                                ...
# 992      1.02  0.001533                                  2
# 993      0.00  0.000000                                  0
# 994      0.00  0.000845                                  2
# 995      6.13  0.006602                                 16
# 996      0.00  0.000000                                  1
#
#      numberOfBugsFoundUntil:  LDHH_numberOfLinesOfCode
# 0                          4                  0.000943
# 1                          4                  0.002165
# 2                          4                  0.003723
# 3                         40                  0.066868
# 4                          2                  0.006238
# ..                       ...                       ...
# 992                        2                  0.001457
# 993                        0                  0.000000
# 994                        2                  0.000000
# 995                       18                  0.008287
# 996                        1                  0.000000
#
# [997 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.87
# Precision :  0.6590909090909091
# Recall :  0.5471698113207547
# F1 Score :  0.5979381443298969
# AUC :  0.7432205331907418

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8733333333333333
# Precision :  0.7272727272727273
# Recall :  0.4528301886792453
# F1 Score :  0.5581395348837209
# AUC :  0.7081964708578412

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8666666666666667
# Precision :  0.6585365853658537
# Recall :  0.5094339622641509
# F1 Score :  0.574468085106383
# AUC :  0.7263769001604156

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8766666666666667
# Precision :  0.6739130434782609
# Recall :  0.5849056603773585
# F1 Score :  0.6262626262626263
# AUC :  0.7620884577190437

# %% [markdown]
# # INFORMATION GAIN 15

# %%
from sklearn.feature_selection import mutual_info_classif
gain = mutual_info_classif(X,Y)
gain
# Out:
# array([0.0008264 , 0.03592105, 0.07789864, 0.03086441, 0.12976546,
#        0.04250582, 0.06952656, 0.12043181, 0.06343531, 0.01056059,
#        0.01431626, 0.1467273 , 0.02272687, 0.03489378, 0.06629399,
#        0.03117571, 0.02355968, 0.07649317, 0.11815928, 0.0340433 ,
#        0.03169391, 0.14535329, 0.        , 0.07193121, 0.12333801,
#        0.12012514, 0.11483236, 0.06707522, 0.03594948, 0.02526523,
#        0.03911777, 0.00383409, 0.00020038, 0.0260023 , 0.06455943,
#        0.10265895, 0.12046941, 0.06660228, 0.13506786, 0.11469268,
#        0.08456831, 0.10252213, 0.14459561, 0.02650473, 0.05912518,
#        0.        , 0.09264162, 0.0376994 , 0.00836535, 0.0771536 ,
#        0.15277968, 0.05977991, 0.14385823, 0.08740125, 0.058512  ,
#        0.14271478, 0.03988074, 0.02119993, 0.07096842, 0.13218639,
#        0.14762633, 0.08792702])

# %%
col_list = X.columns
col_list
# Out:
# Index(['id', 'ck_oo_numberOfPrivateMethods', 'LDHH_lcom', 'LDHH_fanIn',
#        'numberOfNonTrivialBugsFoundUntil:', 'WCHU_numberOfPublicAttributes',
#        'WCHU_numberOfAttributes', 'CvsWEntropy', 'LDHH_numberOfPublicMethods',
#        'WCHU_fanIn', 'LDHH_numberOfPrivateAttributes', 'CvsEntropy',
#        'LDHH_numberOfPublicAttributes', 'WCHU_numberOfPrivateMethods',
#        'WCHU_numberOfMethods', 'ck_oo_numberOfPublicAttributes', 'ck_oo_noc',
#        'numberOfCriticalBugsFoundUntil:', 'ck_oo_wmc',
#        'LDHH_numberOfPrivateMethods', 'WCHU_numberOfPrivateAttributes',
#        'CvsLogEntropy', 'WCHU_noc', 'LDHH_numberOfAttributesInherited',
#        'WCHU_wmc', 'ck_oo_fanOut', 'ck_oo_numberOfLinesOfCode',
#        'ck_oo_numberOfAttributesInherited', 'ck_oo_numberOfMethods',
#        'ck_oo_dit', 'ck_oo_fanIn', 'LDHH_noc', 'WCHU_dit', 'ck_oo_lcom',
#        'WCHU_numberOfAttributesInherited', 'ck_oo_rfc', 'LDHH_wmc',
#        'LDHH_numberOfAttributes', 'LDHH_numberOfLinesOfCode', 'WCHU_fanOut',
#        'WCHU_lcom', 'ck_oo_cbo', 'WCHU_rfc', 'ck_oo_numberOfAttributes',
#        'numberOfHighPriorityBugsFoundUntil:',
#        'ck_oo_numberOfPrivateAttributes', 'numberOfMajorBugsFoundUntil:',
#        'WCHU_numberOfPublicMethods', 'LDHH_dit', 'WCHU_cbo', 'CvsLinEntropy',
#        'WCHU_numberOfMethodsInherited', 'numberOfBugsFoundUntil:',
#        'LDHH_fanOut', 'LDHH_numberOfMethodsInherited', 'LDHH_rfc',
#        'ck_oo_numberOfMethodsInherited', 'ck_oo_numberOfPublicMethods',
#        'LDHH_cbo', 'WCHU_numberOfLinesOfCode', 'CvsExpEntropy',
#        'LDHH_numberOfMethods'],
#       dtype='object')

# %%
temp = pd.DataFrame(list(zip(col_list, gain)), columns =['col', 'score']) 
temp
# Out:
#                                   col     score
# 0                                  id  0.000826
# 1        ck_oo_numberOfPrivateMethods  0.035921
# 2                           LDHH_lcom  0.077899
# 3                          LDHH_fanIn  0.030864
# 4   numberOfNonTrivialBugsFoundUntil:  0.129765
# ..                                ...       ...
# 57        ck_oo_numberOfPublicMethods  0.021200
# 58                           LDHH_cbo  0.070968
# 59           WCHU_numberOfLinesOfCode  0.132186
# 60                      CvsExpEntropy  0.147626
# 61               LDHH_numberOfMethods  0.087927
#
# [62 rows x 2 columns]

# %%
temp_sort = temp.sort_values(['score'], ascending=False)
temp_sort[:15]
# Out:
#                                   col     score
# 50                      CvsLinEntropy  0.152780
# 60                      CvsExpEntropy  0.147626
# 11                         CvsEntropy  0.146727
# 21                      CvsLogEntropy  0.145353
# 42                           WCHU_rfc  0.144596
# 52            numberOfBugsFoundUntil:  0.143858
# 55                           LDHH_rfc  0.142715
# 38           LDHH_numberOfLinesOfCode  0.135068
# 59           WCHU_numberOfLinesOfCode  0.132186
# 4   numberOfNonTrivialBugsFoundUntil:  0.129765
# 24                           WCHU_wmc  0.123338
# 36                           LDHH_wmc  0.120469
# 7                         CvsWEntropy  0.120432
# 25                       ck_oo_fanOut  0.120125
# 18                          ck_oo_wmc  0.118159

# %%
FS = list(temp_sort['col'][:15])
FS
# Out:
# ['CvsLinEntropy',
#  'CvsExpEntropy',
#  'CvsEntropy',
#  'CvsLogEntropy',
#  'WCHU_rfc',
#  'numberOfBugsFoundUntil:',
#  'LDHH_rfc',
#  'LDHH_numberOfLinesOfCode',
#  'WCHU_numberOfLinesOfCode',
#  'numberOfNonTrivialBugsFoundUntil:',
#  'WCHU_wmc',
#  'LDHH_wmc',
#  'CvsWEntropy',
#  'ck_oo_fanOut',
#  'ck_oo_wmc']

# %%
X_new = df[FS]
X_new
# Out:
#      CvsLinEntropy  CvsExpEntropy  CvsEntropy  CvsLogEntropy  WCHU_rfc  \
# 0         0.134499       0.198199     8.73596       8.111400      1.05
# 1         0.157613       0.239334     7.99162       8.150060      2.13
# 2         0.133644       0.187460     8.89835       8.120360      2.03
# 3         0.221639       0.392389    30.88470       8.774240     18.65
# 4         0.014004       0.047726     2.80457       0.091119      2.08
# ..             ...            ...         ...            ...       ...
# 992       0.015043       0.018379     6.88643       0.177039      1.02
# 993       0.006219       0.001031     4.07501       0.097153      0.00
# 994       0.009727       0.001125     6.92698       0.161994      1.01
# 995       0.028620       0.015277    16.46420       0.403196      6.19
# 996       0.007694       0.001130     5.11540       0.121597      0.00
#
#      numberOfBugsFoundUntil:  LDHH_rfc  LDHH_numberOfLinesOfCode  \
# 0                          4  0.000969                  0.000943
# 1                          4  0.002523                  0.002165
# 2                          4  0.003656                  0.003723
# 3                         40  0.060975                  0.066868
# 4                          2  0.006207                  0.006238
# ..                       ...       ...                       ...
# 992                        2  0.001533                  0.001457
# 993                        0  0.000000                  0.000000
# 994                        2  0.000845                  0.000000
# 995                       18  0.006602                  0.008287
# 996                        1  0.000000                  0.000000
#
#      WCHU_numberOfLinesOfCode  numberOfNonTrivialBugsFoundUntil:  WCHU_wmc  \
# 0                        1.03                                  4      1.02
# 1                        2.06                                  3      2.04
# 2                        1.20                                  4      2.08
# 3                       24.14                                 35     16.75
# 4                        2.15                                  2      2.11
# ..                        ...                                ...       ...
# 992                      1.06                                  2      1.02
# 993                      0.00                                  0      0.00
# 994                      0.00                                  2      0.00
# 995                      7.74                                 16      6.13
# 996                      0.00                                  1      0.00
#
#      LDHH_wmc  CvsWEntropy  ck_oo_fanOut  ck_oo_wmc
# 0    0.000954     0.004517             3         11
# 1    0.001815     0.014817             5         14
# 2    0.004731     0.024575             1         12
# 3    0.061236     0.347495            22        253
# 4    0.006215     0.012120             0         10
# ..        ...          ...           ...        ...
# 992  0.001592     0.035075             6         20
# 993  0.000000     0.002208             3         21
# 994  0.000000     0.002781             0          3
# 995  0.007493     0.028787            11         91
# 996  0.000000     0.002386             1          4
#
# [997 rows x 15 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.85
# Precision :  0.5909090909090909
# Recall :  0.49056603773584906
# F1 Score :  0.5360824742268041
# AUC :  0.7088457719043617

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.86
# Precision :  0.6571428571428571
# Recall :  0.4339622641509434
# F1 Score :  0.5227272727272727
# AUC :  0.6926896340997633

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8566666666666667
# Precision :  0.6086956521739131
# Recall :  0.5283018867924528
# F1 Score :  0.5656565656565657
# AUC :  0.7277136964326636

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8766666666666667
# Precision :  0.6818181818181818
# Recall :  0.5660377358490566
# F1 Score :  0.6185567010309277
# AUC :  0.7546787869528683

# %% [markdown]
# # FISHER SCORE

# %%
FScore = []

for m in  range(len(col_list)):
        mu = df[col_list[m]].mean()

        n_1 = df[df['class'] == 0].count()[1]
        mu_1 = df[col_list[m]][df['class'] == 0].mean()
        var_1 = df[col_list[m]][df['class'] == 0].var()

        n_2 = df[df['class'] == 1].count()[1]
        mu_2 = df[col_list[m]][df['class'] == 1].mean()
        var_2 = df[col_list[m]][df['class'] == 1].var()

        inter_class = n_1*(mu_1-mu)**2 + n_2*(mu_2-mu)**2
        intra_class = (n_1-1)*var_1 + (n_2-1)*var_2

        FScore.append(inter_class / intra_class)

FScore
# Out:
# [0.00042125306518029087,
#  0.060174675173949865,
#  0.1601970658516589,
#  0.042951316234713856,
#  0.2907917673949207,
#  0.07508112921143027,
#  0.127055206496163,
#  0.16915849187346424,
#  0.09924417823027838,
#  0.058571191316900605,
#  0.02489513776040696,
#  0.4390057688328846,
#  0.05438048464792577,
#  0.08267997645077436,
#  0.1805340686570621,
#  0.03253649210154825,
#  0.0019446284669744933,
#  0.12306433445181299,
#  0.16578279120602743,
#  0.07535784883030916,
#  0.07410852707782076,
#  0.07061331839140687,
#  0.002667531432188852,
#  0.01916894807776464,
#  0.3387049150681027,
#  0.2494790115940099,
#  0.15040325490379144,
#  0.0008267434253885905,
#  0.09181705082014738,
#  0.000288675925819342,
#  0.050355790053876415,
#  0.0017691018566755863,
#  0.009725607166578061,
#  0.026293952732821563,
#  0.018199316589616172,
#  0.14503124524988603,
#  0.30564687726395495,
#  0.08445234528867747,
#  0.326498884830811,
#  0.26235104140016596,
#  0.044996777305267674,
#  0.17151679160649502,
#  0.34671854953981857,
#  0.07350369217739963,
#  0.13306730374208367,
#  0.007973074100682162,
#  0.19970809395910805,
#  0.11187600683942094,
#  0.010059545760107699,
#  0.1706944799326187,
#  0.16899012810237637,
#  0.03745737986393694,
#  0.2897219846175867,
#  0.18300337828879615,
#  0.023475385293900367,
#  0.3428506870279212,
#  4.23464998790119e-05,
#  0.05514496526698289,
#  0.13127792806082786,
#  0.326673427363565,
#  0.20189827479841443,
#  0.15948721677814187]

# %%
temp = pd.DataFrame(list(zip(col_list, FScore)), columns =['col', 'score']) 
temp
# Out:
#                                   col     score
# 0                                  id  0.000421
# 1        ck_oo_numberOfPrivateMethods  0.060175
# 2                           LDHH_lcom  0.160197
# 3                          LDHH_fanIn  0.042951
# 4   numberOfNonTrivialBugsFoundUntil:  0.290792
# ..                                ...       ...
# 57        ck_oo_numberOfPublicMethods  0.055145
# 58                           LDHH_cbo  0.131278
# 59           WCHU_numberOfLinesOfCode  0.326673
# 60                      CvsExpEntropy  0.201898
# 61               LDHH_numberOfMethods  0.159487
#
# [62 rows x 2 columns]

# %%
temp_sort = temp.sort_values(['score'], ascending=False)
temp_sort[:10]
# Out:
#                                   col     score
# 11                         CvsEntropy  0.439006
# 42                           WCHU_rfc  0.346719
# 55                           LDHH_rfc  0.342851
# 24                           WCHU_wmc  0.338705
# 59           WCHU_numberOfLinesOfCode  0.326673
# 38           LDHH_numberOfLinesOfCode  0.326499
# 36                           LDHH_wmc  0.305647
# 4   numberOfNonTrivialBugsFoundUntil:  0.290792
# 52            numberOfBugsFoundUntil:  0.289722
# 39                        WCHU_fanOut  0.262351

# %%
FS = list(temp_sort['col'][:10])
FS
# Out:
# ['CvsEntropy',
#  'WCHU_rfc',
#  'LDHH_rfc',
#  'WCHU_wmc',
#  'WCHU_numberOfLinesOfCode',
#  'LDHH_numberOfLinesOfCode',
#  'LDHH_wmc',
#  'numberOfNonTrivialBugsFoundUntil:',
#  'numberOfBugsFoundUntil:',
#  'WCHU_fanOut']

# %%
X_new = df[FS]
X_new
# Out:
#      CvsEntropy  WCHU_rfc  LDHH_rfc  WCHU_wmc  WCHU_numberOfLinesOfCode  \
# 0       8.73596      1.05  0.000969      1.02                      1.03
# 1       7.99162      2.13  0.002523      2.04                      2.06
# 2       8.89835      2.03  0.003656      2.08                      1.20
# 3      30.88470     18.65  0.060975     16.75                     24.14
# 4       2.80457      2.08  0.006207      2.11                      2.15
# ..          ...       ...       ...       ...                       ...
# 992     6.88643      1.02  0.001533      1.02                      1.06
# 993     4.07501      0.00  0.000000      0.00                      0.00
# 994     6.92698      1.01  0.000845      0.00                      0.00
# 995    16.46420      6.19  0.006602      6.13                      7.74
# 996     5.11540      0.00  0.000000      0.00                      0.00
#
#      LDHH_numberOfLinesOfCode  LDHH_wmc  numberOfNonTrivialBugsFoundUntil:  \
# 0                    0.000943  0.000954                                  4
# 1                    0.002165  0.001815                                  3
# 2                    0.003723  0.004731                                  4
# 3                    0.066868  0.061236                                 35
# 4                    0.006238  0.006215                                  2
# ..                        ...       ...                                ...
# 992                  0.001457  0.001592                                  2
# 993                  0.000000  0.000000                                  0
# 994                  0.000000  0.000000                                  2
# 995                  0.008287  0.007493                                 16
# 996                  0.000000  0.000000                                  1
#
#      numberOfBugsFoundUntil:  WCHU_fanOut
# 0                          4         1.02
# 1                          4         1.04
# 2                          4         1.01
# 3                         40         4.04
# 4                          2         2.02
# ..                       ...          ...
# 992                        2         0.00
# 993                        0         0.00
# 994                        2         0.00
# 995                       18         0.00
# 996                        1         0.00
#
# [997 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.85
# Precision :  0.5952380952380952
# Recall :  0.4716981132075472
# F1 Score :  0.5263157894736842
# AUC :  0.7014361011381866

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8766666666666667
# Precision :  0.75
# Recall :  0.4528301886792453
# F1 Score :  0.5647058823529413
# AUC :  0.710220762355817

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.88
# Precision :  0.6888888888888889
# Recall :  0.5849056603773585
# F1 Score :  0.6326530612244898
# AUC :  0.7641127492170194

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8766666666666667
# Precision :  0.66
# Recall :  0.6226415094339622
# F1 Score :  0.6407766990291262
# AUC :  0.7769077992513942

# %% [markdown]
# # SVM RFE 10

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,random_state=23)

# %%
from sklearn.feature_selection import RFE
rec_model = RandomForestClassifier()

rfe = RFE(rec_model, n_features_to_select=10)
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=RandomForestClassifier(), n_features_to_select=10)

# %%
X_train = X_train.loc[:, rfe.support_]
X_train
# Out:
#      CvsWEntropy  CvsEntropy  ck_oo_wmc  WCHU_wmc  ck_oo_numberOfLinesOfCode  \
# 567     0.002208     4.07501          4      0.00                         11
# 441     0.004051     7.57299          8      0.00                         23
# 903     0.002208     4.07501         13      0.00                         44
# 557     0.020660    14.16310         52      6.20                        155
# 322     0.058088    21.14730         34      3.06                         96
# ..           ...         ...        ...       ...                        ...
# 950     0.076556    14.26390        108      5.11                        469
# 969     0.035063     8.58795          2      1.02                          6
# 40      0.002208     4.07501          1      0.00                          3
# 742     0.153622    23.61090         72      7.55                        245
# 595     0.003978     7.95479         27      0.00                        106
#
#      ck_oo_rfc  LDHH_numberOfLinesOfCode  numberOfBugsFoundUntil:  LDHH_rfc  \
# 567          2                  0.000000                        1  0.000000
# 441         16                  0.000000                        6  0.000000
# 903         19                  0.000000                        2  0.000000
# 557         59                  0.004940                        8  0.004649
# 322         46                  0.003873                       15  0.004067
# ..         ...                       ...                      ...       ...
# 950        159                  0.038980                       11  0.021999
# 969          4                  0.000932                        4  0.000956
# 40           1                  0.000000                        0  0.000000
# 742         72                  0.009743                       22  0.009468
# 595         51                  0.000000                        8  0.000000
#
#      WCHU_numberOfLinesOfCode
# 567                      0.00
# 441                      0.00
# 903                      0.00
# 557                      6.54
# 322                      3.11
# ..                        ...
# 950                     11.67
# 969                      1.06
# 40                       0.00
# 742                      9.73
# 595                      0.00
#
# [697 rows x 10 columns]

# %%
X_test = X_test.loc[:, rfe.support_]
X_test
# Out:
#      CvsWEntropy  CvsEntropy  ck_oo_wmc  WCHU_wmc  ck_oo_numberOfLinesOfCode  \
# 852     0.012775    10.03980         25      2.07                         67
# 912     0.005218     2.57445         36      1.05                        103
# 208     0.002453     4.07501         14      0.00                         43
# 893     0.001963     4.07501         15      0.00                         59
# 707     0.003817     6.70304         25      0.00                         95
# ..           ...         ...        ...       ...                        ...
# 477     0.002208     4.07501          5      0.00                         21
# 229     0.006544    10.19900          9      1.02                         24
# 826     0.002000     4.55853          2      0.00                         16
# 675     0.176695    27.65800        150     16.16                        533
# 568     0.003817     6.70304         14      0.00                         44
#
#      ck_oo_rfc  LDHH_numberOfLinesOfCode  numberOfBugsFoundUntil:  LDHH_rfc  \
# 852         18                  0.001717                        4  0.001145
# 912         27                  0.001532                        0  0.001731
# 208         11                  0.000000                        1  0.000000
# 893         26                  0.000000                        1  0.000000
# 707         51                  0.000000                        3  0.000000
# ..         ...                       ...                      ...       ...
# 477          5                  0.000000                        0  0.000000
# 229         10                  0.009460                        2  0.009909
# 826          4                  0.000708                       13  0.000000
# 675        143                  0.030221                       28  0.030300
# 568         20                  0.000000                        1  0.000000
#
#      WCHU_numberOfLinesOfCode
# 852                      2.16
# 912                      1.14
# 208                      0.00
# 893                      0.00
# 707                      0.00
# ..                        ...
# 477                      0.00
# 229                      2.11
# 826                      1.01
# 675                     19.15
# 568                      0.00
#
# [300 rows x 10 columns]

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8566666666666667
# Precision :  0.625
# Recall :  0.4716981132075472
# F1 Score :  0.5376344086021505
# AUC :  0.7054846841341379

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.85
# Precision :  0.6176470588235294
# Recall :  0.39622641509433965
# F1 Score :  0.48275862068965514
# AUC :  0.6717974180734857

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8433333333333334
# Precision :  0.5714285714285714
# Recall :  0.4528301886792453
# F1 Score :  0.5052631578947369
# AUC :  0.6899778473760598

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.87
# Precision :  0.675
# Recall :  0.5094339622641509
# F1 Score :  0.5806451612903226
# AUC :  0.7284011916583915

# %% [markdown]
# # SVM RFE 15

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,random_state=23)

# %%
from sklearn.feature_selection import RFE
rec_model = RandomForestClassifier()

rfe = RFE(rec_model, n_features_to_select=15)
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=RandomForestClassifier(), n_features_to_select=15)

# %%
X_train = X_train.loc[:, rfe.support_]
X_train
# Out:
#       id  CvsWEntropy  CvsEntropy  ck_oo_wmc  WCHU_wmc  ck_oo_fanOut  \
# 567  568     0.002208     4.07501          4      0.00             0
# 441  442     0.004051     7.57299          8      0.00             2
# 903  904     0.002208     4.07501         13      0.00             1
# 557  558     0.020660    14.16310         52      6.20             3
# 322  323     0.058088    21.14730         34      3.06            11
# ..   ...          ...         ...        ...       ...           ...
# 950  951     0.076556    14.26390        108      5.11            17
# 969  970     0.035063     8.58795          2      1.02             0
# 40    41     0.002208     4.07501          1      0.00             0
# 742  743     0.153622    23.61090         72      7.55             7
# 595  596     0.003978     7.95479         27      0.00             4
#
#      ck_oo_numberOfLinesOfCode  ck_oo_rfc  LDHH_numberOfLinesOfCode  WCHU_rfc  \
# 567                         11          2                  0.000000      0.00
# 441                         23         16                  0.000000      0.00
# 903                         44         19                  0.000000      0.00
# 557                        155         59                  0.004940      6.19
# 322                         96         46                  0.003873      3.07
# ..                         ...        ...                       ...       ...
# 950                        469        159                  0.038980      7.25
# 969                          6          4                  0.000932      1.02
# 40                           3          1                  0.000000      0.00
# 742                        245         72                  0.009743      7.39
# 595                        106         51                  0.000000      0.00
#
#      CvsLinEntropy  WCHU_numberOfMethodsInherited  LDHH_rfc  \
# 567       0.006219                           1.01  0.000000
# 441       0.011758                           2.02  0.000000
# 903       0.006219                           1.01  0.000000
# 557       0.023267                           1.01  0.004649
# 322       0.157459                           2.02  0.004067
# ..             ...                            ...       ...
# 950       0.204926                           0.00  0.021999
# 969       0.129181                           1.01  0.000956
# 40        0.006219                           3.08  0.000000
# 742       0.170381                           1.01  0.009468
# 595       0.154542                           3.05  0.000000
#
#      WCHU_numberOfLinesOfCode  CvsExpEntropy
# 567                      0.00       0.001031
# 441                      0.00       0.002307
# 903                      0.00       0.001031
# 557                      6.54       0.009538
# 322                      3.11       0.208139
# ..                        ...            ...
# 950                     11.67       0.435957
# 969                      1.06       0.161803
# 40                       0.00       0.001031
# 742                      9.73       0.243506
# 595                      0.00       0.232145
#
# [697 rows x 15 columns]

# %%
X_test = X_test.loc[:, rfe.support_]
X_test
# Out:
#       id  CvsWEntropy  CvsEntropy  ck_oo_wmc  WCHU_wmc  ck_oo_fanOut  \
# 852  853     0.012775    10.03980         25      2.07             4
# 912  913     0.005218     2.57445         36      1.05             3
# 208  209     0.002453     4.07501         14      0.00             1
# 893  894     0.001963     4.07501         15      0.00             2
# 707  708     0.003817     6.70304         25      0.00             4
# ..   ...          ...         ...        ...       ...           ...
# 477  478     0.002208     4.07501          5      0.00             2
# 229  230     0.006544    10.19900          9      1.02             3
# 826  827     0.002000     4.55853          2      0.00             1
# 675  676     0.176695    27.65800        150     16.16            10
# 568  569     0.003817     6.70304         14      0.00             2
#
#      ck_oo_numberOfLinesOfCode  ck_oo_rfc  LDHH_numberOfLinesOfCode  WCHU_rfc  \
# 852                         67         18                  0.001717      1.04
# 912                        103         27                  0.001532      1.04
# 208                         43         11                  0.000000      0.00
# 893                         59         26                  0.000000      0.00
# 707                         95         51                  0.000000      0.00
# ..                         ...        ...                       ...       ...
# 477                         21          5                  0.000000      0.00
# 229                         24         10                  0.009460      2.04
# 826                         16          4                  0.000708      0.00
# 675                        533        143                  0.030221     15.85
# 568                         44         20                  0.000000      0.00
#
#      CvsLinEntropy  WCHU_numberOfMethodsInherited  LDHH_rfc  \
# 852       0.140319                           4.04  0.001145
# 912       0.007367                           0.00  0.001731
# 208       0.006219                           1.01  0.000000
# 893       0.006219                           1.01  0.000000
# 707       0.152618                           2.02  0.000000
# ..             ...                            ...       ...
# 477       0.006219                           1.01  0.000000
# 229       0.142112                           2.03  0.009909
# 826       0.005481                           1.01  0.000000
# 675       0.181130                          24.40  0.030300
# 568       0.152618                           1.01  0.000000
#
#      WCHU_numberOfLinesOfCode  CvsExpEntropy
# 852                      2.16       0.209527
# 912                      1.14       0.008681
# 208                      0.00       0.001031
# 893                      0.00       0.001031
# 707                      0.00       0.231938
# ..                        ...            ...
# 477                      0.00       0.001031
# 229                      2.11       0.207803
# 826                      1.01       0.000127
# 675                     19.15       0.267068
# 568                      0.00       0.231938
#
# [300 rows x 15 columns]

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.87
# Precision :  0.675
# Recall :  0.5094339622641509
# F1 Score :  0.5806451612903226
# AUC :  0.7284011916583915

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.85
# Precision :  0.6333333333333333
# Recall :  0.3584905660377358
# F1 Score :  0.45783132530120485
# AUC :  0.6569780765411352

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8166666666666667
# Precision :  0.47368421052631576
# Recall :  0.33962264150943394
# F1 Score :  0.39560439560439553
# AUC :  0.6293254907952027

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8566666666666667
# Precision :  0.6136363636363636
# Recall :  0.5094339622641509
# F1 Score :  0.556701030927835
# AUC :  0.7203040256664884

# %% [markdown]
# # MRMR 10

# %%
from sklearn.feature_selection import f_regression

F = pd.Series(f_regression(X, Y)[0], index = X.columns)
corr = X.corr().abs().clip(.00001)

# %%
selected = []
feat_score = []
not_selected = list(X.columns)

# %%
K = 10

for i in range(K):
    
    # compute FCQ score for all the (currently) excluded features (this is Formula 2)
    score = F.loc[not_selected] / corr.loc[not_selected, selected].mean(axis = 1).fillna(.00001)
    
    # find best feature, add it to selected and remove it from not_selected
    best = score.index[score.argmax()]
    selected.append(best)
    feat_score.append(score[best])
    not_selected.remove(best)

# %%
selected
# Out:
# ['CvsEntropy',
#  'LDHH_rfc',
#  'WCHU_rfc',
#  'WCHU_wmc',
#  'LDHH_numberOfLinesOfCode',
#  'WCHU_numberOfLinesOfCode',
#  'numberOfNonTrivialBugsFoundUntil:',
#  'ck_oo_fanOut',
#  'LDHH_wmc',
#  'numberOfBugsFoundUntil:']

# %%
X_new = X[selected]
X_new
# Out:
#      CvsEntropy  LDHH_rfc  WCHU_rfc  WCHU_wmc  LDHH_numberOfLinesOfCode  \
# 0       8.73596  0.000969      1.05      1.02                  0.000943
# 1       7.99162  0.002523      2.13      2.04                  0.002165
# 2       8.89835  0.003656      2.03      2.08                  0.003723
# 3      30.88470  0.060975     18.65     16.75                  0.066868
# 4       2.80457  0.006207      2.08      2.11                  0.006238
# ..          ...       ...       ...       ...                       ...
# 992     6.88643  0.001533      1.02      1.02                  0.001457
# 993     4.07501  0.000000      0.00      0.00                  0.000000
# 994     6.92698  0.000845      1.01      0.00                  0.000000
# 995    16.46420  0.006602      6.19      6.13                  0.008287
# 996     5.11540  0.000000      0.00      0.00                  0.000000
#
#      WCHU_numberOfLinesOfCode  numberOfNonTrivialBugsFoundUntil:  \
# 0                        1.03                                  4
# 1                        2.06                                  3
# 2                        1.20                                  4
# 3                       24.14                                 35
# 4                        2.15                                  2
# ..                        ...                                ...
# 992                      1.06                                  2
# 993                      0.00                                  0
# 994                      0.00                                  2
# 995                      7.74                                 16
# 996                      0.00                                  1
#
#      ck_oo_fanOut  LDHH_wmc  numberOfBugsFoundUntil:
# 0               3  0.000954                        4
# 1               5  0.001815                        4
# 2               1  0.004731                        4
# 3              22  0.061236                       40
# 4               0  0.006215                        2
# ..            ...       ...                      ...
# 992             6  0.001592                        2
# 993             3  0.000000                        0
# 994             0  0.000000                        2
# 995            11  0.007493                       18
# 996             1  0.000000                        1
#
# [997 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8566666666666667
# Precision :  0.6086956521739131
# Recall :  0.5283018867924528
# F1 Score :  0.5656565656565657
# AUC :  0.7277136964326636

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.88
# Precision :  0.7741935483870968
# Recall :  0.4528301886792453
# F1 Score :  0.5714285714285714
# AUC :  0.7122450538537927

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8533333333333334
# Precision :  0.6216216216216216
# Recall :  0.4339622641509434
# F1 Score :  0.5111111111111112
# AUC :  0.6886410511038118

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.88
# Precision :  0.6808510638297872
# Recall :  0.6037735849056604
# F1 Score :  0.64
# AUC :  0.7715224199831945

# %% [markdown]
# # MRMR 15

# %%
from sklearn.feature_selection import f_regression

F = pd.Series(f_regression(X, Y)[0], index = X.columns)
corr = X.corr().abs().clip(.00001)

# %%
selected = []
feat_score = []
not_selected = list(X.columns)

# %%
K = 15

for i in range(K):
    
    # compute FCQ score for all the (currently) excluded features (this is Formula 2)
    score = F.loc[not_selected] / corr.loc[not_selected, selected].mean(axis = 1).fillna(.00001)
    
    # find best feature, add it to selected and remove it from not_selected
    best = score.index[score.argmax()]
    selected.append(best)
    feat_score.append(score[best])
    not_selected.remove(best)

# %%
selected
# Out:
# ['CvsEntropy',
#  'LDHH_rfc',
#  'WCHU_rfc',
#  'WCHU_wmc',
#  'LDHH_numberOfLinesOfCode',
#  'WCHU_numberOfLinesOfCode',
#  'numberOfNonTrivialBugsFoundUntil:',
#  'ck_oo_fanOut',
#  'LDHH_wmc',
#  'numberOfBugsFoundUntil:',
#  'WCHU_fanOut',
#  'CvsExpEntropy',
#  'CvsLinEntropy',
#  'numberOfMajorBugsFoundUntil:',
#  'LDHH_fanOut']

# %%
X_new = X[selected]
X_new
# Out:
#      CvsEntropy  LDHH_rfc  WCHU_rfc  WCHU_wmc  LDHH_numberOfLinesOfCode  \
# 0       8.73596  0.000969      1.05      1.02                  0.000943
# 1       7.99162  0.002523      2.13      2.04                  0.002165
# 2       8.89835  0.003656      2.03      2.08                  0.003723
# 3      30.88470  0.060975     18.65     16.75                  0.066868
# 4       2.80457  0.006207      2.08      2.11                  0.006238
# ..          ...       ...       ...       ...                       ...
# 992     6.88643  0.001533      1.02      1.02                  0.001457
# 993     4.07501  0.000000      0.00      0.00                  0.000000
# 994     6.92698  0.000845      1.01      0.00                  0.000000
# 995    16.46420  0.006602      6.19      6.13                  0.008287
# 996     5.11540  0.000000      0.00      0.00                  0.000000
#
#      WCHU_numberOfLinesOfCode  numberOfNonTrivialBugsFoundUntil:  \
# 0                        1.03                                  4
# 1                        2.06                                  3
# 2                        1.20                                  4
# 3                       24.14                                 35
# 4                        2.15                                  2
# ..                        ...                                ...
# 992                      1.06                                  2
# 993                      0.00                                  0
# 994                      0.00                                  2
# 995                      7.74                                 16
# 996                      0.00                                  1
#
#      ck_oo_fanOut  LDHH_wmc  numberOfBugsFoundUntil:  WCHU_fanOut  \
# 0               3  0.000954                        4         1.02
# 1               5  0.001815                        4         1.04
# 2               1  0.004731                        4         1.01
# 3              22  0.061236                       40         4.04
# 4               0  0.006215                        2         2.02
# ..            ...       ...                      ...          ...
# 992             6  0.001592                        2         0.00
# 993             3  0.000000                        0         0.00
# 994             0  0.000000                        2         0.00
# 995            11  0.007493                       18         0.00
# 996             1  0.000000                        1         0.00
#
#      CvsExpEntropy  CvsLinEntropy  numberOfMajorBugsFoundUntil:  LDHH_fanOut
# 0         0.198199       0.134499                             0     0.000993
# 1         0.239334       0.157613                             1     0.000889
# 2         0.187460       0.133644                             0     0.002827
# 3         0.392389       0.221639                             6     0.010602
# 4         0.047726       0.014004                             0     0.005223
# ..             ...            ...                           ...          ...
# 992       0.018379       0.015043                             0     0.000000
# 993       0.001031       0.006219                             0     0.000000
# 994       0.001125       0.009727                             0     0.000000
# 995       0.015277       0.028620                             2     0.000000
# 996       0.001130       0.007694                             0     0.000000
#
# [997 rows x 15 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8633333333333333
# Precision :  0.6363636363636364
# Recall :  0.5283018867924528
# F1 Score :  0.5773195876288659
# AUC :  0.731762279428615

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.87
# Precision :  0.6842105263157895
# Recall :  0.49056603773584906
# F1 Score :  0.5714285714285714
# AUC :  0.720991520892216

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.88
# Precision :  0.7741935483870968
# Recall :  0.4528301886792453
# F1 Score :  0.5714285714285714
# AUC :  0.7122450538537927

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.87
# Precision :  0.6842105263157895
# Recall :  0.49056603773584906
# F1 Score :  0.5714285714285714
# AUC :  0.720991520892216

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8766666666666667
# Precision :  0.6666666666666666
# Recall :  0.6037735849056604
# F1 Score :  0.6336633663366337
# AUC :  0.7694981284852189

# %% [markdown]
# # MRMR HFS

# %%
def HSF(df, df_train):
    
    from copy import deepcopy
    col_list = list(df_train.columns)
    print(col_list)
    d = df_train.shape[1]
    SF = []
    merit = [0 for i in range(d)]
    merit_archive = [0 for i in range(d)]
    Total_FS = [0 for i in range(d)]

    rel_CF = RHFS(df, d, col_list)

    max_value = max(rel_CF)
    Feature_max_index = rel_CF.index(max_value)

    n = 0

    SF.append(Feature_max_index)

    merit_archive[n] = deepcopy(max_value)

    Total_FS[n] = deepcopy(SF)

    while n < d-1:

        for i in range(d):

            red_FF = SHFS(SF, df_train, i, col_list,d)

            top = (d + d*(sum(rel_CF)/len(rel_CF)))
            bottom = (d + (d*(d-1)*(sum(red_FF)/len(red_FF))))**(1/2)
            merit[i] = top/bottom

        for val in SF:
            merit[val] = -9999999

        max_value = max(merit)
        Feature_max_index = merit.index(max_value)

        if Feature_max_index not in SF:
            SF.append(Feature_max_index)

        n += 1
        
        Total_FS[n] = deepcopy(SF)

        merit_archive[n] = max_value

    index_val = merit_archive.index(max(merit_archive))

    Feature_subset = Total_FS[index_val]

    subset_list = []

    for val in Feature_subset:
        subset_list.append(col_list[val])
    return subset_list


def RHFS(df, d, col_list):
    rel_CF = [0 for i in range(d)]
    count = 0

    igain = IG(X,df['class'])

    for m in  range(d):
        mu = df[col_list[m]].mean()

        n_1 = df[df['class'] == 0].count()[1]
        mu_1 = df[col_list[m]][df['class'] == 0].mean()
        var_1 = df[col_list[m]][df['class'] == 0].var()

        n_2 = df[df['class'] == 1].count()[1]
        mu_2 = df[col_list[m]][df['class'] == 1].mean()
        var_2 = df[col_list[m]][df['class'] == 1].var()

        inter_class = n_1*(mu_1-mu)**2 + n_2*(mu_2-mu)**2
        intra_class = (n_1-1)*var_1 + (n_2-1)*var_2

        fscore = inter_class / intra_class

        rel_CF[count] = (1/2)*(fscore + igain[m])
        count += 1
    
    return rel_CF

        
        

def IG(col_1, col_2):
    from sklearn.feature_selection import mutual_info_classif
    gain = mutual_info_classif(col_1,col_2)
    return gain   

def relief(col_1,col_2):
    pass



def SHFS(SF, df_train, i, col_list,d):
    from itertools import combinations
    from copy import deepcopy
    red_FF = []
    temp_SF = deepcopy(SF)
    if i not in SF:
        temp_SF.append(i)
        P_pairs = list(combinations(temp_SF,2))
        for pair in P_pairs:

            ied_value = (IED(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            pc_value = (PC(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            cs_value = (CS(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2

            red_FF.append((1/3)*(ied_value + pc_value + cs_value))
            # red_FF.append((1/2)*(pc_value + cs_value))
    else:
        red_FF = [0]
    return red_FF

def IED(col_1, col_2):
    import numpy as np
    dist = np.linalg.norm(col_1 - col_2)
    return 1/dist

def PC(col_1, col_2):
    from scipy.stats import pearsonr
    corr, _ = pearsonr(col_1 , col_2)
    return corr

def CS(col_1, col_2):
    from scipy import spatial
    similarity = 1 - spatial.distance.cosine(col_1, col_2)
    return similarity

# %%
FS = HSF(df, X)
FS
# Out:
# ['id', 'ck_oo_numberOfPrivateMethods', 'LDHH_lcom', 'LDHH_fanIn', 'numberOfNonTrivialBugsFoundUntil:', 'WCHU_numberOfPublicAttributes', 'WCHU_numberOfAttributes', 'CvsWEntropy', 'LDHH_numberOfPublicMethods', 'WCHU_fanIn', 'LDHH_numberOfPrivateAttributes', 'CvsEntropy', 'LDHH_numberOfPublicAttributes', 'WCHU_numberOfPrivateMethods', 'WCHU_numberOfMethods', 'ck_oo_numberOfPublicAttributes', 'ck_oo_noc', 'numberOfCriticalBugsFoundUntil:', 'ck_oo_wmc', 'LDHH_numberOfPrivateMethods', 'WCHU_numberOfPrivateAttributes', 'CvsLogEntropy', 'WCHU_noc', 'LDHH_numberOfAttributesInherited', 'WCHU_wmc', 'ck_oo_fanOut', 'ck_oo_numberOfLinesOfCode', 'ck_oo_numberOfAttributesInherited', 'ck_oo_numberOfMethods', 'ck_oo_dit', 'ck_oo_fanIn', 'LDHH_noc', 'WCHU_dit', 'ck_oo_lcom', 'WCHU_numberOfAttributesInherited', 'ck_oo_rfc', 'LDHH_wmc', 'LDHH_numberOfAttributes', 'LDHH_numberOfLinesOfCode', 'WCHU_fanOut', 'WCHU_lcom', 'ck_oo_cbo', 'WCHU_rfc', 'ck_oo_numberOfAttributes', 'numberOfHighPriorityBugsFoundUntil:', 'ck_oo_numberOfPrivateAttributes', 'numberOfMajorBugsFoundUntil:', 'WCHU_numberOfPublicMethods', 'LDHH_dit', 'WCHU_cbo', 'CvsLinEntropy', 'WCHU_numberOfMethodsInherited', 'numberOfBugsFoundUntil:', 'LDHH_fanOut', 'LDHH_numberOfMethodsInherited', 'LDHH_rfc', 'ck_oo_numberOfMethodsInherited', 'ck_oo_numberOfPublicMethods', 'LDHH_cbo', 'WCHU_numberOfLinesOfCode', 'CvsExpEntropy', 'LDHH_numberOfMethods']
# ['CvsEntropy', 'LDHH_noc']

# %%
X_new = X[FS]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.83
# Precision :  0.5208333333333334
# Recall :  0.4716981132075472
# F1 Score :  0.49504950495049505
# AUC :  0.6892903521503323

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8833333333333333
# Precision :  0.7647058823529411
# Recall :  0.49056603773584906
# F1 Score :  0.5977011494252874
# AUC :  0.7290886868841188

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.85
# Precision :  0.5833333333333334
# Recall :  0.5283018867924528
# F1 Score :  0.5544554455445545
# AUC :  0.7236651134367121

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.86
# Precision :  0.627906976744186
# Recall :  0.5094339622641509
# F1 Score :  0.5625
# AUC :  0.7223283171644642

# %% [markdown]
# # HFS NEW

# %%
def HSF(df, df_train):
    
    from copy import deepcopy
    col_list = list(df_train.columns)
    print(col_list)
    d = df_train.shape[1]
    SF = []
    merit = [0 for i in range(d)]
    merit_archive = [0 for i in range(d)]
    Total_FS = [0 for i in range(d)]

    rel_CF = RHFS(df, d, col_list)

    max_value = max(rel_CF)
    Feature_max_index = rel_CF.index(max_value)

    n = 0

    SF.append(Feature_max_index)

    merit_archive[n] = deepcopy(max_value)

    Total_FS[n] = deepcopy(SF)

    while n < d-1:

        for i in range(d):

            red_FF = SHFS(SF, df_train, i, col_list,d)

            top = (d + d*(sum(rel_CF)/len(rel_CF)))
            bottom = (d - (sum(red_FF)/len(red_FF)))**(1/2)

            merit[i] = top/bottom

        for val in SF:
            merit[val] = -9999999

        max_value = max(merit)
        Feature_max_index = merit.index(max_value)

        if Feature_max_index not in SF:
            SF.append(Feature_max_index)

        n += 1
        
        Total_FS[n] = deepcopy(SF)

        merit_archive[n] = max_value

    index_val = merit_archive.index(max(merit_archive))

    Feature_subset = Total_FS[index_val]

    subset_list = []

    for val in Feature_subset:
        subset_list.append(col_list[val])
    return subset_list


def RHFS(df, d, col_list):
    rel_CF = [0 for i in range(d)]
    count = 0

    igain = IG(X,df['class'])

    for m in  range(d):
        mu = df[col_list[m]].mean()

        n_1 = df[df['class'] == 0].count()[1]
        mu_1 = df[col_list[m]][df['class'] == 0].mean()
        var_1 = df[col_list[m]][df['class'] == 0].var()

        n_2 = df[df['class'] == 1].count()[1]
        mu_2 = df[col_list[m]][df['class'] == 1].mean()
        var_2 = df[col_list[m]][df['class'] == 1].var()

        inter_class = n_1*(mu_1-mu)**2 + n_2*(mu_2-mu)**2
        intra_class = (n_1-1)*var_1 + (n_2-1)*var_2

        fscore = inter_class / intra_class

        rel_CF[count] = (1/2)*(fscore + igain[m])
        count += 1
    
    return rel_CF

        
        

def IG(col_1, col_2):
    from sklearn.feature_selection import mutual_info_classif
    gain = mutual_info_classif(col_1,col_2)
    return gain   

def relief(col_1,col_2):
    pass



def SHFS(SF, df_train, i, col_list,d):
    from itertools import combinations
    from copy import deepcopy
    red_FF = []
    temp_SF = deepcopy(SF)
    if i not in SF:
        temp_SF.append(i)
        P_pairs = list(combinations(temp_SF,2))
        for pair in P_pairs:

            ied_value = (IED(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            pc_value = (PC(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2
            cs_value = (CS(df_train[col_list[pair[0]]],df_train[col_list[pair[1]]]))**2

            red_FF.append((1/3)*(ied_value + pc_value + cs_value))
            # red_FF.append((1/2)*(pc_value + cs_value))
    else:
        red_FF = [0]
    return red_FF

def IED(col_1, col_2):
    import numpy as np
    dist = np.linalg.norm(col_1 - col_2)
    return 1/dist

def PC(col_1, col_2):
    from scipy.stats import pearsonr
    corr, _ = pearsonr(col_1 , col_2)
    return corr

def CS(col_1, col_2):
    from scipy import spatial
    similarity = 1 - spatial.distance.cosine(col_1, col_2)
    return similarity

# %%
FS = HSF(df, X)
FS
# Out:
# ['id', 'ck_oo_numberOfPrivateMethods', 'LDHH_lcom', 'LDHH_fanIn', 'numberOfNonTrivialBugsFoundUntil:', 'WCHU_numberOfPublicAttributes', 'WCHU_numberOfAttributes', 'CvsWEntropy', 'LDHH_numberOfPublicMethods', 'WCHU_fanIn', 'LDHH_numberOfPrivateAttributes', 'CvsEntropy', 'LDHH_numberOfPublicAttributes', 'WCHU_numberOfPrivateMethods', 'WCHU_numberOfMethods', 'ck_oo_numberOfPublicAttributes', 'ck_oo_noc', 'numberOfCriticalBugsFoundUntil:', 'ck_oo_wmc', 'LDHH_numberOfPrivateMethods', 'WCHU_numberOfPrivateAttributes', 'CvsLogEntropy', 'WCHU_noc', 'LDHH_numberOfAttributesInherited', 'WCHU_wmc', 'ck_oo_fanOut', 'ck_oo_numberOfLinesOfCode', 'ck_oo_numberOfAttributesInherited', 'ck_oo_numberOfMethods', 'ck_oo_dit', 'ck_oo_fanIn', 'LDHH_noc', 'WCHU_dit', 'ck_oo_lcom', 'WCHU_numberOfAttributesInherited', 'ck_oo_rfc', 'LDHH_wmc', 'LDHH_numberOfAttributes', 'LDHH_numberOfLinesOfCode', 'WCHU_fanOut', 'WCHU_lcom', 'ck_oo_cbo', 'WCHU_rfc', 'ck_oo_numberOfAttributes', 'numberOfHighPriorityBugsFoundUntil:', 'ck_oo_numberOfPrivateAttributes', 'numberOfMajorBugsFoundUntil:', 'WCHU_numberOfPublicMethods', 'LDHH_dit', 'WCHU_cbo', 'CvsLinEntropy', 'WCHU_numberOfMethodsInherited', 'numberOfBugsFoundUntil:', 'LDHH_fanOut', 'LDHH_numberOfMethodsInherited', 'LDHH_rfc', 'ck_oo_numberOfMethodsInherited', 'ck_oo_numberOfPublicMethods', 'LDHH_cbo', 'WCHU_numberOfLinesOfCode', 'CvsExpEntropy', 'LDHH_numberOfMethods']
# ['CvsEntropy',
#  'WCHU_rfc',
#  'WCHU_wmc',
#  'WCHU_numberOfLinesOfCode',
#  'LDHH_numberOfLinesOfCode',
#  'LDHH_rfc',
#  'LDHH_wmc',
#  'LDHH_cbo',
#  'LDHH_fanOut',
#  'LDHH_lcom',
#  'LDHH_numberOfMethods',
#  'LDHH_numberOfPublicMethods',
#  'LDHH_numberOfPrivateMethods',
#  'LDHH_numberOfPrivateAttributes',
#  'LDHH_numberOfPublicAttributes',
#  'LDHH_dit',
#  'LDHH_noc']

# %%
X_new = X[FS]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=0.3,random_state=23)

# %% [markdown]
# ### RandomForest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8566666666666667
# Precision :  0.6136363636363636
# Recall :  0.5094339622641509
# F1 Score :  0.556701030927835
# AUC :  0.7203040256664884

# %% [markdown]
# ### Support Vector Machine

# %%
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.88
# Precision :  0.7575757575757576
# Recall :  0.4716981132075472
# F1 Score :  0.5813953488372093
# AUC :  0.719654724619968

# %% [markdown]
# ### KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.87
# Precision :  0.6521739130434783
# Recall :  0.5660377358490566
# F1 Score :  0.6060606060606061
# AUC :  0.750630203956917

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy : " , accuracy_score(y_test,y_pred))
print("Precision : " , precision_score(y_test,y_pred))
print("Recall : " , recall_score(y_test,y_pred))
print("F1 Score : " , f1_score(y_test,y_pred))
print("AUC : " , roc_auc_score(y_test,y_pred))
# Out:
# Accuracy :  0.8566666666666667
# Precision :  0.5892857142857143
# Recall :  0.6226415094339622
# F1 Score :  0.6055045871559632
# AUC :  0.7647620502635399
